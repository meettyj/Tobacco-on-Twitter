# %%
import os
# os.chdir('C:/Users/eddie/Desktop/Prof. Rumi Chunara/alcohol')
import json
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer 
import re

# %%
month_list = ['04','05','06','07','08','09','10','11','12']
# '01', '02', '03',   
# month_list = ['10','11','12']
# month_list = ['01', '02', '03', '04','05','06']

# %%
# sentiment analysis
def analyzeSentimentByVader(texts):
    positive_text = [[],[]]
    neutral_text = [[],[]]
    negative_text = [[],[]]
    
#     score_total = []    

    analyzer = SentimentIntensityAnalyzer()
    for sentence in texts:
        vs = analyzer.polarity_scores(sentence)
    #     print("{:*<65} {}".format(sentence, str(vs)))
    #     print('------------------------')
#         print(vs)
        if vs['compound'] >= 0.05:
#             print(vs['compound'])
            positive_text[0].append(sentence)
            positive_text[1].append(vs)
        elif vs['compound'] <= 0.05 and vs['compound'] > -0.05:
#             print(vs['compound'])
            neutral_text[0].append(sentence)
            neutral_text[1].append(vs)
        elif vs['compound'] <= -0.05:
#             print(vs['compound'])
            negative_text[0].append(sentence)
            negative_text[1].append(vs)
#         score_total.append(vs)

    return positive_text, neutral_text, negative_text

# %%
# text without link.

num_positive_tweets_in_total = []
num_neutral_tweets_in_total = []
num_negative_tweets_in_total = []


filePath = '/mnt/volume/result/State_DelawareLevel/'
for month in month_list:
    
    
    text_in_month = []
    user_month = set()
    fileName = 'juliana_Delaware_allECigarette_2017_'+month+'_categoryKeyWord.json'
    file = filePath + fileName
    with open(file, "r") as f:
        everyLines = f.readlines()
        print('length of tweets in month %s: %d' % (month, len(everyLines)))
        for line in everyLines:
            try:
                lineInJson = json.loads(line)
            except:
                print('Cannot load the line: ', line)
            textInLine = lineInJson["text"]
#             print(textInLine)
            textAfterRE = re.sub('https?:\/\/t\.co\/[\s\S]{10}', '', textInLine)
            text_in_month.append(textAfterRE)
    
    # get sentiment
    positive_text, neutral_text, negative_text = analyzeSentimentByVader(text_in_month)
    num_positive = len(positive_text[0])
    num_neutral = len(neutral_text[0])
    num_negative = len(negative_text[0])
    
    num_positive_tweets_in_total.append(positive_text[0])
    num_neutral_tweets_in_total.append(neutral_text[0])
    num_negative_tweets_in_total.append(negative_text[0])
    
    print('How many positive text: ', num_positive)
    print('How many neutral text: ', num_neutral)
    print('How many negative text: ', num_negative)
    print('--------------------')

#     break
# Out:
# length of tweets in month 01: 7
# How many positive text:  3
# How many neutral text:  2
# How many negative text:  2
# --------------------
# length of tweets in month 02: 6
# How many positive text:  2
# How many neutral text:  4
# How many negative text:  0
# --------------------
# length of tweets in month 03: 13
# How many positive text:  4
# How many neutral text:  7
# How many negative text:  2
# --------------------
# length of tweets in month 04: 5
# How many positive text:  2
# How many neutral text:  3
# How many negative text:  0
# --------------------
# length of tweets in month 05: 5
# How many positive text:  2
# How many neutral text:  2
# How many negative text:  1
# --------------------
# length of tweets in month 06: 9
# How many positive text:  3
# How many neutral text:  5
# How many negative text:  1
# --------------------

# %%
for i in num_positive_tweets_in_total[0]:
    print(i)
    print('')

for i in num_neutral_tweets_in_total[0]:
    print(i)
    print('')
    
for i in num_negative_tweets_in_total[0]:
    print(i)
    print('')
    
print()
for i in num_positive_tweets_in_total[1]:
    print(i)
    print('')
    
print()
for i in num_neutral_tweets_in_total[1]:
    print(i)
    print('')
    
print()
for i in num_negative_tweets_in_total[1]:
    print(i)
    print('')   
    
print()
for i in num_positive_tweets_in_total[2]:
    print(i)
    print('')
    
print()
for i in num_neutral_tweets_in_total[2]:
    print(i)
    print('')
    
print()
for i in num_negative_tweets_in_total[2]:
    print(i)
    print('')
    
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!1
# Out:
# I support Donald Trump &amp; I vape (:
#
# The realest of friends @jjuulleess_
#
# "Dad I broke up with her"
# "I wish you'd break up with your vaping"
# Typical conversation with my friend and his dad
#
# Blue bird sky+ice time=happy boys in the 302! @Buccigross
#
# @Wesleysvape where at? At the vape shop?
#
# @__joseguapo__ @_kvngrel @playboimeet @DeezNutsr who sucking dick for cigs 😂😂😂👀
#
# I had to put new cotton in my vape yesterday I was so mad
#
#
# My dogs scared of my vape lmao
#
# @araizuh_ use VapoRub 😂
#
#
# from gaugevapes_tvl  -  Just stuntin on em TVL ALL DAY EVERYDAY 💎
# ➖➖➖➖➖➖➖➖➖➖➖➖➖➖
# WeOutHere ⬇️⬇️…
#
# Re wick my vape today or wait till I get home?
#
# #vapelyfe #flavorchaser #goodmorning @ Perdue
#
# @Wesleysvape The Allagash Curieux is atop my list right now
#
#
#
# @WesleyVape of course, It's gonna be amazing 😇😃
#
# @WesleyVape I would really need to see more footage from JL to compare honestly. It doesn't look better than wonder woman though
#
# Mack said ion smoke cigarettes I smoke straight blunts bitch😂😂😂😂
#
# @WesleyVape it looks promising but I'm cautious lol
#
#
# @ateezzzy u
#
# I just vaped out my sunroof and some girl I don't know walked over and got in my car
#
# SB24 [NEW] An Act To Amend Title 16 Of The Delaware Code Relating To Medical Marijuana.
#
# Church in Delaware today! #church #jesus #god #praisehim @ First Baptist Church of Delaware
#
# Cig smoke makes me sneeze 🤧
#
# chasing brews with vape smoke 😈👌🏻💯
#
# @WesleyVape exactly   If I had to choose a side between superman and batman, it would be batman  but Henry Cavill is the one as superman
#
#
# People who vape are the worst
#
# @Wesleysvape no but my aunt is going back to get one!!!!

# %%
for i in num_positive_tweets_in_total[3]:
    print(i)
    print('')

print()
for i in num_positive_tweets_in_total[4]:
    print(i)
    print('')
    
print()
for i in num_positive_tweets_in_total[5]:
    print(i)
    print('')
    
print()
for i in num_positive_tweets_in_total[6]:
    print(i)
    print('')

print()
for i in num_positive_tweets_in_total[7]:
    print(i)
    print('')
    
print()
for i in num_positive_tweets_in_total[8]:
    print(i)
    print('')
    
# print()
# for i in num_positive_tweets_in_total[9]:
#     print(i)
#     print('')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%


# 2016.05
print('NEUTRAL')


# # 2016.06

    
print()
for i in num_neutral_tweets_in_total[3]:
    print(i)
    print('')

print()
for i in num_neutral_tweets_in_total[4]:
    print(i)
    print('')
    
print()
for i in num_neutral_tweets_in_total[5]:
    print(i)
    print('')
print()

for i in num_neutral_tweets_in_total[6]:
    print(i)
    print('')
    
print()
for i in num_neutral_tweets_in_total[7]:
    print(i)
    print('')
    
print()
for i in num_neutral_tweets_in_total[8]:
    print(i)
    print('')
    
# print()
# for i in num_neutral_tweets_in_total[9]:
#     print(i)
#     print('')   
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
    
# 2016.05
print('NEGATIVE')


    
print()
for i in num_negative_tweets_in_total[3]:
    print(i)
    print('')
    
print()
for i in num_negative_tweets_in_total[4]:
    print(i)
    print('')
    
print()
for i in num_negative_tweets_in_total[5]:
    print(i)
    print('')
    
print()
for i in num_negative_tweets_in_total[6]:
    print(i)
    print('')

print()
for i in num_negative_tweets_in_total[7]:
    print(i)
    print('')
    
print()
for i in num_negative_tweets_in_total[8]:
    print(i)
    print('')
    
# print()
# for i in num_negative_tweets_in_total[9]:
#     print(i)
#     print('')
# Out:
# Ya wow vapes
#
# Brendan's recent search history is literally just "cool vape tricks"
#
#
# @Wesleysvape Yup!  That’s my favorite style
#
# Getting paid to watch YouTube videos ,vape and sell glass best job ever 💯👌🏼
#
#
# #Vaporwave top at Wal-Mart
#
# Why do people think vaping is so cool
#
# your favorite stahls from right to left @ The Blue Hen
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-137-bd5564419c01> in <module>
#      14
#      15 print()
# ---> 16 for i in num_positive_tweets_in_total[6]:
#      17     print(i)
#      18     print('')
#
# IndexError: list index out of range
