# %%
import os
# os.chdir('C:/Users/eddie/Desktop/Prof. Rumi Chunara/alcohol')
import json
import pandas as pd

# %%
# Category keyword
synonym_ecig = ['electronic-cigarette', 'electronic cigarette', 'electronic cig', ' e-cig', ' ecig', ' e cig', 'e-cigarette', 'ecigarette', ' e cigarette', 'e-juice', ' ejuice', ' e juice', 'e-liquid', ' eliquid', ' e liquid', 'e-smoke', 'esmoke', ' e smoke', 'vape', 'vaper', 'vaping', 'vape-juice',
                'vape-liquid', ' vapor', 'vaporizer', 'boxmod', 'cloud chaser', 'cloudchaser', 'smoke assist', 'ehookah', 'e-hookah', ' e hookah', 'stillblowingsmoke', 'still blowing smoke', 'cherry tip cigarillo', '#e-cig', '#ecig', '#e cigar', '#ejuice', '#e juice', '#eliquid', '#e liquid', '#vapor', '#ehookah', '#e hookah', 'smoke&pod']
# remove ' fin '
brand_ecig = ['juul', 'vaporfi', 'vype pebble', 'v2 cig', 'v2cigs', 'v2 cigs', 'halocigs', ' njoy', 'markten', 'vuse', ' tryst', 'atomizer', 'cartomizer', 'south beach smoke', 'eversmoke', 'joye510', 'joye 510', 'joyetech', 'logicecig', 'smartsmoker', ' mistic', 'smokestiks', '21st century smoke', 'logic black label',
              ' finiti', 'nicotek', 'cigirex', 'ciga&blu', 'cig&blu', 'logic&cig', 'e-swisher', 'e swisher', 'eswisher', 'ezsmoker', 'ez&cig', 'green smoke', 'cigalectric', 'xhale o2', 'xhaleo2', 'cig2o', 'green smart living', 'greensmartliving', 'krave', 'swisher blk', 'grimmgreen', '#njoy', '#fin ', '#finiti']
policy_ecig = ['sb140', 'sb 140', 'sb24', 'sb 24']
cessation_ecig = ['notblowingsmoke', 'not blowing smoke',
                  'tobaccofreekids', 'notareplacement']

# %%
# Change the month here.
month = '07'

# %%
# Change State name here.
State_name_1 = 'Delaware'
State_name_2 = 'NewJersey'
State_name_3 = 'Pennsylvania'
State_name_4 = 'Maryland'
State_name_5 = 'D.C.'

# Change State abbreviation here.
State_abbreviation_1 = 'DE'
State_abbreviation_2 = 'NJ'
State_abbreviation_3 = 'PA'
State_abbreviation_4 = 'MD'
State_abbreviation_5 = 'DC'

# %%
def checkECigaretteInLine(line):
    try:
        lineInJson = json.loads(line)
    except:
        print('Cannot load the line: ', line)
        return False
    textInLine = lineInJson["text"]
    lowercaseLine = textInLine.lower()
    
    # test for synonym
    for keyword in synonym_ecig:
        #         print(keyword)
        if '&' not in keyword and keyword in lowercaseLine:
            return True
        elif '&' in keyword:
            k1, k2 = keyword.split('&')
            if k1 in lowercaseLine and k2 in lowercaseLine:
                return True

            # synonym_ecig_list.append(line)
            # flagHit = True
            # break

    # test for brand
    for keyword in brand_ecig:
        if '&' not in keyword and keyword in lowercaseLine:
            return True
        elif '&' in keyword:
            k1, k2 = keyword.split('&')
            if k1 in lowercaseLine and k2 in lowercaseLine:
                return True
#         if keyword in lowercaseLine:
#             return True
            # brand_ecig_list.append(line)
            # flagHit = True
            # break

    # test for policy
    for keyword in policy_ecig:
        if '&' not in keyword and keyword in lowercaseLine:
            return True
        elif '&' in keyword:
            k1, k2 = keyword.split('&')
            if k1 in lowercaseLine and k2 in lowercaseLine:
                return True
#         if keyword in lowercaseLine:
#             return True
            # policy_ecig_list.append(line)
            # flagHit = True
            # break

    # test for cessation
    for keyword in cessation_ecig:
        if '&' not in keyword and keyword in lowercaseLine:
            return True
        elif '&' in keyword:
            k1, k2 = keyword.split('&')
            if k1 in lowercaseLine and k2 in lowercaseLine:
                return True
#         if keyword in lowercaseLine:
#             return True
            # cessation_ecig_list.append(line)
            # flagHit = True
            # break

    return False

# %%
def getCountryCode(jsonLine):
    return jsonLine['place']['country_code']

# %%
def getState(jsonLine):
    placeFullName = jsonLine['place']['full_name']
    try:
        first_part_full_name, second_part_full_name = placeFullName.split(', ')
    except:
        return placeFullName
    
    if 'USA' not in second_part_full_name:
        return second_part_full_name
    else: 
        try:
            abbreviation = states_full_to_abbreviation[first_part_full_name]
            return abbreviation
        except:
            return first_part_full_name

# %%
def getPlaceName(jsonLine):
    #     print(jsonLine['place']['name'])
    return jsonLine['place']['name']

# %%
def writeStateTweetsToDisk(State_name, allState, allECigarette_State_Line, allECigarette_not_State_Line, not_ECigarette_State_Line):
    State_name = str(State_name)
    
    # Write State data to local file
    # os.chdir('/mnt/volume/result/')
    allState_FileName = './juliana_all'+State_name+'_2017_'+month+'.json'
    with open(allState_FileName, "a", encoding="utf-8") as f:
        for line in allState:
            f.write(str(line))

    # Write E-Cigarette that happened in State data to local file
    allECigarette_State_FileName = './juliana_'+State_name+'_allECigarette_2017_'+month+'_categoryKeyWord.json'
    with open(allECigarette_State_FileName, "a", encoding="utf-8") as f:
        for line in allECigarette_State_Line:
            f.write(str(line))
    
    # Write E-Cigarette that not in State data to local file
    allECigarette_not_State_FileName = './juliana_not_'+State_name+'_allECigarette_2017_'+month+'_categoryKeyWord.json'
    with open(allECigarette_not_State_FileName, "a", encoding="utf-8") as f:
        for line in allECigarette_not_State_Line:
            f.write(str(line))
            
    # Write not E-cig in State to local file.
    not_ECigarette_State_FileName = './juliana_not_ECigarette_'+State_name+'_2017_'+month+'_categoryKeyWord.json'
    with open(not_ECigarette_State_FileName, "a", encoding="utf-8") as f:
        for line in not_ECigarette_State_Line:
            f.write(str(line))

# %%
def checkECigaretteOfEachLineInFile(fileName):

    os.chdir('/mnt/volume/juliana/data')
    
    # Kansas 
    allState_1 = set()
    allECigarette_State_1_Line = set()
    allECigarette_not_State_1_Line = set()
    not_ECigarette_State_1_Line = set()
    
    # Nebraska
    allState_2 = set()
    allECigarette_State_2_Line = set()
    allECigarette_not_State_2_Line = set()
    not_ECigarette_State_2_Line = set()

    # Missouri
    allState_3 = set()
    allECigarette_State_3_Line = set()
    allECigarette_not_State_3_Line = set()
    not_ECigarette_State_3_Line = set()
    
    # Oklahoma
    allState_4 = set()
    allECigarette_State_4_Line = set()
    allECigarette_not_State_4_Line = set()
    not_ECigarette_State_4_Line = set()
    
    # Colorado
    allState_5 = set()
    allECigarette_State_5_Line = set()
    allECigarette_not_State_5_Line = set()
    not_ECigarette_State_5_Line = set()
    
    with open(fileName, "r") as f:
        everyLines = f.readlines()
        for line in everyLines:
            try:
                tweetInJson = json.loads(line)
                tweetState = getState(tweetInJson)
            except:
                continue          
            
            # First Level
            if checkECigaretteInLine(line):
                # State_1
                if tweetState == State_abbreviation_1:
                    allECigarette_State_1_Line.add(line)
                else:
                    allECigarette_not_State_1_Line.add(line)
                    
                # State_2
                if tweetState == State_abbreviation_2:
                    allECigarette_State_2_Line.add(line)
                else:
                    allECigarette_not_State_2_Line.add(line)
                    
                # State_3
                if tweetState == State_abbreviation_3:
                    allECigarette_State_3_Line.add(line)
                else:
                    allECigarette_not_State_3_Line.add(line)
                    
                # State_4
                if tweetState == State_abbreviation_4:
                    allECigarette_State_4_Line.add(line)
                else:
                    allECigarette_not_State_4_Line.add(line)

                # State_5
                if tweetState == State_abbreviation_5:
                    allECigarette_State_5_Line.add(line)
                else:
                    allECigarette_not_State_5_Line.add(line)                    
                
            # Second Level
            if tweetState == State_abbreviation_1:
                allState_1.add(line)
                if not checkECigaretteInLine(line):
                    not_ECigarette_State_1_Line.add(line)
            elif tweetState == State_abbreviation_2:
                allState_2.add(line)
                if not checkECigaretteInLine(line):
                    not_ECigarette_State_2_Line.add(line)
            elif tweetState == State_abbreviation_3:
                allState_3.add(line)
                if not checkECigaretteInLine(line):
                    not_ECigarette_State_3_Line.add(line)
            elif tweetState == State_abbreviation_4:
                allState_4.add(line)
                if not checkECigaretteInLine(line):
                    not_ECigarette_State_4_Line.add(line)
            elif tweetState == State_abbreviation_5:
                allState_5.add(line)
                if not checkECigaretteInLine(line):
                    not_ECigarette_State_5_Line.add(line)

                    
    os.chdir('/mnt/volume/result/State_DelawareLevel/')

#    # Write E-Cigarette data to local file. We already did this before.
#     allECigarette_FileName = './juliana_allECigarette_2017_'+month+'_categoryKeyWord.json'
#     with open(allECigarette_FileName, "a", encoding="utf-8") as f:
#         for line in allECigaretteLine:
#             f.write(str(line))



    writeStateTweetsToDisk(State_name_1, allState_1, allECigarette_State_1_Line, 
                           allECigarette_not_State_1_Line, not_ECigarette_State_1_Line)
    writeStateTweetsToDisk(State_name_2, allState_2, allECigarette_State_2_Line, 
                           allECigarette_not_State_2_Line, not_ECigarette_State_2_Line)
    writeStateTweetsToDisk(State_name_3, allState_3, allECigarette_State_3_Line, 
                           allECigarette_not_State_3_Line, not_ECigarette_State_3_Line)
    writeStateTweetsToDisk(State_name_4, allState_4, allECigarette_State_4_Line, 
                           allECigarette_not_State_4_Line, not_ECigarette_State_4_Line)
    writeStateTweetsToDisk(State_name_5, allState_5, allECigarette_State_5_Line, 
                           allECigarette_not_State_5_Line, not_ECigarette_State_5_Line)

# %%
# Iterate the files in the directory you stored the data.
jsonFileDirectoryPath = "/mnt/volume/juliana/data"
dirNames = os.listdir(jsonFileDirectoryPath)

os.chdir('/mnt/volume/juliana/data')

for dirName in dirNames:
    if dirName.startswith('2017-'+month):
        #     print(dirName)
        files = os.listdir(dirName)
        for file in files:
#             print(file)
            file = dirName + '/' + file
            if not os.path.isdir(file) and (os.path.splitext(file)[-1] == ".json"):

                checkECigaretteOfEachLineInFile(file)
                print('finish file: ', file)
        os.chdir('/mnt/volume/juliana/data')

print('Finished all the files.')
# Out:
# finish file:  2017-07-10/twitter_2017-07-10_08h.json
# finish file:  2017-07-10/twitter_2017-07-10_19h.json
# finish file:  2017-07-10/twitter_2017-07-10_22h.json
# finish file:  2017-07-10/twitter_2017-07-10_21h.json
# finish file:  2017-07-10/twitter_2017-07-10_20h.json
# finish file:  2017-07-10/twitter_2017-07-10_18h.json
# finish file:  2017-07-10/twitter_2017-07-10_16h.json
# finish file:  2017-07-10/twitter_2017-07-10_11h.json
# finish file:  2017-07-10/twitter_2017-07-10_09h.json
# finish file:  2017-07-10/twitter_2017-07-10_03h.json
# finish file:  2017-07-10/twitter_2017-07-10_15h.json
# finish file:  2017-07-10/twitter_2017-07-10_10h.json
# finish file:  2017-07-10/twitter_2017-07-10_07h.json
# finish file:  2017-07-10/twitter_2017-07-10_04h.json
# finish file:  2017-07-10/twitter_2017-07-10_12h.json
# finish file:  2017-07-10/twitter_2017-07-10_17h.json
# finish file:  2017-07-10/twitter_2017-07-10_06h.json
# finish file:  2017-07-10/twitter_2017-07-10_13h.json
# finish file:  2017-07-10/twitter_2017-07-10_23h.json
# finish file:  2017-07-10/twitter_2017-07-10_14h.json
# finish file:  2017-07-10/twitter_2017-07-10_02h.json
# finish file:  2017-07-10/twitter_2017-07-10_01h.json
# finish file:  2017-07-10/twitter_2017-07-10_05h.json
# finish file:  2017-07-10/twitter_2017-07-10_00h.json
# finish file:  2017-07-19/twitter_2017-07-19_16h.json
# finish file:  2017-07-19/twitter_2017-07-19_11h.json
# finish file:  2017-07-19/twitter_2017-07-19_21h.json
# finish file:  2017-07-19/twitter_2017-07-19_15h.json
# finish file:  2017-07-19/twitter_2017-07-19_04h.json
# finish file:  2017-07-19/twitter_2017-07-19_14h.json
# finish file:  2017-07-19/twitter_2017-07-19_05h.json
# finish file:  2017-07-19/twitter_2017-07-19_23h.json
# finish file:  2017-07-19/twitter_2017-07-19_03h.json
# finish file:  2017-07-19/twitter_2017-07-19_08h.json
# finish file:  2017-07-19/twitter_2017-07-19_22h.json
# finish file:  2017-07-19/twitter_2017-07-19_19h.json
# finish file:  2017-07-19/twitter_2017-07-19_00h.json
# finish file:  2017-07-19/twitter_2017-07-19_01h.json
# finish file:  2017-07-19/twitter_2017-07-19_18h.json
# finish file:  2017-07-19/twitter_2017-07-19_06h.json
# finish file:  2017-07-19/twitter_2017-07-19_09h.json
# finish file:  2017-07-19/twitter_2017-07-19_02h.json
# finish file:  2017-07-19/twitter_2017-07-19_20h.json
# finish file:  2017-07-19/twitter_2017-07-19_07h.json
# finish file:  2017-07-19/twitter_2017-07-19_13h.json
# finish file:  2017-07-19/twitter_2017-07-19_17h.json
# finish file:  2017-07-19/twitter_2017-07-19_10h.json
# finish file:  2017-07-19/twitter_2017-07-19_12h.json
# finish file:  2017-07-01/twitter_2017-07-01_00h.json
# finish file:  2017-07-01/twitter_2017-07-01_18h.json
# finish file:  2017-07-01/twitter_2017-07-01_03h.json
# finish file:  2017-07-01/twitter_2017-07-01_06h.json
# finish file:  2017-07-01/twitter_2017-07-01_20h.json
# finish file:  2017-07-01/twitter_2017-07-01_22h.json
# finish file:  2017-07-01/twitter_2017-07-01_17h.json
# finish file:  2017-07-01/twitter_2017-07-01_21h.json
# finish file:  2017-07-01/twitter_2017-07-01_14h.json
# finish file:  2017-07-01/twitter_2017-07-01_23h.json
# finish file:  2017-07-01/twitter_2017-07-01_15h.json
# finish file:  2017-07-01/twitter_2017-07-01_10h.json
# finish file:  2017-07-01/twitter_2017-07-01_16h.json
# finish file:  2017-07-01/twitter_2017-07-01_08h.json
# finish file:  2017-07-01/twitter_2017-07-01_07h.json
# finish file:  2017-07-01/twitter_2017-07-01_19h.json
# finish file:  2017-07-01/twitter_2017-07-01_11h.json
# finish file:  2017-07-01/twitter_2017-07-01_01h.json
# finish file:  2017-07-01/twitter_2017-07-01_13h.json
# finish file:  2017-07-01/twitter_2017-07-01_05h.json
# finish file:  2017-07-01/twitter_2017-07-01_02h.json
# finish file:  2017-07-01/twitter_2017-07-01_04h.json
# finish file:  2017-07-01/twitter_2017-07-01_09h.json
# finish file:  2017-07-01/twitter_2017-07-01_12h.json
# finish file:  2017-07-28/twitter_2017-07-28_08h.json
# finish file:  2017-07-28/twitter_2017-07-28_05h.json
# finish file:  2017-07-28/twitter_2017-07-28_12h.json
# finish file:  2017-07-28/twitter_2017-07-28_10h.json
# finish file:  2017-07-28/twitter_2017-07-28_23h.json
# finish file:  2017-07-28/twitter_2017-07-28_18h.json
# finish file:  2017-07-28/twitter_2017-07-28_14h.json
# finish file:  2017-07-28/twitter_2017-07-28_09h.json
# finish file:  2017-07-28/twitter_2017-07-28_04h.json
# finish file:  2017-07-28/twitter_2017-07-28_16h.json
# finish file:  2017-07-28/twitter_2017-07-28_03h.json
# finish file:  2017-07-28/twitter_2017-07-28_00h.json
# finish file:  2017-07-28/twitter_2017-07-28_17h.json
# finish file:  2017-07-28/twitter_2017-07-28_11h.json
# finish file:  2017-07-28/twitter_2017-07-28_19h.json
# finish file:  2017-07-28/twitter_2017-07-28_07h.json
# finish file:  2017-07-28/twitter_2017-07-28_15h.json
# finish file:  2017-07-28/twitter_2017-07-28_01h.json
# finish file:  2017-07-28/twitter_2017-07-28_02h.json
# finish file:  2017-07-28/twitter_2017-07-28_20h.json
# finish file:  2017-07-28/twitter_2017-07-28_13h.json
# finish file:  2017-07-28/twitter_2017-07-28_21h.json
# finish file:  2017-07-28/twitter_2017-07-28_06h.json
# finish file:  2017-07-28/twitter_2017-07-28_22h.json
# finish file:  2017-07-12/twitter_2017-07-12_23h.json
# finish file:  2017-07-12/twitter_2017-07-12_16h.json
# finish file:  2017-07-12/twitter_2017-07-12_21h.json
# finish file:  2017-07-12/twitter_2017-07-12_04h.json
# finish file:  2017-07-12/twitter_2017-07-12_19h.json
# finish file:  2017-07-12/twitter_2017-07-12_14h.json
# finish file:  2017-07-12/twitter_2017-07-12_11h.json
# finish file:  2017-07-12/twitter_2017-07-12_08h.json
# finish file:  2017-07-12/twitter_2017-07-12_20h.json
# finish file:  2017-07-12/twitter_2017-07-12_18h.json
# finish file:  2017-07-12/twitter_2017-07-12_22h.json
# finish file:  2017-07-12/twitter_2017-07-12_01h.json
# finish file:  2017-07-12/twitter_2017-07-12_03h.json
# finish file:  2017-07-12/twitter_2017-07-12_12h.json
# finish file:  2017-07-12/twitter_2017-07-12_02h.json
# finish file:  2017-07-12/twitter_2017-07-12_06h.json
# finish file:  2017-07-12/twitter_2017-07-12_15h.json
# finish file:  2017-07-12/twitter_2017-07-12_17h.json
# finish file:  2017-07-12/twitter_2017-07-12_13h.json
# finish file:  2017-07-12/twitter_2017-07-12_10h.json
# finish file:  2017-07-12/twitter_2017-07-12_05h.json
# finish file:  2017-07-12/twitter_2017-07-12_00h.json
# finish file:  2017-07-12/twitter_2017-07-12_09h.json
# finish file:  2017-07-12/twitter_2017-07-12_07h.json
# finish file:  2017-07-11/twitter_2017-07-11_10h.json
# finish file:  2017-07-11/twitter_2017-07-11_00h.json
# finish file:  2017-07-11/twitter_2017-07-11_06h.json
# finish file:  2017-07-11/twitter_2017-07-11_17h.json
# finish file:  2017-07-11/twitter_2017-07-11_01h.json
# finish file:  2017-07-11/twitter_2017-07-11_13h.json
# finish file:  2017-07-11/twitter_2017-07-11_12h.json
# finish file:  2017-07-11/twitter_2017-07-11_03h.json
# finish file:  2017-07-11/twitter_2017-07-11_22h.json
# finish file:  2017-07-11/twitter_2017-07-11_02h.json
# finish file:  2017-07-11/twitter_2017-07-11_21h.json
# finish file:  2017-07-11/twitter_2017-07-11_23h.json
# finish file:  2017-07-11/twitter_2017-07-11_18h.json
# finish file:  2017-07-11/twitter_2017-07-11_16h.json
# finish file:  2017-07-11/twitter_2017-07-11_15h.json
# finish file:  2017-07-11/twitter_2017-07-11_14h.json
# finish file:  2017-07-11/twitter_2017-07-11_08h.json
# finish file:  2017-07-11/twitter_2017-07-11_19h.json
# finish file:  2017-07-11/twitter_2017-07-11_09h.json
# finish file:  2017-07-11/twitter_2017-07-11_04h.json
# finish file:  2017-07-11/twitter_2017-07-11_07h.json
# finish file:  2017-07-11/twitter_2017-07-11_11h.json
# finish file:  2017-07-11/twitter_2017-07-11_20h.json
# finish file:  2017-07-11/twitter_2017-07-11_05h.json
# finish file:  2017-07-20/twitter_2017-07-20_16h.json
# finish file:  2017-07-20/twitter_2017-07-20_14h.json
# finish file:  2017-07-20/twitter_2017-07-20_10h.json
# finish file:  2017-07-20/twitter_2017-07-20_18h.json
# finish file:  2017-07-20/twitter_2017-07-20_08h.json
# finish file:  2017-07-20/twitter_2017-07-20_03h.json
# finish file:  2017-07-20/twitter_2017-07-20_21h.json
# finish file:  2017-07-20/twitter_2017-07-20_05h.json
# finish file:  2017-07-20/twitter_2017-07-20_12h.json
# finish file:  2017-07-20/twitter_2017-07-20_23h.json
# finish file:  2017-07-20/twitter_2017-07-20_11h.json
# finish file:  2017-07-20/twitter_2017-07-20_06h.json
# finish file:  2017-07-20/twitter_2017-07-20_19h.json
# finish file:  2017-07-20/twitter_2017-07-20_20h.json
# finish file:  2017-07-20/twitter_2017-07-20_17h.json
# finish file:  2017-07-20/twitter_2017-07-20_09h.json
# finish file:  2017-07-20/twitter_2017-07-20_07h.json
# finish file:  2017-07-20/twitter_2017-07-20_01h.json
# finish file:  2017-07-20/twitter_2017-07-20_13h.json
# finish file:  2017-07-20/twitter_2017-07-20_04h.json
# finish file:  2017-07-20/twitter_2017-07-20_02h.json
# finish file:  2017-07-20/twitter_2017-07-20_15h.json
# finish file:  2017-07-20/twitter_2017-07-20_00h.json
# finish file:  2017-07-20/twitter_2017-07-20_22h.json
# finish file:  2017-07-09/twitter_2017-07-09_14h.json
# finish file:  2017-07-09/twitter_2017-07-09_23h.json
# finish file:  2017-07-09/twitter_2017-07-09_20h.json
# finish file:  2017-07-09/twitter_2017-07-09_02h.json
# finish file:  2017-07-09/twitter_2017-07-09_18h.json
# finish file:  2017-07-09/twitter_2017-07-09_15h.json
# finish file:  2017-07-09/twitter_2017-07-09_11h.json
# finish file:  2017-07-09/twitter_2017-07-09_21h.json
# finish file:  2017-07-09/twitter_2017-07-09_00h.json
# finish file:  2017-07-09/twitter_2017-07-09_17h.json
# finish file:  2017-07-09/twitter_2017-07-09_05h.json
# finish file:  2017-07-09/twitter_2017-07-09_06h.json
# finish file:  2017-07-09/twitter_2017-07-09_12h.json
# finish file:  2017-07-09/twitter_2017-07-09_08h.json
# finish file:  2017-07-09/twitter_2017-07-09_07h.json
# finish file:  2017-07-09/twitter_2017-07-09_03h.json
# finish file:  2017-07-09/twitter_2017-07-09_01h.json
# finish file:  2017-07-09/twitter_2017-07-09_22h.json
# finish file:  2017-07-09/twitter_2017-07-09_19h.json
# finish file:  2017-07-09/twitter_2017-07-09_16h.json
# finish file:  2017-07-09/twitter_2017-07-09_10h.json
# finish file:  2017-07-09/twitter_2017-07-09_09h.json
# finish file:  2017-07-09/twitter_2017-07-09_13h.json
# finish file:  2017-07-09/twitter_2017-07-09_04h.json
# finish file:  2017-07-03/twitter_2017-07-03_16h.json
# finish file:  2017-07-03/twitter_2017-07-03_00h.json
# finish file:  2017-07-03/twitter_2017-07-03_17h.json
# finish file:  2017-07-03/twitter_2017-07-03_23h.json
# finish file:  2017-07-03/twitter_2017-07-03_14h.json
# finish file:  2017-07-03/twitter_2017-07-03_20h.json
# finish file:  2017-07-03/twitter_2017-07-03_08h.json
# finish file:  2017-07-03/twitter_2017-07-03_02h.json
# finish file:  2017-07-03/twitter_2017-07-03_21h.json
# finish file:  2017-07-03/twitter_2017-07-03_10h.json
# finish file:  2017-07-03/twitter_2017-07-03_18h.json
# finish file:  2017-07-03/twitter_2017-07-03_19h.json
# finish file:  2017-07-03/twitter_2017-07-03_05h.json
# finish file:  2017-07-03/twitter_2017-07-03_06h.json
# finish file:  2017-07-03/twitter_2017-07-03_09h.json
# finish file:  2017-07-03/twitter_2017-07-03_01h.json
# finish file:  2017-07-03/twitter_2017-07-03_03h.json
# finish file:  2017-07-03/twitter_2017-07-03_13h.json
# finish file:  2017-07-03/twitter_2017-07-03_12h.json
# finish file:  2017-07-03/twitter_2017-07-03_11h.json
# finish file:  2017-07-03/twitter_2017-07-03_04h.json
# finish file:  2017-07-03/twitter_2017-07-03_15h.json
# finish file:  2017-07-03/twitter_2017-07-03_07h.json
# finish file:  2017-07-03/twitter_2017-07-03_22h.json
# finish file:  2017-07-07/twitter_2017-07-07_16h.json
# finish file:  2017-07-07/twitter_2017-07-07_17h.json
# finish file:  2017-07-07/twitter_2017-07-07_15h.json
# finish file:  2017-07-07/twitter_2017-07-07_11h.json
# finish file:  2017-07-07/twitter_2017-07-07_22h.json
# finish file:  2017-07-07/twitter_2017-07-07_18h.json
# finish file:  2017-07-07/twitter_2017-07-07_02h.json
# finish file:  2017-07-07/twitter_2017-07-07_21h.json
# finish file:  2017-07-07/twitter_2017-07-07_23h.json
# finish file:  2017-07-07/twitter_2017-07-07_14h.json
# finish file:  2017-07-07/twitter_2017-07-07_19h.json
# finish file:  2017-07-07/twitter_2017-07-07_12h.json
# finish file:  2017-07-07/twitter_2017-07-07_10h.json
# finish file:  2017-07-07/twitter_2017-07-07_05h.json
# finish file:  2017-07-07/twitter_2017-07-07_00h.json
# finish file:  2017-07-07/twitter_2017-07-07_03h.json
# finish file:  2017-07-07/twitter_2017-07-07_13h.json
# finish file:  2017-07-07/twitter_2017-07-07_01h.json
# finish file:  2017-07-07/twitter_2017-07-07_09h.json
# finish file:  2017-07-07/twitter_2017-07-07_07h.json
# finish file:  2017-07-07/twitter_2017-07-07_04h.json
# finish file:  2017-07-07/twitter_2017-07-07_08h.json
# finish file:  2017-07-07/twitter_2017-07-07_20h.json
# finish file:  2017-07-07/twitter_2017-07-07_06h.json
# finish file:  2017-07-04/twitter_2017-07-04_08h.json
# finish file:  2017-07-04/twitter_2017-07-04_02h.json
# finish file:  2017-07-04/twitter_2017-07-04_17h.json
# finish file:  2017-07-04/twitter_2017-07-04_05h.json
# finish file:  2017-07-04/twitter_2017-07-04_22h.json
# finish file:  2017-07-04/twitter_2017-07-04_19h.json
# finish file:  2017-07-04/twitter_2017-07-04_14h.json
# finish file:  2017-07-04/twitter_2017-07-04_11h.json
# finish file:  2017-07-04/twitter_2017-07-04_21h.json
# finish file:  2017-07-04/twitter_2017-07-04_15h.json
# finish file:  2017-07-04/twitter_2017-07-04_06h.json
# finish file:  2017-07-04/twitter_2017-07-04_07h.json
# finish file:  2017-07-04/twitter_2017-07-04_23h.json
# finish file:  2017-07-04/twitter_2017-07-04_03h.json
# finish file:  2017-07-04/twitter_2017-07-04_09h.json
# finish file:  2017-07-04/twitter_2017-07-04_01h.json
# finish file:  2017-07-04/twitter_2017-07-04_16h.json
# finish file:  2017-07-04/twitter_2017-07-04_10h.json
# finish file:  2017-07-04/twitter_2017-07-04_04h.json
# finish file:  2017-07-04/twitter_2017-07-04_18h.json
# finish file:  2017-07-04/twitter_2017-07-04_00h.json
# finish file:  2017-07-04/twitter_2017-07-04_13h.json
# finish file:  2017-07-04/twitter_2017-07-04_20h.json
# finish file:  2017-07-04/twitter_2017-07-04_12h.json
# finish file:  2017-07-29/twitter_2017-07-29_09h.json
# finish file:  2017-07-29/twitter_2017-07-29_19h.json
# finish file:  2017-07-29/twitter_2017-07-29_12h.json
# finish file:  2017-07-29/twitter_2017-07-29_00h.json
# finish file:  2017-07-29/twitter_2017-07-29_15h.json
# finish file:  2017-07-29/twitter_2017-07-29_11h.json
# finish file:  2017-07-29/twitter_2017-07-29_22h.json
# finish file:  2017-07-29/twitter_2017-07-29_10h.json
# finish file:  2017-07-29/twitter_2017-07-29_06h.json
# finish file:  2017-07-29/twitter_2017-07-29_16h.json
# finish file:  2017-07-29/twitter_2017-07-29_23h.json
# finish file:  2017-07-29/twitter_2017-07-29_17h.json
# finish file:  2017-07-29/twitter_2017-07-29_21h.json
# finish file:  2017-07-29/twitter_2017-07-29_20h.json
# finish file:  2017-07-29/twitter_2017-07-29_07h.json
# finish file:  2017-07-29/twitter_2017-07-29_08h.json
# finish file:  2017-07-29/twitter_2017-07-29_18h.json
# finish file:  2017-07-29/twitter_2017-07-29_13h.json
# finish file:  2017-07-29/twitter_2017-07-29_01h.json
# finish file:  2017-07-29/twitter_2017-07-29_14h.json
# finish file:  2017-07-29/twitter_2017-07-29_04h.json
# finish file:  2017-07-29/twitter_2017-07-29_05h.json
# finish file:  2017-07-25/twitter_2017-07-25_22h.json
# finish file:  2017-07-25/twitter_2017-07-25_13h.json
# finish file:  2017-07-25/twitter_2017-07-25_05h.json
# finish file:  2017-07-25/twitter_2017-07-25_21h.json
# finish file:  2017-07-25/twitter_2017-07-25_19h.json
# finish file:  2017-07-25/twitter_2017-07-25_06h.json
# finish file:  2017-07-25/twitter_2017-07-25_07h.json
# finish file:  2017-07-25/twitter_2017-07-25_16h.json
# finish file:  2017-07-25/twitter_2017-07-25_00h.json
# finish file:  2017-07-25/twitter_2017-07-25_14h.json
# finish file:  2017-07-25/twitter_2017-07-25_10h.json
# finish file:  2017-07-25/twitter_2017-07-25_23h.json
# finish file:  2017-07-25/twitter_2017-07-25_08h.json
# finish file:  2017-07-25/twitter_2017-07-25_17h.json
# finish file:  2017-07-25/twitter_2017-07-25_15h.json
# finish file:  2017-07-25/twitter_2017-07-25_04h.json
# finish file:  2017-07-25/twitter_2017-07-25_01h.json
# finish file:  2017-07-25/twitter_2017-07-25_18h.json
# finish file:  2017-07-25/twitter_2017-07-25_12h.json
# finish file:  2017-07-25/twitter_2017-07-25_02h.json
# finish file:  2017-07-25/twitter_2017-07-25_11h.json
# finish file:  2017-07-25/twitter_2017-07-25_09h.json
# finish file:  2017-07-25/twitter_2017-07-25_03h.json
# finish file:  2017-07-25/twitter_2017-07-25_20h.json
# finish file:  2017-07-17/twitter_2017-07-17_20h.json
# finish file:  2017-07-17/twitter_2017-07-17_02h.json
# finish file:  2017-07-17/twitter_2017-07-17_14h.json
# finish file:  2017-07-17/twitter_2017-07-17_09h.json
# finish file:  2017-07-17/twitter_2017-07-17_13h.json
# finish file:  2017-07-17/twitter_2017-07-17_18h.json
# finish file:  2017-07-17/twitter_2017-07-17_10h.json
# finish file:  2017-07-17/twitter_2017-07-17_07h.json
# finish file:  2017-07-17/twitter_2017-07-17_01h.json
# finish file:  2017-07-17/twitter_2017-07-17_00h.json
# finish file:  2017-07-17/twitter_2017-07-17_23h.json
# finish file:  2017-07-17/twitter_2017-07-17_21h.json
# finish file:  2017-07-17/twitter_2017-07-17_04h.json
# finish file:  2017-07-17/twitter_2017-07-17_08h.json
# finish file:  2017-07-17/twitter_2017-07-17_06h.json
# finish file:  2017-07-17/twitter_2017-07-17_05h.json
# finish file:  2017-07-17/twitter_2017-07-17_22h.json
# finish file:  2017-07-17/twitter_2017-07-17_11h.json
# finish file:  2017-07-17/twitter_2017-07-17_17h.json
# finish file:  2017-07-17/twitter_2017-07-17_12h.json
# finish file:  2017-07-17/twitter_2017-07-17_15h.json
# finish file:  2017-07-17/twitter_2017-07-17_03h.json
# finish file:  2017-07-17/twitter_2017-07-17_16h.json
# finish file:  2017-07-17/twitter_2017-07-17_19h.json
# finish file:  2017-07-22/twitter_2017-07-22_19h.json
# finish file:  2017-07-22/twitter_2017-07-22_15h.json
# finish file:  2017-07-22/twitter_2017-07-22_00h.json
# finish file:  2017-07-22/twitter_2017-07-22_09h.json
# finish file:  2017-07-22/twitter_2017-07-22_05h.json
# finish file:  2017-07-22/twitter_2017-07-22_12h.json
# finish file:  2017-07-22/twitter_2017-07-22_06h.json
# finish file:  2017-07-22/twitter_2017-07-22_20h.json
# finish file:  2017-07-22/twitter_2017-07-22_01h.json
# finish file:  2017-07-22/twitter_2017-07-22_21h.json
# finish file:  2017-07-22/twitter_2017-07-22_16h.json
# finish file:  2017-07-22/twitter_2017-07-22_11h.json
# finish file:  2017-07-22/twitter_2017-07-22_13h.json
# finish file:  2017-07-22/twitter_2017-07-22_10h.json
# finish file:  2017-07-22/twitter_2017-07-22_17h.json
# finish file:  2017-07-22/twitter_2017-07-22_04h.json
# finish file:  2017-07-22/twitter_2017-07-22_14h.json
# finish file:  2017-07-22/twitter_2017-07-22_23h.json
# finish file:  2017-07-22/twitter_2017-07-22_03h.json
# finish file:  2017-07-22/twitter_2017-07-22_22h.json
# finish file:  2017-07-22/twitter_2017-07-22_08h.json
# finish file:  2017-07-22/twitter_2017-07-22_07h.json
# finish file:  2017-07-22/twitter_2017-07-22_02h.json
# finish file:  2017-07-22/twitter_2017-07-22_18h.json
# finish file:  2017-07-21/twitter_2017-07-21_03h.json
# finish file:  2017-07-21/twitter_2017-07-21_19h.json
# finish file:  2017-07-21/twitter_2017-07-21_12h.json
# finish file:  2017-07-21/twitter_2017-07-21_23h.json
# finish file:  2017-07-21/twitter_2017-07-21_08h.json
# finish file:  2017-07-21/twitter_2017-07-21_15h.json
# finish file:  2017-07-21/twitter_2017-07-21_05h.json
# finish file:  2017-07-21/twitter_2017-07-21_21h.json
# finish file:  2017-07-21/twitter_2017-07-21_16h.json
# finish file:  2017-07-21/twitter_2017-07-21_00h.json
# finish file:  2017-07-21/twitter_2017-07-21_02h.json
# finish file:  2017-07-21/twitter_2017-07-21_20h.json
# finish file:  2017-07-21/twitter_2017-07-21_10h.json
# finish file:  2017-07-21/twitter_2017-07-21_11h.json
# finish file:  2017-07-21/twitter_2017-07-21_04h.json
# finish file:  2017-07-21/twitter_2017-07-21_17h.json
# finish file:  2017-07-21/twitter_2017-07-21_14h.json
# finish file:  2017-07-21/twitter_2017-07-21_22h.json
# finish file:  2017-07-21/twitter_2017-07-21_09h.json
# finish file:  2017-07-21/twitter_2017-07-21_06h.json
# finish file:  2017-07-21/twitter_2017-07-21_13h.json
# finish file:  2017-07-21/twitter_2017-07-21_18h.json
# finish file:  2017-07-21/twitter_2017-07-21_01h.json
# finish file:  2017-07-21/twitter_2017-07-21_07h.json
# finish file:  2017-07-15/twitter_2017-07-15_10h.json
# finish file:  2017-07-15/twitter_2017-07-15_06h.json
# finish file:  2017-07-15/twitter_2017-07-15_23h.json
# finish file:  2017-07-15/twitter_2017-07-15_12h.json
# finish file:  2017-07-15/twitter_2017-07-15_02h.json
# finish file:  2017-07-15/twitter_2017-07-15_03h.json
# finish file:  2017-07-15/twitter_2017-07-15_14h.json
# finish file:  2017-07-15/twitter_2017-07-15_05h.json
# finish file:  2017-07-15/twitter_2017-07-15_18h.json
# finish file:  2017-07-15/twitter_2017-07-15_01h.json
# finish file:  2017-07-15/twitter_2017-07-15_19h.json
# finish file:  2017-07-15/twitter_2017-07-15_09h.json
# finish file:  2017-07-15/twitter_2017-07-15_11h.json
# finish file:  2017-07-15/twitter_2017-07-15_16h.json
# finish file:  2017-07-15/twitter_2017-07-15_00h.json
# finish file:  2017-07-15/twitter_2017-07-15_22h.json
# finish file:  2017-07-15/twitter_2017-07-15_15h.json
# finish file:  2017-07-15/twitter_2017-07-15_13h.json
# finish file:  2017-07-15/twitter_2017-07-15_17h.json
# finish file:  2017-07-15/twitter_2017-07-15_04h.json
# finish file:  2017-07-15/twitter_2017-07-15_08h.json
# finish file:  2017-07-15/twitter_2017-07-15_21h.json
# finish file:  2017-07-15/twitter_2017-07-15_07h.json
# finish file:  2017-07-15/twitter_2017-07-15_20h.json
# finish file:  2017-07-02/twitter_2017-07-02_16h.json
# finish file:  2017-07-02/twitter_2017-07-02_20h.json
# finish file:  2017-07-02/twitter_2017-07-02_12h.json
# finish file:  2017-07-02/twitter_2017-07-02_22h.json
# finish file:  2017-07-02/twitter_2017-07-02_18h.json
# finish file:  2017-07-02/twitter_2017-07-02_00h.json
# finish file:  2017-07-02/twitter_2017-07-02_11h.json
# finish file:  2017-07-02/twitter_2017-07-02_09h.json
# finish file:  2017-07-02/twitter_2017-07-02_04h.json
# finish file:  2017-07-02/twitter_2017-07-02_03h.json
# finish file:  2017-07-02/twitter_2017-07-02_13h.json
# finish file:  2017-07-02/twitter_2017-07-02_21h.json
# finish file:  2017-07-02/twitter_2017-07-02_23h.json
# finish file:  2017-07-02/twitter_2017-07-02_01h.json
# finish file:  2017-07-02/twitter_2017-07-02_14h.json
# finish file:  2017-07-02/twitter_2017-07-02_10h.json
# finish file:  2017-07-02/twitter_2017-07-02_15h.json
# finish file:  2017-07-02/twitter_2017-07-02_02h.json
# finish file:  2017-07-02/twitter_2017-07-02_08h.json
# finish file:  2017-07-02/twitter_2017-07-02_19h.json
# finish file:  2017-07-02/twitter_2017-07-02_17h.json
# finish file:  2017-07-02/twitter_2017-07-02_06h.json
# finish file:  2017-07-02/twitter_2017-07-02_05h.json
# finish file:  2017-07-02/twitter_2017-07-02_07h.json
# finish file:  2017-07-27/twitter_2017-07-27_20h.json
# finish file:  2017-07-27/twitter_2017-07-27_21h.json
# finish file:  2017-07-27/twitter_2017-07-27_15h.json
# finish file:  2017-07-27/twitter_2017-07-27_05h.json
# finish file:  2017-07-27/twitter_2017-07-27_18h.json
# finish file:  2017-07-27/twitter_2017-07-27_07h.json
# finish file:  2017-07-27/twitter_2017-07-27_04h.json
# finish file:  2017-07-27/twitter_2017-07-27_23h.json
# finish file:  2017-07-27/twitter_2017-07-27_03h.json
# finish file:  2017-07-27/twitter_2017-07-27_01h.json
# finish file:  2017-07-27/twitter_2017-07-27_19h.json
# finish file:  2017-07-27/twitter_2017-07-27_14h.json
# finish file:  2017-07-27/twitter_2017-07-27_17h.json
# finish file:  2017-07-27/twitter_2017-07-27_11h.json
# finish file:  2017-07-27/twitter_2017-07-27_16h.json
# finish file:  2017-07-27/twitter_2017-07-27_10h.json
# finish file:  2017-07-27/twitter_2017-07-27_02h.json
# finish file:  2017-07-27/twitter_2017-07-27_06h.json
# finish file:  2017-07-27/twitter_2017-07-27_00h.json
# finish file:  2017-07-27/twitter_2017-07-27_13h.json
# finish file:  2017-07-27/twitter_2017-07-27_12h.json
# finish file:  2017-07-27/twitter_2017-07-27_22h.json
# finish file:  2017-07-27/twitter_2017-07-27_09h.json
# finish file:  2017-07-27/twitter_2017-07-27_08h.json
# finish file:  2017-07-08/twitter_2017-07-08_04h.json
# finish file:  2017-07-08/twitter_2017-07-08_11h.json
# finish file:  2017-07-08/twitter_2017-07-08_01h.json
# finish file:  2017-07-08/twitter_2017-07-08_08h.json
# finish file:  2017-07-08/twitter_2017-07-08_06h.json
# finish file:  2017-07-08/twitter_2017-07-08_07h.json
# finish file:  2017-07-08/twitter_2017-07-08_20h.json
# finish file:  2017-07-08/twitter_2017-07-08_21h.json
# finish file:  2017-07-08/twitter_2017-07-08_23h.json
# finish file:  2017-07-08/twitter_2017-07-08_14h.json
# finish file:  2017-07-08/twitter_2017-07-08_15h.json
# finish file:  2017-07-08/twitter_2017-07-08_02h.json
# finish file:  2017-07-08/twitter_2017-07-08_16h.json
# finish file:  2017-07-08/twitter_2017-07-08_09h.json
# finish file:  2017-07-08/twitter_2017-07-08_13h.json
# finish file:  2017-07-08/twitter_2017-07-08_05h.json
# finish file:  2017-07-08/twitter_2017-07-08_03h.json
# finish file:  2017-07-08/twitter_2017-07-08_18h.json
# finish file:  2017-07-08/twitter_2017-07-08_17h.json
# finish file:  2017-07-08/twitter_2017-07-08_12h.json
# finish file:  2017-07-08/twitter_2017-07-08_00h.json
# finish file:  2017-07-08/twitter_2017-07-08_19h.json
# finish file:  2017-07-08/twitter_2017-07-08_10h.json
# finish file:  2017-07-08/twitter_2017-07-08_22h.json
# finish file:  2017-07-13/twitter_2017-07-13_23h.json
# finish file:  2017-07-13/twitter_2017-07-13_14h.json
# finish file:  2017-07-13/twitter_2017-07-13_15h.json
# finish file:  2017-07-13/twitter_2017-07-13_18h.json
# finish file:  2017-07-13/twitter_2017-07-13_08h.json
# finish file:  2017-07-13/twitter_2017-07-13_19h.json
# finish file:  2017-07-13/twitter_2017-07-13_03h.json
# finish file:  2017-07-13/twitter_2017-07-13_05h.json
# finish file:  2017-07-13/twitter_2017-07-13_16h.json
# finish file:  2017-07-13/twitter_2017-07-13_17h.json
# finish file:  2017-07-13/twitter_2017-07-13_09h.json
# finish file:  2017-07-13/twitter_2017-07-13_12h.json
# finish file:  2017-07-13/twitter_2017-07-13_02h.json
# finish file:  2017-07-13/twitter_2017-07-13_07h.json
# finish file:  2017-07-13/twitter_2017-07-13_00h.json
# finish file:  2017-07-13/twitter_2017-07-13_04h.json
# finish file:  2017-07-13/twitter_2017-07-13_01h.json
# finish file:  2017-07-13/twitter_2017-07-13_20h.json
# finish file:  2017-07-13/twitter_2017-07-13_21h.json
# finish file:  2017-07-13/twitter_2017-07-13_22h.json
# finish file:  2017-07-13/twitter_2017-07-13_11h.json
# finish file:  2017-07-13/twitter_2017-07-13_06h.json
# finish file:  2017-07-13/twitter_2017-07-13_13h.json
# finish file:  2017-07-13/twitter_2017-07-13_10h.json
# finish file:  2017-07-30/twitter_2017-07-30_01h.json
# finish file:  2017-07-30/twitter_2017-07-30_11h.json
# finish file:  2017-07-30/twitter_2017-07-30_21h.json
# finish file:  2017-07-30/twitter_2017-07-30_14h.json
# finish file:  2017-07-30/twitter_2017-07-30_05h.json
# finish file:  2017-07-30/twitter_2017-07-30_08h.json
# finish file:  2017-07-30/twitter_2017-07-30_04h.json
# finish file:  2017-07-30/twitter_2017-07-30_09h.json
# finish file:  2017-07-30/twitter_2017-07-30_19h.json
# finish file:  2017-07-30/twitter_2017-07-30_12h.json
# finish file:  2017-07-30/twitter_2017-07-30_22h.json
# finish file:  2017-07-30/twitter_2017-07-30_20h.json
# finish file:  2017-07-30/twitter_2017-07-30_23h.json
# finish file:  2017-07-30/twitter_2017-07-30_17h.json
# finish file:  2017-07-30/twitter_2017-07-30_00h.json
# finish file:  2017-07-30/twitter_2017-07-30_10h.json
# finish file:  2017-07-30/twitter_2017-07-30_13h.json
# finish file:  2017-07-30/twitter_2017-07-30_18h.json
# finish file:  2017-07-30/twitter_2017-07-30_16h.json
# finish file:  2017-07-30/twitter_2017-07-30_06h.json
# finish file:  2017-07-30/twitter_2017-07-30_03h.json
# finish file:  2017-07-30/twitter_2017-07-30_02h.json
# finish file:  2017-07-30/twitter_2017-07-30_07h.json
# finish file:  2017-07-30/twitter_2017-07-30_15h.json
# finish file:  2017-07-31/twitter_2017-07-31_13h.json
# finish file:  2017-07-31/twitter_2017-07-31_21h.json
# finish file:  2017-07-31/twitter_2017-07-31_00h.json
# finish file:  2017-07-31/twitter_2017-07-31_23h.json
# finish file:  2017-07-31/twitter_2017-07-31_19h.json
# finish file:  2017-07-31/twitter_2017-07-31_12h.json
# finish file:  2017-07-31/twitter_2017-07-31_15h.json
# finish file:  2017-07-31/twitter_2017-07-31_06h.json
# finish file:  2017-07-31/twitter_2017-07-31_10h.json
# finish file:  2017-07-31/twitter_2017-07-31_20h.json
# finish file:  2017-07-31/twitter_2017-07-31_01h.json
# finish file:  2017-07-31/twitter_2017-07-31_22h.json
# finish file:  2017-07-31/twitter_2017-07-31_03h.json
# finish file:  2017-07-31/twitter_2017-07-31_18h.json
# finish file:  2017-07-31/twitter_2017-07-31_04h.json
# finish file:  2017-07-31/twitter_2017-07-31_14h.json
# finish file:  2017-07-31/twitter_2017-07-31_16h.json
# finish file:  2017-07-31/twitter_2017-07-31_05h.json
# finish file:  2017-07-31/twitter_2017-07-31_09h.json
# finish file:  2017-07-31/twitter_2017-07-31_17h.json
# finish file:  2017-07-31/twitter_2017-07-31_07h.json
# finish file:  2017-07-31/twitter_2017-07-31_02h.json
# finish file:  2017-07-31/twitter_2017-07-31_08h.json
# finish file:  2017-07-31/twitter_2017-07-31_11h.json
# finish file:  2017-07-18/twitter_2017-07-18_21h.json
# finish file:  2017-07-18/twitter_2017-07-18_09h.json
# finish file:  2017-07-18/twitter_2017-07-18_12h.json
# finish file:  2017-07-18/twitter_2017-07-18_17h.json
# finish file:  2017-07-18/twitter_2017-07-18_16h.json
# finish file:  2017-07-18/twitter_2017-07-18_11h.json
# finish file:  2017-07-18/twitter_2017-07-18_04h.json
# finish file:  2017-07-18/twitter_2017-07-18_15h.json
# finish file:  2017-07-18/twitter_2017-07-18_10h.json
# finish file:  2017-07-18/twitter_2017-07-18_03h.json
# finish file:  2017-07-18/twitter_2017-07-18_23h.json
# finish file:  2017-07-18/twitter_2017-07-18_19h.json
# finish file:  2017-07-18/twitter_2017-07-18_22h.json
# finish file:  2017-07-18/twitter_2017-07-18_08h.json
# finish file:  2017-07-18/twitter_2017-07-18_05h.json
# finish file:  2017-07-18/twitter_2017-07-18_00h.json
# finish file:  2017-07-18/twitter_2017-07-18_18h.json
# finish file:  2017-07-18/twitter_2017-07-18_20h.json
# finish file:  2017-07-18/twitter_2017-07-18_13h.json
# finish file:  2017-07-18/twitter_2017-07-18_02h.json
# finish file:  2017-07-18/twitter_2017-07-18_07h.json
# finish file:  2017-07-18/twitter_2017-07-18_01h.json
# finish file:  2017-07-18/twitter_2017-07-18_06h.json
# finish file:  2017-07-18/twitter_2017-07-18_14h.json
# finish file:  2017-07-14/twitter_2017-07-14_06h.json
# finish file:  2017-07-14/twitter_2017-07-14_11h.json
# finish file:  2017-07-14/twitter_2017-07-14_03h.json
# finish file:  2017-07-14/twitter_2017-07-14_21h.json
# finish file:  2017-07-14/twitter_2017-07-14_10h.json
# finish file:  2017-07-14/twitter_2017-07-14_15h.json
# finish file:  2017-07-14/twitter_2017-07-14_12h.json
# finish file:  2017-07-14/twitter_2017-07-14_09h.json
# finish file:  2017-07-14/twitter_2017-07-14_13h.json
# finish file:  2017-07-14/twitter_2017-07-14_01h.json
# finish file:  2017-07-14/twitter_2017-07-14_19h.json
# finish file:  2017-07-14/twitter_2017-07-14_20h.json
# finish file:  2017-07-14/twitter_2017-07-14_04h.json
# finish file:  2017-07-14/twitter_2017-07-14_23h.json
# finish file:  2017-07-14/twitter_2017-07-14_14h.json
# finish file:  2017-07-14/twitter_2017-07-14_16h.json
# finish file:  2017-07-14/twitter_2017-07-14_22h.json
# finish file:  2017-07-14/twitter_2017-07-14_17h.json
# finish file:  2017-07-14/twitter_2017-07-14_05h.json
# finish file:  2017-07-14/twitter_2017-07-14_07h.json
# finish file:  2017-07-14/twitter_2017-07-14_18h.json
# finish file:  2017-07-14/twitter_2017-07-14_02h.json
# finish file:  2017-07-14/twitter_2017-07-14_08h.json
# finish file:  2017-07-14/twitter_2017-07-14_00h.json
# finish file:  2017-07-24/twitter_2017-07-24_21h.json
# finish file:  2017-07-24/twitter_2017-07-24_20h.json
# finish file:  2017-07-24/twitter_2017-07-24_18h.json
# finish file:  2017-07-24/twitter_2017-07-24_08h.json
# finish file:  2017-07-24/twitter_2017-07-24_12h.json
# finish file:  2017-07-24/twitter_2017-07-24_06h.json
# finish file:  2017-07-24/twitter_2017-07-24_07h.json
# finish file:  2017-07-24/twitter_2017-07-24_13h.json
# finish file:  2017-07-24/twitter_2017-07-24_01h.json
# finish file:  2017-07-24/twitter_2017-07-24_15h.json
# finish file:  2017-07-24/twitter_2017-07-24_02h.json
# finish file:  2017-07-24/twitter_2017-07-24_19h.json
# finish file:  2017-07-24/twitter_2017-07-24_23h.json
# finish file:  2017-07-24/twitter_2017-07-24_09h.json
# finish file:  2017-07-24/twitter_2017-07-24_04h.json
# finish file:  2017-07-24/twitter_2017-07-24_14h.json
# finish file:  2017-07-24/twitter_2017-07-24_11h.json
# finish file:  2017-07-24/twitter_2017-07-24_05h.json
# finish file:  2017-07-24/twitter_2017-07-24_00h.json
# finish file:  2017-07-24/twitter_2017-07-24_10h.json
# finish file:  2017-07-24/twitter_2017-07-24_22h.json
# finish file:  2017-07-24/twitter_2017-07-24_03h.json
# finish file:  2017-07-24/twitter_2017-07-24_16h.json
# finish file:  2017-07-24/twitter_2017-07-24_17h.json
# finish file:  2017-07-23/twitter_2017-07-23_18h.json
# finish file:  2017-07-23/twitter_2017-07-23_05h.json
# finish file:  2017-07-23/twitter_2017-07-23_22h.json
# finish file:  2017-07-23/twitter_2017-07-23_23h.json
# finish file:  2017-07-23/twitter_2017-07-23_21h.json
# finish file:  2017-07-23/twitter_2017-07-23_14h.json
# finish file:  2017-07-23/twitter_2017-07-23_00h.json
# finish file:  2017-07-23/twitter_2017-07-23_06h.json
# finish file:  2017-07-23/twitter_2017-07-23_04h.json
# finish file:  2017-07-23/twitter_2017-07-23_10h.json
# finish file:  2017-07-23/twitter_2017-07-23_07h.json
# finish file:  2017-07-23/twitter_2017-07-23_11h.json
# finish file:  2017-07-23/twitter_2017-07-23_03h.json
# finish file:  2017-07-23/twitter_2017-07-23_16h.json
# finish file:  2017-07-23/twitter_2017-07-23_08h.json
# finish file:  2017-07-23/twitter_2017-07-23_19h.json
# finish file:  2017-07-23/twitter_2017-07-23_20h.json
# finish file:  2017-07-23/twitter_2017-07-23_09h.json
# finish file:  2017-07-23/twitter_2017-07-23_17h.json
# finish file:  2017-07-23/twitter_2017-07-23_15h.json
# finish file:  2017-07-23/twitter_2017-07-23_02h.json
# finish file:  2017-07-23/twitter_2017-07-23_13h.json
# finish file:  2017-07-23/twitter_2017-07-23_12h.json
# finish file:  2017-07-23/twitter_2017-07-23_01h.json
# finish file:  2017-07-16/twitter_2017-07-16_23h.json
# finish file:  2017-07-16/twitter_2017-07-16_10h.json
# finish file:  2017-07-16/twitter_2017-07-16_07h.json
# finish file:  2017-07-16/twitter_2017-07-16_06h.json
# finish file:  2017-07-16/twitter_2017-07-16_19h.json
# finish file:  2017-07-16/twitter_2017-07-16_02h.json
# finish file:  2017-07-16/twitter_2017-07-16_17h.json
# finish file:  2017-07-16/twitter_2017-07-16_22h.json
# finish file:  2017-07-16/twitter_2017-07-16_08h.json
# finish file:  2017-07-16/twitter_2017-07-16_01h.json
# finish file:  2017-07-16/twitter_2017-07-16_16h.json
# finish file:  2017-07-16/twitter_2017-07-16_12h.json
# finish file:  2017-07-16/twitter_2017-07-16_15h.json
# finish file:  2017-07-16/twitter_2017-07-16_21h.json
# finish file:  2017-07-16/twitter_2017-07-16_09h.json
# finish file:  2017-07-16/twitter_2017-07-16_04h.json
# finish file:  2017-07-16/twitter_2017-07-16_03h.json
# finish file:  2017-07-16/twitter_2017-07-16_20h.json
# finish file:  2017-07-16/twitter_2017-07-16_18h.json
# finish file:  2017-07-16/twitter_2017-07-16_00h.json
# finish file:  2017-07-16/twitter_2017-07-16_11h.json
# finish file:  2017-07-16/twitter_2017-07-16_05h.json
# finish file:  2017-07-16/twitter_2017-07-16_13h.json
# finish file:  2017-07-16/twitter_2017-07-16_14h.json
# finish file:  2017-07-26/twitter_2017-07-26_19h.json
# finish file:  2017-07-26/twitter_2017-07-26_20h.json
# finish file:  2017-07-26/twitter_2017-07-26_23h.json
# finish file:  2017-07-26/twitter_2017-07-26_06h.json
# finish file:  2017-07-26/twitter_2017-07-26_00h.json
# finish file:  2017-07-26/twitter_2017-07-26_11h.json
# finish file:  2017-07-26/twitter_2017-07-26_12h.json
# finish file:  2017-07-26/twitter_2017-07-26_03h.json
# finish file:  2017-07-26/twitter_2017-07-26_13h.json
# finish file:  2017-07-26/twitter_2017-07-26_04h.json
# finish file:  2017-07-26/twitter_2017-07-26_08h.json
# finish file:  2017-07-26/twitter_2017-07-26_17h.json
# finish file:  2017-07-26/twitter_2017-07-26_01h.json
# finish file:  2017-07-26/twitter_2017-07-26_21h.json
# finish file:  2017-07-26/twitter_2017-07-26_10h.json
# finish file:  2017-07-26/twitter_2017-07-26_16h.json
# finish file:  2017-07-26/twitter_2017-07-26_02h.json
# finish file:  2017-07-26/twitter_2017-07-26_07h.json
# finish file:  2017-07-26/twitter_2017-07-26_05h.json
# finish file:  2017-07-26/twitter_2017-07-26_18h.json
# finish file:  2017-07-26/twitter_2017-07-26_22h.json
# finish file:  2017-07-26/twitter_2017-07-26_14h.json
# finish file:  2017-07-26/twitter_2017-07-26_15h.json
# finish file:  2017-07-05/twitter_2017-07-05_05h.json
# finish file:  2017-07-05/twitter_2017-07-05_04h.json
# finish file:  2017-07-05/twitter_2017-07-05_19h.json
# finish file:  2017-07-05/twitter_2017-07-05_07h.json
# finish file:  2017-07-05/twitter_2017-07-05_20h.json
# finish file:  2017-07-05/twitter_2017-07-05_13h.json
# finish file:  2017-07-05/twitter_2017-07-05_02h.json
# finish file:  2017-07-05/twitter_2017-07-05_11h.json
# finish file:  2017-07-05/twitter_2017-07-05_09h.json
# finish file:  2017-07-05/twitter_2017-07-05_08h.json
# finish file:  2017-07-05/twitter_2017-07-05_10h.json
# finish file:  2017-07-05/twitter_2017-07-05_16h.json
# finish file:  2017-07-05/twitter_2017-07-05_18h.json
# finish file:  2017-07-05/twitter_2017-07-05_03h.json
# finish file:  2017-07-05/twitter_2017-07-05_15h.json
# finish file:  2017-07-05/twitter_2017-07-05_12h.json
# finish file:  2017-07-05/twitter_2017-07-05_22h.json
# finish file:  2017-07-05/twitter_2017-07-05_21h.json
# finish file:  2017-07-05/twitter_2017-07-05_14h.json
# finish file:  2017-07-05/twitter_2017-07-05_00h.json
# finish file:  2017-07-05/twitter_2017-07-05_23h.json
# finish file:  2017-07-05/twitter_2017-07-05_17h.json
# finish file:  2017-07-05/twitter_2017-07-05_06h.json
# finish file:  2017-07-05/twitter_2017-07-05_01h.json
# finish file:  2017-07-06/twitter_2017-07-06_21h.json
# finish file:  2017-07-06/twitter_2017-07-06_20h.json
# finish file:  2017-07-06/twitter_2017-07-06_17h.json
# finish file:  2017-07-06/twitter_2017-07-06_16h.json
# finish file:  2017-07-06/twitter_2017-07-06_22h.json
# finish file:  2017-07-06/twitter_2017-07-06_01h.json
# finish file:  2017-07-06/twitter_2017-07-06_14h.json
# finish file:  2017-07-06/twitter_2017-07-06_23h.json
# finish file:  2017-07-06/twitter_2017-07-06_08h.json
# finish file:  2017-07-06/twitter_2017-07-06_03h.json
# finish file:  2017-07-06/twitter_2017-07-06_13h.json
# finish file:  2017-07-06/twitter_2017-07-06_15h.json
# finish file:  2017-07-06/twitter_2017-07-06_02h.json
# finish file:  2017-07-06/twitter_2017-07-06_18h.json
# finish file:  2017-07-06/twitter_2017-07-06_10h.json
# finish file:  2017-07-06/twitter_2017-07-06_19h.json
# finish file:  2017-07-06/twitter_2017-07-06_06h.json
# finish file:  2017-07-06/twitter_2017-07-06_07h.json
# finish file:  2017-07-06/twitter_2017-07-06_00h.json
# finish file:  2017-07-06/twitter_2017-07-06_12h.json
# finish file:  2017-07-06/twitter_2017-07-06_11h.json
# finish file:  2017-07-06/twitter_2017-07-06_05h.json
# finish file:  2017-07-06/twitter_2017-07-06_09h.json
# finish file:  2017-07-06/twitter_2017-07-06_04h.json
# Finished all the files.

# %%
# Count lines of each file above.
def countLinesOfFile(State_name, month):
    State_name = str(State_name)
    length_of_juliana_allState = len(
        open('/mnt/volume/result/State_DelawareLevel/juliana_all'+State_name+'_2017_'+month+'.json', 'rU').readlines())
    length_of_juliana_State_allECigarette = len(open(
        '/mnt/volume/result/State_DelawareLevel/juliana_'+State_name+'_allECigarette_2017_'+month+'_categoryKeyWord.json', 'rU').readlines())
    length_of_juliana_not_State_allECigarette = len(open(
        '/mnt/volume/result/State_DelawareLevel/juliana_not_'+State_name+'_allECigarette_2017_'+month+'_categoryKeyWord.json', 'rU').readlines())
    length_of_not_ECigarette_State_FileName = len(open(
        '/mnt/volume/result/State_DelawareLevel/juliana_not_ECigarette_'+State_name+'_2017_'+month+'_categoryKeyWord.json', 'rU').readlines())
    
    print('month: ', month)
    print('juliana_all'+State_name+': ', length_of_juliana_allState)
    print('juliana_'+State_name+'_allECigarette: ', length_of_juliana_State_allECigarette)
    print('juliana_not_'+State_name+'_allECigarette: ', length_of_juliana_not_State_allECigarette)
    print('juliana_not_ECigarette_'+State_name+': ', length_of_not_ECigarette_State_FileName)
    
#     print('Writing to file in disk ...')
    # Write in seperate file.
    with open('/mnt/volume/result/State_DelawareLevel/result_2017_'+State_name, "a", encoding="utf-8") as f:
        f.write(str('month: ') + str(month) +'\n')
        f.write(str('juliana_all'+State_name+': ') + str(length_of_juliana_allState) +'\n')
        f.write(str('juliana_'+State_name+'_allECigarette: ') + str(length_of_juliana_State_allECigarette) +'\n')
        f.write(str('juliana_not_'+State_name+'_allECigarette: ') + str(length_of_juliana_not_State_allECigarette) +'\n')
        f.write(str('juliana_not_ECigarette_'+State_name+': ') + str(length_of_not_ECigarette_State_FileName) +'\n')
    
    print('Finished writing to disk.')

# %%
# Count lines of each state files.
countLinesOfFile(State_name_1, month)
print('-------------------------')
countLinesOfFile(State_name_2, month)
print('-------------------------')
countLinesOfFile(State_name_3, month)
print('-------------------------')
countLinesOfFile(State_name_4, month)
print('-------------------------')
countLinesOfFile(State_name_5, month)
print('-------------------------')
# Out:
# /home/centos/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: 'U' mode is deprecated
#   """
# /home/centos/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: DeprecationWarning: 'U' mode is deprecated
#   import sys
# /home/centos/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: DeprecationWarning: 'U' mode is deprecated
#   if __name__ == '__main__':
# /home/centos/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: DeprecationWarning: 'U' mode is deprecated
#   # This is added back by InteractiveShellApp.init_path()
# month:  07
# juliana_allDelaware:  53764
# juliana_Delaware_allECigarette:  16
# juliana_not_Delaware_allECigarette:  13551
# juliana_not_ECigarette_Delaware:  53748
# Finished writing to disk.
# -------------------------
# month:  07
# juliana_allNewJersey:  1114713
# juliana_NewJersey_allECigarette:  290
# juliana_not_NewJersey_allECigarette:  13277
# juliana_not_ECigarette_NewJersey:  1114423
# Finished writing to disk.
# -------------------------
# month:  07
# juliana_allPennsylvania:  1066400
# juliana_Pennsylvania_allECigarette:  300
# juliana_not_Pennsylvania_allECigarette:  13267
# juliana_not_ECigarette_Pennsylvania:  1066100
# Finished writing to disk.
# -------------------------
# month:  07
# juliana_allMaryland:  913206
# juliana_Maryland_allECigarette:  151
# juliana_not_Maryland_allECigarette:  13416
# juliana_not_ECigarette_Maryland:  913055
# Finished writing to disk.
# -------------------------
# month:  07
# juliana_allD.C.:  416015
# juliana_D.C._allECigarette:  77
# juliana_not_D.C._allECigarette:  13490
# juliana_not_ECigarette_D.C.:  415938
# Finished writing to disk.
# -------------------------

# %%
# # Write in seperate file.
# with open('/mnt/volume/result/State/result_2017_'+month, "w", encoding="utf-8") as f:
#     f.write(str('month: ') + str(month) +'\n')
#     f.write(str('juliana_allCalifornia: ') + str(length_of_juliana_allCalifornia) +'\n')
#     f.write(str('juliana_California_allECigarette: ') + str(length_of_juliana_California_allECigarette) +'\n')
#     f.write(str('juliana_not_California_allECigarette: ') + str(length_of_juliana_not_California_allECigarette) +'\n')
#     f.write(str('juliana_not_ECigarette_California: ') + str(length_of_not_ECigarette_California_FileName) +'\n')

# # Write in a file.
# with open('/mnt/volume/result/State/result_2017_total', "a", encoding="utf-8") as f:
#     f.write(str('month: ') + str(month) +'\n')
#     f.write(str('juliana_allCalifornia: ') + str(length_of_juliana_allCalifornia) +'\n')
#     f.write(str('juliana_California_allECigarette: ') + str(length_of_juliana_California_allECigarette) +'\n')
#     f.write(str('juliana_not_California_allECigarette: ') + str(length_of_juliana_not_California_allECigarette) +'\n')
#     f.write(str('juliana_not_ECigarette_California: ') + str(length_of_not_ECigarette_California_FileName) +'\n')
