# %%
import os
# os.chdir('C:/Users/eddie/Desktop/Prof. Rumi Chunara/alcohol')
import json
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer 
import re

# %%
# month_list = ['01','02','03','04','05','06','07','08','09','10','11','12']
month_list = ['04','05','06','07','08','09','10','11','12']
month_list_2 = ['01','02','03','04','05','06','07','08','09','10','11','12']
month_list_3 = ['01','02','03','04','05','06','07','08','09','10','11','12']
month_list_4 = ['01','02','03','04']

# %%
# sentiment analysis
def analyzeSentimentByVader(texts):
    positive_text = [[],[]]
    neutral_text = [[],[]]
    negative_text = [[],[]]
    
#     score_total = []    

    analyzer = SentimentIntensityAnalyzer()
    for sentence in texts:
        vs = analyzer.polarity_scores(sentence)
    #     print("{:*<65} {}".format(sentence, str(vs)))
    #     print('------------------------')
#         print(vs)
        if vs['compound'] >= 0.05:
#             print(vs['compound'])
            positive_text[0].append(sentence)
            positive_text[1].append(vs)
        elif vs['compound'] <= 0.05 and vs['compound'] > -0.05:
#             print(vs['compound'])
            neutral_text[0].append(sentence)
            neutral_text[1].append(vs)
        elif vs['compound'] <= -0.05:
#             print(vs['compound'])
            negative_text[0].append(sentence)
            negative_text[1].append(vs)
#         score_total.append(vs)

    return positive_text, neutral_text, negative_text

# %%
# text with link.

# text_in_month = []

# filePath = '/mnt/volume/result/'
# for month in month_list:
#     user_month = set()
#     fileName = 'juliana_allSF_tobacco_2016_'+month+'.json'
#     file = filePath + fileName
#     with open(file, "r") as f:
#         everyLines = f.readlines()
#         print('length of tweets in month %s: %d' % (month, len(everyLines)))
#         for line in everyLines:
#             try:
#                 lineInJson = json.loads(line)
#             except:
#                 print('Cannot load the line: ', line)
#             textInLine = lineInJson["text"]
# #             print(textInLine)
#             text_in_month.append(textInLine)
    
#     # get sentiment
#     positive_text, neutral_text, negative_text = analyzeSentimentByVader(text_in_month)
#     print('How many positive text: ', len(positive_text[0]))
#     print('How many neutral text: ', len(neutral_text[0]))
#     print('How many negative text: ', len(negative_text[0]))

#     break

# %% [markdown]
# What if I remove the link within the text?

# %%
# text without link.

# for sentence in text_in_month:
#     tt = re.sub('https?:\/\/t\.co\/[\s\S]{10}', '', sentence)
#     print(sentence)
#     print('--------------')
#     print(tt)
#     print('*********************')

    

num_positive_in_total = []
num_neutral_in_total = []
num_negative_in_total = []


filePath = '/mnt/volume/result/'
for month in month_list:
    text_in_month = []
    user_month = set()
    fileName = 'juliana_allSF_flavored_tobacco_2016_'+month+'.json'
    file = filePath + fileName
    with open(file, "r") as f:
        everyLines = f.readlines()
        print('length of tweets in month %s: %d' % (month, len(everyLines)))
        for line in everyLines:
            try:
                lineInJson = json.loads(line)
            except:
                print('Cannot load the line: ', line)
            textInLine = lineInJson["text"]
#             print(textInLine)
            textAfterRE = re.sub('https?:\/\/t\.co\/[\s\S]{10}', '', textInLine)
            text_in_month.append(textAfterRE)
    
    # get sentiment
    positive_text, neutral_text, negative_text = analyzeSentimentByVader(text_in_month)
    num_positive = len(positive_text[0])
    num_neutral = len(neutral_text[0])
    num_negative = len(negative_text[0])
    
    num_positive_in_total.append(num_positive)
    num_neutral_in_total.append(num_neutral)
    num_negative_in_total.append(num_negative)
    
    print('How many positive text: ', num_positive)
    print('How many neutral text: ', num_neutral)
    print('How many negative text: ', num_negative)
    print('--------------------')

    
for month in month_list_2:
    text_in_month = []
    user_month = set()
    fileName = 'juliana_allSF_flavored_tobacco_2017_'+month+'.json'
    file = filePath + fileName
    with open(file, "r") as f:
        everyLines = f.readlines()
        print('length of tweets in month %s: %d' % (month, len(everyLines)))
        for line in everyLines:
            try:
                lineInJson = json.loads(line)
            except:
                print('Cannot load the line: ', line)
            textInLine = lineInJson["text"]
#             print(textInLine)
            textAfterRE = re.sub('https?:\/\/t\.co\/[\s\S]{10}', '', textInLine)
            text_in_month.append(textAfterRE)
    
    # get sentiment
    positive_text, neutral_text, negative_text = analyzeSentimentByVader(text_in_month)
    num_positive = len(positive_text[0])
    num_neutral = len(neutral_text[0])
    num_negative = len(negative_text[0])
    
    num_positive_in_total.append(num_positive)
    num_neutral_in_total.append(num_neutral)
    num_negative_in_total.append(num_negative)
    
    print('How many positive text: ', num_positive)
    print('How many neutral text: ', num_neutral)
    print('How many negative text: ', num_negative)
    print('--------------------')
    

for month in month_list_3:
    text_in_month = []
    user_month = set()
    fileName = 'juliana_allSF_flavored_tobacco_2018_'+month+'.json'
    file = filePath + fileName
    with open(file, "r") as f:
        everyLines = f.readlines()
        print('length of tweets in month %s: %d' % (month, len(everyLines)))
        for line in everyLines:
            try:
                lineInJson = json.loads(line)
            except:
                print('Cannot load the line: ', line)
            textInLine = lineInJson["text"]
#             print(textInLine)
            textAfterRE = re.sub('https?:\/\/t\.co\/[\s\S]{10}', '', textInLine)
            text_in_month.append(textAfterRE)
    
    # get sentiment
    positive_text, neutral_text, negative_text = analyzeSentimentByVader(text_in_month)
    num_positive = len(positive_text[0])
    num_neutral = len(neutral_text[0])
    num_negative = len(negative_text[0])
    
    num_positive_in_total.append(num_positive)
    num_neutral_in_total.append(num_neutral)
    num_negative_in_total.append(num_negative)
    
    print('How many positive text: ', num_positive)
    print('How many neutral text: ', num_neutral)
    print('How many negative text: ', num_negative)
    print('--------------------')
    
for month in month_list_4:
    text_in_month = []
    user_month = set()
    fileName = 'juliana_allSF_flavored_tobacco_2019_'+month+'.json'
    file = filePath + fileName
    with open(file, "r") as f:
        everyLines = f.readlines()
        print('length of tweets in month %s: %d' % (month, len(everyLines)))
        for line in everyLines:
            try:
                lineInJson = json.loads(line)
            except:
                print('Cannot load the line: ', line)
            textInLine = lineInJson["text"]
#             print(textInLine)
            textAfterRE = re.sub('https?:\/\/t\.co\/[\s\S]{10}', '', textInLine)
            text_in_month.append(textAfterRE)
    
    # get sentiment
    positive_text, neutral_text, negative_text = analyzeSentimentByVader(text_in_month)
    num_positive = len(positive_text[0])
    num_neutral = len(neutral_text[0])
    num_negative = len(negative_text[0])
    
    num_positive_in_total.append(num_positive)
    num_neutral_in_total.append(num_neutral)
    num_negative_in_total.append(num_negative)
    
    print('How many positive text: ', num_positive)
    print('How many neutral text: ', num_neutral)
    print('How many negative text: ', num_negative)
    print('--------------------')
# Out:
# length of tweets in month 04: 97
# How many positive text:  22
# How many neutral text:  68
# How many negative text:  7
# --------------------
# length of tweets in month 05: 77
# How many positive text:  21
# How many neutral text:  50
# How many negative text:  6
# --------------------
# length of tweets in month 06: 69
# How many positive text:  13
# How many neutral text:  49
# How many negative text:  7
# --------------------
# length of tweets in month 07: 85
# How many positive text:  21
# How many neutral text:  61
# How many negative text:  3
# --------------------
# length of tweets in month 08: 75
# How many positive text:  16
# How many neutral text:  51
# How many negative text:  8
# --------------------
# length of tweets in month 09: 71
# How many positive text:  15
# How many neutral text:  44
# How many negative text:  12
# --------------------
# length of tweets in month 10: 62
# How many positive text:  20
# How many neutral text:  37
# How many negative text:  5
# --------------------
# length of tweets in month 11: 45
# How many positive text:  15
# How many neutral text:  26
# How many negative text:  4
# --------------------
# length of tweets in month 12: 57
# How many positive text:  11
# How many neutral text:  38
# How many negative text:  8
# --------------------
# length of tweets in month 01: 61
# How many positive text:  13
# How many neutral text:  42
# How many negative text:  6
# --------------------
# length of tweets in month 02: 52
# How many positive text:  13
# How many neutral text:  36
# How many negative text:  3
# --------------------
# length of tweets in month 03: 53
# How many positive text:  17
# How many neutral text:  33
# How many negative text:  3
# --------------------
# length of tweets in month 04: 56
# How many positive text:  16
# How many neutral text:  32
# How many negative text:  8
# --------------------
# length of tweets in month 05: 60
# How many positive text:  18
# How many neutral text:  38
# How many negative text:  4
# --------------------
# length of tweets in month 06: 44
# How many positive text:  18
# How many neutral text:  20
# How many negative text:  6
# --------------------
# length of tweets in month 07: 42
# How many positive text:  12
# How many neutral text:  28
# How many negative text:  2
# --------------------
# length of tweets in month 08: 56
# How many positive text:  11
# How many neutral text:  38
# How many negative text:  7
# --------------------
# length of tweets in month 09: 35
# How many positive text:  10
# How many neutral text:  20
# How many negative text:  5
# --------------------
# length of tweets in month 10: 27
# How many positive text:  8
# How many neutral text:  16
# How many negative text:  3
# --------------------
# length of tweets in month 11: 51
# How many positive text:  9
# How many neutral text:  34
# How many negative text:  8
# --------------------
# length of tweets in month 12: 31
# How many positive text:  9
# How many neutral text:  18
# How many negative text:  4
# --------------------
# length of tweets in month 01: 44
# How many positive text:  11
# How many neutral text:  25
# How many negative text:  8
# --------------------
# length of tweets in month 02: 45
# How many positive text:  12
# How many neutral text:  25
# How many negative text:  8
# --------------------
# length of tweets in month 03: 40
# How many positive text:  7
# How many neutral text:  24
# How many negative text:  9
# --------------------
# length of tweets in month 04: 35
# How many positive text:  6
# How many neutral text:  22
# How many negative text:  7
# --------------------
# length of tweets in month 05: 32
# How many positive text:  5
# How many neutral text:  17
# How many negative text:  10
# --------------------
# length of tweets in month 06: 38
# How many positive text:  7
# How many neutral text:  27
# How many negative text:  4
# --------------------
# length of tweets in month 07: 51
# How many positive text:  7
# How many neutral text:  38
# How many negative text:  6
# --------------------
# length of tweets in month 08: 54
# How many positive text:  14
# How many neutral text:  36
# How many negative text:  4
# --------------------
# length of tweets in month 09: 56
# How many positive text:  11
# How many neutral text:  41
# How many negative text:  4
# --------------------
# length of tweets in month 10: 40
# How many positive text:  9
# How many neutral text:  29
# How many negative text:  2
# --------------------
# length of tweets in month 11: 38
# How many positive text:  7
# How many neutral text:  25
# How many negative text:  6
# --------------------
# length of tweets in month 12: 33
# How many positive text:  8
# How many neutral text:  21
# How many negative text:  4
# --------------------
# length of tweets in month 01: 42
# How many positive text:  11
# How many neutral text:  24
# How many negative text:  7
# --------------------
# length of tweets in month 02: 36
# How many positive text:  12
# How many neutral text:  19
# How many negative text:  5
# --------------------
# length of tweets in month 03: 48
# How many positive text:  8
# How many neutral text:  30
# How many negative text:  10
# --------------------
# length of tweets in month 04: 43
# How many positive text:  9
# How many neutral text:  30
# How many negative text:  4
# --------------------

# %%
num_positive_in_total
# Out:
# [22,
#  21,
#  13,
#  21,
#  16,
#  15,
#  20,
#  15,
#  11,
#  13,
#  13,
#  17,
#  16,
#  18,
#  18,
#  12,
#  11,
#  10,
#  8,
#  9,
#  9,
#  11,
#  12,
#  7,
#  6,
#  5,
#  7,
#  7,
#  14,
#  11,
#  9,
#  7,
#  8,
#  11,
#  12,
#  8,
#  9]

# %%
num_neutral_in_total
# Out:
# [68,
#  50,
#  49,
#  61,
#  51,
#  44,
#  37,
#  26,
#  38,
#  42,
#  36,
#  33,
#  32,
#  38,
#  20,
#  28,
#  38,
#  20,
#  16,
#  34,
#  18,
#  25,
#  25,
#  24,
#  22,
#  17,
#  27,
#  38,
#  36,
#  41,
#  29,
#  25,
#  21,
#  24,
#  19,
#  30,
#  30]

# %%
num_negative_in_total
# Out:
# [7,
#  6,
#  7,
#  3,
#  8,
#  12,
#  5,
#  4,
#  8,
#  6,
#  3,
#  3,
#  8,
#  4,
#  6,
#  2,
#  7,
#  5,
#  3,
#  8,
#  4,
#  8,
#  8,
#  9,
#  7,
#  10,
#  4,
#  6,
#  4,
#  4,
#  2,
#  6,
#  4,
#  7,
#  5,
#  10,
#  4]

# %%
# print the neutral text and corresponding score
# for index in range(len(neutral_text[0])):
#     print(neutral_text[0][index])
#     print(neutral_text[1][index])
#     print('--------------------')
