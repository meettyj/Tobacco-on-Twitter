# %% [markdown]
# Here we do some keyword adjustment based on the result filter by filterFlavor_allCity.ipynb.

# %%
import os
# os.chdir('C:/Users/eddie/Desktop/Prof. Rumi Chunara/alcohol')
import json
import pandas as pd
import re

# %%
# Flavor keyword with some space included.
fruit_flavor_ecig = ['blueberry', 'pomegranate', 'strawberry', ' orange', 'candy,', 'grapefruit', 'kiwi', 'guave', 
                     'lemonade', 'apple', 'mango ', ' peach ', 'pineapple', 'raspberry', 'mint ', 'lemon', 
                     'grape', 'watermelon', 'fruit', 'citrus', 'lime', 'banana', 'coconut', 'berry', 'dragon fruit'
                     'melon', 'cherry', 'menthol']
candy_and_desert_flavor_ecig = ['vanilla', 'gummy', 'cotton candy', 'butterscotch', 'candy cane', 'caramel', 
                                ' tart', 'cheesecake', 'cinnamon roll', 'macaron', 'cream', 'cookie', 'cake']
beverage_flavor_ecig = ['coffee', 'espresso', 'milk', 'cracker', 'mocha', 'cappuccino', 'cocoa']
others_flavor_ecig = ['flavor', 'pod'] # 'eon pod', 'cali pod', 'sea pod', 'ziip pod', 

# flavor_ecig.extend(fruit_flavor_ecig)
# not_flavor_ecig = ['smoky', 'smoked']

# %%
# State_name = 'Kansas'
month_list = ['04','05','06','07','08','09','10','11','12']
month_list_2 = ['01','02','03','04','05','06','07','08','09','10','11','12']
month_list_3 = ['01','02','03','04','05','06','07','08','09','10','11','12']
month_list_4 = ['01','02','03','04']
# State_name = 'NewJersey'
# monthList = ['04','05','06']

# %%
def checkFlavorECigaretteInLine(line):
    try:
        lineInJson = json.loads(line)
    except:
        print('Cannot load the line: ', line)
        return False
    textInLine = lineInJson["text"]
#     print(textInLine)
    textAfterRE = re.sub('https?:\/\/t\.co\/[\s\S]{10}', '', textInLine)
    lowercaseLine = textAfterRE.lower()
#     print('----')
#     print(lowercaseLine)
#     print('*******************')
    
    # test for synonym
#     if 'smok' not in lowercaseLine:
#         return 0
#     else:
#     for not_flavor_keyword in not_flavor_ecig:
#         if not_flavor_keyword in lowercaseLine:
#             return 0

    # have flavor keywords list
    for fruit_flavor_keyword in fruit_flavor_ecig:
        if fruit_flavor_keyword in lowercaseLine:
            return 1
    for candy_and_desert_flavor_keyword in candy_and_desert_flavor_ecig:
        if candy_and_desert_flavor_keyword in lowercaseLine:
            return 2
    for beverage_flavor_keyword in beverage_flavor_ecig:
        if beverage_flavor_keyword in lowercaseLine:
            return 3
    for others_flavor_keyword in others_flavor_ecig:
        if others_flavor_keyword in lowercaseLine:
            return 4

    return 0

# %%
def checkECigaretteOfEachLineInFile_version_2(fileName, year, month):


    
    fruit_flavor_list = []
    candy_and_desert_flavor_list = []
    beverage_flavor_list = []
    others_flavor_list = []

    allFlavor_list = []
    length_of_tobacco = 0
    
    with open(fileName, "r") as f:
        everyLines = f.readlines()
        length_of_tobacco = len(everyLines)
#         print('length of this file: ', length_of_tobacco)
        for line in everyLines:
           
            # Filter out those e-cig flavor
            status = checkFlavorECigaretteInLine(line)
            if status == 0:
                continue
            elif status == 1:
                fruit_flavor_list.append(line)
            elif status == 2:
                candy_and_desert_flavor_list.append(line)    
            elif status == 3:
                beverage_flavor_list.append(line)
            elif status == 4:
                others_flavor_list.append(line)
    
    # remove duplication
    fruit_flavor_set = list(set(fruit_flavor_list))
    candy_and_desert_flavor_set = list(set(candy_and_desert_flavor_list))
    beverage_flavor_set = list(set(beverage_flavor_list))
    others_flavor_set = list(set(others_flavor_list))
    
    # output the result
#     print('length of fruit_flavor_set: ', len(fruit_flavor_set))
#     print('length of candy_and_desert_flavor_set: ', len(candy_and_desert_flavor_set))
#     print('length of beverage_flavor_set: ', len(beverage_flavor_set))
#     print('length of others_flavor_set: ', len(others_flavor_set))
    
    flavored_tobacco_total = []
    flavored_tobacco_total.extend(fruit_flavor_set)
    flavored_tobacco_total.extend(candy_and_desert_flavor_set)
    flavored_tobacco_total.extend(beverage_flavor_set)
    flavored_tobacco_total.extend(others_flavor_set)
        
    # Write flavored tobacco data to local file
    all_Flavored_tobacco_FileName = '/mnt/volume/result/juliana_allSF_flavored_tobacco_'+year+'_'+str(month)+'.json'
    with open(all_Flavored_tobacco_FileName, "w", encoding="utf-8") as f:
        for line in flavored_tobacco_total:
            f.write(str(line))
    
    length_of_flavored_tobacco = len(flavored_tobacco_total)
#     print('flavored tobacco: ', length_of_flavored_tobacco)
    return length_of_tobacco, length_of_flavored_tobacco
    
    # output the specific information
#     print('*******************************')
#     print('fruit_flavor_set: ')
#     for i in fruit_flavor_set:
#         lineInJson = json.loads(i)
#         textInLine = lineInJson["text"]
#         textAfterRE = re.sub('https?:\/\/t\.co\/[\s\S]{10}', '', textInLine)
#         print(textAfterRE)
#         print('---------------------')
        
#     print('*******************************')
#     print('candy_and_desert_flavor_set: ')
#     for i in candy_and_desert_flavor_set:
#         lineInJson = json.loads(i)
#         textInLine = lineInJson["text"]
#         textAfterRE = re.sub('https?:\/\/t\.co\/[\s\S]{10}', '', textInLine)
#         print(textAfterRE)
#         print('---------------------')
    
#     print('*******************************')
#     print('beverage_flavor_set: ')
#     for i in beverage_flavor_set:
#         lineInJson = json.loads(i)
#         textInLine = lineInJson["text"]
#         textAfterRE = re.sub('https?:\/\/t\.co\/[\s\S]{10}', '', textInLine)
#         print(textAfterRE)
#         print('---------------------')
    
#     print('*******************************')
#     print('others_flavor_set: ')
#     for i in others_flavor_set:
#         lineInJson = json.loads(i)
#         textInLine = lineInJson["text"]
#         textAfterRE = re.sub('https?:\/\/t\.co\/[\s\S]{10}', '', textInLine)
#         print(textAfterRE)
#         print('---------------------')

# %%
# Run experiments on Kansa data to test the flavor keyword list.

# resulrDirectoryPath = "/mnt/volume/result"

# os.chdir(resulrDirectoryPath)


os.chdir('/mnt/volume/result/')
# os.chdir('/mnt/volume/result/State_NewJerseyLevel/')

# tobacco_list = []
flavored_list = []

# Deal with flavor.
for month in month_list:
    year = str(2016)
    after_FlavorList_month = []

    fileName = 'juliana_allSF_tobacco_'+year+'_'+str(month) + '.json'
#     print('Processing: ', fileName)
    
    length_of_tobacco, length_of_flavored_tobacco = checkECigaretteOfEachLineInFile_version_2(fileName, year, month)
    print('Month: ', month)
    print('length of tobacco: ', length_of_tobacco)
    print('length of flavored: ', length_of_flavored_tobacco)
    flavored_list.append(length_of_flavored_tobacco)

for month in month_list_2:
    after_FlavorList_month = []
    year = str(2017)
    fileName = 'juliana_allSF_tobacco_'+year+'_'+str(month) + '.json'
#     print('Processing: ', fileName)
    
    length_of_tobacco, length_of_flavored_tobacco = checkECigaretteOfEachLineInFile_version_2(fileName, year, month)
    print('Month: ', month)
    print('length of tobacco: ', length_of_tobacco)
    print('length of flavored: ', length_of_flavored_tobacco)
    flavored_list.append(length_of_flavored_tobacco)  
    
    
for month in month_list_3:
    after_FlavorList_month = []
    year = str(2018)
    fileName = 'juliana_allSF_tobacco_'+year+'_'+str(month) + '.json'
#     print('Processing: ', fileName)
    
    length_of_tobacco, length_of_flavored_tobacco = checkECigaretteOfEachLineInFile_version_2(fileName, year, month)
    print('Month: ', month)
    print('length of tobacco: ', length_of_tobacco)
    print('length of flavored: ', length_of_flavored_tobacco)
    flavored_list.append(length_of_flavored_tobacco)  
    
    
for month in month_list_4:
    after_FlavorList_month = []
    year = str(2019)
    fileName = 'juliana_allSF_tobacco_'+year+'_'+str(month) + '.json'
#     print('Processing: ', fileName)
    
    length_of_tobacco, length_of_flavored_tobacco = checkECigaretteOfEachLineInFile_version_2(fileName, year, month)
    print('Month: ', month)
    print('length of tobacco: ', length_of_tobacco)
    print('length of flavored: ', length_of_flavored_tobacco)
    flavored_list.append(length_of_flavored_tobacco)  
    
    
    
    
    
print('flavored_list: ', flavored_list)
# Out:
# Month:  04
# length of tobacco:  907
# length of flavored:  97
# Month:  05
# length of tobacco:  930
# length of flavored:  77
# Month:  06
# length of tobacco:  974
# length of flavored:  69
# Month:  07
# length of tobacco:  899
# length of flavored:  85
# Month:  08
# length of tobacco:  888
# length of flavored:  75
# Month:  09
# length of tobacco:  710
# length of flavored:  71
# Month:  10
# length of tobacco:  775
# length of flavored:  62
# Month:  11
# length of tobacco:  731
# length of flavored:  45
# Month:  12
# length of tobacco:  663
# length of flavored:  57
# Month:  01
# length of tobacco:  626
# length of flavored:  61
# Month:  02
# length of tobacco:  571
# length of flavored:  52
# Month:  03
# length of tobacco:  619
# length of flavored:  53
# Month:  04
# length of tobacco:  588
# length of flavored:  56
# Month:  05
# length of tobacco:  570
# length of flavored:  60
# Month:  06
# length of tobacco:  580
# length of flavored:  44
# Month:  07
# ...

# %% [markdown]
# -----------------------------------
# Besides, we can still see if there are any tweets within the result of e-cigarette are relevant to flavor.

# %%
# os.chdir('/mnt/volume/result/State_KansasLevel/')
# # os.chdir('/mnt/volume/result/State_NewJerseyLevel/')

# for month in monthList:
#     after_FlavorList_month = []
    
#     fileName = 'juliana_'+State_name+'_allECigarette_2017_' + str(month) + '_categoryKeyWord.json'
# #     fileName = 'juliana_'+State_name+'_allECigarette_2018_' + str(month) + '_categoryKeyWord.json'
#     print('Processing: ', fileName)
    
#     checkECigaretteOfEachLineInFile_version_2(fileName, month, State_name)
#     print('finish file: ', fileName)
#     print('&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&')
