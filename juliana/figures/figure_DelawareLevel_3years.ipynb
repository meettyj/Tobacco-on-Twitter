# %%
import matplotlib.pyplot as plt
import numpy as np

from scipy import optimize

# %%
import datetime

import matplotlib as mpl
 
fig = plt.figure()
 
start = datetime.datetime(2016, 1, 1)
end = datetime.datetime(2017, 1, 1)
# 设置日期的间隔为1
delta = datetime.timedelta(days= 29)
 
# 生成一个matplotlib可以识别的日期对象
dates = mpl.dates.drange(start, end, delta)

print(dates)

date_format = mpl.dates.DateFormatter("%Y-%m")
print(date_format)
# Out:
# [735964. 735993. 736022. 736051. 736080. 736109. 736138. 736167. 736196.
#  736225. 736254. 736283. 736312.]
# ...

# %%
# Number

# ----------------------------- Delaware -----------------------------
# Delaware_allECigarette
Delaware_allECigarette = [9, 29, 23, 28, 9, 15, 13, 15, 6, 7, 6, 13, 5, 5, 9, 16, 5, 10, 7, 17, 17, 17, 12, 13, 23, 15, 32,23, 28, 12, 17, 22, 17, 13, 13, 20, 14]
print('length of Delaware_allECigarette: ', len(Delaware_allECigarette))

# not_Delaware_allECigarette
not_Delaware_allECigarette = [22777, 24578, 21228, 23651, 20208, 16283, 17593, 16738, 16409, 18032, 13818, 14752, 14272, 13075, 13612, 13551, 14084, 6923, 9338, 15622, 15664, 17339, 15397, 17309, 17225, 15527, 16271,18847, 17370, 19156, 15090, 19037, 17653, 18683, 16282, 13668, 13312]
print('length of not_Delaware_allECigarette: ', len(not_Delaware_allECigarette))

# allECigarette
allECigarette = []
for i in range(37):
    allECigarette.append(Delaware_allECigarette[i]+not_Delaware_allECigarette[i])
print('length of allECigarette: ', len(allECigarette))


# allDelaware
allDelaware = [99731, 101037, 95872, 90802, 92265, 87661, 96660, 93238, 77539, 82828, 66600, 66786, 59285, 53608, 52341, 53764, 56830, 26115, 39980, 55502, 47932, 56502, 52335, 62645, 62067, 56398, 49702,53516, 49699, 61044, 48584, 53582, 48999, 52770, 44956, 34793, 38503]
print('length of allDelaware: ', len(allDelaware))


# Number of users that tweets ecig in Delaware.
users_Delaware_ecig = [9, 14, 15, 19, 8, 12, 11, 14, 5, 7, 6, 11, 5, 5, 9, 13, 5, 10, 6, 15, 15, 15, 11, 12, 14, 13, 14,14, 22, 12, 16, 10, 15, 13, 10, 15, 11]
print('length of users_Delaware_ecig: ', len(users_Delaware_ecig))


# average number of per person tweets about ecig in Delaware.
average_num_per_person_tweets_Delaware_ecig = []
for i in range(37):
    average_num_per_person_tweets_Delaware_ecig.append(Delaware_allECigarette[i]/users_Delaware_ecig[i])
print('length of average_num_per_person_tweets_Delaware_ecig: ', len(average_num_per_person_tweets_Delaware_ecig))


# Number of users that tweets in Delaware
users_Delaware = [5547, 6712, 8319, 8558, 8052, 5770, 6015, 5592, 5117,4687, 4309, 4484, 4555, 4827, 5676, 6128, 6001, 3244, 3621, 4531, 4326, 3694, 3806, 4239, 4162, 4430, 4755,5226, 4789, 4304, 3907, 3890, 3770, 3269, 3231, 3164, 2950]
print('length of users_Delaware: ', len(users_Delaware))

# average number of per person tweets in Delaware.
average_num_per_person_tweets_Delaware = []
for i in range(37):
    average_num_per_person_tweets_Delaware.append(allDelaware[i]/users_Delaware[i])
print('length of average_num_per_person_tweets_Delaware: ', len(average_num_per_person_tweets_Delaware))

# allTweets
allTweets = [70798094, 76153908, 77039352, 79730585, 75060717, 63144176, 68592777, 68306197, 60640789, 64761879, 49292002, 51379810, 46841051, 45592367, 46897952, 50163222, 51079160, 22112648, 31365136, 46232294, 43487766, 46059070, 40432909, 47289301, 45660765, 44166238, 44212483, 45858463, 39900707, 45395994, 37985764, 42937313, 41362576, 44209494, 38750216, 32702554, 33860264]
print('length of allTweets: ', len(allTweets))

# Sentiment analysis
vader_positive_Delaware = [3, 12, 5, 13, 3, 4, 6, 5, 0,3, 2, 4, 2, 2, 3, 6, 2, 0, 2, 4, 3, 5, 1, 5, 5, 9, 8, 6, 13, 2, 6, 5, 4, 5, 4, 6, 3]
vader_neutral_Delaware = [3, 12, 14, 11, 5, 7, 3, 6, 5, 2, 4, 7, 3, 2, 5, 8, 1, 7, 1, 8, 9, 10, 7, 3, 12, 3, 20, 15, 12, 6, 8, 4, 8, 5, 7, 8, 7]
vader_negative_Delaware = [3, 5, 4, 4, 1, 4, 4, 4, 1,2, 0, 2, 0, 1, 1, 2, 2, 3, 4, 5, 5, 2, 4, 5, 6, 3, 4,2, 3, 4, 3, 13, 5, 3, 2, 6, 4]
print('length of vader_positive_Delaware: ', len(vader_positive_Delaware))
print('length of vader_neutral_Delaware: ', len(vader_neutral_Delaware))
print('length of vader_negative_Delaware: ', len(vader_negative_Delaware))

print('----------------------------------')
# ----------------------------- NewJersey -----------------------------

# NewJersey_allECigarette
NewJersey_allECigarette = [421, 520, 471, 509, 437, 315, 365, 351, 288, 336, 280, 364, 256, 291, 310, 290, 318, 159, 230, 379, 407, 431, 515, 352, 394, 377, 464,718, 522, 317, 310, 313, 327, 297, 247, 220, 189]
print('length of NewJersey_allECigarette: ', len(NewJersey_allECigarette))


# allNewJersey
allNewJersey = [1640985, 1831517, 1849522, 1965775, 1815107, 1437392, 1527071, 1535928, 1363440, 1444572, 1076167, 1140128, 1005554, 999074, 1048626, 1114713, 1124508, 456279, 662423, 975345, 972957, 1020021, 863451, 994925, 950771, 901259, 936500,987062, 831611, 912493, 796119, 883162, 871125, 926252, 795728, 678771, 687775]
print('length of allNewJersey: ', len(allNewJersey))


# Number of users that tweets ecig in NewJersey.
users_NewJersey_ecig = [289, 361, 339, 342, 273, 208, 226, 211, 196,203, 173, 221, 176, 176, 206, 200, 235, 118, 144, 252, 235, 291, 270, 253, 247, 242, 269,298, 215, 250, 191, 244, 240, 243, 204, 179, 146]
print('length of users_NewJersey_ecig: ', len(users_NewJersey_ecig))


# average number of per person tweets about ecig in NewJersey.
average_num_per_person_tweets_NewJersey_ecig = []
for i in range(37):
    average_num_per_person_tweets_NewJersey_ecig.append(NewJersey_allECigarette[i]/users_NewJersey_ecig[i])
print('length of average_num_per_person_tweets_NewJersey_ecig: ', len(average_num_per_person_tweets_NewJersey_ecig))


# Number of users that tweets in NewJersey
users_NewJersey = [77022, 85994, 96261, 105613, 95283, 76686, 78880, 79642, 74867,70472, 62031, 65919, 65308, 69170, 74451, 79201, 76977, 46205, 54198, 67462, 67514, 59971, 56012, 63296, 61237, 59945, 66088,70886, 63909, 61401, 53816, 58553, 58506, 52533, 48259, 47165, 44841]
print('length of users_NewJersey: ', len(users_NewJersey))

# average number of per person tweets in NewJersey.
average_num_per_person_tweets_NewJersey = []
for i in range(37):
    average_num_per_person_tweets_NewJersey.append(allNewJersey[i]/users_NewJersey[i])
print('length of average_num_per_person_tweets_NewJersey: ', len(average_num_per_person_tweets_NewJersey))

# Sentiment analysis
vader_positive_NewJersey = [136, 181, 147, 152, 137, 94, 114, 121, 97,121, 102, 115, 109, 85, 111, 93, 108, 44, 58, 98, 141, 138, 124, 102, 110, 107, 134,212, 121, 111, 98, 106, 102, 96, 78, 62, 70]
vader_neutral_NewJersey = [206, 243, 229, 260, 206, 157, 185, 178, 149,144, 128, 172, 108, 144, 137, 139, 127, 89, 133, 217, 206, 196, 321, 174, 209, 203, 244,395, 314, 146, 134, 121, 148, 120, 110, 96, 86]
vader_negative_NewJersey = [79, 96, 95, 97, 94, 64, 66, 52, 42,71, 50, 77, 39, 62, 62, 58, 83, 26, 39, 64, 60, 97, 70, 76, 75, 67, 86,111, 87, 60, 78, 86, 77, 81, 59, 62, 33]
print('length of vader_positive_NewJersey: ', len(vader_positive_NewJersey))
print('length of vader_neutral_NewJersey: ', len(vader_neutral_NewJersey))
print('length of vader_negative_NewJersey: ', len(vader_negative_NewJersey))



print('----------------------------------')
# ----------------------------- Pennsylvania -----------------------------

# Pennsylvania_allECigarette
Pennsylvania_allECigarette = [608, 551, 448, 566, 461, 468, 404, 344, 306,301, 240, 255, 256, 221, 217, 300, 285, 177, 246, 429, 473, 468, 540, 473, 448, 345, 362,383, 349, 711, 433, 570, 437, 506, 495, 411, 667]
print('length of Pennsylvania_allECigarette: ', len(Pennsylvania_allECigarette))


# allPennsylvania
allPennsylvania = [1789157, 1814176, 1743177, 1823654, 1723617, 1577605, 1690383, 1657002, 1446995, 1536200, 1184100, 1177434, 1101369, 1042755, 1031138, 1066400, 1117120, 503333, 743855, 1088504, 1040445, 1115812, 1014250, 1081833, 1074942, 963058, 927204,985919, 868872, 1048747, 847043, 975967, 992347, 1092174, 945646, 783152, 811483]
print('length of allPennsylvania: ', len(allPennsylvania))


# Number of users that tweets ecig in Pennsylvania.
users_Pennsylvania_ecig = [403, 373, 307, 391, 333, 313, 293, 259, 232,225, 174, 210, 208, 178, 165, 190, 193, 121, 175, 300, 300, 323, 337, 310, 352, 282, 269,276, 263, 362, 276, 334, 320, 321, 272, 199, 229]
print('length of users_Pennsylvania_ecig: ', len(users_Pennsylvania_ecig))


# average number of per person tweets about ecig in Pennsylvania.
average_num_per_person_tweets_Pennsylvania_ecig = []
for i in range(37):
    average_num_per_person_tweets_Pennsylvania_ecig.append(Pennsylvania_allECigarette[i]/users_Pennsylvania_ecig[i])
print('length of average_num_per_person_tweets_Pennsylvania_ecig: ', len(average_num_per_person_tweets_Pennsylvania_ecig))


# Number of users that tweets in Pennsylvania
users_Pennsylvania = [88676, 90074, 94320, 99925, 94028, 88266, 91999, 90135, 82334,78742, 72819, 75114, 75989, 73545, 72275, 74318, 76297, 52856, 62347, 76226, 72069, 67390, 67943, 70107, 70020, 64301, 65451,67932, 64035, 68726, 62597, 65962, 64809, 58783, 56594, 54897, 50568]
print('length of users_Pennsylvania: ', len(users_Pennsylvania))

# average number of per person tweets in Pennsylvania.
average_num_per_person_tweets_Pennsylvania = []
for i in range(37):
    average_num_per_person_tweets_Pennsylvania.append(allPennsylvania[i]/users_Pennsylvania[i])
print('length of average_num_per_person_tweets_Pennsylvania: ', len(average_num_per_person_tweets_Pennsylvania))

# Sentiment analysis
vader_positive_Pennsylvania = [182, 167, 158, 195, 156, 177, 137, 129, 106,87, 84, 78, 85, 67, 86, 97, 109, 62, 76, 143, 163, 171, 181, 161, 122, 98, 96,123, 119, 139, 146, 141, 132, 158, 121, 85, 91]
vader_neutral_Pennsylvania = [325, 293, 215, 294, 214, 221, 194, 151, 148,153, 113, 123, 121, 121, 95, 151, 134, 78, 114, 208, 213, 199, 232, 228, 247, 163, 176,172, 155, 451, 200, 307, 195, 245, 290, 277, 522]
vader_negative_Pennsylvania = [101, 91, 75, 77, 91, 70, 73, 64, 52,61, 43, 54, 50, 33, 36, 52, 42, 37, 56, 78, 97, 98, 127, 84, 79, 84, 90,88, 75, 121, 87, 122, 110, 103, 84, 49, 54]
print('length of vader_positive_Pennsylvania: ', len(vader_positive_Pennsylvania))
print('length of vader_neutral_Pennsylvania: ', len(vader_neutral_Pennsylvania))
print('length of vader_negative_Pennsylvania: ', len(vader_negative_Pennsylvania))


print('----------------------------------')
# ----------------------------- Maryland -----------------------------

# Maryland_allECigarette
Maryland_allECigarette = [381, 330, 266, 360, 340, 267, 251, 269, 239,310, 177, 160, 165, 127, 148, 151, 147, 72, 99, 202, 196, 243, 191, 229, 243, 206, 241,256, 222, 230, 184, 266, 236, 245, 280, 206, 196]
print('length of Maryland_allECigarette: ', len(Maryland_allECigarette))


# allMaryland
allMaryland = [1336293, 1527105, 1455242, 1466647, 1372734, 1100402, 1200834, 1270371, 1165689, 1201569, 888383, 929124, 832248, 838373, 860648, 913206, 910536, 375999, 543010, 821829, 807107, 820085, 696106, 837322, 817365, 848671, 815445,825020, 704656, 814361, 675225, 783357, 789550, 824539, 700529, 559635, 585748]
print('length of allMaryland: ', len(allMaryland))


# Number of users that tweets ecig in Maryland.
users_Maryland_ecig = [180, 201, 152, 231, 179, 135, 133, 151, 121,140, 111, 119, 123, 96, 116, 116, 122, 60, 75, 165, 165, 200, 151, 181, 176, 169, 190,199, 160, 182, 144, 196, 178, 195, 194, 128, 130]
print('length of users_Maryland_ecig: ', len(users_Maryland_ecig))


# average number of per person tweets about ecig in Maryland.
average_num_per_person_tweets_Maryland_ecig = []
for i in range(37):
    average_num_per_person_tweets_Maryland_ecig.append(Maryland_allECigarette[i]/users_Maryland_ecig[i])
print('length of average_num_per_person_tweets_Maryland_ecig: ', len(average_num_per_person_tweets_Maryland_ecig))


# Number of users that tweets in Maryland
users_Maryland = [52890, 56856, 61771, 64392, 61229, 51890, 53662, 54115, 51635,50816, 43913, 46441, 46621, 47776, 50047, 52472, 52172, 32874, 38400, 48576, 45742, 41852, 40300, 46474, 45044, 44801, 48064,49120, 44624, 44605, 40522, 44459, 43044, 39977, 37018, 36482, 34020]
print('length of users_Maryland: ', len(users_Maryland))

# average number of per person tweets in Maryland.
average_num_per_person_tweets_Maryland = []
for i in range(37):
    average_num_per_person_tweets_Maryland.append(allMaryland[i]/users_Maryland[i])
print('length of average_num_per_person_tweets_Maryland: ', len(average_num_per_person_tweets_Maryland))

# Sentiment analysis
vader_positive_Maryland = [118, 106, 86, 121, 133, 95, 102, 98, 97,125, 72, 61, 58, 42, 50, 44, 60, 29, 23, 65, 57, 85, 56, 78, 87, 77, 61,81, 69, 66, 55, 77, 74, 87, 101, 51, 58]
vader_neutral_Maryland = [197, 163, 137, 185, 145, 124, 112, 116, 108,139, 71, 76, 75, 64, 72, 70, 59, 24, 51, 88, 92, 111, 83, 110, 103, 85, 119,113, 92, 119, 86, 113, 99, 100, 113, 118, 88]
vader_negative_Maryland = [66, 61, 43, 54, 62, 48, 37, 55, 34, 46, 34, 23, 32, 21, 26, 37, 28, 19, 25, 49, 47, 47, 52, 41, 53, 44, 61, 62, 61, 45, 43, 76, 63, 58, 66, 37, 50]
print('length of vader_positive_Maryland: ', len(vader_positive_Maryland))
print('length of vader_neutral_Maryland: ', len(vader_neutral_Maryland))
print('length of vader_negative_Maryland: ', len(vader_negative_Maryland))


print('----------------------------------')
# ----------------------------- DC -----------------------------

# DC_allECigarette
DC_allECigarette = [85, 101, 120, 87, 60, 62, 101, 80, 107, 88, 73, 98, 86, 149, 60, 77, 82, 38, 36, 75, 58, 80, 64, 98, 155, 118, 84,108, 117, 109, 106, 114, 127, 97, 93, 94, 110]
print('length of DC_allECigarette: ', len(DC_allECigarette))


# allDC
allDC = [495712, 489237, 528290, 526050, 478299, 452592, 507273, 505881, 416684, 561879, 418441, 446522, 425394, 403578, 415853, 416015, 405251, 184175, 279285, 393599, 323480, 377268, 332743, 399649, 386906, 357477, 378537,382960, 327654, 381864, 326346, 361666, 339518, 397796, 353538, 308972, 340837]
print('length of allDC: ', len(allDC))


# Number of users that tweets ecig in DC.
users_DC_ecig = [68, 76, 76, 74, 55, 42, 66, 58, 55, 56, 51, 63, 66, 64, 55, 54, 67, 36, 33, 59, 48, 60, 50, 70, 86, 83, 63, 71, 67, 74, 59, 75, 62, 53, 70, 59, 64]
print('length of users_DC_ecig: ', len(users_DC_ecig))


# average number of per person tweets about ecig in DC.
average_num_per_person_tweets_DC_ecig = []
for i in range(37):
    average_num_per_person_tweets_DC_ecig.append(DC_allECigarette[i]/users_DC_ecig[i])
print('length of average_num_per_person_tweets_DC_ecig: ', len(average_num_per_person_tweets_DC_ecig))


# Number of users that tweets in DC
users_DC = [37449, 35711, 39215, 39180, 34580, 34581, 37051, 36896, 31891,47629, 32477, 37703, 37248, 34376, 35986, 35488, 32560, 21064, 27727, 33955, 28311, 28878, 27560, 36587, 34803, 30131, 33677,33165, 28191, 30745, 29287, 29969, 27471, 27855, 26338, 27991, 27209]
print('length of users_DC: ', len(users_DC))

# average number of per person tweets in DC.
average_num_per_person_tweets_DC = []
for i in range(37):
    average_num_per_person_tweets_DC.append(allDC[i]/users_DC[i])
print('length of average_num_per_person_tweets_DC: ', len(average_num_per_person_tweets_DC))

# Sentiment analysis
vader_positive_DC = [30, 39, 39, 30, 16, 23, 28, 13, 24, 33, 29, 30, 32, 51, 27, 30, 20, 12, 15, 29, 18, 25, 13, 30, 52, 40, 28, 42, 57, 45, 42, 43, 35, 39, 35, 35, 36]
vader_neutral_DC = [40, 44, 59, 37, 34, 26, 56, 49, 54, 36, 29, 52, 38, 60, 28, 38, 42, 15, 18, 41, 24, 43, 39, 53, 72, 54, 39, 41, 42, 47, 32, 42, 69, 39, 38, 37, 40]
vader_negative_DC = [15, 18, 22, 20, 10, 13, 17, 18, 29, 19, 15, 16, 16, 38, 5, 9, 20, 11, 3, 5, 16, 12, 12, 15, 31, 24, 17, 25, 18, 17, 32, 29, 23, 19, 20, 22, 34]
print('length of vader_positive_DC: ', len(vader_positive_DC))
print('length of vader_neutral_DC: ', len(vader_neutral_DC))
print('length of vader_negative_DC: ', len(vader_negative_DC))
# Out:
# length of Delaware_allECigarette:  37
# length of not_Delaware_allECigarette:  37
# length of allECigarette:  37
# length of allDelaware:  37
# length of users_Delaware_ecig:  37
# length of average_num_per_person_tweets_Delaware_ecig:  37
# length of users_Delaware:  37
# length of average_num_per_person_tweets_Delaware:  37
# length of allTweets:  37
# length of vader_positive_Delaware:  37
# length of vader_neutral_Delaware:  37
# length of vader_negative_Delaware:  37
# ----------------------------------
# length of NewJersey_allECigarette:  37
# length of allNewJersey:  37
# length of users_NewJersey_ecig:  37
# length of average_num_per_person_tweets_NewJersey_ecig:  37
# length of users_NewJersey:  37
# length of average_num_per_person_tweets_NewJersey:  37
# length of vader_positive_NewJersey:  37
# length of vader_neutral_NewJersey:  37
# length of vader_negative_NewJersey:  37
# ----------------------------------
# length of Pennsylvania_allECigarette:  37
# ...

# %%
# Propotion

# ----------------------------- Delaware -----------------------------
propotion_Delaware_ecig_in_all_ecig = []
propotion_Delaware_ecig_in_all_Delaware_tweets = []
propotion_Delaware_in_all_tweets = []
propotion_Delaware_ecig_users_in_all_Delaware_users = []
propotion_positive_ecig_Delaware = []
propotion_neutral_ecig_Delaware = []
propotion_negative_ecig_Delaware = []


# propotion of Delaware e-cig tweets in all e-cig tweets.
for i in range(37):
    propotion_Delaware_ecig_in_all_ecig.append((Delaware_allECigarette[i]/allECigarette[i])*100)
print('length of propotion_Delaware_ecig_in_all_ecig: ', len(propotion_Delaware_ecig_in_all_ecig))


# propotion of Delaware e-cig tweets in all Delaware tweets.
for i in range(37):
    propotion_Delaware_ecig_in_all_Delaware_tweets.append((Delaware_allECigarette[i]/allDelaware[i])*100)
print('length of propotion_Delaware_ecig_in_all_Delaware_tweets: ', len(propotion_Delaware_ecig_in_all_Delaware_tweets))


# propotion of Delaware tweets in total tweets.
for i in range(37):
    propotion_Delaware_in_all_tweets.append((allDelaware[i]/allTweets[i])*100)
print('length of propotion_Delaware_in_all_tweets: ', len(propotion_Delaware_in_all_tweets))


# propotion of users post Delaware e-cig in all Delaware users.
for i in range(37):
    propotion_Delaware_ecig_users_in_all_Delaware_users.append((users_Delaware_ecig[i]/users_Delaware[i])*100)
print('length of propotion_Delaware_ecig_users_in_all_Delaware_users: ', len(propotion_Delaware_ecig_users_in_all_Delaware_users))


# Sentiment analysis
for i in range(37):
    propotion_positive_ecig_Delaware.append((vader_positive_Delaware[i]/Delaware_allECigarette[i])*100)
print('length of propotion_positive_ecig_Delaware: ', len(propotion_positive_ecig_Delaware))

for i in range(37):
    propotion_neutral_ecig_Delaware.append((vader_neutral_Delaware[i]/Delaware_allECigarette[i])*100)
print('length of propotion_neutral_ecig_Delaware: ', len(propotion_neutral_ecig_Delaware))

for i in range(37):
    propotion_negative_ecig_Delaware.append((vader_negative_Delaware[i]/Delaware_allECigarette[i])*100)
print('length of propotion_negative_ecig_Delaware: ', len(propotion_negative_ecig_Delaware))


print('----------------------------------')
# ----------------------------- NewJersey -----------------------------
propotion_NewJersey_ecig_in_all_ecig = []
propotion_NewJersey_ecig_in_all_NewJersey_tweets = []
propotion_NewJersey_in_all_tweets = []
propotion_NewJersey_ecig_users_in_all_NewJersey_users = []
propotion_positive_ecig_NewJersey = []
propotion_neutral_ecig_NewJersey = []
propotion_negative_ecig_NewJersey = []


# propotion of NewJersey e-cig tweets in all e-cig tweets.
for i in range(37):
    propotion_NewJersey_ecig_in_all_ecig.append((NewJersey_allECigarette[i]/allECigarette[i])*100)
print('length of propotion_NewJersey_ecig_in_all_ecig: ', len(propotion_NewJersey_ecig_in_all_ecig))


# propotion of NewJersey e-cig tweets in all NewJersey tweets.
for i in range(37):
    propotion_NewJersey_ecig_in_all_NewJersey_tweets.append((NewJersey_allECigarette[i]/allNewJersey[i])*100)
print('length of propotion_NewJersey_ecig_in_all_NewJersey_tweets: ', len(propotion_NewJersey_ecig_in_all_NewJersey_tweets))


# propotion of NewJersey tweets in total tweets.
for i in range(37):
    propotion_NewJersey_in_all_tweets.append((allNewJersey[i]/allTweets[i])*100)
print('length of propotion_NewJersey_in_all_tweets: ', len(propotion_NewJersey_in_all_tweets))


# propotion of users post NewJersey e-cig in all NewJersey users.
for i in range(37):
    propotion_NewJersey_ecig_users_in_all_NewJersey_users.append((users_NewJersey_ecig[i]/users_NewJersey[i])*100)
print('length of propotion_NewJersey_ecig_users_in_all_NewJersey_users: ', len(propotion_NewJersey_ecig_users_in_all_NewJersey_users))


# Sentiment analysis
for i in range(37):
    propotion_positive_ecig_NewJersey.append((vader_positive_NewJersey[i]/NewJersey_allECigarette[i])*100)
print('length of propotion_positive_ecig_NewJersey: ', len(propotion_positive_ecig_NewJersey))

for i in range(37):
    propotion_neutral_ecig_NewJersey.append((vader_neutral_NewJersey[i]/NewJersey_allECigarette[i])*100)
print('length of propotion_neutral_ecig_NewJersey: ', len(propotion_neutral_ecig_NewJersey))

for i in range(37):
    propotion_negative_ecig_NewJersey.append((vader_negative_NewJersey[i]/NewJersey_allECigarette[i])*100)
print('length of propotion_negative_ecig_NewJersey: ', len(propotion_negative_ecig_NewJersey))


print('----------------------------------')
# ----------------------------- Pennsylvania -----------------------------
propotion_Pennsylvania_ecig_in_all_ecig = []
propotion_Pennsylvania_ecig_in_all_Pennsylvania_tweets = []
propotion_Pennsylvania_in_all_tweets = []
propotion_Pennsylvania_ecig_users_in_all_Pennsylvania_users = []
propotion_positive_ecig_Pennsylvania = []
propotion_neutral_ecig_Pennsylvania = []
propotion_negative_ecig_Pennsylvania = []


# propotion of Pennsylvania e-cig tweets in all e-cig tweets.
for i in range(37):
    propotion_Pennsylvania_ecig_in_all_ecig.append((Pennsylvania_allECigarette[i]/allECigarette[i])*100)
print('length of propotion_Pennsylvania_ecig_in_all_ecig: ', len(propotion_Pennsylvania_ecig_in_all_ecig))


# propotion of Pennsylvania e-cig tweets in all Pennsylvania tweets.
for i in range(37):
    propotion_Pennsylvania_ecig_in_all_Pennsylvania_tweets.append((Pennsylvania_allECigarette[i]/allPennsylvania[i])*100)
print('length of propotion_Pennsylvania_ecig_in_all_Pennsylvania_tweets: ', len(propotion_Pennsylvania_ecig_in_all_Pennsylvania_tweets))


# propotion of Pennsylvania tweets in total tweets.
for i in range(37):
    propotion_Pennsylvania_in_all_tweets.append((allPennsylvania[i]/allTweets[i])*100)
print('length of propotion_Pennsylvania_in_all_tweets: ', len(propotion_Pennsylvania_in_all_tweets))


# propotion of users post Pennsylvania e-cig in all Pennsylvania users.
for i in range(37):
    propotion_Pennsylvania_ecig_users_in_all_Pennsylvania_users.append((users_Pennsylvania_ecig[i]/users_Pennsylvania[i])*100)
print('length of propotion_Pennsylvania_ecig_users_in_all_Pennsylvania_users: ', len(propotion_Pennsylvania_ecig_users_in_all_Pennsylvania_users))


# Sentiment analysis
for i in range(37):
    propotion_positive_ecig_Pennsylvania.append((vader_positive_Pennsylvania[i]/Pennsylvania_allECigarette[i])*100)
print('length of propotion_positive_ecig_Pennsylvania: ', len(propotion_positive_ecig_Pennsylvania))

for i in range(37):
    propotion_neutral_ecig_Pennsylvania.append((vader_neutral_Pennsylvania[i]/Pennsylvania_allECigarette[i])*100)
print('length of propotion_neutral_ecig_Pennsylvania: ', len(propotion_neutral_ecig_Pennsylvania))

for i in range(37):
    propotion_negative_ecig_Pennsylvania.append((vader_negative_Pennsylvania[i]/Pennsylvania_allECigarette[i])*100)
print('length of propotion_negative_ecig_Pennsylvania: ', len(propotion_negative_ecig_Pennsylvania))


print('----------------------------------')
# ----------------------------- Maryland -----------------------------
propotion_Maryland_ecig_in_all_ecig = []
propotion_Maryland_ecig_in_all_Maryland_tweets = []
propotion_Maryland_in_all_tweets = []
propotion_Maryland_ecig_users_in_all_Maryland_users = []
propotion_positive_ecig_Maryland = []
propotion_neutral_ecig_Maryland = []
propotion_negative_ecig_Maryland = []


# propotion of Maryland e-cig tweets in all e-cig tweets.
for i in range(37):
    propotion_Maryland_ecig_in_all_ecig.append((Maryland_allECigarette[i]/allECigarette[i])*100)
print('length of propotion_Maryland_ecig_in_all_ecig: ', len(propotion_Maryland_ecig_in_all_ecig))


# propotion of Maryland e-cig tweets in all Maryland tweets.
for i in range(37):
    propotion_Maryland_ecig_in_all_Maryland_tweets.append((Maryland_allECigarette[i]/allMaryland[i])*100)
print('length of propotion_Maryland_ecig_in_all_Maryland_tweets: ', len(propotion_Maryland_ecig_in_all_Maryland_tweets))


# propotion of Maryland tweets in total tweets.
for i in range(37):
    propotion_Maryland_in_all_tweets.append((allMaryland[i]/allTweets[i])*100)
print('length of propotion_Maryland_in_all_tweets: ', len(propotion_Maryland_in_all_tweets))


# propotion of users post Maryland e-cig in all Maryland users.
for i in range(37):
    propotion_Maryland_ecig_users_in_all_Maryland_users.append((users_Maryland_ecig[i]/users_Maryland[i])*100)
print('length of propotion_Maryland_ecig_users_in_all_Maryland_users: ', len(propotion_Maryland_ecig_users_in_all_Maryland_users))


# Sentiment analysis
for i in range(37):
    propotion_positive_ecig_Maryland.append((vader_positive_Maryland[i]/Maryland_allECigarette[i])*100)
print('length of propotion_positive_ecig_Maryland: ', len(propotion_positive_ecig_Maryland))

for i in range(37):
    propotion_neutral_ecig_Maryland.append((vader_neutral_Maryland[i]/Maryland_allECigarette[i])*100)
print('length of propotion_neutral_ecig_Maryland: ', len(propotion_neutral_ecig_Maryland))

for i in range(37):
    propotion_negative_ecig_Maryland.append((vader_negative_Maryland[i]/Maryland_allECigarette[i])*100)
print('length of propotion_negative_ecig_Maryland: ', len(propotion_negative_ecig_Maryland))


print('----------------------------------')
# ----------------------------- DC -----------------------------
propotion_DC_ecig_in_all_ecig = []
propotion_DC_ecig_in_all_DC_tweets = []
propotion_DC_in_all_tweets = []
propotion_DC_ecig_users_in_all_DC_users = []
propotion_positive_ecig_DC = []
propotion_neutral_ecig_DC = []
propotion_negative_ecig_DC = []


# propotion of DC e-cig tweets in all e-cig tweets.
for i in range(37):
    propotion_DC_ecig_in_all_ecig.append((DC_allECigarette[i]/allECigarette[i])*100)
print('length of propotion_DC_ecig_in_all_ecig: ', len(propotion_DC_ecig_in_all_ecig))


# propotion of DC e-cig tweets in all DC tweets.
for i in range(37):
    propotion_DC_ecig_in_all_DC_tweets.append((DC_allECigarette[i]/allDC[i])*100)
print('length of propotion_DC_ecig_in_all_DC_tweets: ', len(propotion_DC_ecig_in_all_DC_tweets))


# propotion of DC tweets in total tweets.
for i in range(37):
    propotion_DC_in_all_tweets.append((allDC[i]/allTweets[i])*100)
print('length of propotion_DC_in_all_tweets: ', len(propotion_DC_in_all_tweets))


# propotion of users post DC e-cig in all DC users.
for i in range(37):
    propotion_DC_ecig_users_in_all_DC_users.append((users_DC_ecig[i]/users_DC[i])*100)
print('length of propotion_DC_ecig_users_in_all_DC_users: ', len(propotion_DC_ecig_users_in_all_DC_users))


# Sentiment analysis
for i in range(37):
    propotion_positive_ecig_DC.append((vader_positive_DC[i]/DC_allECigarette[i])*100)
print('length of propotion_positive_ecig_DC: ', len(propotion_positive_ecig_DC))

for i in range(37):
    propotion_neutral_ecig_DC.append((vader_neutral_DC[i]/DC_allECigarette[i])*100)
print('length of propotion_neutral_ecig_DC: ', len(propotion_neutral_ecig_DC))

for i in range(37):
    propotion_negative_ecig_DC.append((vader_negative_DC[i]/DC_allECigarette[i])*100)
print('length of propotion_negative_ecig_DC: ', len(propotion_negative_ecig_DC))
# Out:
# length of propotion_Delaware_ecig_in_all_ecig:  37
# length of propotion_Delaware_ecig_in_all_Delaware_tweets:  37
# length of propotion_Delaware_in_all_tweets:  37
# length of propotion_Delaware_ecig_users_in_all_Delaware_users:  37
# length of propotion_positive_ecig_Delaware:  37
# length of propotion_neutral_ecig_Delaware:  37
# length of propotion_negative_ecig_Delaware:  37
# ----------------------------------
# length of propotion_NewJersey_ecig_in_all_ecig:  37
# length of propotion_NewJersey_ecig_in_all_NewJersey_tweets:  37
# length of propotion_NewJersey_in_all_tweets:  37
# length of propotion_NewJersey_ecig_users_in_all_NewJersey_users:  37
# length of propotion_positive_ecig_NewJersey:  37
# length of propotion_neutral_ecig_NewJersey:  37
# length of propotion_negative_ecig_NewJersey:  37
# ----------------------------------
# length of propotion_Pennsylvania_ecig_in_all_ecig:  37
# length of propotion_Pennsylvania_ecig_in_all_Pennsylvania_tweets:  37
# ...

# %% [markdown]
# ---------------------------------
# Draw Figures.

# %%
def linearRegression(x, A, B):
    return A*x + B

# %%
# Regression line
length_of_section_1 = 12+9
length_of_section_2 = length_of_section_1+6+6+4
x_number_section_1 = [i for i in range(0,length_of_section_1)]
x_number_section_2 = [i for i in range(length_of_section_1, length_of_section_2)]


def drawRegressionLine_two_section(y, color):
#     print('y: ', y)
#     print('section 1: ', y[:length_of_section_1])
#     print('section 2: ', y[length_of_section_1:length_of_section_2])
    
    # section 1
    popt_1, pcov_1 = optimize.curve_fit(linearRegression, x_number_section_1, y[:length_of_section_1])
    A_section_1, B_section_1 = popt_1
    x_plot_section_1 = np.arange(0, length_of_section_1, 0.01)
    y_plot_section_1 = A_section_1 * x_plot_section_1 + B_section_1
    plt.plot(x_plot_section_1, y_plot_section_1, color+'-') # , label='Users' is useless
    # Calculate the R square
    residuals_1 = y[:length_of_section_1]- linearRegression(np.asarray(x_number_section_1), *[float(A_section_1), float(B_section_1)])
    ss_res_1 = np.sum(residuals_1**2)
    ss_tot_1 = np.sum((y[:length_of_section_1]-np.mean(y[:length_of_section_1]))**2)
    r_squared_1 = 1 - (ss_res_1 / ss_tot_1)
#     print('section 1 slope: ', A_section_1)
#     print('section 1 R^2: ', r_squared_1)

    # section 2: length_of_section_1-1:length_of_section_2
    popt_2, pcov_2 = optimize.curve_fit(linearRegression, x_number_section_2, y[length_of_section_1:length_of_section_2])
    A_section_2, B_section_2 = popt_2
    x_plot_section_2 = np.arange(length_of_section_1, length_of_section_2-1, 0.01)
    y_plot_section_2 = A_section_2 * x_plot_section_2 + B_section_2
    plt.plot(x_plot_section_2, y_plot_section_2, color+'-')
    # Calculate the R square
    residuals_2 = y[length_of_section_1:length_of_section_2]- linearRegression(np.asarray(x_number_section_2), *[float(A_section_2), float(B_section_2)])
    ss_res_2 = np.sum(residuals_2**2)
    ss_tot_2 = np.sum((y[length_of_section_1:length_of_section_2]-np.mean(y[length_of_section_1:length_of_section_2]))**2)
    r_squared_2 = 1 - (ss_res_2 / ss_tot_2)
#     print('section 2 slope: ', A_section_2)
#     print('section 2 R^2: ', r_squared_2)
    
    print('slope: ', [A_section_1, A_section_2])
    print('intercept: ', [B_section_1, B_section_2])
    print('R^2: ', [r_squared_1, r_squared_2])
    
    
#     print('--------------------------')
#     print()

# %%
x = ['2016-04','2016-05','2016-06','2016-07','2016-08','2016-09','2016-10','2016-11','2016-12', '2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12','2018-01','2018-02', '2018-03','2018-04','2018-05','2018-06','2018-07','2018-08','2018-09','2018-10','2018-11','2018-12','2019-01','2019-02', '2019-03','2019-04']

plt.figure(figsize=(14,7))

plt.plot(x, Delaware_allECigarette, 'rx', label='Delaware e-cigarette realated tweets')
plt.plot(x, NewJersey_allECigarette, 'gx', label='NewJersey e-cigarette realated tweets')
plt.plot(x, Pennsylvania_allECigarette, 'bx', label='Pennsylvania e-cigarette realated tweets')
plt.plot(x, Maryland_allECigarette, 'cx', label='Maryland e-cigarette realated tweets')
plt.plot(x, DC_allECigarette, 'mx', label='DC e-cigarette realated tweets')
# plt.plot(x, users_Delaware_ecig, 'yx', label='Users of Delaware e-cigarette tweets')


# plt.plot(x, average_num_per_persion_tweets_SF_ecig, 'm-', label='not first person')
plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(21, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(7,0.1))


print('Delaware:')
drawRegressionLine_two_section(Delaware_allECigarette, color='r')
print('NewJersey:')
drawRegressionLine_two_section(NewJersey_allECigarette, color='g')
print('Pennsylvania:')
drawRegressionLine_two_section(Pennsylvania_allECigarette, color='b')
print('Maryland:')
drawRegressionLine_two_section(Maryland_allECigarette, color='c')
print('DC:')
drawRegressionLine_two_section(DC_allECigarette, color='m')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for number of e-cigarette related tweets in different states by month. ')
# plt.figure(figsize=(40,1))
plt.show()


print('******************************************************')

# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


# plt.plot(x, Delaware_allECigarette, 'rx', label='Delaware e-cigarette realated tweets')
plt.plot(x, users_Delaware_ecig, 'rx', label='Users of Delaware e-cigarette tweets')
plt.plot(x, users_NewJersey_ecig, 'gx', label='Users of NewJersey e-cigarette tweets')
plt.plot(x, users_Pennsylvania_ecig, 'bx', label='Users of Pennsylvania e-cigarette tweets')
plt.plot(x, users_Maryland_ecig, 'cx', label='Users of Maryland e-cigarette tweets')
plt.plot(x, users_DC_ecig, 'mx', label='Users of DC e-cigarette tweets')
# plt.plot(x, average_num_per_persion_tweets_SF_ecig, 'm-', label='not first person')
plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(21, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(7,0.1))

print('Delaware:')
drawRegressionLine_two_section(users_Delaware_ecig, color='r')
print('NewJersey:')
drawRegressionLine_two_section(users_NewJersey_ecig, color='g')
print('Pennsylvania:')
drawRegressionLine_two_section(users_Pennsylvania_ecig, color='b')
print('Maryland:')
drawRegressionLine_two_section(users_Maryland_ecig, color='c')
print('DC:')
drawRegressionLine_two_section(users_DC_ecig, color='m')

plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for number of users that post e-cigarette related tweets in different states by month. ')
# plt.figure(figsize=(40,1))
plt.show()

print('******************************************************')

# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


# plt.plot(x, Delaware_allECigarette, 'rx', label='Delaware e-cigarette realated tweets')
plt.plot(x, average_num_per_person_tweets_Delaware_ecig, 'rx', label='Delaware ecig tweets per person')
plt.plot(x, average_num_per_person_tweets_NewJersey_ecig, 'gx', label='NewJersey ecig tweets per person')
plt.plot(x, average_num_per_person_tweets_Pennsylvania_ecig, 'bx', label='Pennsylvania ecig tweets per person')
plt.plot(x, average_num_per_person_tweets_Maryland_ecig, 'cx', label='Maryland ecig tweets per person')
plt.plot(x, average_num_per_person_tweets_DC_ecig, 'mx', label='DC ecig tweets per person')
# plt.plot(x, average_num_per_persion_tweets_SF_ecig, 'm-', label='not first person')
plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(21, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(7,0.1))

print('Delaware:')
drawRegressionLine_two_section(average_num_per_person_tweets_Delaware_ecig, color='r')
print('NewJersey:')
drawRegressionLine_two_section(average_num_per_person_tweets_NewJersey_ecig, color='g')
print('Pennsylvania:')
drawRegressionLine_two_section(average_num_per_person_tweets_Pennsylvania_ecig, color='b')
print('Maryland:')
drawRegressionLine_two_section(average_num_per_person_tweets_Maryland_ecig, color='c')
print('DC:')
drawRegressionLine_two_section(average_num_per_person_tweets_DC_ecig, color='m')

plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for average tweets number per person post e-cigarette related tweets in different states by month. ')
# plt.figure(figsize=(40,1))
plt.show()

print('******************************************************')

# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


plt.plot(x, allTweets, 'mx', label='All tweets that collected')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(21, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(7,0.1))

print('allTweets: ')
drawRegressionLine_two_section(allTweets, color='m')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for all tweets that collected from Twitter by month. ')
# plt.figure(figsize=(40,1))
plt.show()

print('******************************************************')

# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


plt.plot(x, allDelaware, 'rx', label='All tweets that collected in Delaware')
plt.plot(x, allNewJersey, 'gx', label='All tweets that collected in NewJersey')
plt.plot(x, allPennsylvania, 'bx', label='All tweets that collected in Pennsylvania')
plt.plot(x, allMaryland, 'cx', label='All tweets that collected in Maryland')
plt.plot(x, allDC, 'mx', label='All tweets that collected in DC')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(21, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(7,0.1))

print('Delaware:')
drawRegressionLine_two_section(allDelaware, color='r')
print('NewJersey:')
drawRegressionLine_two_section(allNewJersey, color='g')
print('Pennsylvania:')
drawRegressionLine_two_section(allPennsylvania, color='b')
print('Maryland:')
drawRegressionLine_two_section(allMaryland, color='c')
print('DC:')
drawRegressionLine_two_section(allDC, color='m')

plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for tweets that collected from Twitter in different states by month. ')
# plt.figure(figsize=(40,1))
plt.show()

print('******************************************************')
# Out:
# Delaware:
# slope:  [-0.4454545420521768, -0.14852941176721113]
# intercept:  [17.02597399195034, 22.420588235340844]
# R^2:  [0.14619141110393175, 0.01387900597963243]
# NewJersey:
# slope:  [-9.171428571450743, -17.686764705923125]
# intercept:  [439.19047619143174, 878.635294119562]
# R^2:  [0.39159437797947905, 0.40040124903589014]
# Pennsylvania:
# slope:  [-12.916883116913468, 6.276470588246798]
# intercept:  [488.9783549794192, 295.9955882359378]
# R^2:  [0.391837063540562, 0.07912993759986364]
# Maryland:
# slope:  [-11.98441558444391, 0.2882352941160914]
# intercept:  [341.6060606068034, 221.41029411812798]
# R^2:  [0.700190700509315, 0.0025221151207418524]
# DC:
# slope:  [-1.689610389616254, 0.679411764705184]
# intercept:  [98.94372294393652, 85.2617647060661]
# R^2:  [0.159555107406937, 0.02395453392560143]
# ******************************************************
# Delaware:
# slope:  [-0.14285714285963547, -0.0720588235317503]
# ...

# %% [markdown]
# ------------------------------------------------
# add after.

# %%
# Number of users
plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


plt.plot(x, users_Delaware, 'rx', label='Twitter users in Delaware')
plt.plot(x, users_NewJersey, 'gx', label='Twitter users in NewJersey')
plt.plot(x, users_Pennsylvania, 'bx', label='Twitter users in Pennsylvania')
plt.plot(x, users_Maryland, 'cx', label='Twitter users in Maryland')
plt.plot(x, users_DC, 'mx', label='Twitter users in DC')
# plt.plot(x, average_num_per_persion_tweets_SF_ecig, 'm-', label='not first person')
plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(21, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))


drawRegressionLine_two_section(users_Delaware, color='r')
drawRegressionLine_two_section(users_NewJersey, color='g')
drawRegressionLine_two_section(users_Pennsylvania, color='b')
drawRegressionLine_two_section(users_Maryland, color='c')
drawRegressionLine_two_section(users_DC, color='m')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for number of Twitter users in different states by month. ')
# plt.figure(figsize=(40,1))
plt.show()


# ----------------------------------------------------
# Number of state tweets per person
plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)

plt.plot(x, average_num_per_person_tweets_Delaware, 'rx', label='Delaware tweets per person')
plt.plot(x, average_num_per_person_tweets_NewJersey, 'gx', label='NewJersey tweets per person')
plt.plot(x, average_num_per_person_tweets_Pennsylvania, 'bx', label='Pennsylvania tweets per person')
plt.plot(x, average_num_per_person_tweets_Maryland, 'cx', label='Maryland tweets per person')
plt.plot(x, average_num_per_person_tweets_DC, 'mx', label='DC tweets per person')
# plt.plot(x, average_num_per_persion_tweets_SF_ecig, 'm-', label='not first person')
plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(21, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))


drawRegressionLine_two_section(average_num_per_person_tweets_Delaware, color='r')
drawRegressionLine_two_section(average_num_per_person_tweets_NewJersey, color='g')
drawRegressionLine_two_section(average_num_per_person_tweets_Pennsylvania, color='b')
drawRegressionLine_two_section(average_num_per_person_tweets_Maryland, color='c')
drawRegressionLine_two_section(average_num_per_person_tweets_DC, color='m')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for average tweets number per person post tweets in different states by month. ')
# plt.figure(figsize=(40,1))
plt.show()
# Out:
# slope:  [-158.59090882437715, -76.4970599996019]
# intercept:  [7113.0995630824655, 6154.291209576237]
# R^2:  [0.4629640819601962, 0.32206721403806615]
# slope:  [-1538.0415292108669, -1010.5441156071852]
# intercept:  [90102.12970736611, 86701.63229480477]
# R^2:  [0.48456001236225543, 0.4560503365174958]
# slope:  [-1554.6480522666795, -995.4514710289408]
# intercept:  [95658.57576264605, 92127.55442432482]
# R^2:  [0.6991553954295411, 0.6855561652542019]
# slope:  [-847.9298708531015, -548.3382341185144]
# intercept:  [59159.77489778526, 58153.01467237767]
# R^2:  [0.5128021713438807, 0.37985943597317073]
# slope:  [-447.42468105649164, -354.32793974569853]
# intercept:  [39287.48488743038, 40089.40878275241]
# R^2:  [0.2867596939300028, 0.30978653789595323]
# slope:  [-0.274271729509312, -0.05740868083472961]
# intercept:  [15.682908694321972, 14.763232232194873]
# R^2:  [0.3151733508861736, 0.022191245578722762]
# slope:  [-0.4442236747709445, -0.004332821076671323]
# ...

# %% [markdown]
# ----------------------------
#
# propotion

# %%
# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


plt.plot(x, propotion_Delaware_in_all_tweets, 'rx', label='Proportion of Delaware tweets in all tweets')
plt.plot(x, propotion_NewJersey_in_all_tweets, 'gx', label='Proportion of NewJersey tweets in all tweets')
plt.plot(x, propotion_Pennsylvania_in_all_tweets, 'bx', label='Proportion of Pennsylvania tweets in all tweets')
plt.plot(x, propotion_Maryland_in_all_tweets, 'cx', label='Proportion of Maryland tweets in all tweets')
plt.plot(x, propotion_DC_in_all_tweets, 'mx', label='Proportion of DC tweets in all tweets')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(21, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))

print('Delaware:')
drawRegressionLine_two_section(propotion_Delaware_in_all_tweets, color='r')
print('NewJersey:')
drawRegressionLine_two_section(propotion_NewJersey_in_all_tweets, color='g')
print('Pennsylvania:')
drawRegressionLine_two_section(propotion_Pennsylvania_in_all_tweets, color='b')
print('Maryland:')
drawRegressionLine_two_section(propotion_Maryland_in_all_tweets, color='c')
print('DC:')
drawRegressionLine_two_section(propotion_DC_in_all_tweets, color='m')

plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Proportion (%)')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Proportion of different states tweets in all tweets that collected from Twitter.')
# plt.figure(figsize=(40,1))
plt.show()




print('******************************************************')


# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


plt.plot(x, propotion_Delaware_ecig_in_all_ecig, 'rx', label='Proportion of Delaware ecig tweets in all ecig tweets')
plt.plot(x, propotion_NewJersey_ecig_in_all_ecig, 'gx', label='Proportion of NewJersey ecig tweets in all ecig tweets')
plt.plot(x, propotion_Pennsylvania_ecig_in_all_ecig, 'bx', label='Proportion of Pennsylvania ecig tweets in all ecig tweets')
plt.plot(x, propotion_Maryland_ecig_in_all_ecig, 'cx', label='Proportion of Maryland ecig tweets in all ecig tweets')
plt.plot(x, propotion_DC_ecig_in_all_ecig, 'mx', label='Proportion of DC ecig tweets in all ecig tweets')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(21, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))

print('Delaware:')
drawRegressionLine_two_section(propotion_Delaware_ecig_in_all_ecig, color='r')
print('NewJersey:')
drawRegressionLine_two_section(propotion_NewJersey_ecig_in_all_ecig, color='g')
print('Pennsylvania:')
drawRegressionLine_two_section(propotion_Pennsylvania_ecig_in_all_ecig, color='b')
print('Maryland:')
drawRegressionLine_two_section(propotion_Maryland_ecig_in_all_ecig, color='c')
print('DC:')
drawRegressionLine_two_section(propotion_DC_ecig_in_all_ecig, color='m')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Proportion (%)')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Proportion of different states e-cigarette tweets in all e-cigarette tweets that collected from Twitter.')
# plt.figure(figsize=(40,1))
plt.show()

print('******************************************************')

# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


plt.plot(x, propotion_Delaware_ecig_in_all_Delaware_tweets, 'rx', label='Proportion of Delaware ecig tweets in all Delaware tweets')
plt.plot(x, propotion_NewJersey_ecig_in_all_NewJersey_tweets, 'gx', label='Proportion of NewJersey ecig tweets in all NewJersey tweets')
plt.plot(x, propotion_Pennsylvania_ecig_in_all_Pennsylvania_tweets, 'bx', label='Proportion of Pennsylvania ecig tweets in all Pennsylvania tweets')
plt.plot(x, propotion_Maryland_ecig_in_all_Maryland_tweets, 'cx', label='Proportion of Maryland ecig tweets in all Maryland tweets')
plt.plot(x, propotion_DC_ecig_in_all_DC_tweets, 'mx', label='Proportion of DC ecig tweets in all Maryland tweets')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(21, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))

print('Delaware:')
drawRegressionLine_two_section(propotion_Delaware_ecig_in_all_Delaware_tweets, color='r')
print('NewJersey:')
drawRegressionLine_two_section(propotion_NewJersey_ecig_in_all_NewJersey_tweets, color='g')
print('Pennsylvania:')
drawRegressionLine_two_section(propotion_Pennsylvania_ecig_in_all_Pennsylvania_tweets, color='b')
print('Maryland:')
drawRegressionLine_two_section(propotion_Maryland_ecig_in_all_Maryland_tweets, color='c')
print('DC:')
drawRegressionLine_two_section(propotion_DC_ecig_in_all_DC_tweets, color='m')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Proportion (%)')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Proportion of different state e-cigarette tweets in all tweets that collected from the same state.')
# plt.figure(figsize=(40,1))
plt.show()

print('******************************************************')
# Out:
# Delaware:
# slope:  [-0.0009989102358629598, -0.0010637692519785968]
# intercept:  [0.13484270920916885, 0.15300392700099896]
# R^2:  [0.3494106864449863, 0.35738311809217693]
# NewJersey:
# slope:  [-0.013645923981106645, -0.005971435104677569]
# intercept:  [2.3821678667525394, 2.2611820517110828]
# R^2:  [0.6403634438264693, 0.320757624570561]
# Pennsylvania:
# slope:  [-0.0064290836272138385, 0.00535242460667773]
# intercept:  [2.404344307654143, 2.165738836186348]
# R^2:  [0.15529049694571317, 0.042022132715016536]
# Maryland:
# slope:  [-0.005911023958671491, -5.1458540014648335e-05]
# intercept:  [1.8834196579208937, 1.8022584391662995]
# R^2:  [0.27631096701389224, 1.6241633074565165e-05]
# DC:
# slope:  [0.010560981639238335, 0.008398598455099271]
# intercept:  [0.6761167012049498, 0.6220987672742586]
# R^2:  [0.5111780348277037, 0.5538047359445374]
# ******************************************************
# Delaware:
# slope:  [0.0005956256706503016, -9.02732609817658e-05]
# ...

# %% [markdown]
# ----------------------------
# Sentiment analysis

# %%
# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


plt.plot(x, vader_positive_Delaware, 'rx', label='Positive towards e-cigarette in Delaware')
plt.plot(x, vader_positive_NewJersey, 'gx', label='Positive towards e-cigarette in NewJersey')
plt.plot(x, vader_positive_Pennsylvania, 'bx', label='Positive towards e-cigarette in Pennsylvania')
plt.plot(x, vader_positive_Maryland, 'cx', label='Positive towards e-cigarette in Maryland')
plt.plot(x, vader_positive_DC, 'mx', label='Positive towards e-cigarette in DC')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(21, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))

print('Delaware:')
drawRegressionLine_two_section(vader_positive_Delaware, color='r')
print('NewJersey:')
drawRegressionLine_two_section(vader_positive_NewJersey, color='g')
print('Pennsylvania:')
drawRegressionLine_two_section(vader_positive_Pennsylvania, color='b')
print('Maryland:')
drawRegressionLine_two_section(vader_positive_Maryland, color='c')
print('DC:')
drawRegressionLine_two_section(vader_positive_DC, color='m')

plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for positive attitude towards e-cigarette by month. Y-axis represents the number of corresponding tweets within each month. ')
# plt.figure(figsize=(40,1))
plt.show()



print('******************************************************')

# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


plt.plot(x, vader_neutral_Delaware, 'rx', label='Neutral towards e-cigarette in Delaware')
plt.plot(x, vader_neutral_NewJersey, 'gx', label='Neutral towards e-cigarette in NewJersey')
plt.plot(x, vader_neutral_Pennsylvania, 'bx', label='Neutral towards e-cigarette in Pennsylvania')
plt.plot(x, vader_neutral_Maryland, 'cx', label='Neutral towards e-cigarette in Maryland')
plt.plot(x, vader_neutral_DC, 'mx', label='Neutral towards e-cigarette in DC')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(21, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))

print('Delaware:')
drawRegressionLine_two_section(vader_neutral_Delaware, color='r')
print('NewJersey:')
drawRegressionLine_two_section(vader_neutral_NewJersey, color='g')
print('Pennsylvania:')
drawRegressionLine_two_section(vader_neutral_Pennsylvania, color='b')
print('Maryland:')
drawRegressionLine_two_section(vader_neutral_Maryland, color='c')
print('DC:')
drawRegressionLine_two_section(vader_neutral_DC, color='m')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for neutral attitude towards e-cigarette by month. Y-axis represents the number of corresponding tweets within each month. ')
# plt.figure(figsize=(40,1))
plt.show()

print('******************************************************')

# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


plt.plot(x, vader_negative_Delaware, 'rx', label='Negative towards e-cigarette in Delaware')
plt.plot(x, vader_negative_NewJersey, 'gx', label='Negative towards e-cigarette in NewJersey')
plt.plot(x, vader_negative_Pennsylvania, 'bx', label='Negative towards e-cigarette in Pennsylvania')
plt.plot(x, vader_negative_Maryland, 'cx', label='Negative towards e-cigarette in Maryland')
plt.plot(x, vader_negative_DC, 'mx', label='Negative towards e-cigarette in DC')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(21, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))

print('Delaware:')
drawRegressionLine_two_section(vader_negative_Delaware, color='r')
print('NewJersey:')
drawRegressionLine_two_section(vader_negative_NewJersey, color='g')
print('Pennsylvania:')
drawRegressionLine_two_section(vader_negative_Pennsylvania, color='b')
print('Maryland:')
drawRegressionLine_two_section(vader_negative_Maryland, color='c')
print('DC:')
drawRegressionLine_two_section(vader_negative_DC, color='m')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for negative attitude towards e-cigarette by month. Y-axis represents the number of corresponding tweets within each month. ')
# plt.figure(figsize=(40,1))
plt.show()

print('******************************************************')
# Out:
# Delaware:
# slope:  [-0.2584415584443034, -0.05441176470818232]
# intercept:  [6.584415584427762, 6.988235294130717]
# R^2:  [0.24259372702768944, 0.00839285166906778]
# NewJersey:
# slope:  [-3.176623376632488, -4.033823515610065]
# intercept:  [144.33766233797496, 225.65147019488683]
# R^2:  [0.40265135811774866, 0.3162189554041296]
# Pennsylvania:
# slope:  [-4.046753246764253, -2.9588235294204024]
# intercept:  [161.61038961073987, 214.57647058870128]
# R^2:  [0.3515132206786795, 0.23757494377749522]
# Maryland:
# slope:  [-4.335064912490634, -0.35147058823824273]
# intercept:  [121.54112529929483, 82.70441176488416]
# R^2:  [0.673757337376407, 0.014134820366949463]
# DC:
# slope:  [-0.4493506493538104, 0.6132352941168029]
# intercept:  [31.54112554119214, 19.835294117688164]
# R^2:  [0.08585279563980597, 0.07751706798440616]
# ******************************************************
# Delaware:
# slope:  [-0.16883116883371785, -0.18088235654710086]
# ...

# %% [markdown]
# ---------------------------------------
# Proportion in sentiment analysis

# %%
# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


plt.plot(x, propotion_positive_ecig_Delaware, 'rx', label='Positive towards e-cigarette in Delaware')
plt.plot(x, propotion_positive_ecig_NewJersey, 'gx', label='Positive towards e-cigarette in NewJersey')
plt.plot(x, propotion_positive_ecig_Pennsylvania, 'bx', label='Positive towards e-cigarette in Pennsylvania')
plt.plot(x, propotion_positive_ecig_Maryland, 'cx', label='Positive towards e-cigarette in Maryland')
plt.plot(x, propotion_positive_ecig_DC, 'mx', label='Positive towards e-cigarette in DC')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(21, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))

print('Delaware:')
drawRegressionLine_two_section(propotion_positive_ecig_Delaware, color='r')
print('NewJersey:')
drawRegressionLine_two_section(propotion_positive_ecig_NewJersey, color='g')
print('Pennsylvania:')
drawRegressionLine_two_section(propotion_positive_ecig_Pennsylvania, color='b')
print('Maryland:')
drawRegressionLine_two_section(propotion_positive_ecig_Maryland, color='c')
print('DC:')
drawRegressionLine_two_section(propotion_positive_ecig_DC, color='m')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Proportion (%)')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for positive attitude towards e-cigarette by month. Y-axis represents the propotion of corresponding tweets within each month. ')
# plt.figure(figsize=(40,1))
plt.show()

print('******************************************************')
# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


plt.plot(x, propotion_neutral_ecig_Delaware, 'rx', label='Neutral towards e-cigarette in Delaware')
plt.plot(x, propotion_neutral_ecig_NewJersey, 'gx', label='Neutral towards e-cigarette in NewJersey')
plt.plot(x, propotion_neutral_ecig_Pennsylvania, 'bx', label='Neutral towards e-cigarette in Pennsylvania')
plt.plot(x, propotion_neutral_ecig_Maryland, 'cx', label='Neutral towards e-cigarette in Maryland')
plt.plot(x, propotion_neutral_ecig_DC, 'mx', label='Neutral towards e-cigarette in DC')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(21, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))

print('Delaware:')
drawRegressionLine_two_section(propotion_neutral_ecig_Delaware, color='r')
print('NewJersey:')
drawRegressionLine_two_section(propotion_neutral_ecig_NewJersey, color='g')
print('Pennsylvania:')
drawRegressionLine_two_section(propotion_neutral_ecig_Pennsylvania, color='b')
print('Maryland:')
drawRegressionLine_two_section(propotion_neutral_ecig_Maryland, color='c')
print('DC:')
drawRegressionLine_two_section(propotion_neutral_ecig_DC, color='m')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Proportion (%)')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for neutral attitude towards e-cigarette by month. Y-axis represents the propotion of corresponding tweets within each month. ')
# plt.figure(figsize=(40,1))
plt.show()


print('******************************************************')
# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


plt.plot(x, propotion_negative_ecig_Delaware, 'rx', label='Negative towards e-cigarette in Delaware')
plt.plot(x, propotion_negative_ecig_NewJersey, 'gx', label='Negative towards e-cigarette in NewJersey')
plt.plot(x, propotion_negative_ecig_Pennsylvania, 'bx', label='Negative towards e-cigarette in Pennsylvania')
plt.plot(x, propotion_negative_ecig_Maryland, 'cx', label='Negative towards e-cigarette in Maryland')
plt.plot(x, propotion_negative_ecig_DC, 'mx', label='Negative towards e-cigarette in DC')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(21, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))

print('Delaware:')
drawRegressionLine_two_section(propotion_negative_ecig_Delaware, color='r')
print('NewJersey:')
drawRegressionLine_two_section(propotion_negative_ecig_NewJersey, color='g')
print('Pennsylvania:')
drawRegressionLine_two_section(propotion_negative_ecig_Pennsylvania, color='b')
print('Maryland:')
drawRegressionLine_two_section(propotion_negative_ecig_Maryland, color='c')
print('DC:')
drawRegressionLine_two_section(propotion_negative_ecig_DC, color='m')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Proportion (%)')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for negative attitude towards e-cigarette by month. Y-axis represents the propotion of corresponding tweets within each month. ')
# plt.figure(figsize=(40,1))
plt.show()


print('******************************************************')
# Out:
# Delaware:
# slope:  [-0.5935801869245974, -0.060284000390872006]
# intercept:  [36.88382398745131, 31.364225533070936]
# R^2:  [0.08233630446077045, 0.00054575132536272]
# NewJersey:
# slope:  [-0.1009496637780356, 0.38175288386470896]
# intercept:  [33.381547142864804, 19.355560578599555]
# R^2:  [0.02545899850871991, 0.24888153471803665]
# Pennsylvania:
# slope:  [0.052825953870842546, -0.8616965952458575]
# intercept:  [33.26284141659831, 52.725213368089065]
# R^2:  [0.01227629762780258, 0.42162442498066266]
# Maryland:
# slope:  [-0.1520523362576618, -0.223896566068444]
# intercept:  [36.62737879229657, 37.90573703093382]
# R^2:  [0.037981034346468046, 0.0781654939758687]
# DC:
# slope:  [0.1977439630818857, 0.5170969290685902]
# intercept:  [31.433544473873013, 20.54704479842555]
# R^2:  [0.031043553004889035, 0.14546579472421584]
# ******************************************************
# Delaware:
# slope:  [0.0017911226423840132, -0.3458060262569076]
# ...

# %%
# Fourth figure
x1 = np.linspace(1, 12, 12)
x2 = np.tile(x1, 2)
x3 = np.linspace(1, 6, 6)
# x = np.tile(x, 2)
# itemNum = len(x)

x = np.concatenate((x2, x3), axis=0)
x = list(x)
x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12',
    '2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06', '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12',
    '2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06', ]

plt.figure(figsize=(14,7))


# print(x)
itemNum = len(x)
# print(itemNum)


# plt.subplot(2, 1, 1)
plt.plot(x, np.ones(itemNum), 'r-', label='tobacco related positive')
plt.plot(x, np.ones(itemNum)-0.1, 'r--', label='tobacco related neutral')
plt.plot(x, np.ones(itemNum)-0.2, 'r-.', label='tobacco related negtive')

plt.plot(x, np.ones(itemNum)-0.3, 'g-', label='e-cigarette realated positive')
plt.plot(x, np.ones(itemNum)-0.4, 'g--', label='e-cigarette related neutral')
plt.plot(x, np.ones(itemNum)-0.5, 'g-.', label='e-cigarette related negtive')

plt.plot(x, np.ones(itemNum)-0.6, 'b-', label='other tobacco positive')
plt.plot(x, np.ones(itemNum)-0.7, 'b--', label='other tobacco neutral')
plt.plot(x, np.ones(itemNum)-0.8, 'b-.', label='other tobacco negtive')

plt.plot(x, np.ones(itemNum)-0.9, 'y-', label='first person positive')
plt.plot(x, np.ones(itemNum)-1, 'y--', label='first person neutral')
plt.plot(x, np.ones(itemNum)-1.1, 'y-.', label='first person negtive')

plt.plot(x, np.ones(itemNum)-1.2, 'm-', label='not first person positive')
plt.plot(x, np.ones(itemNum)-1.3, 'm--', label='not first person neutral')
plt.plot(x, np.ones(itemNum)-1.4, 'm-.', label='not first person negtive')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(5, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Proposal', xy=(4,-0.3))
plt.axvline(17, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Approved', xy=(16,-0.3))
plt.axvline(24, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Enforcement ', xy=(23,-0.3))




plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Attitude')
plt.title('Figure 4: Trends for attitude towards tobacco by month. Y-axis represents the propotion of corresponding tweets within each month. ')
# plt.figure(figsize=(40,1))
plt.show()

# %%
# # Second figure
# x1 = np.linspace(1, 12, 12)
# x2 = np.tile(x1, 2)
# x3 = np.linspace(1, 6, 6)
# # x = np.tile(x, 2)
# # itemNum = len(x)

# x = np.concatenate((x2, x3), axis=0)
# x = list(x)
# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12',
#     '2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06', '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12',
#     '2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06', ]

# plt.figure(figsize=(14,7))


# # print(x)
# itemNum = len(x)
# print(itemNum)


# # plt.subplot(2, 1, 1)
# plt.plot(x, np.ones(itemNum), 'r-', label='mentioning tweets')
# plt.plot(x, np.ones(itemNum)/2, 'g-.', label='mentioning users')
# plt.plot(x, np.zeros(itemNum), 'b.', label='first person users')
# plt.legend()
# # plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
# plt.axvline(5, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))
# plt.axvline(17, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Approved', xy=(16,0.1))
# plt.axvline(24, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Enforcement ', xy=(23,0.1))




# plt.xticks(rotation=80)
# plt.xlabel('Month')
# plt.ylabel('# of mentioning')
# plt.title('Figure 1: Trends for number of tobacco related tweet by month. Y-axis represents the number of corresponding tweets within each month. ')
# # plt.figure(figsize=(40,1))
# plt.show()
