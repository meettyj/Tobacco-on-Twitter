# %%
import matplotlib.pyplot as plt
import numpy as np

from scipy import optimize

# %%
import datetime

import matplotlib as mpl
 
fig = plt.figure()
 
start = datetime.datetime(2016, 1, 1)
end = datetime.datetime(2017, 1, 1)
# 设置日期的间隔为1
delta = datetime.timedelta(days= 29)
 
# 生成一个matplotlib可以识别的日期对象
dates = mpl.dates.drange(start, end, delta)

print(dates)

date_format = mpl.dates.DateFormatter("%Y-%m")
print(date_format)
# Out:
# [735964. 735993. 736022. 736051. 736080. 736109. 736138. 736167. 736196.
#  736225. 736254. 736283. 736312.]
# ...

# %%
# Number

# ----------------------------- California -----------------------------
# California_allECigarette_2017
California_allECigarette_2017 = [3406, 3295, 3464, 3785, 3115, 2627, 2688, 2537, 2516, 2367, 1988, 2092, 1805, 1737, 1771, 1909, 2033, 976, 1174, 1961, 2008, 2166, 1834, 2160, 2174, 1757, 1938, 2211, 1932, 2011, 1690, 2034, 2031, 2165, 1971, 1596, 1544]
print('length of California_allECigarette_2017: ', len(California_allECigarette_2017))

# not_California_allECigarette_2017
not_California_allECigarette_2017 = [19380, 21312, 17787, 19894, 17102, 13671, 14918, 14216, 13899, 15672, 11836, 12673, 12472, 11343, 11850, 11658, 12056, 5957, 8171, 13678, 13673, 15190, 13575, 15162, 15074, 13785, 14365, 16659, 15466, 17157, 13417, 17025, 15639, 16531, 14324, 12092, 11782]
print('length of not_California_allECigarette_2017: ', len(not_California_allECigarette_2017))

# allECigarette_2017
allECigarette_2017 = []
for i in range(37):
    allECigarette_2017.append(California_allECigarette_2017[i]+not_California_allECigarette_2017[i])
print('length of allECigarette_2017: ', len(allECigarette_2017))


# allCalifornia_2017
allCalifornia_2017 = [8735704, 9439283, 10060029, 10166810, 9452532, 7724895, 8270415, 8050048, 7065826, 7688806, 5950614, 6130864, 5623066, 5542298, 5872374, 6284243, 6242231, 2686895, 3874158, 5584508, 5218406, 5561829, 4905649, 5727563, 5502914, 5377620, 5627578, 5879980, 5000225, 5381725, 4592721, 5047163, 4900812, 5342015, 4795218, 3958389, 4210282]
print('length of allCalifornia_2017: ', len(allCalifornia_2017))


# Number of users that tweets ecig in California.
users_California_ecig_2017 = [2065, 2205, 2054, 2264, 1817, 1521, 1507, 1366, 1293, 1313, 1131, 1230, 1097, 1084, 1149, 1264, 1246, 647, 852, 1351, 1397, 1494, 1285, 1497, 1507, 1325, 1388, 1476, 1356, 1382, 1196, 1458, 1371, 1568, 1427, 1105, 1048]
print('length of users_California_ecig_2017: ', len(users_California_ecig_2017))


# average number of per person tweets about ecig in California.
average_num_per_person_tweets_California_ecig = []
for i in range(37):
    average_num_per_person_tweets_California_ecig.append(California_allECigarette_2017[i]/users_California_ecig_2017[i])
print('length of average_num_per_person_tweets_California_ecig: ', len(average_num_per_person_tweets_California_ecig))


# Number of users that tweets in California
# 04, 05,06,07,08,09,10,
# 360175, 365369, 395811, 409394, 387877, 351081, 361695,351973, 326733, 
# 293996, 281709,309755, 300606,279575, 295525,309587,285522,283311,270281,278072,268812,270915,256192,251221, 229056

users_California_2017 = [360175, 365369, 395811, 409394, 387877, 351081, 361695,351973, 326733, 333885, 307678, 325899, 312275, 309270, 323365, 336303, 330514, 231445, 271542, 316768, 300338,293996, 281709,309755, 300606,279575, 295525,309587,285522,283311,270281,278072,268812,270915,256192,251221, 229056]
print('length of users_California_2017: ', len(users_California_2017))

# average number of per person tweets in California.
average_num_per_person_tweets_California = []
for i in range(37):
    average_num_per_person_tweets_California.append(allCalifornia_2017[i]/users_California_2017[i])
print('length of average_num_per_person_tweets_California: ', len(average_num_per_person_tweets_California))

# allTweets
allTweets_2017 = [70798094, 76153908, 77039352, 79730585, 75060717, 63144176, 68592777, 68306197, 60640789, 64761879, 49292002, 51379810, 46841051, 45592367, 46897952, 50163222, 51079160, 22112648, 31365136, 46232294, 43487766, 46059070, 40432909, 47289301, 45660765, 44166238, 44212483, 45858463, 39900707, 45395994, 37985764, 42937313, 41362576, 44209494, 38750216, 32702554, 33860264]
print('length of allTweets_2017: ', len(allTweets_2017))

# Sentiment analysis
vader_positive_California_2017 = [1109, 1114, 1084, 1261, 1036, 876, 944, 853, 853, 775, 667, 719, 580, 590, 565, 605, 693, 328, 378, 645, 672, 667, 543, 680, 683, 520, 625, 735, 625, 678, 528, 670, 665, 653, 629, 540, 516]
vader_neutral_California_2017 = [1727, 1572, 1803, 1919, 1563, 1330, 1307, 1281, 1274, 1187, 1025, 1058, 942, 874, 891, 975, 991, 500, 582, 936, 891, 1034, 911, 995, 1092, 835, 903, 1013, 902, 903, 778, 895, 900, 1001, 893, 712, 700]
vader_negative_California_2017 = [570, 609, 577, 605, 516, 421, 437, 403, 389, 405, 296, 315, 283, 273, 315, 329, 349, 148, 214, 380, 445,465, 380, 485, 399, 402, 410, 463, 405, 430, 384, 469, 466, 511, 449, 344, 328]
print('length of vader_positive_California_2017: ', len(vader_positive_California_2017))
print('length of vader_neutral_California_2017: ', len(vader_neutral_California_2017))
print('length of vader_negative_California_2017: ', len(vader_negative_California_2017))

print('----------------------------------')
# ----------------------------- Oregon -----------------------------

# Oregon_allECigarette_2017
Oregon_allECigarette_2017 = [274, 302, 240, 307, 225, 244, 281, 325, 281, 261, 195, 233, 221, 258, 263, 273, 257, 119, 152, 237, 284, 263, 209, 212, 214, 192, 192, 207, 229, 233, 153, 222, 183, 223, 166, 148, 146]
print('length of Oregon_allECigarette_2017: ', len(Oregon_allECigarette_2017))


# allOregon_2017
allOregon_2017 = [599777, 644250, 612666, 618797, 575851, 512339, 565743, 570314, 495921, 576389, 451267, 489471, 432418, 409505, 414368, 441048, 460374, 209586, 283148, 430226, 383564, 417210, 379330, 425150, 401396, 385676, 404462, 408670, 369111, 411442, 345204, 394339, 364140, 406922, 368350, 309742, 325747]
print('length of allOregon_2017: ', len(allOregon_2017))


# Number of users that tweets ecig in Oregon.
users_Oregon_ecig_2017 = [163, 178, 154, 202, 143, 121, 135, 145, 111, 121, 93, 118, 123, 103, 106, 124, 139, 64, 98, 156, 164, 164, 138, 116, 129, 134, 135, 150, 137, 148, 111, 153, 130, 149, 132, 94, 94]
print('length of users_Oregon_ecig_2017: ', len(users_Oregon_ecig_2017))


# average number of per person tweets about ecig in Oregon.
average_num_per_person_tweets_Oregon_ecig = []
for i in range(37):
    average_num_per_person_tweets_Oregon_ecig.append(Oregon_allECigarette_2017[i]/users_Oregon_ecig_2017[i])
print('length of average_num_per_person_tweets_Oregon_ecig: ', len(average_num_per_person_tweets_Oregon_ecig))


# Number of users that tweets in Oregon
users_Oregon_2017 = [30984, 32054, 34350, 36517, 34460, 31271, 31934, 30752, 28886,28914, 26389, 27777, 26903, 26769, 28342, 29185, 31473, 20171, 23160, 27581, 25123, 23666, 23408, 25586, 24886, 23210, 25547, 26353, 24030, 24797, 22385, 23075, 21674, 21182, 20600, 20306, 18434]
print('length of users_Oregon_2017: ', len(users_Oregon_2017))

# average number of per person tweets in Oregon.
average_num_per_person_tweets_Oregon = []
for i in range(37):
    average_num_per_person_tweets_Oregon.append(allOregon_2017[i]/users_Oregon_2017[i])
print('length of average_num_per_person_tweets_Oregon: ', len(average_num_per_person_tweets_Oregon))

# Sentiment analysis
vader_positive_Oregon_2017 = [99, 111, 85, 129, 84, 92, 120, 117, 128, 107, 82, 100, 87, 94, 105, 103, 72, 39, 43, 78, 84, 94, 75, 66, 72, 57, 67, 69, 74, 91, 51, 73, 54, 83, 50, 42, 49]
vader_neutral_Oregon_2017 = [137, 130, 106, 136, 108, 117, 127, 173, 129,108, 85, 97, 106, 139, 127, 137, 148, 60, 84, 108, 139, 114, 84, 113, 105, 101, 89, 93, 107, 103, 64, 91, 94, 95, 78, 79, 68]
vader_negative_Oregon_2017 = [38, 61, 49, 42, 33, 35, 34, 35, 24,46, 28, 36, 28, 25, 31, 33, 37, 20, 25, 51, 61, 55, 50, 33, 37, 34, 36, 45, 48, 39, 38, 58, 35, 45, 38, 27, 29]
print('length of vader_positive_Oregon_2017: ', len(vader_positive_Oregon_2017))
print('length of vader_neutral_Oregon_2017: ', len(vader_neutral_Oregon_2017))
print('length of vader_negative_Oregon_2017: ', len(vader_negative_Oregon_2017))


print('----------------------------------')
# ----------------------------- Nevada -----------------------------

# Nevada_allECigarette_2017
Nevada_allECigarette_2017 = [492, 371, 316, 388, 429, 319, 380, 427, 320, 481, 518, 516, 546, 487, 436, 417, 336, 92, 128, 245, 253, 236, 221, 221, 208, 240, 214, 276, 241, 264, 228, 288, 271, 295, 258, 198, 184]
print('length of Nevada_allECigarette_2017: ', len(Nevada_allECigarette_2017))


# allNevada_2017
allNevada_2017 = [728432, 794363, 859419, 921170, 797947, 671803, 719944, 715447, 641579, 681641, 511694, 559172, 508382, 503636, 544346, 580917, 585303, 241846, 363262, 539410, 487596, 546049, 483434, 582721, 568494, 568432, 558238, 596718, 480559, 546846, 439811, 481335, 490998, 553409, 480211, 413775, 426641]
print('length of allNevada_2017: ', len(allNevada_2017))


# Number of users that tweets ecig in Nevada.
users_Nevada_ecig_2017 = [181, 206, 200, 199, 175, 130, 158, 149, 135, 123, 117, 130, 134, 111, 135, 160, 139, 68, 93, 185, 177,175, 168, 165, 151, 178, 164, 201, 149, 166, 134, 183, 182, 191, 170, 135, 129]
print('length of users_Nevada_ecig_2017: ', len(users_Nevada_ecig_2017))


# average number of per person tweets about ecig in Nevada.
average_num_per_person_tweets_Nevada_ecig = []
for i in range(37):
    average_num_per_person_tweets_Nevada_ecig.append(Nevada_allECigarette_2017[i]/users_Nevada_ecig_2017[i])
print('length of average_num_per_person_tweets_Nevada_ecig: ', len(average_num_per_person_tweets_Nevada_ecig))


# Number of users that tweets in Nevada
users_Nevada_2017 = [43980, 44552, 51813, 57165, 49885, 42041, 44345, 42735, 40257, 43055, 35526, 42399, 39318, 38744, 43377, 46753, 44795, 25326, 31593, 38779, 37093, 38441, 33971, 41728, 38627, 37988, 37442, 43248, 37931, 38681, 34131, 36964, 35012, 37538, 32326, 34087, 30886]
print('length of users_Nevada_2017: ', len(users_Nevada_2017))

# average number of per person tweets in Nevada.
average_num_per_person_tweets_Nevada = []
for i in range(37):
    average_num_per_person_tweets_Nevada.append(allNevada_2017[i]/users_Nevada_2017[i])
print('length of average_num_per_person_tweets_Nevada: ', len(average_num_per_person_tweets_Nevada))


# Sentiment analysis
vader_positive_Nevada_2017 = [212, 133, 122, 111, 141, 138, 175, 229, 96, 154, 322, 328, 350, 305, 291, 253, 194, 33, 52, 81, 83, 75, 73, 67, 74, 82, 63, 94, 82, 90, 76, 113, 91, 89, 95, 65, 53]
vader_neutral_Nevada_2017 = [214, 181, 164, 211, 230, 142, 169, 166, 183, 288, 157, 146, 163, 152, 106, 117, 109, 38, 53, 112, 111, 105, 97, 103, 86, 99, 110, 134, 125, 117, 110, 125, 113, 149, 116, 82, 96]
vader_negative_Nevada_2017 = [66, 57, 30, 66, 58, 39, 36, 32, 41, 39, 39, 42, 33, 30, 39, 47, 33, 21, 23, 52, 59, 56, 51, 51, 48, 59, 41, 48, 34, 57, 42, 50, 67, 57, 47, 51, 35]
print('length of vader_positive_Nevada_2017: ', len(vader_positive_Nevada_2017))
print('length of vader_neutral_Nevada_2017: ', len(vader_neutral_Nevada_2017))
print('length of vader_negative_Nevada_2017: ', len(vader_negative_Nevada_2017))


print('----------------------------------')
# ----------------------------- Arizona -----------------------------

# Arizona_allECigarette_2017
Arizona_allECigarette_2017 = [568, 636, 450, 453, 630, 362, 430, 419, 353, 422, 293, 336, 411, 302, 230, 292, 325, 162, 253, 409, 382, 442, 412, 416, 360, 405, 381, 358, 371, 382, 320, 426, 413, 406, 389, 283, 286]
print('length of Arizona_allECigarette_2017: ', len(Arizona_allECigarette_2017))


# allArizona_2017
allArizona_2017 = [1262589, 1285618, 1298666, 1334544, 1280635, 1132938, 1217316, 1167490, 982169, 1086204, 852986, 864083, 773664, 715142, 726453, 798319, 851711, 376349, 527391, 764080, 704562, 776647, 695828, 795739, 779177, 726661, 715880, 736675, 662689, 758293, 625817, 703006, 660777, 742468, 653478, 554828, 549231]
print('length of allArizona_2017: ', len(allArizona_2017))


# Number of users that tweets ecig in Arizona.
users_Arizona_ecig_2017 = [397, 450, 320, 350, 314, 275, 334, 293, 248, 290, 210, 256, 260, 200, 161, 229, 261, 132, 215, 330, 296,330, 304, 329, 282, 291, 291, 284, 307, 297, 251, 304, 292, 318, 280, 220, 196]
print('length of users_Arizona_ecig_2017: ', len(users_Arizona_ecig_2017))


# average number of per person tweets about ecig in Arizona.
average_num_per_person_tweets_Arizona_ecig = []
for i in range(37):
    average_num_per_person_tweets_Arizona_ecig.append(Arizona_allECigarette_2017[i]/users_Arizona_ecig_2017[i])
print('length of average_num_per_person_tweets_Arizona_ecig: ', len(average_num_per_person_tweets_Arizona_ecig))


# Number of users that tweets in Arizona
users_Arizona_2017 = [52763, 53112, 53964, 56318, 55317, 51738, 53956, 53488, 51121, 50460, 46956, 53007, 47507, 44051, 43259, 45744, 47430, 33200, 39831, 48491, 46966, 44665, 44570, 50916, 45998, 42231, 40754, 42731, 41412, 42470, 40395, 42791, 42693, 43481, 40832, 40712, 33816]
print('length of users_Arizona_2017: ', len(users_Arizona_2017))

# average number of per person tweets in Arizona.
average_num_per_person_tweets_Arizona = []
for i in range(37):
    average_num_per_person_tweets_Arizona.append(allArizona_2017[i]/users_Arizona_2017[i])
print('length of average_num_per_person_tweets_Arizona: ', len(average_num_per_person_tweets_Arizona))

# Sentiment analysis
vader_positive_Arizona_2017 = [201, 242, 159, 173, 198, 128, 136, 148, 110, 121, 89, 113, 156, 100, 74, 81, 102, 59, 74, 137, 104, 146, 117, 136, 116, 107, 110, 107, 140, 103, 105, 117, 143, 121, 117, 84, 100]
vader_neutral_Arizona_2017 = [264, 277, 218, 198, 298, 151, 205, 186, 169, 224, 137, 155, 185, 135, 95, 149, 148, 73, 124, 154, 172, 197, 184, 195, 153, 195, 180, 143, 139, 159, 138, 183, 184, 177, 181, 133, 115]
vader_negative_Arizona_2017 = [103, 117, 73, 82, 134, 83, 89, 85, 74, 77, 67, 68, 70, 67, 61, 62, 75, 30, 55, 118, 106, 99, 111, 85, 91, 103, 91, 108, 92, 120, 77, 126, 86, 108, 91, 66, 71]
print('length of vader_positive_Arizona_2017: ', len(vader_positive_Arizona_2017))
print('length of vader_neutral_Arizona_2017: ', len(vader_neutral_Arizona_2017))
print('length of vader_negative_Arizona_2017: ', len(vader_negative_Arizona_2017))
# Out:
# length of California_allECigarette_2017:  37
# length of not_California_allECigarette_2017:  37
# length of allECigarette_2017:  37
# length of allCalifornia_2017:  37
# length of users_California_ecig_2017:  37
# length of average_num_per_person_tweets_California_ecig:  37
# length of users_California_2017:  37
# length of average_num_per_person_tweets_California:  37
# length of allTweets_2017:  37
# length of vader_positive_California_2017:  37
# length of vader_neutral_California_2017:  37
# length of vader_negative_California_2017:  37
# ----------------------------------
# length of Oregon_allECigarette_2017:  37
# length of allOregon_2017:  37
# length of users_Oregon_ecig_2017:  37
# length of average_num_per_person_tweets_Oregon_ecig:  37
# length of users_Oregon_2017:  37
# length of average_num_per_person_tweets_Oregon:  37
# length of vader_positive_Oregon_2017:  37
# length of vader_neutral_Oregon_2017:  37
# length of vader_negative_Oregon_2017:  37
# ...

# %%
# Propotion

# ----------------------------- California -----------------------------
propotion_California_ecig_in_all_ecig = []
propotion_California_ecig_in_all_California_tweets = []
propotion_California_in_all_tweets = []
propotion_California_ecig_users_in_all_California_users = []
propotion_positive_ecig_California = []
propotion_neutral_ecig_California = []
propotion_negative_ecig_California = []


# propotion of California e-cig tweets in all e-cig tweets.
for i in range(37):
    propotion_California_ecig_in_all_ecig.append((California_allECigarette_2017[i]/allECigarette_2017[i])*100)
print('length of propotion_California_ecig_in_all_ecig: ', len(propotion_California_ecig_in_all_ecig))


# propotion of California e-cig tweets in all California tweets.
for i in range(37):
    propotion_California_ecig_in_all_California_tweets.append((California_allECigarette_2017[i]/allCalifornia_2017[i])*100)
print('length of propotion_California_ecig_in_all_California_tweets: ', len(propotion_California_ecig_in_all_California_tweets))


# propotion of California tweets in total tweets.
for i in range(37):
    propotion_California_in_all_tweets.append((allCalifornia_2017[i]/allTweets_2017[i])*100)
print('length of propotion_California_in_all_tweets: ', len(propotion_California_in_all_tweets))


# propotion of users post California e-cig in all California users.
# for i in range(37):
#     propotion_California_ecig_users_in_all_California_users.append((users_California_ecig_2017[i]/users_California_2017[i])*100)
# print('length of propotion_California_ecig_users_in_all_California_users: ', len(propotion_California_ecig_users_in_all_California_users))


# Sentiment analysis
for i in range(37):
    propotion_positive_ecig_California.append((vader_positive_California_2017[i]/California_allECigarette_2017[i])*100)
print('length of propotion_positive_ecig_California: ', len(propotion_positive_ecig_California))

for i in range(37):
    propotion_neutral_ecig_California.append((vader_neutral_California_2017[i]/California_allECigarette_2017[i])*100)
print('length of propotion_neutral_ecig_California: ', len(propotion_neutral_ecig_California))

for i in range(37):
    propotion_negative_ecig_California.append((vader_negative_California_2017[i]/California_allECigarette_2017[i])*100)
print('length of propotion_negative_ecig_California: ', len(propotion_negative_ecig_California))


print('----------------------------------')
# ----------------------------- Oregon -----------------------------
propotion_Oregon_ecig_in_all_ecig = []
propotion_Oregon_ecig_in_all_Oregon_tweets = []
propotion_Oregon_in_all_tweets = []
propotion_Oregon_ecig_users_in_all_Oregon_users = []
propotion_positive_ecig_Oregon = []
propotion_neutral_ecig_Oregon = []
propotion_negative_ecig_Oregon = []


# propotion of Oregon e-cig tweets in all e-cig tweets.
for i in range(37):
    propotion_Oregon_ecig_in_all_ecig.append((Oregon_allECigarette_2017[i]/allECigarette_2017[i])*100)
print('length of propotion_Oregon_ecig_in_all_ecig: ', len(propotion_Oregon_ecig_in_all_ecig))


# propotion of Oregon e-cig tweets in all Oregon tweets.
for i in range(37):
    propotion_Oregon_ecig_in_all_Oregon_tweets.append((Oregon_allECigarette_2017[i]/allOregon_2017[i])*100)
print('length of propotion_Oregon_ecig_in_all_Oregon_tweets: ', len(propotion_Oregon_ecig_in_all_Oregon_tweets))


# propotion of Oregon tweets in total tweets.
for i in range(37):
    propotion_Oregon_in_all_tweets.append((allOregon_2017[i]/allTweets_2017[i])*100)
print('length of propotion_Oregon_in_all_tweets: ', len(propotion_Oregon_in_all_tweets))


# propotion of users post Oregon e-cig in all Oregon users.
for i in range(37):
    propotion_Oregon_ecig_users_in_all_Oregon_users.append((users_Oregon_ecig_2017[i]/users_Oregon_2017[i])*100)
print('length of propotion_Oregon_ecig_users_in_all_Oregon_users: ', len(propotion_Oregon_ecig_users_in_all_Oregon_users))


# Sentiment analysis
for i in range(37):
    propotion_positive_ecig_Oregon.append((vader_positive_Oregon_2017[i]/Oregon_allECigarette_2017[i])*100)
print('length of propotion_positive_ecig_Oregon: ', len(propotion_positive_ecig_Oregon))

for i in range(37):
    propotion_neutral_ecig_Oregon.append((vader_neutral_Oregon_2017[i]/Oregon_allECigarette_2017[i])*100)
print('length of propotion_neutral_ecig_Oregon: ', len(propotion_neutral_ecig_Oregon))

for i in range(37):
    propotion_negative_ecig_Oregon.append((vader_negative_Oregon_2017[i]/Oregon_allECigarette_2017[i])*100)
print('length of propotion_negative_ecig_Oregon: ', len(propotion_negative_ecig_Oregon))


print('----------------------------------')
# ----------------------------- Nevada -----------------------------
propotion_Nevada_ecig_in_all_ecig = []
propotion_Nevada_ecig_in_all_Nevada_tweets = []
propotion_Nevada_in_all_tweets = []
propotion_Nevada_ecig_users_in_all_Nevada_users = []
propotion_positive_ecig_Nevada = []
propotion_neutral_ecig_Nevada = []
propotion_negative_ecig_Nevada = []


# propotion of Nevada e-cig tweets in all e-cig tweets.
for i in range(37):
    propotion_Nevada_ecig_in_all_ecig.append((Nevada_allECigarette_2017[i]/allECigarette_2017[i])*100)
print('length of propotion_Nevada_ecig_in_all_ecig: ', len(propotion_Nevada_ecig_in_all_ecig))


# propotion of Nevada e-cig tweets in all Nevada tweets.
for i in range(37):
    propotion_Nevada_ecig_in_all_Nevada_tweets.append((Nevada_allECigarette_2017[i]/allNevada_2017[i])*100)
print('length of propotion_Nevada_ecig_in_all_Nevada_tweets: ', len(propotion_Nevada_ecig_in_all_Nevada_tweets))


# propotion of Nevada tweets in total tweets.
for i in range(37):
    propotion_Nevada_in_all_tweets.append((allNevada_2017[i]/allTweets_2017[i])*100)
print('length of propotion_Nevada_in_all_tweets: ', len(propotion_Nevada_in_all_tweets))


# propotion of users post Nevada e-cig in all Nevada users.
for i in range(37):
    propotion_Nevada_ecig_users_in_all_Nevada_users.append((users_Nevada_ecig_2017[i]/users_Nevada_2017[i])*100)
print('length of propotion_Nevada_ecig_users_in_all_Nevada_users: ', len(propotion_Nevada_ecig_users_in_all_Nevada_users))


# Sentiment analysis
for i in range(37):
    propotion_positive_ecig_Nevada.append((vader_positive_Nevada_2017[i]/Nevada_allECigarette_2017[i])*100)
print('length of propotion_positive_ecig_Nevada: ', len(propotion_positive_ecig_Nevada))

for i in range(37):
    propotion_neutral_ecig_Nevada.append((vader_neutral_Nevada_2017[i]/Nevada_allECigarette_2017[i])*100)
print('length of propotion_neutral_ecig_Nevada: ', len(propotion_neutral_ecig_Nevada))

for i in range(37):
    propotion_negative_ecig_Nevada.append((vader_negative_Nevada_2017[i]/Nevada_allECigarette_2017[i])*100)
print('length of propotion_negative_ecig_Nevada: ', len(propotion_negative_ecig_Nevada))


print('----------------------------------')
# ----------------------------- Arizona -----------------------------
propotion_Arizona_ecig_in_all_ecig = []
propotion_Arizona_ecig_in_all_Arizona_tweets = []
propotion_Arizona_in_all_tweets = []
propotion_Arizona_ecig_users_in_all_Arizona_users = []
propotion_positive_ecig_Arizona = []
propotion_neutral_ecig_Arizona = []
propotion_negative_ecig_Arizona = []


# propotion of Arizona e-cig tweets in all e-cig tweets.
for i in range(37):
    propotion_Arizona_ecig_in_all_ecig.append((Arizona_allECigarette_2017[i]/allECigarette_2017[i])*100)
print('length of propotion_Arizona_ecig_in_all_ecig: ', len(propotion_Arizona_ecig_in_all_ecig))


# propotion of Arizona e-cig tweets in all Arizona tweets.
for i in range(37):
    propotion_Arizona_ecig_in_all_Arizona_tweets.append((Arizona_allECigarette_2017[i]/allArizona_2017[i])*100)
print('length of propotion_Arizona_ecig_in_all_Arizona_tweets: ', len(propotion_Arizona_ecig_in_all_Arizona_tweets))


# propotion of Arizona tweets in total tweets.
for i in range(37):
    propotion_Arizona_in_all_tweets.append((allArizona_2017[i]/allTweets_2017[i])*100)
print('length of propotion_Arizona_in_all_tweets: ', len(propotion_Arizona_in_all_tweets))


# propotion of users post Arizona e-cig in all Arizona users.
for i in range(37):
    propotion_Arizona_ecig_users_in_all_Arizona_users.append((users_Arizona_ecig_2017[i]/users_Arizona_2017[i])*100)
print('length of propotion_Arizona_ecig_users_in_all_Arizona_users: ', len(propotion_Arizona_ecig_users_in_all_Arizona_users))


# Sentiment analysis
for i in range(37):
    propotion_positive_ecig_Arizona.append((vader_positive_Arizona_2017[i]/Arizona_allECigarette_2017[i])*100)
print('length of propotion_positive_ecig_Arizona: ', len(propotion_positive_ecig_Arizona))

for i in range(37):
    propotion_neutral_ecig_Arizona.append((vader_neutral_Arizona_2017[i]/Arizona_allECigarette_2017[i])*100)
print('length of propotion_neutral_ecig_Arizona: ', len(propotion_neutral_ecig_Arizona))

for i in range(37):
    propotion_negative_ecig_Arizona.append((vader_negative_Arizona_2017[i]/Arizona_allECigarette_2017[i])*100)
print('length of propotion_negative_ecig_Arizona: ', len(propotion_negative_ecig_Arizona))
# Out:
# length of propotion_California_ecig_in_all_ecig:  37
# length of propotion_California_ecig_in_all_California_tweets:  37
# length of propotion_California_in_all_tweets:  37
# length of propotion_positive_ecig_California:  37
# length of propotion_neutral_ecig_California:  37
# length of propotion_negative_ecig_California:  37
# ----------------------------------
# length of propotion_Oregon_ecig_in_all_ecig:  37
# length of propotion_Oregon_ecig_in_all_Oregon_tweets:  37
# length of propotion_Oregon_in_all_tweets:  37
# length of propotion_Oregon_ecig_users_in_all_Oregon_users:  37
# length of propotion_positive_ecig_Oregon:  37
# length of propotion_neutral_ecig_Oregon:  37
# length of propotion_negative_ecig_Oregon:  37
# ----------------------------------
# length of propotion_Nevada_ecig_in_all_ecig:  37
# length of propotion_Nevada_ecig_in_all_Nevada_tweets:  37
# length of propotion_Nevada_in_all_tweets:  37
# length of propotion_Nevada_ecig_users_in_all_Nevada_users:  37
# ...

# %% [markdown]
# ---------------------------------
# Draw Figures.

# %%
def linearRegression(x, A, B):
    return A*x + B

# %%
# Regression line
length_of_section_1 = 3+9
length_of_section_2 = length_of_section_1+9+12+4
x_number_section_1 = [i for i in range(0,length_of_section_1)]
x_number_section_2 = [i for i in range(length_of_section_1, length_of_section_2)]

# In the California level, we just take the first three month into consideration.
# def drawRegressionLine_two_section(y, color):
#     print('y: ', y)
#     print('section 1: ', y[:length_of_section_1])
#     print('section 2: ', y[length_of_section_1:length_of_section_2])
#     print('--------------------------')
    
#     # section 1
#     A_section_1, B_section_1 = optimize.curve_fit(linearRegression, x_number_section_1, y[:length_of_section_1])[0]
#     x_plot_section_1 = np.arange(0, length_of_section_1, 0.01)
#     y_plot_section_1 = A_section_1 * x_plot_section_1 + B_section_1
#     plt.plot(x_plot_section_1, y_plot_section_1, color+'-') # , label='Users' is useless

#     # section 2: length_of_section_1-1:length_of_section_2
#     A_section_2, B_section_2 = optimize.curve_fit(linearRegression, x_number_section_2, y[length_of_section_1:length_of_section_2])[0]
#     x_plot_section_2 = np.arange(length_of_section_1, length_of_section_2-1, 0.01)
#     y_plot_section_2 = A_section_2 * x_plot_section_2 + B_section_2
#     plt.plot(x_plot_section_2, y_plot_section_2, color+'-')

from scipy import stats
def drawRegressionLine_two_section(y, color):
#     print('y: ', y)
#     print('section 1: ', y[:length_of_section_1])
#     print('section 2: ', y[length_of_section_1:length_of_section_2])
    
    # section 1
    popt_1, pcov_1 = optimize.curve_fit(linearRegression, x_number_section_1, y[:length_of_section_1])
    A_section_1, B_section_1 = popt_1
    x_plot_section_1 = np.arange(0, length_of_section_1, 0.01)
    y_plot_section_1 = A_section_1 * x_plot_section_1 + B_section_1
    plt.plot(x_plot_section_1, y_plot_section_1, color+'-') # , label='Users' is useless
    # Calculate the R square
    residuals_1 = y[:length_of_section_1]- linearRegression(np.asarray(x_number_section_1), *popt_1) # [float(A_section_1), float(B_section_1)]
    ss_res_1 = np.sum(residuals_1**2)
    ss_tot_1 = np.sum((y[:length_of_section_1]-np.mean(y[:length_of_section_1]))**2)
    r_squared_1 = 1 - (ss_res_1 / ss_tot_1)
#     print('section 1 slope: ', A_section_1)
#     print('section 1 R^2: ', r_squared_1)

    # section 2: length_of_section_1-1:length_of_section_2
    popt_2, pcov_2 = optimize.curve_fit(linearRegression, x_number_section_2, y[length_of_section_1:length_of_section_2])
    A_section_2, B_section_2 = popt_2
    x_plot_section_2 = np.arange(length_of_section_1, length_of_section_2-1, 0.01)
    y_plot_section_2 = A_section_2 * x_plot_section_2 + B_section_2
    plt.plot(x_plot_section_2, y_plot_section_2, color+'-')
    # Calculate the R square
    residuals_2 = y[length_of_section_1:length_of_section_2]- linearRegression(np.asarray(x_number_section_2), *popt_2) #*[float(A_section_2), float(B_section_2)]
    ss_res_2 = np.sum(residuals_2**2)
    ss_tot_2 = np.sum((y[length_of_section_1:length_of_section_2]-np.mean(y[length_of_section_1:length_of_section_2]))**2)
    r_squared_2 = 1 - (ss_res_2 / ss_tot_2)
#     print('section 2 slope: ', A_section_2)
#     print('section 2 R^2: ', r_squared_2)
    
    print('slope: ', [A_section_1, A_section_2])
    print('intercept: ', [B_section_1, B_section_2])
    print('R^2: ', [r_squared_1, r_squared_2])
    
    # Student t-test
#     leveneResult = stats.levene(y[:length_of_section_1], y[length_of_section_1:length_of_section_2])
#     _, levene_p_value = leveneResult
#     print('leveneResult: ', leveneResult)
#     # Cannot run t-test in two value. Or should I run t-test in x?
# #     t_TestResult = stats.ttest_ind([12], [34])
#     t_TestResult = stats.ttest_ind([12,34])
#     print('Student t test: ', t_TestResult)
    
    print('--------------------------')
#     print()

# %%
# x1 = np.linspace(1, 12, 12)
# x2 = np.tile(x1, 2)
# x3 = np.linspace(1, 6, 6)
# # x = np.tile(x, 2)
# # itemNum = len(x)

# x = np.concatenate((x2, x3), axis=0)
# x = list(x)
x = ['2016-04','2016-05','2016-06','2016-07','2016-08','2016-09','2016-10','2016-11','2016-12','2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12', '2018-01','2018-02', '2018-03','2018-04','2018-05','2018-06','2018-07','2018-08','2018-09','2018-10','2018-11','2018-12', '2019-01','2019-02', '2019-03','2019-04',]

plt.figure(figsize=(14,7))


# print(x)
# itemNum = len(x)
# print(itemNum)


plt.plot(x, California_allECigarette_2017, 'rx', label='California e-cigarette realated tweets')
plt.plot(x, Oregon_allECigarette_2017, 'bx', label='Oregon e-cigarette realated tweets')
plt.plot(x, Nevada_allECigarette_2017, 'gx', label='Nevada e-cigarette realated tweets')
plt.plot(x, Arizona_allECigarette_2017, 'cx', label='Arizona e-cigarette realated tweets')
# plt.plot(x, users_California_ecig_2017, 'yx', label='Users of California e-cigarette tweets')


# plt.plot(x, average_num_per_persion_tweets_SF_ecig, 'm-', label='not first person')
plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(12, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))



drawRegressionLine_two_section(California_allECigarette_2017, color='r')
drawRegressionLine_two_section(Oregon_allECigarette_2017, color='b')
drawRegressionLine_two_section(Nevada_allECigarette_2017, color='g')
drawRegressionLine_two_section(Arizona_allECigarette_2017, color='c')



plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for number of e-cigarette related tweets in different states by month. ')
# plt.figure(figsize=(40,1))
plt.show()
# Out:
# slope:  [-146.55244800394078, 7.686923076937627]
# intercept:  [3629.3717973550074, 1679.0338461575068]
# R^2:  [0.8399633425975782, 0.03562282155815566]
# slope:  [-3.706293706303981, -2.9669230769317303]
# intercept:  [284.3846153852336, 281.4461538467656]
# R^2:  [0.12338791861404974, 0.23937930414362807]
# slope:  [8.590909090925651, -6.751538461555373]
# intercept:  [365.8333333341291, 433.35692307786627]
# R^2:  [0.16666844128071323, 0.22818540613472194]
# slope:  [-24.12587423151189, 2.58230769231114]
# intercept:  [578.6923082733153, 290.6646153852473]
# R^2:  [0.6045487052169213, 0.07244304309907135]

# %%
# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


# plt.plot(x, California_allECigarette_2017, 'rx', label='California e-cigarette realated tweets')
plt.plot(x, users_California_ecig_2017, 'rx', label='Users of California e-cigarette tweets')
plt.plot(x, users_Oregon_ecig_2017, 'bx', label='Users of Oregon e-cigarette tweets')
plt.plot(x, users_Nevada_ecig_2017, 'gx', label='Users of Nevada e-cigarette tweets')
plt.plot(x, users_Arizona_ecig_2017, 'cx', label='Users of Arizona e-cigarette tweets')
# plt.plot(x, average_num_per_persion_tweets_SF_ecig, 'm-', label='not first person')
plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(12, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))


drawRegressionLine_two_section(users_California_ecig_2017, color='r')
drawRegressionLine_two_section(users_Oregon_ecig_2017, color='b')
drawRegressionLine_two_section(users_Nevada_ecig_2017, color='g')
drawRegressionLine_two_section(users_Arizona_ecig_2017, color='c')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for number of users that post e-cigarette related tweets in different states by month. ')
# plt.figure(figsize=(40,1))
plt.show()
# Out:
# slope:  [-105.80419541923095, 10.670000000021087]
# intercept:  [2229.089741472437, 1022.7200000022286]
# R^2:  [0.8640085549932177, 0.12962393325579413]
# slope:  [-6.734265734282599, 0.3761538461524845]
# intercept:  [177.3717948721795, 118.61230769256429]
# R^2:  [0.6279952778016045, 0.012579828335934296]
# slope:  [-7.940559440578941, 1.6184615696519042]
# intercept:  [202.25641025684922, 114.8769223283543]
# R^2:  [0.774153838548564, 0.14228209525087787]
# slope:  [-15.50699300702901, 2.144615458744811]
# intercept:  [396.70512820599123, 214.92922899692147]
# R^2:  [0.7147391772069818, 0.08715762940304506]

# %%
# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


# plt.plot(x, California_allECigarette_2017, 'rx', label='California e-cigarette realated tweets')
plt.plot(x, average_num_per_person_tweets_California_ecig, 'rx', label='California ecig tweets per person')
plt.plot(x, average_num_per_person_tweets_Oregon_ecig, 'bx', label='Oregon ecig tweets per person')
plt.plot(x, average_num_per_person_tweets_Nevada_ecig, 'gx', label='Nevada ecig tweets per person')
plt.plot(x, average_num_per_person_tweets_Arizona_ecig, 'cx', label='Arizona ecig tweets per person')
# plt.plot(x, average_num_per_persion_tweets_SF_ecig, 'm-', label='not first person')
plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(12, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))


drawRegressionLine_two_section(average_num_per_person_tweets_California_ecig, color='r')
drawRegressionLine_two_section(average_num_per_person_tweets_Oregon_ecig, color='b')
drawRegressionLine_two_section(average_num_per_person_tweets_Nevada_ecig, color='g')
drawRegressionLine_two_section(average_num_per_person_tweets_Arizona_ecig, color='c')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for average tweets number per person post e-cigarette related tweets in different states by month. ')
# plt.figure(figsize=(40,1))
plt.show()
# Out:
# slope:  [0.019599896592946364, -0.006479097745139294]
# intercept:  [1.6248343832346754, 1.6170243167054743]
# R^2:  [0.39219525822380463, 0.3659152067242958]
# slope:  [0.06345590018880225, -0.031059344273665745]
# intercept:  [1.5783740012734422, 2.41338825525323]
# R^2:  [0.5139222516878836, 0.5116150463361273]
# slope:  [0.19933475765479924, -0.07105245064792975]
# intercept:  [1.6455406797938263, 3.52656514487728]
# R^2:  [0.6306002629023423, 0.36940801506072196]
# slope:  [-0.007808996422428827, -0.001101618892884515]
# intercept:  [1.4738736031891806, 1.353147792013041]
# R^2:  [0.021779536854427017, 0.006783855643205494]

# %%
# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


plt.plot(x, allTweets_2017, 'mx', label='All tweets that collected')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(12, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))

drawRegressionLine_two_section(allTweets_2017, color='m')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for all tweets that collected from Twitter by month. ')
# plt.figure(figsize=(40,1))
plt.show()
# Out:
# slope:  [-2278197.637592111, -261192.30555005217]
# intercept:  [79605110.8448723, 48450843.6088691]
# R^2:  [0.7081308372551267, 0.08664583352024591]

# %%
# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


plt.plot(x, allCalifornia_2017, 'rx', label='All tweets that collected in California')
plt.plot(x, allOregon_2017, 'bx', label='All tweets that collected in Oregon')
plt.plot(x, allNevada_2017, 'gx', label='All tweets that collected in Nevada')
plt.plot(x, allArizona_2017, 'cx', label='All tweets that collected in Arizona')


plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(12, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))

drawRegressionLine_two_section(allCalifornia_2017, color='r')
drawRegressionLine_two_section(allOregon_2017, color='b')
drawRegressionLine_two_section(allNevada_2017, color='g')
drawRegressionLine_two_section(allArizona_2017, color='c')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for tweets that collected from Twitter in different states by month. ')
# plt.figure(figsize=(40,1))
plt.show()
# Out:
# slope:  [-335023.3371946207, -33357.2217472664]
# intercept:  [10070613.855709523, 5950167.814671075]
# R^2:  [0.734499012004541, 0.09217921056174583]
# slope:  [-13222.863505672221, -1858.143027273191]
# intercept:  [632124.4992811972, 427840.5526317357]
# R^2:  [0.645383817401807, 0.06188599059559863]
# slope:  [-25341.40176024697, -908.1925979977341]
# intercept:  [856261.9598334475, 524691.3821761678]
# R^2:  [0.6094178532730326, 0.006840309766082298]
# slope:  [-41193.77591462368, -3603.6099219664156]
# intercept:  [1373668.9341970969, 781481.2400680198]
# R^2:  [0.7789495110819668, 0.06484702231526696]

# %% [markdown]
# ------------------------------------------------
# add after.

# %%
# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


# plt.plot(x, California_allECigarette_2017, 'rx', label='California e-cigarette realated tweets')
plt.plot(x, users_California_2017, 'rx', label='Twitter users in California')
plt.plot(x, users_Oregon_2017, 'bx', label='Twitter users in Oregon')
plt.plot(x, users_Nevada_2017, 'gx', label='Twitter users in Nevada')
plt.plot(x, users_Arizona_2017, 'cx', label='Twitter users in Arizona')
# plt.plot(x, average_num_per_persion_tweets_SF_ecig, 'm-', label='not first person')
plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(12, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))


drawRegressionLine_two_section(users_California_2017, color='r')
drawRegressionLine_two_section(users_Oregon_2017, color='b')
drawRegressionLine_two_section(users_Nevada_2017, color='g')
drawRegressionLine_two_section(users_Arizona_2017, color='c')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for number of Twitter users in different states by month. ')
# plt.figure(figsize=(40,1))
plt.show()
# Out:
# slope:  [-6434.055925096836, -2503.4661676582173]
# intercept:  [391851.4742727773, 347921.387987594]
# R^2:  [0.5795659585530448, 0.42607358880726054]
# slope:  [-604.6503383585372, -302.46999465206665]
# intercept:  [34516.24352763862, 31573.1198716496]
# R^2:  [0.5458281789106382, 0.5157153215411201]
# slope:  [-921.7377637103685, -236.10846851995933]
# intercept:  [49882.30770040703, 43057.76324447903]
# R^2:  [0.34107699453483686, 0.13669434122617374]
# slope:  [-372.3846137917176, -221.13308591640805]
# intercept:  [54731.4486721689, 48385.03402870949]
# R^2:  [0.30307326751684505, 0.16414176138074066]

# %%
x
# Out:
# ['2016-04',
#  '2016-05',
#  '2016-06',
#  '2016-07',
#  '2016-08',
#  '2016-09',
#  '2016-10',
#  '2016-11',
#  '2016-12',
#  '2017-01',
#  '2017-02',
#  '2017-03',
#  '2017-04',
#  '2017-05',
#  '2017-06',
#  '2017-07',
#  '2017-08',
#  '2017-09',
#  '2017-10',
#  '2017-11',
#  '2017-12',
#  '2018-01',
#  '2018-02',
#  '2018-03',
#  '2018-04',
#  '2018-05',
#  '2018-06',
#  '2018-07',
#  '2018-08',
#  '2018-09',
#  '2018-10',
#  '2018-11',
#  '2018-12',
#  '2019-01',
#  '2019-02',
#  '2019-03',
#  '2019-04']

# %%
# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


# plt.plot(x, California_allECigarette_2017, 'rx', label='California e-cigarette realated tweets')
plt.plot(x, average_num_per_person_tweets_California, 'rx', label='California tweets per person')
plt.plot(x, average_num_per_person_tweets_Oregon, 'bx', label='Oregon tweets per person')
plt.plot(x, average_num_per_person_tweets_Nevada, 'gx', label='Nevada tweets per person')
plt.plot(x, average_num_per_person_tweets_Arizona, 'cx', label='Arizona tweets per person')
# plt.plot(x, average_num_per_persion_tweets_SF_ecig, 'm-', label='not first person')
plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(12, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))


drawRegressionLine_two_section(average_num_per_person_tweets_California, color='r')
drawRegressionLine_two_section(average_num_per_person_tweets_Oregon, color='b')
drawRegressionLine_two_section(average_num_per_person_tweets_Nevada, color='g')
drawRegressionLine_two_section(average_num_per_person_tweets_Arizona, color='c')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for average tweets number per person post tweets in different states by month. ')
# plt.figure(figsize=(40,1))
plt.show()
# Out:
# slope:  [-0.5409139921182968, 0.049272740189434505]
# intercept:  [25.91299343018854, 16.63332395963463]
# R^2:  [0.767854293176491, 0.0439393737691256]
# slope:  [-0.08196509501168059, 0.1306660423163093]
# intercept:  [18.402386591374743, 12.665238378660536]
# R^2:  [0.05521733214856128, 0.2984918544448699]
# slope:  [-0.2504815323884022, 0.06593542297109396]
# intercept:  [17.328199545942336, 11.823502622090762]
# R^2:  [0.5947075196307333, 0.15372462381957552]
# slope:  [-0.6355721628882005, 0.006451971667011502]
# intercept:  [25.207287928922028, 15.91887995660027]
# R^2:  [0.8069321816877938, 0.0009572620421838263]

# %% [markdown]
# ----------------------------
#
# propotion

# %%
# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


plt.plot(x, propotion_California_in_all_tweets, 'rx', label='Propotion of California tweets in all tweets')
plt.plot(x, propotion_Oregon_in_all_tweets, 'bx', label='Propotion of Oregon tweets in all tweets')
plt.plot(x, propotion_Nevada_in_all_tweets, 'gx', label='Propotion of Nevada tweets in all tweets')
plt.plot(x, propotion_Arizona_in_all_tweets, 'cx', label='Propotion of Arizona tweets in all tweets')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(12, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))

drawRegressionLine_two_section(propotion_California_in_all_tweets, color='r')
drawRegressionLine_two_section(propotion_Oregon_in_all_tweets, color='b')
drawRegressionLine_two_section(propotion_Nevada_in_all_tweets, color='g')
drawRegressionLine_two_section(propotion_Arizona_in_all_tweets, color='c')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Propotion (%)')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Propotion of different states tweets in all tweets that collected from Twitter.')
# plt.figure(figsize=(40,1))
plt.show()
# Out:
# slope:  [-0.08313149909690765, -0.0028449142034996378]
# intercept:  [12.685728029828699, 12.275779975610181]
# R^2:  [0.5114934615842548, 0.006125740089976239]
# slope:  [0.010050180519845076, 0.0012643560031343481]
# intercept:  [0.7846214514828247, 0.8804164951011255]
# R^2:  [0.42564912399299737, 0.13528971419826974]
# slope:  [-0.0013311375148497007, 0.005437188493343625]
# intercept:  [1.074306490883083, 1.0613077817867635]
# R^2:  [0.0174989254921607, 0.4154907189218986]
# slope:  [-0.003768005334282565, 0.001364441880962186]
# intercept:  [1.7310936042961087, 1.6172356875279628]
# R^2:  [0.06881793866387587, 0.051248323033373566]

# %%
# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


plt.plot(x, propotion_California_ecig_in_all_ecig, 'rx', label='Propotion of California ecig tweets in all ecig tweets')
plt.plot(x, propotion_Oregon_ecig_in_all_ecig, 'bx', label='Propotion of Oregon ecig tweets in all ecig tweets')
plt.plot(x, propotion_Nevada_ecig_in_all_ecig, 'gx', label='Propotion of Nevada ecig tweets in all ecig tweets')
plt.plot(x, propotion_Arizona_ecig_in_all_ecig, 'cx', label='Propotion of Arizona ecig tweets in all ecig tweets')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(12, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))

drawRegressionLine_two_section(propotion_California_ecig_in_all_ecig, color='r')
drawRegressionLine_two_section(propotion_Oregon_ecig_in_all_ecig, color='b')
drawRegressionLine_two_section(propotion_Nevada_ecig_in_all_ecig, color='g')
drawRegressionLine_two_section(propotion_Arizona_ecig_in_all_ecig, color='c')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Propotion (%)')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Propotion of different states e-cigarette tweets in all e-cigarette tweets that collected from Twitter.')
# plt.figure(figsize=(40,1))
plt.show()
# Out:
# slope:  [-0.09384435281584147, -0.10621493065980481]
# intercept:  [15.479410624823208, 14.77501869441739]
# R^2:  [0.10991618884992072, 0.5825451652167167]
# slope:  [0.044266207744821484, -0.038968869044691434]
# intercept:  [1.1856234612548517, 2.33272576473971]
# R^2:  [0.4027548289136744, 0.7829838416121105]
# slope:  [0.16131981639701082, -0.06939526808558899]
# intercept:  [1.3991290497000004, 3.464843660575604]
# R^2:  [0.6468005332162584, 0.42937036618072466]
# slope:  [-0.019086791310536193, -0.011561780646944353]
# intercept:  [2.461122413700058, 2.5802146300700946]
# R^2:  [0.04945096393410875, 0.09698066503502156]

# %%
# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


plt.plot(x, propotion_California_ecig_in_all_California_tweets, 'rx', label='Propotion of California ecig tweets in all California tweets')
plt.plot(x, propotion_Oregon_ecig_in_all_Oregon_tweets, 'bx', label='Propotion of Oregon ecig tweets in all Oregon tweets')
plt.plot(x, propotion_Nevada_ecig_in_all_Nevada_tweets, 'gx', label='Propotion of Nevada ecig tweets in all Nevada tweets')
plt.plot(x, propotion_Arizona_ecig_in_all_Arizona_tweets, 'cx', label='Propotion of Arizona ecig tweets in all Arizona tweets')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(12, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))

drawRegressionLine_two_section(propotion_California_ecig_in_all_California_tweets, color='r')
drawRegressionLine_two_section(propotion_Oregon_ecig_in_all_Oregon_tweets, color='b')
drawRegressionLine_two_section(propotion_Nevada_ecig_in_all_Nevada_tweets, color='g')
drawRegressionLine_two_section(propotion_Arizona_ecig_in_all_Arizona_tweets, color='c')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Propotion (%)')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Propotion of different state e-cigarette tweets in all tweets that collected from the same state.')
# plt.figure(figsize=(40,1))
plt.show()
# Out:
# slope:  [-0.00037235161674264994, 0.0003762716764416085]
# intercept:  [0.03625298277946187, 0.027297275266573773]
# R^2:  [0.3381765265988733, 0.5817997401179016]
# slope:  [0.00042630056148218465, -0.0005289764037652134]
# intercept:  [0.044943366069916446, 0.06734050178544629]
# R^2:  [0.07426220201675471, 0.3018428265784504]
# slope:  [0.003710747264772274, -0.0011523842232834536]
# intercept:  [0.03965767351976768, 0.08115839792722401]
# R^2:  [0.4582531652591926, 0.22142088275768446]
# slope:  [-0.0007005781675977207, 0.0006307508730988754]
# intercept:  [0.04247305406415436, 0.03568397647441891]
# R^2:  [0.17722813188722453, 0.36577583600797514]

# %% [markdown]
# ----------------------------
# Sentiment analysis

# %%
# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


plt.plot(x, vader_positive_California_2017, 'rx', label='Positive towards e-cigarette in California')
plt.plot(x, vader_positive_Oregon_2017, 'bx', label='Positive towards e-cigarette in Oregon')
plt.plot(x, vader_positive_Nevada_2017, 'gx', label='Positive towards e-cigarette in Nevada')
plt.plot(x, vader_positive_Arizona_2017, 'cx', label='Positive towards e-cigarette in Arizona')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(12, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))

drawRegressionLine_two_section(vader_positive_California_2017, color='r')
drawRegressionLine_two_section(vader_positive_Oregon_2017, color='b')
drawRegressionLine_two_section(vader_positive_Nevada_2017, color='g')
drawRegressionLine_two_section(vader_positive_Arizona_2017, color='c')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for positive attitude towards e-cigarette by month. Y-axis represents the number of corresponding tweets within each month. ')
# plt.figure(figsize=(40,1))
plt.show()
# Out:
# slope:  [-45.44405645238917, 2.314615384618243]
# intercept:  [1190.858977154807, 544.9692307704175]
# R^2:  [0.8165519627236377, 0.03130610949270196]
# slope:  [0.09090909090710686, -1.3007692307742524]
# intercept:  [104.00000000022469, 102.09846153868213]
# R^2:  [0.0003798836971451447, 0.25022077678425825]
# slope:  [11.982517482541438, -7.43615384617225]
# intercept:  [114.17948717973402, 295.4276923083346]
# R^2:  [0.3070491452500034, 0.3924277896063503]
# slope:  [-10.7272727272983, 0.5199999999989542]
# intercept:  [210.5000000004569, 97.76000000021102]
# R^2:  [0.7423483720682258, 0.024736533957845364]

# %%
# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


plt.plot(x, vader_neutral_California_2017, 'rx', label='Neutral towards e-cigarette in California')
plt.plot(x, vader_neutral_Oregon_2017, 'bx', label='Neutral towards e-cigarette in Oregon')
plt.plot(x, vader_neutral_Nevada_2017, 'gx', label='Neutral towards e-cigarette in Nevada')
plt.plot(x, vader_neutral_Arizona_2017, 'cx', label='Neutral towards e-cigarette in Arizona')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(12, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))

drawRegressionLine_two_section(vader_neutral_California_2017, color='r')
drawRegressionLine_two_section(vader_neutral_Oregon_2017, color='b')
drawRegressionLine_two_section(vader_neutral_Nevada_2017, color='g')
drawRegressionLine_two_section(vader_neutral_Arizona_2017, color='c')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for neutral attitude towards e-cigarette by month. Y-axis represents the number of corresponding tweets within each month. ')
# plt.figure(figsize=(40,1))
plt.show()
# Out:
# slope:  [-72.33566373650619, -1.2146153846202385]
# intercept:  [1818.3461513562618, 911.1107692327552]
# R^2:  [0.7991004587886319, 0.004240493905123266]
# slope:  [-2.311188797733001, -1.9515384615449016]
# intercept:  [133.79487172086485, 147.8769230772435]
# R^2:  [0.13131491232719006, 0.3631146022374161]
# slope:  [-1.4020979021031414, -0.010000000002202691]
# intercept:  [195.2948717952956, 109.36000000023634]
# R^2:  [0.014563634823958282, 7.378549081948904e-06]
# slope:  [-9.944056006846017, 0.8576923076919966]
# intercept:  [261.5256413709864, 135.05538461567704]
# R^2:  [0.47853154189379077, 0.03831781870956852]

# %%
# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


plt.plot(x, vader_negative_California_2017, 'rx', label='Negative towards e-cigarette in California')
plt.plot(x, vader_negative_Oregon_2017, 'bx', label='Negative towards e-cigarette in Oregon')
plt.plot(x, vader_negative_Nevada_2017, 'gx', label='Negative towards e-cigarette in Nevada')
plt.plot(x, vader_negative_Arizona_2017, 'cx', label='Negative towards e-cigarette in Arizona')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(12, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))

drawRegressionLine_two_section(vader_negative_California_2017, color='r')
drawRegressionLine_two_section(vader_negative_Oregon_2017, color='b')
drawRegressionLine_two_section(vader_negative_Nevada_2017, color='g')
drawRegressionLine_two_section(vader_negative_Arizona_2017, color='c')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for negative attitude towards e-cigarette by month. Y-axis represents the number of corresponding tweets within each month. ')
# plt.figure(figsize=(40,1))
plt.show()
# Out:
# slope:  [-28.772727272792217, 6.58692307693526]
# intercept:  [620.1666666680172, 222.95384615433042]
# R^2:  [0.8874937989358733, 0.3040851082345213]
# slope:  [-1.486013986019409, 0.28538461393205794]
# intercept:  [46.58974358984303, 31.470769279407044]
# R^2:  [0.2905263868999206, 0.03752611868680267]
# slope:  [-1.989510489517011, 0.6946153846147181]
# intercept:  [56.35897435909511, 28.569230769290915]
# R^2:  [0.31429312901711215, 0.187427594995366]
# slope:  [-3.4545454545551753, 1.2046153753035713]
# intercept:  [106.66666666689716, 57.849231033313295]
# R^2:  [0.3682132022178053, 0.14432646285298356]

# %% [markdown]
# ---------------------------------------
# Proportion in sentiment analysis

# %%
# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


plt.plot(x, propotion_positive_ecig_California, 'rx', label='Positive towards e-cigarette in California')
plt.plot(x, propotion_positive_ecig_Oregon, 'bx', label='Positive towards e-cigarette in Oregon')
plt.plot(x, propotion_positive_ecig_Nevada, 'gx', label='Positive towards e-cigarette in Nevada')
plt.plot(x, propotion_positive_ecig_Arizona, 'cx', label='Positive towards e-cigarette in Arizona')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(12, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))

drawRegressionLine_two_section(propotion_positive_ecig_California, color='r')
drawRegressionLine_two_section(propotion_positive_ecig_Oregon, color='b')
drawRegressionLine_two_section(propotion_positive_ecig_Nevada, color='g')
drawRegressionLine_two_section(propotion_positive_ecig_Arizona, color='c')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Propotion (%)')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for positive attitude towards e-cigarette by month. Y-axis represents the propotion of corresponding tweets within each month. ')
# plt.figure(figsize=(40,1))
plt.show()
# Out:
# slope:  [0.11720676218013137, -0.00803525352119916]
# intercept:  [32.76278927732085, 32.458853631726]
# R^2:  [0.19659010782536057, 0.0020394214676389133]
# slope:  [0.6295143205218405, -0.143764796389656]
# intercept:  [36.16958366256505, 36.87897861597102]
# R^2:  [0.43865928933783926, 0.08709534406291619]
# slope:  [1.7061609048251591, -1.1731096926945952]
# intercept:  [33.091860447292476, 67.5747524491598]
# R^2:  [0.26361305375289534, 0.5097315484353695]
# slope:  [-0.567163317487031, -0.07445449336935828]
# intercept:  [36.83101868127237, 33.163276673888795]
# R^2:  [0.4500619262803881, 0.02701914595425703]

# %%
# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


plt.plot(x, propotion_neutral_ecig_California, 'rx', label='Neutral towards e-cigarette in California')
plt.plot(x, propotion_neutral_ecig_Oregon, 'bx', label='Neutral towards e-cigarette in Oregon')
plt.plot(x, propotion_neutral_ecig_Nevada, 'gx', label='Neutral towards e-cigarette in Nevada')
plt.plot(x, propotion_neutral_ecig_Arizona, 'cx', label='Neutral towards e-cigarette in Arizona')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(12, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))

drawRegressionLine_two_section(propotion_neutral_ecig_California, color='r')
drawRegressionLine_two_section(propotion_neutral_ecig_Oregon, color='b')
drawRegressionLine_two_section(propotion_neutral_ecig_Nevada, color='g')
drawRegressionLine_two_section(propotion_neutral_ecig_Arizona, color='c')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Propotion (%)')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for neutral attitude towards e-cigarette by month. Y-axis represents the propotion of corresponding tweets within each month. ')
# plt.figure(figsize=(40,1))
plt.show()
# Out:
# slope:  [0.06477416704980576, -0.27783189171210565]
# intercept:  [49.97713526362254, 54.13253546055692]
# R^2:  [0.040391249177727295, 0.6713561119642033]
# slope:  [-0.29966745998555067, -0.23006187287837232]
# intercept:  [47.3479581568112, 53.623375663814016]
# R^2:  [0.09380949640104963, 0.1329988726164325]
# slope:  [-1.0765894923356591, 0.7424945327849355]
# intercept:  [52.23008478164016, 24.35214430902846]
# R^2:  [0.14951200258002662, 0.5223308217954165]
# slope:  [0.26408608070679673, -0.0944498306795798]
# intercept:  [44.973365028523546, 46.480182679075654]
# R^2:  [0.10500855186360802, 0.04412149189416248]

# %%
# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


plt.plot(x, propotion_negative_ecig_California, 'rx', label='Negative towards e-cigarette in California')
plt.plot(x, propotion_negative_ecig_Oregon, 'bx', label='Negative towards e-cigarette in Oregon')
plt.plot(x, propotion_negative_ecig_Nevada, 'gx', label='Negative towards e-cigarette in Nevada')
plt.plot(x, propotion_negative_ecig_Arizona, 'cx', label='Negative towards e-cigarette in Arizona')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(12, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))

drawRegressionLine_two_section(propotion_negative_ecig_California, color='r')
drawRegressionLine_two_section(propotion_negative_ecig_Oregon, color='b')
drawRegressionLine_two_section(propotion_negative_ecig_Nevada, color='g')
drawRegressionLine_two_section(propotion_negative_ecig_Arizona, color='c')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Propotion (%)')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for negative attitude towards e-cigarette by month. Y-axis represents the propotion of corresponding tweets within each month. ')
# plt.figure(figsize=(40,1))
plt.show()
# Out:
# slope:  [-0.18198092923647957, 0.28586714480103825]
# intercept:  [17.26007545926817, 13.408610922742158]
# R^2:  [0.4564953912176689, 0.6548645954821182]
# slope:  [-0.32984685558522675, 0.3738266693983019]
# intercept:  [16.48245815536921, 9.497645720123097]
# R^2:  [0.11598437562390773, 0.42441574642770863]
# slope:  [-0.6295713940947105, 0.4306151599031146]
# intercept:  [14.678054709889475, 8.073103242023365]
# R^2:  [0.4841877364321442, 0.29142388236531314]
# slope:  [0.3030772367736919, 0.1689043240423922]
# intercept:  [18.195616290415654, 20.356540647247197]
# R^2:  [0.28104470230885337, 0.1211958118798604]

# %%
# Fourth figure
x1 = np.linspace(1, 12, 12)
x2 = np.tile(x1, 2)
x3 = np.linspace(1, 6, 6)
# x = np.tile(x, 2)
# itemNum = len(x)

x = np.concatenate((x2, x3), axis=0)
x = list(x)
x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12',
    '2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06', '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12',
    '2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06', ]

plt.figure(figsize=(14,7))


# print(x)
itemNum = len(x)
# print(itemNum)


# plt.subplot(2, 1, 1)
plt.plot(x, np.ones(itemNum), 'r-', label='tobacco related positive')
plt.plot(x, np.ones(itemNum)-0.1, 'r--', label='tobacco related neutral')
plt.plot(x, np.ones(itemNum)-0.2, 'r-.', label='tobacco related negtive')

plt.plot(x, np.ones(itemNum)-0.3, 'g-', label='e-cigarette realated positive')
plt.plot(x, np.ones(itemNum)-0.4, 'g--', label='e-cigarette related neutral')
plt.plot(x, np.ones(itemNum)-0.5, 'g-.', label='e-cigarette related negtive')

plt.plot(x, np.ones(itemNum)-0.6, 'b-', label='other tobacco positive')
plt.plot(x, np.ones(itemNum)-0.7, 'b--', label='other tobacco neutral')
plt.plot(x, np.ones(itemNum)-0.8, 'b-.', label='other tobacco negtive')

plt.plot(x, np.ones(itemNum)-0.9, 'y-', label='first person positive')
plt.plot(x, np.ones(itemNum)-1, 'y--', label='first person neutral')
plt.plot(x, np.ones(itemNum)-1.1, 'y-.', label='first person negtive')

plt.plot(x, np.ones(itemNum)-1.2, 'm-', label='not first person positive')
plt.plot(x, np.ones(itemNum)-1.3, 'm--', label='not first person neutral')
plt.plot(x, np.ones(itemNum)-1.4, 'm-.', label='not first person negtive')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(5, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Proposal', xy=(4,-0.3))
plt.axvline(17, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Approved', xy=(16,-0.3))
plt.axvline(24, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Enforcement ', xy=(23,-0.3))




plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Attitude')
plt.title('Figure 4: Trends for attitude towards tobacco by month. Y-axis represents the propotion of corresponding tweets within each month. ')
# plt.figure(figsize=(40,1))
plt.show()

# %%
# # Second figure
# x1 = np.linspace(1, 12, 12)
# x2 = np.tile(x1, 2)
# x3 = np.linspace(1, 6, 6)
# # x = np.tile(x, 2)
# # itemNum = len(x)

# x = np.concatenate((x2, x3), axis=0)
# x = list(x)
# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12',
#     '2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06', '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12',
#     '2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06', ]

# plt.figure(figsize=(14,7))


# # print(x)
# itemNum = len(x)
# print(itemNum)


# # plt.subplot(2, 1, 1)
# plt.plot(x, np.ones(itemNum), 'r-', label='mentioning tweets')
# plt.plot(x, np.ones(itemNum)/2, 'g-.', label='mentioning users')
# plt.plot(x, np.zeros(itemNum), 'b.', label='first person users')
# plt.legend()
# # plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
# plt.axvline(5, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))
# plt.axvline(17, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Approved', xy=(16,0.1))
# plt.axvline(24, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Enforcement ', xy=(23,0.1))




# plt.xticks(rotation=80)
# plt.xlabel('Month')
# plt.ylabel('# of mentioning')
# plt.title('Figure 1: Trends for number of tobacco related tweet by month. Y-axis represents the number of corresponding tweets within each month. ')
# # plt.figure(figsize=(40,1))
# plt.show()
