# %%
import matplotlib.pyplot as plt
import numpy as np

from scipy import optimize

# %%
import datetime

import matplotlib as mpl
 
fig = plt.figure()
 
start = datetime.datetime(2016, 1, 1)
end = datetime.datetime(2017, 1, 1)
# 设置日期的间隔为1
delta = datetime.timedelta(days= 29)
 
# 生成一个matplotlib可以识别的日期对象
dates = mpl.dates.drange(start, end, delta)

print(dates)

date_format = mpl.dates.DateFormatter("%Y-%m")
print(date_format)
# Out:
# [735964. 735993. 736022. 736051. 736080. 736109. 736138. 736167. 736196.
#  736225. 736254. 736283. 736312.]
# <matplotlib.dates.DateFormatter object at 0x7ff36c6b8630>

# %%
# Number

# ----------------------------- Delaware -----------------------------
# Delaware_allECigarette
Delaware_allECigarette = [16, 5, 10, 7, 17, 17, 17, 12, 13, 23, 15, 32]
print('length of Delaware_allECigarette: ', len(Delaware_allECigarette))

# not_Delaware_allECigarette
not_Delaware_allECigarette = [13551, 14084, 6923, 9338, 15622, 15664, 17339, 15397, 17309, 17225, 15527, 16271]
print('length of not_Delaware_allECigarette: ', len(not_Delaware_allECigarette))

# allECigarette
allECigarette = []
for i in range(12):
    allECigarette.append(Delaware_allECigarette[i]+not_Delaware_allECigarette[i])
print('length of allECigarette: ', len(allECigarette))


# allDelaware
allDelaware = [53764, 56830, 26115, 39980, 55502, 47932, 56502, 52335, 62645, 62067, 56398, 49702]
print('length of allDelaware: ', len(allDelaware))


# Number of users that tweets ecig in Delaware.
users_Delaware_ecig = [13, 5, 10, 6, 15, 15, 15, 11, 12, 14, 13, 14]
print('length of users_Delaware_ecig: ', len(users_Delaware_ecig))


# average number of per person tweets about ecig in Delaware.
average_num_per_person_tweets_Delaware_ecig = []
for i in range(12):
    average_num_per_person_tweets_Delaware_ecig.append(Delaware_allECigarette[i]/users_Delaware_ecig[i])
print('length of average_num_per_person_tweets_Delaware_ecig: ', len(average_num_per_person_tweets_Delaware_ecig))


# Number of users that tweets in Delaware
users_Delaware = [6128, 6001, 3244, 3621, 4531, 4326, 3694, 3806, 4239, 4162, 4430, 4755]
print('length of users_Delaware: ', len(users_Delaware))

# allTweets
allTweets = [50163222, 51079160, 22112648, 31365136, 46232294, 43487766, 46059070, 40432909, 47289301, 45660765, 44166238, 44212483]
print('length of allTweets: ', len(allTweets))

# Sentiment analysis
vader_positive_Delaware = [6, 2, 0, 2, 4, 3, 5, 1, 5, 5, 9, 8]
vader_neutral_Delaware = [8, 1, 7, 1, 8, 9, 10, 7, 3, 12, 3, 20]
vader_negative_Delaware = [2, 2, 3, 4, 5, 5, 2, 4, 5, 6, 3, 4]
print('length of vader_positive_Delaware: ', len(vader_positive_Delaware))
print('length of vader_neutral_Delaware: ', len(vader_neutral_Delaware))
print('length of vader_negative_Delaware: ', len(vader_negative_Delaware))

print('----------------------------------')
# ----------------------------- NewJersey -----------------------------

# NewJersey_allECigarette
NewJersey_allECigarette = [290, 318, 159, 230, 379, 407, 431, 515, 352, 394, 377, 464]
print('length of NewJersey_allECigarette: ', len(NewJersey_allECigarette))

# not_NewJersey_allECigarette
not_NewJersey_allECigarette = [13277, 13771, 6774, 9115, 15260, 15274, 16925, 14894, 16970, 16854, 15165, 15839]
print('length of not_NewJersey_allECigarette: ', len(not_NewJersey_allECigarette))

# allNewJersey
allNewJersey = [1114713, 1124508, 456279, 662423, 975345, 972957, 1020021, 863451, 994925, 950771, 901259, 936500]
print('length of allNewJersey: ', len(allNewJersey))


# Number of users that tweets ecig in NewJersey.
users_NewJersey_ecig = [200, 235, 118, 144, 252, 235, 291, 270, 253, 247, 242, 269]
print('length of users_NewJersey_ecig: ', len(users_NewJersey_ecig))


# average number of per person tweets about ecig in NewJersey.
average_num_per_person_tweets_NewJersey_ecig = []
for i in range(12):
    average_num_per_person_tweets_NewJersey_ecig.append(NewJersey_allECigarette[i]/users_NewJersey_ecig[i])
print('length of average_num_per_person_tweets_NewJersey_ecig: ', len(average_num_per_person_tweets_NewJersey_ecig))


# Number of users that tweets in NewJersey
users_NewJersey = [79201, 76977, 46205, 54198, 67462, 67514, 59971, 56012, 63296, 61237, 59945, 66088]
print('length of users_NewJersey: ', len(users_NewJersey))

# Sentiment analysis
vader_positive_NewJersey = [93, 108, 44, 58, 98, 141, 138, 124, 102, 110, 107, 134]
vader_neutral_NewJersey = [139, 127, 89, 133, 217, 206, 196, 321, 174, 209, 203, 244]
vader_negative_NewJersey = [58, 83, 26, 39, 64, 60, 97, 70, 76, 75, 67, 86]
print('length of vader_positive_NewJersey: ', len(vader_positive_NewJersey))
print('length of vader_neutral_NewJersey: ', len(vader_neutral_NewJersey))
print('length of vader_negative_NewJersey: ', len(vader_negative_NewJersey))



print('----------------------------------')
# ----------------------------- Pennsylvania -----------------------------

# Pennsylvania_allECigarette
Pennsylvania_allECigarette = [300, 285, 177, 246, 429, 473, 468, 540, 473, 448, 345, 362]
print('length of Pennsylvania_allECigarette: ', len(Pennsylvania_allECigarette))

# not_Pennsylvania_allECigarette
not_Pennsylvania_allECigarette = [13267, 13804, 6756, 9099, 15210, 15208, 16888, 14869, 16849, 16800, 15197, 15941]
print('length of not_Pennsylvania_allECigarette: ', len(not_Pennsylvania_allECigarette))

# allPennsylvania
allPennsylvania = [1066400, 1117120, 503333, 743855, 1088504, 1040445, 1115812, 1014250, 1081833, 1074942, 963058, 927204]
print('length of allPennsylvania: ', len(allPennsylvania))


# Number of users that tweets ecig in Pennsylvania.
users_Pennsylvania_ecig = [190, 193, 121, 175, 300, 300, 323, 337, 310, 352, 282, 269]
print('length of users_Pennsylvania_ecig: ', len(users_Pennsylvania_ecig))


# average number of per person tweets about ecig in Pennsylvania.
average_num_per_person_tweets_Pennsylvania_ecig = []
for i in range(12):
    average_num_per_person_tweets_Pennsylvania_ecig.append(Pennsylvania_allECigarette[i]/users_Pennsylvania_ecig[i])
print('length of average_num_per_person_tweets_Pennsylvania_ecig: ', len(average_num_per_person_tweets_Pennsylvania_ecig))


# Number of users that tweets in Pennsylvania
users_Pennsylvania = [74318, 76297, 52856, 62347, 76226, 72069, 67390, 67943, 70107, 70020, 64301, 65451]
print('length of users_Pennsylvania: ', len(users_Pennsylvania))

# Sentiment analysis
vader_positive_Pennsylvania = [97, 109, 62, 76, 143, 163, 171, 181, 161, 122, 98, 96]
vader_neutral_Pennsylvania = [151, 134, 78, 114, 208, 213, 199, 232, 228, 247, 163, 176]
vader_negative_Pennsylvania = [52, 42, 37, 56, 78, 97, 98, 127, 84, 79, 84, 90]
print('length of vader_positive_Pennsylvania: ', len(vader_positive_Pennsylvania))
print('length of vader_neutral_Pennsylvania: ', len(vader_neutral_Pennsylvania))
print('length of vader_negative_Pennsylvania: ', len(vader_negative_Pennsylvania))


print('----------------------------------')
# ----------------------------- Maryland -----------------------------

# Maryland_allECigarette
Maryland_allECigarette = [151, 147, 72, 99, 202, 196, 243, 191, 229, 243, 206, 241]
print('length of Maryland_allECigarette: ', len(Maryland_allECigarette))

# not_Maryland_allECigarette
not_Maryland_allECigarette = [13416, 13942, 6861, 9246, 15437, 15485, 17113, 15218, 17093, 17005, 15336, 16062]
print('length of not_Maryland_allECigarette: ', len(not_Maryland_allECigarette))

# allMaryland
allMaryland = [913206, 910536, 375999, 543010, 821829, 807107, 820085, 696106, 837322, 817365, 848671, 815445]
print('length of allMaryland: ', len(allMaryland))


# Number of users that tweets ecig in Maryland.
users_Maryland_ecig = [116, 122, 60, 75, 165, 165, 200, 151, 181, 176, 169, 190]
print('length of users_Maryland_ecig: ', len(users_Maryland_ecig))


# average number of per person tweets about ecig in Maryland.
average_num_per_person_tweets_Maryland_ecig = []
for i in range(12):
    average_num_per_person_tweets_Maryland_ecig.append(Maryland_allECigarette[i]/users_Maryland_ecig[i])
print('length of average_num_per_person_tweets_Maryland_ecig: ', len(average_num_per_person_tweets_Maryland_ecig))


# Number of users that tweets in Maryland
users_Maryland = [52472, 52172, 32874, 38400, 48576, 45742, 41852, 40300, 46474, 45044, 44801, 48064]
print('length of users_Maryland: ', len(users_Maryland))

# Sentiment analysis
vader_positive_Maryland = [44, 60, 29, 23, 65, 57, 85, 56, 78, 87, 77, 61]
vader_neutral_Maryland = [70, 59, 24, 51, 88, 92, 111, 83, 110, 103, 85, 119]
vader_negative_Maryland = [37, 28, 19, 25, 49, 47, 47, 52, 41, 53, 44, 61]
print('length of vader_positive_Maryland: ', len(vader_positive_Maryland))
print('length of vader_neutral_Maryland: ', len(vader_neutral_Maryland))
print('length of vader_negative_Maryland: ', len(vader_negative_Maryland))


print('----------------------------------')
# ----------------------------- DC -----------------------------

# DC_allECigarette
DC_allECigarette = [77, 82, 38, 36, 75, 58, 80, 64, 98, 155, 118, 84]
print('length of DC_allECigarette: ', len(DC_allECigarette))

# not_DC_allECigarette
not_DC_allECigarette = [13490, 14007, 6895, 9309, 15564, 15623, 17276, 15345, 17224, 17093, 15424, 16219]
print('length of not_DC_allECigarette: ', len(not_DC_allECigarette))

# allDC
allDC = [416015, 405251, 184175, 279285, 393599, 323480, 377268, 332743, 399649, 386906, 357477, 378537]
print('length of allDC: ', len(allDC))


# Number of users that tweets ecig in DC.
users_DC_ecig = [54, 67, 36, 33, 59, 48, 60, 50, 70, 86, 83, 63]
print('length of users_DC_ecig: ', len(users_DC_ecig))


# average number of per person tweets about ecig in DC.
average_num_per_person_tweets_DC_ecig = []
for i in range(12):
    average_num_per_person_tweets_DC_ecig.append(DC_allECigarette[i]/users_DC_ecig[i])
print('length of average_num_per_person_tweets_DC_ecig: ', len(average_num_per_person_tweets_DC_ecig))


# Number of users that tweets in DC
users_DC = [35488, 32560, 21064, 27727, 33955, 28311, 28878, 27560, 36587, 34803, 30131, 33677]
print('length of users_DC: ', len(users_DC))

# Sentiment analysis
vader_positive_DC = [30, 20, 12, 15, 29, 18, 25, 13, 30, 52, 40, 28]
vader_neutral_DC = [38, 42, 15, 18, 41, 24, 43, 39, 53, 72, 54, 39]
vader_negative_DC = [9, 20, 11, 3, 5, 16, 12, 12, 15, 31, 24, 17]
print('length of vader_positive_DC: ', len(vader_positive_DC))
print('length of vader_neutral_DC: ', len(vader_neutral_DC))
print('length of vader_negative_DC: ', len(vader_negative_DC))
# Out:
# length of Delaware_allECigarette:  12
# length of not_Delaware_allECigarette:  12
# length of allECigarette:  12
# length of allDelaware:  12
# length of users_Delaware_ecig:  12
# length of average_num_per_person_tweets_Delaware_ecig:  12
# length of users_Delaware:  12
# length of allTweets:  12
# length of vader_positive_Delaware:  12
# length of vader_neutral_Delaware:  12
# length of vader_negative_Delaware:  12
# ----------------------------------
# length of NewJersey_allECigarette:  12
# length of not_NewJersey_allECigarette:  12
# length of allNewJersey:  12
# length of users_NewJersey_ecig:  12
# length of average_num_per_person_tweets_NewJersey_ecig:  12
# length of users_NewJersey:  12
# length of vader_positive_NewJersey:  12
# length of vader_neutral_NewJersey:  12
# length of vader_negative_NewJersey:  12
# ----------------------------------
# length of Pennsylvania_allECigarette:  12
# length of not_Pennsylvania_allECigarette:  12
# length of allPennsylvania:  12
# length of users_Pennsylvania_ecig:  12
# length of average_num_per_person_tweets_Pennsylvania_ecig:  12
# length of users_Pennsylvania:  12
# length of vader_positive_Pennsylvania:  12
# length of vader_neutral_Pennsylvania:  12
# length of vader_negative_Pennsylvania:  12
# ----------------------------------
# length of Maryland_allECigarette:  12
# length of not_Maryland_allECigarette:  12
# length of allMaryland:  12
# length of users_Maryland_ecig:  12
# length of average_num_per_person_tweets_Maryland_ecig:  12
# length of users_Maryland:  12
# length of vader_positive_Maryland:  12
# length of vader_neutral_Maryland:  12
# length of vader_negative_Maryland:  12
# ----------------------------------
# length of DC_allECigarette:  12
# length of not_DC_allECigarette:  12
# length of allDC:  12
# length of users_DC_ecig:  12
# length of average_num_per_person_tweets_DC_ecig:  12
# length of users_DC:  12
# length of vader_positive_DC:  12
# length of vader_neutral_DC:  12
# length of vader_negative_DC:  12

# %%
# # Number

# # ----------------------------- Kansas -----------------------------
# # Kansas_allECigarette_2017
# Kansas_allECigarette_2017 = []
# print('length of Kansas_allECigarette_2017: ', len(Kansas_allECigarette_2017))

# # not_Kansas_allECigarette_2017
# not_Kansas_allECigarette_2017 = []
# print('length of not_Kansas_allECigarette_2017: ', len(not_Kansas_allECigarette_2017))

# # allECigarette_2017
# allECigarette_2017 = []
# for i in range(12):
#     allECigarette_2017.append(Kansas_allECigarette_2017[i]+not_Kansas_allECigarette_2017[i])
# print('length of allECigarette_2017: ', len(allECigarette_2017))


# # allKansas_2017
# allKansas_2017 = []
# print('length of allKansas_2017: ', len(allKansas_2017))


# # Number of users that tweets ecig in Kansas.
# users_Kansas_ecig_2017 = []
# print('length of users_Kansas_ecig_2017: ', len(users_Kansas_ecig_2017))


# # average number of per person tweets about ecig in Kansas.
# average_num_per_person_tweets_Kansas_ecig = []
# for i in range(12):
#     average_num_per_person_tweets_Kansas_ecig.append(Kansas_allECigarette_2017[i]/users_Kansas_ecig_2017[i])
# print('length of average_num_per_person_tweets_Kansas_ecig: ', len(average_num_per_person_tweets_Kansas_ecig))


# # Number of users that tweets in Kansas
# users_Kansas_2017 = []
# print('length of users_Kansas_2017: ', len(users_Kansas_2017))

# # allTweets
# allTweets_2017 = []
# print('length of allTweets_2017: ', len(allTweets_2017))

# # Sentiment analysis
# vader_positive_Kansas_2017 = []
# vader_neutral_Kansas_2017 = []
# vader_negative_Kansas_2017 = []
# print('length of vader_positive_Kansas_2017: ', len(vader_positive_Kansas_2017))
# print('length of vader_neutral_Kansas_2017: ', len(vader_neutral_Kansas_2017))
# print('length of vader_negative_Kansas_2017: ', len(vader_negative_Kansas_2017))

# print('----------------------------------')
# # ----------------------------- Nebraska -----------------------------

# # Nebraska_allECigarette_2017
# Nebraska_allECigarette_2017 = []
# print('length of Nebraska_allECigarette_2017: ', len(Nebraska_allECigarette_2017))

# # not_Nebraska_allECigarette_2017
# not_Nebraska_allECigarette_2017 = []
# print('length of not_Nebraska_allECigarette_2017: ', len(not_Nebraska_allECigarette_2017))

# # allNebraska_2017
# allNebraska_2017 = []
# print('length of allNebraska_2017: ', len(allNebraska_2017))


# # Number of users that tweets ecig in Nebraska.
# users_Nebraska_ecig_2017 = []
# print('length of users_Nebraska_ecig_2017: ', len(users_Nebraska_ecig_2017))


# # average number of per person tweets about ecig in Nebraska.
# average_num_per_person_tweets_Nebraska_ecig = []
# for i in range(12):
#     average_num_per_person_tweets_Nebraska_ecig.append(Nebraska_allECigarette_2017[i]/users_Nebraska_ecig_2017[i])
# print('length of average_num_per_person_tweets_Nebraska_ecig: ', len(average_num_per_person_tweets_Nebraska_ecig))


# # Number of users that tweets in Nebraska
# users_Nebraska_2017 = []
# print('length of users_Nebraska_2017: ', len(users_Nebraska_2017))

# # Sentiment analysis
# vader_positive_Nebraska_2017 = []
# vader_neutral_Nebraska_2017 = []
# vader_negative_Nebraska_2017 = []
# print('length of vader_positive_Nebraska_2017: ', len(vader_positive_Nebraska_2017))
# print('length of vader_neutral_Nebraska_2017: ', len(vader_neutral_Nebraska_2017))
# print('length of vader_negative_Nebraska_2017: ', len(vader_negative_Nebraska_2017))



# print('----------------------------------')
# # ----------------------------- Missouri -----------------------------

# # Missouri_allECigarette_2017
# Missouri_allECigarette_2017 = []
# print('length of Missouri_allECigarette_2017: ', len(Missouri_allECigarette_2017))

# # not_Missouri_allECigarette_2017
# not_Missouri_allECigarette_2017 = []
# print('length of not_Missouri_allECigarette_2017: ', len(not_Missouri_allECigarette_2017))

# # allMissouri_2017
# allMissouri_2017 = []
# print('length of allMissouri_2017: ', len(allMissouri_2017))


# # Number of users that tweets ecig in Missouri.
# users_Missouri_ecig_2017 = []
# print('length of users_Missouri_ecig_2017: ', len(users_Missouri_ecig_2017))


# # average number of per person tweets about ecig in Missouri.
# average_num_per_person_tweets_Missouri_ecig = []
# for i in range(12):
#     average_num_per_person_tweets_Missouri_ecig.append(Missouri_allECigarette_2017[i]/users_Missouri_ecig_2017[i])
# print('length of average_num_per_person_tweets_Missouri_ecig: ', len(average_num_per_person_tweets_Missouri_ecig))


# # Number of users that tweets in Missouri
# users_Missouri_2017 = []
# print('length of users_Missouri_2017: ', len(users_Missouri_2017))

# # Sentiment analysis
# vader_positive_Missouri_2017 = []
# vader_neutral_Missouri_2017 = []
# vader_negative_Missouri_2017 = []
# print('length of vader_positive_Missouri_2017: ', len(vader_positive_Missouri_2017))
# print('length of vader_neutral_Missouri_2017: ', len(vader_neutral_Missouri_2017))
# print('length of vader_negative_Missouri_2017: ', len(vader_negative_Missouri_2017))


# print('----------------------------------')
# # ----------------------------- Oklahoma -----------------------------

# # Oklahoma_allECigarette_2017
# Oklahoma_allECigarette_2017 = []
# print('length of Oklahoma_allECigarette_2017: ', len(Oklahoma_allECigarette_2017))

# # not_Oklahoma_allECigarette_2017
# not_Oklahoma_allECigarette_2017 = []
# print('length of not_Oklahoma_allECigarette_2017: ', len(not_Oklahoma_allECigarette_2017))

# # allOklahoma_2017
# allOklahoma_2017 = []
# print('length of allOklahoma_2017: ', len(allOklahoma_2017))


# # Number of users that tweets ecig in Oklahoma.
# users_Oklahoma_ecig_2017 = []
# print('length of users_Oklahoma_ecig_2017: ', len(users_Oklahoma_ecig_2017))


# # average number of per person tweets about ecig in Oklahoma.
# average_num_per_person_tweets_Oklahoma_ecig = []
# for i in range(12):
#     average_num_per_person_tweets_Oklahoma_ecig.append(Oklahoma_allECigarette_2017[i]/users_Oklahoma_ecig_2017[i])
# print('length of average_num_per_person_tweets_Oklahoma_ecig: ', len(average_num_per_person_tweets_Oklahoma_ecig))


# # Number of users that tweets in Oklahoma
# users_Oklahoma_2017 = []
# print('length of users_Oklahoma_2017: ', len(users_Oklahoma_2017))

# # Sentiment analysis
# vader_positive_Oklahoma_2017 = []
# vader_neutral_Oklahoma_2017 = []
# vader_negative_Oklahoma_2017 = []
# print('length of vader_positive_Oklahoma_2017: ', len(vader_positive_Oklahoma_2017))
# print('length of vader_neutral_Oklahoma_2017: ', len(vader_neutral_Oklahoma_2017))
# print('length of vader_negative_Oklahoma_2017: ', len(vader_negative_Oklahoma_2017))


# print('----------------------------------')
# # ----------------------------- Colorado -----------------------------

# # Colorado_allECigarette_2017
# Colorado_allECigarette_2017 = []
# print('length of Colorado_allECigarette_2017: ', len(Colorado_allECigarette_2017))

# # not_Colorado_allECigarette_2017
# not_Colorado_allECigarette_2017 = []
# print('length of not_Colorado_allECigarette_2017: ', len(not_Colorado_allECigarette_2017))

# # allColorado_2017
# allColorado_2017 = []
# print('length of allColorado_2017: ', len(allColorado_2017))


# # Number of users that tweets ecig in Colorado.
# users_Colorado_ecig_2017 = []
# print('length of users_Colorado_ecig_2017: ', len(users_Colorado_ecig_2017))


# # average number of per person tweets about ecig in Colorado.
# average_num_per_person_tweets_Colorado_ecig = []
# for i in range(12):
#     average_num_per_person_tweets_Colorado_ecig.append(Colorado_allECigarette_2017[i]/users_Colorado_ecig_2017[i])
# print('length of average_num_per_person_tweets_Colorado_ecig: ', len(average_num_per_person_tweets_Colorado_ecig))


# # Number of users that tweets in Colorado
# users_Colorado_2017 = []
# print('length of users_Colorado_2017: ', len(users_Colorado_2017))

# # Sentiment analysis
# vader_positive_Colorado_2017 = []
# vader_neutral_Colorado_2017 = []
# vader_negative_Colorado_2017 = []
# print('length of vader_positive_Colorado_2017: ', len(vader_positive_Colorado_2017))
# print('length of vader_neutral_Colorado_2017: ', len(vader_neutral_Colorado_2017))
# print('length of vader_negative_Colorado_2017: ', len(vader_negative_Colorado_2017))

# %%
# Propotion

# ----------------------------- Delaware -----------------------------
propotion_Delaware_ecig_in_all_ecig = []
propotion_Delaware_ecig_in_all_Delaware_tweets = []
propotion_Delaware_in_all_tweets = []
propotion_Delaware_ecig_users_in_all_Delaware_users = []
propotion_positive_ecig_Delaware = []
propotion_neutral_ecig_Delaware = []
propotion_negative_ecig_Delaware = []


# propotion of Delaware e-cig tweets in all e-cig tweets.
for i in range(12):
    propotion_Delaware_ecig_in_all_ecig.append((Delaware_allECigarette[i]/allECigarette[i])*100)
print('length of propotion_Delaware_ecig_in_all_ecig: ', len(propotion_Delaware_ecig_in_all_ecig))


# propotion of Delaware e-cig tweets in all Delaware tweets.
for i in range(12):
    propotion_Delaware_ecig_in_all_Delaware_tweets.append((Delaware_allECigarette[i]/allDelaware[i])*100)
print('length of propotion_Delaware_ecig_in_all_Delaware_tweets: ', len(propotion_Delaware_ecig_in_all_Delaware_tweets))


# propotion of Delaware tweets in total tweets.
for i in range(12):
    propotion_Delaware_in_all_tweets.append((allDelaware[i]/allTweets[i])*100)
print('length of propotion_Delaware_in_all_tweets: ', len(propotion_Delaware_in_all_tweets))


# propotion of users post Delaware e-cig in all Delaware users.
for i in range(12):
    propotion_Delaware_ecig_users_in_all_Delaware_users.append((users_Delaware_ecig[i]/users_Delaware[i])*100)
print('length of propotion_Delaware_ecig_users_in_all_Delaware_users: ', len(propotion_Delaware_ecig_users_in_all_Delaware_users))


# Sentiment analysis
for i in range(12):
    propotion_positive_ecig_Delaware.append((vader_positive_Delaware[i]/Delaware_allECigarette[i])*100)
print('length of propotion_positive_ecig_Delaware: ', len(propotion_positive_ecig_Delaware))

for i in range(12):
    propotion_neutral_ecig_Delaware.append((vader_neutral_Delaware[i]/Delaware_allECigarette[i])*100)
print('length of propotion_neutral_ecig_Delaware: ', len(propotion_neutral_ecig_Delaware))

for i in range(12):
    propotion_negative_ecig_Delaware.append((vader_negative_Delaware[i]/Delaware_allECigarette[i])*100)
print('length of propotion_negative_ecig_Delaware: ', len(propotion_negative_ecig_Delaware))


print('----------------------------------')
# ----------------------------- NewJersey -----------------------------
propotion_NewJersey_ecig_in_all_ecig = []
propotion_NewJersey_ecig_in_all_NewJersey_tweets = []
propotion_NewJersey_in_all_tweets = []
propotion_NewJersey_ecig_users_in_all_NewJersey_users = []
propotion_positive_ecig_NewJersey = []
propotion_neutral_ecig_NewJersey = []
propotion_negative_ecig_NewJersey = []


# propotion of NewJersey e-cig tweets in all e-cig tweets.
for i in range(12):
    propotion_NewJersey_ecig_in_all_ecig.append((NewJersey_allECigarette[i]/allECigarette[i])*100)
print('length of propotion_NewJersey_ecig_in_all_ecig: ', len(propotion_NewJersey_ecig_in_all_ecig))


# propotion of NewJersey e-cig tweets in all NewJersey tweets.
for i in range(12):
    propotion_NewJersey_ecig_in_all_NewJersey_tweets.append((NewJersey_allECigarette[i]/allNewJersey[i])*100)
print('length of propotion_NewJersey_ecig_in_all_NewJersey_tweets: ', len(propotion_NewJersey_ecig_in_all_NewJersey_tweets))


# propotion of NewJersey tweets in total tweets.
for i in range(12):
    propotion_NewJersey_in_all_tweets.append((allNewJersey[i]/allTweets[i])*100)
print('length of propotion_NewJersey_in_all_tweets: ', len(propotion_NewJersey_in_all_tweets))


# propotion of users post NewJersey e-cig in all NewJersey users.
for i in range(12):
    propotion_NewJersey_ecig_users_in_all_NewJersey_users.append((users_NewJersey_ecig[i]/users_NewJersey[i])*100)
print('length of propotion_NewJersey_ecig_users_in_all_NewJersey_users: ', len(propotion_NewJersey_ecig_users_in_all_NewJersey_users))


# Sentiment analysis
for i in range(12):
    propotion_positive_ecig_NewJersey.append((vader_positive_NewJersey[i]/NewJersey_allECigarette[i])*100)
print('length of propotion_positive_ecig_NewJersey: ', len(propotion_positive_ecig_NewJersey))

for i in range(12):
    propotion_neutral_ecig_NewJersey.append((vader_neutral_NewJersey[i]/NewJersey_allECigarette[i])*100)
print('length of propotion_neutral_ecig_NewJersey: ', len(propotion_neutral_ecig_NewJersey))

for i in range(12):
    propotion_negative_ecig_NewJersey.append((vader_negative_NewJersey[i]/NewJersey_allECigarette[i])*100)
print('length of propotion_negative_ecig_NewJersey: ', len(propotion_negative_ecig_NewJersey))


print('----------------------------------')
# ----------------------------- Pennsylvania -----------------------------
propotion_Pennsylvania_ecig_in_all_ecig = []
propotion_Pennsylvania_ecig_in_all_Pennsylvania_tweets = []
propotion_Pennsylvania_in_all_tweets = []
propotion_Pennsylvania_ecig_users_in_all_Pennsylvania_users = []
propotion_positive_ecig_Pennsylvania = []
propotion_neutral_ecig_Pennsylvania = []
propotion_negative_ecig_Pennsylvania = []


# propotion of Pennsylvania e-cig tweets in all e-cig tweets.
for i in range(12):
    propotion_Pennsylvania_ecig_in_all_ecig.append((Pennsylvania_allECigarette[i]/allECigarette[i])*100)
print('length of propotion_Pennsylvania_ecig_in_all_ecig: ', len(propotion_Pennsylvania_ecig_in_all_ecig))


# propotion of Pennsylvania e-cig tweets in all Pennsylvania tweets.
for i in range(12):
    propotion_Pennsylvania_ecig_in_all_Pennsylvania_tweets.append((Pennsylvania_allECigarette[i]/allPennsylvania[i])*100)
print('length of propotion_Pennsylvania_ecig_in_all_Pennsylvania_tweets: ', len(propotion_Pennsylvania_ecig_in_all_Pennsylvania_tweets))


# propotion of Pennsylvania tweets in total tweets.
for i in range(12):
    propotion_Pennsylvania_in_all_tweets.append((allPennsylvania[i]/allTweets[i])*100)
print('length of propotion_Pennsylvania_in_all_tweets: ', len(propotion_Pennsylvania_in_all_tweets))


# propotion of users post Pennsylvania e-cig in all Pennsylvania users.
for i in range(12):
    propotion_Pennsylvania_ecig_users_in_all_Pennsylvania_users.append((users_Pennsylvania_ecig[i]/users_Pennsylvania[i])*100)
print('length of propotion_Pennsylvania_ecig_users_in_all_Pennsylvania_users: ', len(propotion_Pennsylvania_ecig_users_in_all_Pennsylvania_users))


# Sentiment analysis
for i in range(12):
    propotion_positive_ecig_Pennsylvania.append((vader_positive_Pennsylvania[i]/Pennsylvania_allECigarette[i])*100)
print('length of propotion_positive_ecig_Pennsylvania: ', len(propotion_positive_ecig_Pennsylvania))

for i in range(12):
    propotion_neutral_ecig_Pennsylvania.append((vader_neutral_Pennsylvania[i]/Pennsylvania_allECigarette[i])*100)
print('length of propotion_neutral_ecig_Pennsylvania: ', len(propotion_neutral_ecig_Pennsylvania))

for i in range(12):
    propotion_negative_ecig_Pennsylvania.append((vader_negative_Pennsylvania[i]/Pennsylvania_allECigarette[i])*100)
print('length of propotion_negative_ecig_Pennsylvania: ', len(propotion_negative_ecig_Pennsylvania))


print('----------------------------------')
# ----------------------------- Maryland -----------------------------
propotion_Maryland_ecig_in_all_ecig = []
propotion_Maryland_ecig_in_all_Maryland_tweets = []
propotion_Maryland_in_all_tweets = []
propotion_Maryland_ecig_users_in_all_Maryland_users = []
propotion_positive_ecig_Maryland = []
propotion_neutral_ecig_Maryland = []
propotion_negative_ecig_Maryland = []


# propotion of Maryland e-cig tweets in all e-cig tweets.
for i in range(12):
    propotion_Maryland_ecig_in_all_ecig.append((Maryland_allECigarette[i]/allECigarette[i])*100)
print('length of propotion_Maryland_ecig_in_all_ecig: ', len(propotion_Maryland_ecig_in_all_ecig))


# propotion of Maryland e-cig tweets in all Maryland tweets.
for i in range(12):
    propotion_Maryland_ecig_in_all_Maryland_tweets.append((Maryland_allECigarette[i]/allMaryland[i])*100)
print('length of propotion_Maryland_ecig_in_all_Maryland_tweets: ', len(propotion_Maryland_ecig_in_all_Maryland_tweets))


# propotion of Maryland tweets in total tweets.
for i in range(12):
    propotion_Maryland_in_all_tweets.append((allMaryland[i]/allTweets[i])*100)
print('length of propotion_Maryland_in_all_tweets: ', len(propotion_Maryland_in_all_tweets))


# propotion of users post Maryland e-cig in all Maryland users.
for i in range(12):
    propotion_Maryland_ecig_users_in_all_Maryland_users.append((users_Maryland_ecig[i]/users_Maryland[i])*100)
print('length of propotion_Maryland_ecig_users_in_all_Maryland_users: ', len(propotion_Maryland_ecig_users_in_all_Maryland_users))


# Sentiment analysis
for i in range(12):
    propotion_positive_ecig_Maryland.append((vader_positive_Maryland[i]/Maryland_allECigarette[i])*100)
print('length of propotion_positive_ecig_Maryland: ', len(propotion_positive_ecig_Maryland))

for i in range(12):
    propotion_neutral_ecig_Maryland.append((vader_neutral_Maryland[i]/Maryland_allECigarette[i])*100)
print('length of propotion_neutral_ecig_Maryland: ', len(propotion_neutral_ecig_Maryland))

for i in range(12):
    propotion_negative_ecig_Maryland.append((vader_negative_Maryland[i]/Maryland_allECigarette[i])*100)
print('length of propotion_negative_ecig_Maryland: ', len(propotion_negative_ecig_Maryland))


print('----------------------------------')
# ----------------------------- DC -----------------------------
propotion_DC_ecig_in_all_ecig = []
propotion_DC_ecig_in_all_DC_tweets = []
propotion_DC_in_all_tweets = []
propotion_DC_ecig_users_in_all_DC_users = []
propotion_positive_ecig_DC = []
propotion_neutral_ecig_DC = []
propotion_negative_ecig_DC = []


# propotion of DC e-cig tweets in all e-cig tweets.
for i in range(12):
    propotion_DC_ecig_in_all_ecig.append((DC_allECigarette[i]/allECigarette[i])*100)
print('length of propotion_DC_ecig_in_all_ecig: ', len(propotion_DC_ecig_in_all_ecig))


# propotion of DC e-cig tweets in all DC tweets.
for i in range(12):
    propotion_DC_ecig_in_all_DC_tweets.append((DC_allECigarette[i]/allDC[i])*100)
print('length of propotion_DC_ecig_in_all_DC_tweets: ', len(propotion_DC_ecig_in_all_DC_tweets))


# propotion of DC tweets in total tweets.
for i in range(12):
    propotion_DC_in_all_tweets.append((allDC[i]/allTweets[i])*100)
print('length of propotion_DC_in_all_tweets: ', len(propotion_DC_in_all_tweets))


# propotion of users post DC e-cig in all DC users.
for i in range(12):
    propotion_DC_ecig_users_in_all_DC_users.append((users_DC_ecig[i]/users_DC[i])*100)
print('length of propotion_DC_ecig_users_in_all_DC_users: ', len(propotion_DC_ecig_users_in_all_DC_users))


# Sentiment analysis
for i in range(12):
    propotion_positive_ecig_DC.append((vader_positive_DC[i]/DC_allECigarette[i])*100)
print('length of propotion_positive_ecig_DC: ', len(propotion_positive_ecig_DC))

for i in range(12):
    propotion_neutral_ecig_DC.append((vader_neutral_DC[i]/DC_allECigarette[i])*100)
print('length of propotion_neutral_ecig_DC: ', len(propotion_neutral_ecig_DC))

for i in range(12):
    propotion_negative_ecig_DC.append((vader_negative_DC[i]/DC_allECigarette[i])*100)
print('length of propotion_negative_ecig_DC: ', len(propotion_negative_ecig_DC))
# Out:
# length of propotion_Delaware_ecig_in_all_ecig:  12
# length of propotion_Delaware_ecig_in_all_Delaware_tweets:  12
# length of propotion_Delaware_in_all_tweets:  12
# length of propotion_Delaware_ecig_users_in_all_Delaware_users:  12
# length of propotion_positive_ecig_Delaware:  12
# length of propotion_neutral_ecig_Delaware:  12
# length of propotion_negative_ecig_Delaware:  12
# ----------------------------------
# length of propotion_NewJersey_ecig_in_all_ecig:  12
# length of propotion_NewJersey_ecig_in_all_NewJersey_tweets:  12
# length of propotion_NewJersey_in_all_tweets:  12
# length of propotion_NewJersey_ecig_users_in_all_NewJersey_users:  12
# length of propotion_positive_ecig_NewJersey:  12
# length of propotion_neutral_ecig_NewJersey:  12
# length of propotion_negative_ecig_NewJersey:  12
# ----------------------------------
# length of propotion_Pennsylvania_ecig_in_all_ecig:  12
# length of propotion_Pennsylvania_ecig_in_all_Pennsylvania_tweets:  12
# length of propotion_Pennsylvania_in_all_tweets:  12
# length of propotion_Pennsylvania_ecig_users_in_all_Pennsylvania_users:  12
# length of propotion_positive_ecig_Pennsylvania:  12
# length of propotion_neutral_ecig_Pennsylvania:  12
# length of propotion_negative_ecig_Pennsylvania:  12
# ----------------------------------
# length of propotion_Maryland_ecig_in_all_ecig:  12
# length of propotion_Maryland_ecig_in_all_Maryland_tweets:  12
# length of propotion_Maryland_in_all_tweets:  12
# length of propotion_Maryland_ecig_users_in_all_Maryland_users:  12
# length of propotion_positive_ecig_Maryland:  12
# length of propotion_neutral_ecig_Maryland:  12
# length of propotion_negative_ecig_Maryland:  12
# ----------------------------------
# length of propotion_DC_ecig_in_all_ecig:  12
# length of propotion_DC_ecig_in_all_DC_tweets:  12
# length of propotion_DC_in_all_tweets:  12
# length of propotion_DC_ecig_users_in_all_DC_users:  12
# length of propotion_positive_ecig_DC:  12
# length of propotion_neutral_ecig_DC:  12
# length of propotion_negative_ecig_DC:  12

# %% [markdown]
# ---------------------------------
# Draw Figures.

# %%
def linearRegression(x, A, B):
    return A*x + B

# %%
# Regression line
length_of_section_1 = 6
length_of_section_2 = length_of_section_1+6
x_number_section_1 = [i for i in range(0,length_of_section_1)]
x_number_section_2 = [i for i in range(length_of_section_1, length_of_section_2)]


def drawRegressionLine_two_section(y, color):
#     print('y: ', y)
#     print('section 1: ', y[:length_of_section_1])
#     print('section 2: ', y[length_of_section_1:length_of_section_2])
    
    # section 1
    popt_1, pcov_1 = optimize.curve_fit(linearRegression, x_number_section_1, y[:length_of_section_1])
    A_section_1, B_section_1 = popt_1
    x_plot_section_1 = np.arange(0, length_of_section_1, 0.01)
    y_plot_section_1 = A_section_1 * x_plot_section_1 + B_section_1
    plt.plot(x_plot_section_1, y_plot_section_1, color+'-') # , label='Users' is useless
    # Calculate the R square
    residuals_1 = y[:length_of_section_1]- linearRegression(np.asarray(x_number_section_1), *[float(A_section_1), float(B_section_1)])
    ss_res_1 = np.sum(residuals_1**2)
    ss_tot_1 = np.sum((y[:length_of_section_1]-np.mean(y[:length_of_section_1]))**2)
    r_squared_1 = 1 - (ss_res_1 / ss_tot_1)
#     print('section 1 slope: ', A_section_1)
#     print('section 1 R^2: ', r_squared_1)

    # section 2: length_of_section_1-1:length_of_section_2
    popt_2, pcov_2 = optimize.curve_fit(linearRegression, x_number_section_2, y[length_of_section_1:length_of_section_2])
    A_section_2, B_section_2 = popt_2
    x_plot_section_2 = np.arange(length_of_section_1, length_of_section_2-1, 0.01)
    y_plot_section_2 = A_section_2 * x_plot_section_2 + B_section_2
    plt.plot(x_plot_section_2, y_plot_section_2, color+'-')
    # Calculate the R square
    residuals_2 = y[length_of_section_1:length_of_section_2]- linearRegression(np.asarray(x_number_section_2), *[float(A_section_2), float(B_section_2)])
    ss_res_2 = np.sum(residuals_2**2)
    ss_tot_2 = np.sum((y[length_of_section_1:length_of_section_2]-np.mean(y[length_of_section_1:length_of_section_2]))**2)
    r_squared_2 = 1 - (ss_res_2 / ss_tot_2)
#     print('section 2 slope: ', A_section_2)
#     print('section 2 R^2: ', r_squared_2)
    
    print('slope: ', [A_section_1, A_section_2])
    print('R^2: ', [r_squared_1, r_squared_2])
#     print('--------------------------')
#     print()

# %%
x = ['2017-07','2017-08','2017-09','2017-10','2017-11','2017-12','2018-01','2018-02', '2018-03','2018-04','2018-05','2018-06',]

plt.figure(figsize=(14,7))

plt.plot(x, Delaware_allECigarette, 'rx', label='Delaware e-cigarette realated tweets')
plt.plot(x, NewJersey_allECigarette, 'bx', label='NewJersey e-cigarette realated tweets')
plt.plot(x, Pennsylvania_allECigarette, 'gx', label='Pennsylvania e-cigarette realated tweets')
plt.plot(x, Maryland_allECigarette, 'cx', label='Maryland e-cigarette realated tweets')
plt.plot(x, DC_allECigarette, 'mx', label='DC e-cigarette realated tweets')
# plt.plot(x, users_Delaware_ecig, 'yx', label='Users of Delaware e-cigarette tweets')


# plt.plot(x, average_num_per_persion_tweets_SF_ecig, 'm-', label='not first person')
plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(6, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Proposal', xy=(7,0.1))


print('Delaware:')
drawRegressionLine_two_section(Delaware_allECigarette, color='r')
print('NewJersey:')
drawRegressionLine_two_section(NewJersey_allECigarette, color='b')
print('Pennsylvania:')
drawRegressionLine_two_section(Pennsylvania_allECigarette, color='g')
print('Maryland:')
drawRegressionLine_two_section(Maryland_allECigarette, color='c')
print('DC:')
drawRegressionLine_two_section(DC_allECigarette, color='m')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for number of e-cigarette related tweets in different states by month. ')
# plt.figure(figsize=(40,1))
plt.show()


print('******************************************************')

# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


# plt.plot(x, Delaware_allECigarette, 'rx', label='Delaware e-cigarette realated tweets')
plt.plot(x, users_Delaware_ecig, 'rx', label='Users of Delaware e-cigarette tweets')
plt.plot(x, users_NewJersey_ecig, 'gx', label='Users of NewJersey e-cigarette tweets')
plt.plot(x, users_Pennsylvania_ecig, 'bx', label='Users of Pennsylvania e-cigarette tweets')
plt.plot(x, users_Maryland_ecig, 'cx', label='Users of Maryland e-cigarette tweets')
plt.plot(x, users_DC_ecig, 'mx', label='Users of DC e-cigarette tweets')
# plt.plot(x, average_num_per_persion_tweets_SF_ecig, 'm-', label='not first person')
plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(6, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Proposal', xy=(7,0.1))

print('Delaware:')
drawRegressionLine_two_section(users_Delaware_ecig, color='r')
print('NewJersey:')
drawRegressionLine_two_section(users_NewJersey_ecig, color='b')
print('Pennsylvania:')
drawRegressionLine_two_section(users_Pennsylvania_ecig, color='g')
print('Maryland:')
drawRegressionLine_two_section(users_Maryland_ecig, color='c')
print('DC:')
drawRegressionLine_two_section(users_DC_ecig, color='m')

plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for number of users that post e-cigarette related tweets in different states by month. ')
# plt.figure(figsize=(40,1))
plt.show()

print('******************************************************')

# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


# plt.plot(x, Delaware_allECigarette, 'rx', label='Delaware e-cigarette realated tweets')
plt.plot(x, average_num_per_person_tweets_Delaware_ecig, 'rx', label='Delaware ecig tweets per person')
plt.plot(x, average_num_per_person_tweets_NewJersey_ecig, 'gx', label='NewJersey ecig tweets per person')
plt.plot(x, average_num_per_person_tweets_Pennsylvania_ecig, 'bx', label='Pennsylvania ecig tweets per person')
plt.plot(x, average_num_per_person_tweets_Maryland_ecig, 'cx', label='Maryland ecig tweets per person')
plt.plot(x, average_num_per_person_tweets_DC_ecig, 'mx', label='DC ecig tweets per person')
# plt.plot(x, average_num_per_persion_tweets_SF_ecig, 'm-', label='not first person')
plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(6, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Proposal', xy=(7,0.1))

print('Delaware:')
drawRegressionLine_two_section(average_num_per_person_tweets_Delaware_ecig, color='r')
print('NewJersey:')
drawRegressionLine_two_section(average_num_per_person_tweets_NewJersey_ecig, color='b')
print('Pennsylvania:')
drawRegressionLine_two_section(average_num_per_person_tweets_Pennsylvania_ecig, color='g')
print('Maryland:')
drawRegressionLine_two_section(average_num_per_person_tweets_Maryland_ecig, color='c')
print('DC:')
drawRegressionLine_two_section(average_num_per_person_tweets_DC_ecig, color='m')

plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for average tweets number per person post e-cigarette related tweets in different states by month. ')
# plt.figure(figsize=(40,1))
plt.show()

print('******************************************************')

# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


plt.plot(x, allTweets, 'mx', label='All tweets that collected')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(6, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Proposal', xy=(7,0.1))

print('allTweets: ')
drawRegressionLine_two_section(allTweets, color='m')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for all tweets that collected from Twitter by month. ')
# plt.figure(figsize=(40,1))
plt.show()

print('******************************************************')

# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


plt.plot(x, allDelaware, 'rx', label='All tweets that collected in Delaware')
plt.plot(x, allNewJersey, 'gx', label='All tweets that collected in NewJersey')
plt.plot(x, allPennsylvania, 'bx', label='All tweets that collected in Pennsylvania')
plt.plot(x, allMaryland, 'cx', label='All tweets that collected in Maryland')
plt.plot(x, allDC, 'mx', label='All tweets that collected in DC')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(6, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Proposal', xy=(7,0.1))

print('Delaware:')
drawRegressionLine_two_section(allDelaware, color='r')
print('NewJersey:')
drawRegressionLine_two_section(allNewJersey, color='g')
print('Pennsylvania:')
drawRegressionLine_two_section(allPennsylvania, color='b')
print('Maryland:')
drawRegressionLine_two_section(allMaryland, color='c')
print('DC:')
drawRegressionLine_two_section(allDC, color='m')

plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for tweets that collected from Twitter in different states by month. ')
# plt.figure(figsize=(40,1))
plt.show()

print('******************************************************')
# Out:
# Delaware:
# slope:  [1.0857143006261338, 2.6857142857179643]
# R^2:  [0.1432539682539683, 0.43627386438446336]
# NewJersey:
# slope:  [23.971428722639455, -5.914285714300782]
# R^2:  [0.23469679095026785, 0.03362820283079915]
# Pennsylvania:
# slope:  [39.028571428571425, -32.5714285715018]
# R^2:  [0.42430913597465303, 0.686517229842757]
# Maryland:
# slope:  [11.914285714309514, 1.400000000000889]
# R^2:  [0.18630731401571754, 0.014083350441387643]
# DC:
# slope:  [-3.3714285730449682, 6.828571428584141]
# R^2:  [0.09674819344080066, 0.1538246792009086]
# ******************************************************
# Delaware:
# slope:  [1.02857142857149, 0.085714285712292]
# R^2:  [0.19021526418786716, 0.011868131868131293]
# NewJersey:
# slope:  [7.200000000013524, -5.714285714300364]
# R^2:  [0.060595805316827844, 0.34423407917383886]
# Pennsylvania:
# slope:  [26.42857142862688, -11.228571428598105]
# R^2:  [0.47057912283226533, 0.43272924245042077]
# Maryland:
# slope:  [11.114285714307767, -0.02857142857366668]
# R^2:  [0.22408685801163475, 9.846557808002032e-06]
# DC:
# slope:  [-1.6285714285771622, 3.7142857142916372]
# R^2:  [0.05313598822471177, 0.2506178942165104]
# ******************************************************
# Delaware:
# slope:  [0.0022710622688859594, 0.1860068502907889]
# R^2:  [0.0020950588440480367, 0.5170707540597412]
# NewJersey:
# slope:  [0.06033341019818872, 0.010691596671070669]
# R^2:  [0.5763313395646489, 0.011834248899618371]
# Pennsylvania:
# slope:  [-0.005958598684608907, -0.05445558807878381]
# R^2:  [0.022987397837009982, 0.4741597608339544]
# Maryland:
# slope:  [-0.011178673596989012, 0.00699132737345709]
# R^2:  [0.13663290571607967, 0.047714835874687056]
# DC:
# slope:  [-0.026019768477103744, 0.02363959492241896]
# R^2:  [0.1337888785993704, 0.054099355844484776]
# ******************************************************
# allTweets:
# slope:  [-1104725.289712435, 9671.756941351225]
# R^2:  [0.03195877502196487, 5.8089746095113526e-05]
# ******************************************************
# Delaware:
# slope:  [-550.8284049419544, -639.6855315675939]
# R^2:  [0.007580866328953384, 0.0541460323770131]
# NewJersey:
# slope:  [-27146.428389010005, -9952.429662284674]
# R^2:  [0.035885653485980384, 0.10325077447797237]
# Pennsylvania:
# slope:  [711.4000000002266, -31528.772043008972]
# R^2:  [2.879566955849011e-05, 0.6357053639139558]
# Maryland:
# slope:  [-17988.714151037595, 11843.94320809571]
# R^2:  [0.023516389710202756, 0.16050055811383945]
# DC:
# slope:  [-11500.60033935936, 1937.2573372984443]
# R^2:  [0.05658332605114058, 0.023379933211950643]
# ******************************************************

# %% [markdown]
# ----------------------------
#
# propotion

# %%
x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


plt.plot(x, propotion_Kansas_in_all_tweets, 'rx', label='Propotion of Kansas tweets in all tweets')
plt.plot(x, propotion_Nebraska_in_all_tweets, 'gx', label='Propotion of Nebraska tweets in all tweets')
plt.plot(x, propotion_Missouri_in_all_tweets, 'bx', label='Propotion of Missouri tweets in all tweets')
plt.plot(x, propotion_Oklahoma_in_all_tweets, 'cx', label='Propotion of Oklahoma tweets in all tweets')
plt.plot(x, propotion_Colorado_in_all_tweets, 'mx', label='Propotion of Colorado tweets in all tweets')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(6, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Proposal', xy=(4,0.1))

print('Kansas:')
drawRegressionLine_two_section(propotion_Kansas_in_all_tweets, color='r')
print('Nebraska:')
drawRegressionLine_two_section(propotion_Nebraska_in_all_tweets, color='g')
print('Missouri:')
drawRegressionLine_two_section(propotion_Missouri_in_all_tweets, color='b')
print('Oklahoma:')
drawRegressionLine_two_section(propotion_Oklahoma_in_all_tweets, color='c')
print('Colorado:')
drawRegressionLine_two_section(propotion_Colorado_in_all_tweets, color='m')

plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Propotion (%)')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Propotion of different states tweets in all tweets that collected from Twitter.')
# plt.figure(figsize=(40,1))
plt.show()




print('******************************************************')


x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


plt.plot(x, propotion_Kansas_ecig_in_all_ecig, 'rx', label='Propotion of Kansas ecig tweets in all ecig tweets')
plt.plot(x, propotion_Nebraska_ecig_in_all_ecig, 'gx', label='Propotion of Nebraska ecig tweets in all ecig tweets')
plt.plot(x, propotion_Missouri_ecig_in_all_ecig, 'bx', label='Propotion of Missouri ecig tweets in all ecig tweets')
plt.plot(x, propotion_Oklahoma_ecig_in_all_ecig, 'cx', label='Propotion of Oklahoma ecig tweets in all ecig tweets')
plt.plot(x, propotion_Colorado_ecig_in_all_ecig, 'mx', label='Propotion of Colorado ecig tweets in all ecig tweets')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(6, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Proposal', xy=(4,0.1))

print('Kansas:')
drawRegressionLine_two_section(propotion_Kansas_ecig_in_all_ecig, color='r')
print('Nebraska:')
drawRegressionLine_two_section(propotion_Nebraska_ecig_in_all_ecig, color='g')
print('Missouri:')
drawRegressionLine_two_section(propotion_Missouri_ecig_in_all_ecig, color='b')
print('Oklahoma:')
drawRegressionLine_two_section(propotion_Oklahoma_ecig_in_all_ecig, color='c')
print('Colorado:')
drawRegressionLine_two_section(propotion_Colorado_ecig_in_all_ecig, color='m')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Propotion (%)')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Propotion of different states e-cigarette tweets in all e-cigarette tweets that collected from Twitter.')
# plt.figure(figsize=(40,1))
plt.show()

print('******************************************************')

x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


plt.plot(x, propotion_Kansas_ecig_in_all_Kansas_tweets, 'rx', label='Propotion of Kansas ecig tweets in all Kansas tweets')
plt.plot(x, propotion_Nebraska_ecig_in_all_Nebraska_tweets, 'gx', label='Propotion of Nebraska ecig tweets in all Nebraska tweets')
plt.plot(x, propotion_Missouri_ecig_in_all_Missouri_tweets, 'bx', label='Propotion of Missouri ecig tweets in all Missouri tweets')
plt.plot(x, propotion_Oklahoma_ecig_in_all_Oklahoma_tweets, 'cx', label='Propotion of Oklahoma ecig tweets in all Oklahoma tweets')
plt.plot(x, propotion_Colorado_ecig_in_all_Colorado_tweets, 'mx', label='Propotion of Colorado ecig tweets in all Oklahoma tweets')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(6, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))

print('Kansas:')
drawRegressionLine_two_section(propotion_Kansas_ecig_in_all_Kansas_tweets, color='r')
print('Nebraska:')
drawRegressionLine_two_section(propotion_Nebraska_ecig_in_all_Nebraska_tweets, color='g')
print('Missouri:')
drawRegressionLine_two_section(propotion_Missouri_ecig_in_all_Missouri_tweets, color='b')
print('Oklahoma:')
drawRegressionLine_two_section(propotion_Oklahoma_ecig_in_all_Oklahoma_tweets, color='c')
print('Colorado:')
drawRegressionLine_two_section(propotion_Colorado_ecig_in_all_Colorado_tweets, color='m')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Propotion (%)')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Propotion of different state e-cigarette tweets in all tweets that collected from the same state.')
# plt.figure(figsize=(40,1))
plt.show()

print('******************************************************')
# Out:
# Kansas:
# slope:  [-0.017929402392264458, 0.004152356101586929]
# R^2:  [0.8702511639451377, 0.11913540511330756]
# Nebraska:
# slope:  [-0.0059578842862249015, 0.00419443553422949]
# R^2:  [0.6401273766398261, 0.1954421739261175]
# Missouri:
# slope:  [-0.00398152628297721, 0.008436861797297412]
# R^2:  [0.04578343621737713, 0.47295636065077684]
# Oklahoma:
# slope:  [-0.013432092075540192, 0.013309058642581917]
# R^2:  [0.6120106586667238, 0.5981574956158533]
# Colorado:
# slope:  [-0.006497604345015784, -0.007883999728209856]
# R^2:  [0.4303404750109796, 0.24846078439913222]
# ******************************************************
# Kansas:
# slope:  [-0.017002240773503336, 0.011698231780740365]
# R^2:  [0.18954262423314272, 0.21512002080725234]
# Nebraska:
# slope:  [-0.011397858711595044, 0.0203477295598391]
# R^2:  [0.18710620724625426, 0.25475266814815467]
# Missouri:
# slope:  [-0.00517061603623481, 0.037980714195781494]
# R^2:  [0.04665216241626258, 0.18006713538078767]
# Oklahoma:
# slope:  [-0.029418715705746168, 0.05657936765280891]
# R^2:  [0.2162497206823285, 0.13791595282527913]
# Colorado:
# slope:  [-0.0059058710838102435, 0.004933058002801305]
# R^2:  [0.008557278060324025, 0.0029087702588291853]
# ******************************************************
# Kansas:
# slope:  [0.00011933271820230296, 0.001981285963713164]
# R^2:  [0.003918725955248115, 0.542877822234265]
# Nebraska:
# slope:  [-0.0002101866346120307, 0.00341070874740923]
# R^2:  [0.017417786360606757, 0.6038080886276265]
# Missouri:
# slope:  [0.00034193678410721073, 0.0030090120626357075]
# R^2:  [0.17124381092538865, 0.6922275028330322]
# Oklahoma:
# slope:  [-0.0004542429316714003, 0.0032399434718870523]
# R^2:  [0.04427956911737563, 0.2802633961113349]
# Colorado:
# slope:  [0.0003640124493539121, 0.002890541492840737]
# R^2:  [0.026727876409141427, 0.6167560360247663]
# ******************************************************

# %% [markdown]
# ----------------------------
# Sentiment analysis

# %%
x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


plt.plot(x, vader_positive_Kansas_2017, 'rx', label='Positive towards e-cigarette in Kansas')
plt.plot(x, vader_positive_Nebraska_2017, 'gx', label='Positive towards e-cigarette in Nebraska')
plt.plot(x, vader_positive_Missouri_2017, 'bx', label='Positive towards e-cigarette in Missouri')
plt.plot(x, vader_positive_Oklahoma_2017, 'cx', label='Positive towards e-cigarette in Oklahoma')
plt.plot(x, vader_positive_Colorado_2017, 'mx', label='Positive towards e-cigarette in Colorado')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(6, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))

print('Kansas:')
drawRegressionLine_two_section(vader_positive_Kansas_2017, color='r')
print('Nebraska:')
drawRegressionLine_two_section(vader_positive_Nebraska_2017, color='g')
print('Missouri:')
drawRegressionLine_two_section(vader_positive_Missouri_2017, color='b')
print('Oklahoma:')
drawRegressionLine_two_section(vader_positive_Oklahoma_2017, color='c')
print('Colorado:')
drawRegressionLine_two_section(vader_positive_Colorado_2017, color='m')

plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for positive attitude towards e-cigarette by month. Y-axis represents the number of corresponding tweets within each month. ')
# plt.figure(figsize=(40,1))
plt.show()



print('******************************************************')

x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


plt.plot(x, vader_neutral_Kansas_2017, 'rx', label='Neutral towards e-cigarette in Kansas')
plt.plot(x, vader_neutral_Nebraska_2017, 'gx', label='Neutral towards e-cigarette in Nebraska')
plt.plot(x, vader_neutral_Missouri_2017, 'bx', label='Neutral towards e-cigarette in Missouri')
plt.plot(x, vader_neutral_Oklahoma_2017, 'cx', label='Neutral towards e-cigarette in Oklahoma')
plt.plot(x, vader_neutral_Colorado_2017, 'mx', label='Neutral towards e-cigarette in Colorado')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(6, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))

print('Kansas:')
drawRegressionLine_two_section(vader_neutral_Kansas_2017, color='r')
print('Nebraska:')
drawRegressionLine_two_section(vader_neutral_Nebraska_2017, color='g')
print('Missouri:')
drawRegressionLine_two_section(vader_neutral_Missouri_2017, color='b')
print('Oklahoma:')
drawRegressionLine_two_section(vader_neutral_Oklahoma_2017, color='c')
print('Colorado:')
drawRegressionLine_two_section(vader_neutral_Colorado_2017, color='m')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for neutral attitude towards e-cigarette by month. Y-axis represents the number of corresponding tweets within each month. ')
# plt.figure(figsize=(40,1))
plt.show()

print('******************************************************')

x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


plt.plot(x, vader_negative_Kansas_2017, 'rx', label='Negative towards e-cigarette in Kansas')
plt.plot(x, vader_negative_Nebraska_2017, 'gx', label='Negative towards e-cigarette in Nebraska')
plt.plot(x, vader_negative_Missouri_2017, 'bx', label='Negative towards e-cigarette in Missouri')
plt.plot(x, vader_negative_Oklahoma_2017, 'cx', label='Negative towards e-cigarette in Oklahoma')
plt.plot(x, vader_negative_Colorado_2017, 'mx', label='Negative towards e-cigarette in Colorado')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(6, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))

print('Kansas:')
drawRegressionLine_two_section(vader_negative_Kansas_2017, color='r')
print('Nebraska:')
drawRegressionLine_two_section(vader_negative_Nebraska_2017, color='g')
print('Missouri:')
drawRegressionLine_two_section(vader_negative_Missouri_2017, color='b')
print('Oklahoma:')
drawRegressionLine_two_section(vader_negative_Oklahoma_2017, color='c')
print('Colorado:')
drawRegressionLine_two_section(vader_negative_Colorado_2017, color='m')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for negative attitude towards e-cigarette by month. Y-axis represents the number of corresponding tweets within each month. ')
# plt.figure(figsize=(40,1))
plt.show()

print('******************************************************')
# Out:
# Kansas:
# slope:  [-1.9142856997196813, 0.22857142857143117]
# R^2:  [0.34570658452060077, 0.005336297943301815]
# Nebraska:
# slope:  [-0.7714285714324358, 1.8571428571447268]
# R^2:  [0.05345227911523909, 0.12966088691115552]
# Missouri:
# slope:  [-4.428571428583274, 3.628571428577163]
# R^2:  [0.4704788015274648, 0.41379398811305423]
# Oklahoma:
# slope:  [-3.8857142857249443, 3.942857142863564]
# R^2:  [0.3629513343799058, 0.21354563803543403]
# Colorado:
# slope:  [-4.857142857155637, 1.9428571428592036]
# R^2:  [0.32355575459023733, 0.029419748897183573]
# ******************************************************
# Kansas:
# slope:  [-3.028571428580218, 4.342857237105822]
# R^2:  [0.5090305043793417, 0.614250265863169]
# Nebraska:
# slope:  [-3.1428571428661805, 2.5142857142890174]
# R^2:  [0.7262905162064826, 0.19849624060150384]
# Missouri:
# slope:  [-3.371428559728934, 3.314285714290761]
# R^2:  [0.30169001877798673, 0.04155993905201194]
# Oklahoma:
# slope:  [-1.6857142857201453, 7.485714285728431]
# R^2:  [0.3130864937790435, 0.42611322628703874]
# Colorado:
# slope:  [-3.342857142866623, 3.0000000000043707]
# R^2:  [0.27433782023447706, 0.047399307819631975]
# ******************************************************
# Kansas:
# slope:  [-0.4000000000030537, -0.7714285714324345]
# R^2:  [0.07118644067796609, 0.1770133549170374]
# Nebraska:
# slope:  [-0.314285714288582, 1.0285714285714926]
# R^2:  [0.6100840336134454, 0.08760703019378091]
# Missouri:
# slope:  [-1.7714285671802528, 4.571428571436364]
# R^2:  [0.5883673469387758, 0.5065294815987337]
# Oklahoma:
# slope:  [-3.6571428571530182, 1.2285714285719287]
# R^2:  [0.6624258760107817, 0.1408761904761905]
# Colorado:
# slope:  [-0.314285714288582, 1.7142857142872752]
# R^2:  [0.005695457754765765, 0.08816326530612262]
# ******************************************************

# %% [markdown]
# ---------------------------------------
# Proportion in sentiment analysis

# %%
x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


plt.plot(x, propotion_positive_ecig_Kansas, 'rx', label='Positive towards e-cigarette in Kansas')
plt.plot(x, propotion_positive_ecig_Nebraska, 'gx', label='Positive towards e-cigarette in Nebraska')
plt.plot(x, propotion_positive_ecig_Missouri, 'bx', label='Positive towards e-cigarette in Missouri')
plt.plot(x, propotion_positive_ecig_Oklahoma, 'cx', label='Positive towards e-cigarette in Oklahoma')
plt.plot(x, propotion_positive_ecig_Colorado, 'mx', label='Positive towards e-cigarette in Colorado')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(6, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))

print('Kansas:')
drawRegressionLine_two_section(propotion_positive_ecig_Kansas, color='r')
print('Nebraska:')
drawRegressionLine_two_section(propotion_positive_ecig_Nebraska, color='g')
print('Missouri:')
drawRegressionLine_two_section(propotion_positive_ecig_Missouri, color='b')
print('Oklahoma:')
drawRegressionLine_two_section(propotion_positive_ecig_Oklahoma, color='c')
print('Colorado:')
drawRegressionLine_two_section(propotion_positive_ecig_Colorado, color='m')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Propotion (%)')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for positive attitude towards e-cigarette by month. Y-axis represents the propotion of corresponding tweets within each month. ')
# plt.figure(figsize=(40,1))
plt.show()

print('******************************************************')
x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


plt.plot(x, propotion_neutral_ecig_Kansas, 'rx', label='Neutral towards e-cigarette in Kansas')
plt.plot(x, propotion_neutral_ecig_Nebraska, 'gx', label='Neutral towards e-cigarette in Nebraska')
plt.plot(x, propotion_neutral_ecig_Missouri, 'bx', label='Neutral towards e-cigarette in Missouri')
plt.plot(x, propotion_neutral_ecig_Oklahoma, 'cx', label='Neutral towards e-cigarette in Oklahoma')
plt.plot(x, propotion_neutral_ecig_Colorado, 'mx', label='Neutral towards e-cigarette in Colorado')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(6, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))

print('Kansas:')
drawRegressionLine_two_section(propotion_neutral_ecig_Kansas, color='r')
print('Nebraska:')
drawRegressionLine_two_section(propotion_neutral_ecig_Nebraska, color='g')
print('Missouri:')
drawRegressionLine_two_section(propotion_neutral_ecig_Missouri, color='b')
print('Oklahoma:')
drawRegressionLine_two_section(propotion_neutral_ecig_Oklahoma, color='c')
print('Colorado:')
drawRegressionLine_two_section(propotion_neutral_ecig_Colorado, color='m')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Propotion (%)')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for neutral attitude towards e-cigarette by month. Y-axis represents the propotion of corresponding tweets within each month. ')
# plt.figure(figsize=(40,1))
plt.show()


print('******************************************************')
x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


plt.plot(x, propotion_negative_ecig_Kansas, 'rx', label='Negative towards e-cigarette in Kansas')
plt.plot(x, propotion_negative_ecig_Nebraska, 'gx', label='Negative towards e-cigarette in Nebraska')
plt.plot(x, propotion_negative_ecig_Missouri, 'bx', label='Negative towards e-cigarette in Missouri')
plt.plot(x, propotion_negative_ecig_Oklahoma, 'cx', label='Negative towards e-cigarette in Oklahoma')
plt.plot(x, propotion_negative_ecig_Colorado, 'mx', label='Negative towards e-cigarette in Colorado')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(6, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))

print('Kansas:')
drawRegressionLine_two_section(propotion_negative_ecig_Kansas, color='r')
print('Nebraska:')
drawRegressionLine_two_section(propotion_negative_ecig_Nebraska, color='g')
print('Missouri:')
drawRegressionLine_two_section(propotion_negative_ecig_Missouri, color='b')
print('Oklahoma:')
drawRegressionLine_two_section(propotion_negative_ecig_Oklahoma, color='c')
print('Colorado:')
drawRegressionLine_two_section(propotion_negative_ecig_Colorado, color='m')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Propotion (%)')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for negative attitude towards e-cigarette by month. Y-axis represents the propotion of corresponding tweets within each month. ')
# plt.figure(figsize=(40,1))
plt.show()


print('******************************************************')
# Out:
# Kansas:
# slope:  [0.40852623412162714, -1.7039839214559254]
# R^2:  [0.015010562097925617, 0.23838134730081006]
# Nebraska:
# slope:  [1.6477305207811503, 0.12374609703995065]
# R^2:  [0.11195625892682737, 0.0005661652833283126]
# Missouri:
# slope:  [-0.6253239122830008, 0.016433778240141472]
# R^2:  [0.12222093204886164, 3.69588833365464e-05]
# Oklahoma:
# slope:  [0.10570043234489657, -0.9854613584411901]
# R^2:  [0.0027821707887809577, 0.02044047651639802]
# Colorado:
# slope:  [-0.7719825674828515, -0.21032658007728156]
# R^2:  [0.04554744411466205, 0.00805480819650406]
# ******************************************************
# Kansas:
# slope:  [-1.2651099026206483, 4.350480049567874]
# R^2:  [0.11155499977682404, 0.7603829356451691]
# Nebraska:
# slope:  [-2.375378722925102, 0.9110378141138624]
# R^2:  [0.3270075292688355, 0.033124614688952114]
# Missouri:
# slope:  [1.0481424274616333, -1.6056525985197085]
# R^2:  [0.22248318981980275, 0.38973635818138785]
# Oklahoma:
# slope:  [1.7395175955773885, 2.4311699198766332]
# R^2:  [0.4834210376212462, 0.0628889673581331]
# Colorado:
# slope:  [0.2231499356639537, 0.0894726731471327]
# R^2:  [0.008061199464001079, 0.0007065695117189907]
# ******************************************************
# Kansas:
# slope:  [0.8565836684924742, -2.646496128118491]
# R^2:  [0.13289630154287313, 0.7075841362635296]
# Nebraska:
# slope:  [0.7276482021374034, -1.0347839111603556]
# R^2:  [0.12171790407366045, 0.07304569894269741]
# Missouri:
# slope:  [-0.42281850563467366, 1.589218820273028]
# R^2:  [0.19954657715652868, 0.4870592395273655]
# Oklahoma:
# slope:  [-1.8452180279288388, -1.4457084977524928]
# R^2:  [0.6094769922322852, 0.21925763591409442]
# Colorado:
# slope:  [0.5488326318123464, 0.1208539069236052]
# R^2:  [0.10327521143207574, 0.00687703913566351]
# ******************************************************

# %%
# Fourth figure
x1 = np.linspace(1, 12, 12)
x2 = np.tile(x1, 2)
x3 = np.linspace(1, 6, 6)
# x = np.tile(x, 2)
# itemNum = len(x)

x = np.concatenate((x2, x3), axis=0)
x = list(x)
x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12',
    '2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06', '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12',
    '2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06', ]

plt.figure(figsize=(14,7))


# print(x)
itemNum = len(x)
# print(itemNum)


# plt.subplot(2, 1, 1)
plt.plot(x, np.ones(itemNum), 'r-', label='tobacco related positive')
plt.plot(x, np.ones(itemNum)-0.1, 'r--', label='tobacco related neutral')
plt.plot(x, np.ones(itemNum)-0.2, 'r-.', label='tobacco related negtive')

plt.plot(x, np.ones(itemNum)-0.3, 'g-', label='e-cigarette realated positive')
plt.plot(x, np.ones(itemNum)-0.4, 'g--', label='e-cigarette related neutral')
plt.plot(x, np.ones(itemNum)-0.5, 'g-.', label='e-cigarette related negtive')

plt.plot(x, np.ones(itemNum)-0.6, 'b-', label='other tobacco positive')
plt.plot(x, np.ones(itemNum)-0.7, 'b--', label='other tobacco neutral')
plt.plot(x, np.ones(itemNum)-0.8, 'b-.', label='other tobacco negtive')

plt.plot(x, np.ones(itemNum)-0.9, 'y-', label='first person positive')
plt.plot(x, np.ones(itemNum)-1, 'y--', label='first person neutral')
plt.plot(x, np.ones(itemNum)-1.1, 'y-.', label='first person negtive')

plt.plot(x, np.ones(itemNum)-1.2, 'm-', label='not first person positive')
plt.plot(x, np.ones(itemNum)-1.3, 'm--', label='not first person neutral')
plt.plot(x, np.ones(itemNum)-1.4, 'm-.', label='not first person negtive')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(5, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Proposal', xy=(4,-0.3))
plt.axvline(17, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Approved', xy=(16,-0.3))
plt.axvline(24, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Enforcement ', xy=(23,-0.3))




plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Attitude')
plt.title('Figure 4: Trends for attitude towards tobacco by month. Y-axis represents the propotion of corresponding tweets within each month. ')
# plt.figure(figsize=(40,1))
plt.show()

# %%
# # Second figure
# x1 = np.linspace(1, 12, 12)
# x2 = np.tile(x1, 2)
# x3 = np.linspace(1, 6, 6)
# # x = np.tile(x, 2)
# # itemNum = len(x)

# x = np.concatenate((x2, x3), axis=0)
# x = list(x)
# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12',
#     '2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06', '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12',
#     '2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06', ]

# plt.figure(figsize=(14,7))


# # print(x)
# itemNum = len(x)
# print(itemNum)


# # plt.subplot(2, 1, 1)
# plt.plot(x, np.ones(itemNum), 'r-', label='mentioning tweets')
# plt.plot(x, np.ones(itemNum)/2, 'g-.', label='mentioning users')
# plt.plot(x, np.zeros(itemNum), 'b.', label='first person users')
# plt.legend()
# # plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
# plt.axvline(5, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))
# plt.axvline(17, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Approved', xy=(16,0.1))
# plt.axvline(24, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Enforcement ', xy=(23,0.1))




# plt.xticks(rotation=80)
# plt.xlabel('Month')
# plt.ylabel('# of mentioning')
# plt.title('Figure 1: Trends for number of tobacco related tweet by month. Y-axis represents the number of corresponding tweets within each month. ')
# # plt.figure(figsize=(40,1))
# plt.show()
