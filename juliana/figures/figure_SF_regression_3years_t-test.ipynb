# %%
import matplotlib.pyplot as plt
import numpy as np

from scipy import optimize

# %%
import datetime

import matplotlib as mpl
 
fig = plt.figure()
 
start = datetime.datetime(2016, 1, 1)
end = datetime.datetime(2017, 1, 1)
# 设置日期的间隔为1
delta = datetime.timedelta(days= 29)
 
# 生成一个matplotlib可以识别的日期对象
dates = mpl.dates.drange(start, end, delta)

print(dates)

date_format = mpl.dates.DateFormatter("%Y-%m")
print(date_format)
# Out:
# [735964. 735993. 736022. 736051. 736080. 736109. 736138. 736167. 736196.
#  736225. 736254. 736283. 736312.]
# <matplotlib.dates.DateFormatter object at 0x7f3db0312a20>

# %%
# Font size
font_setting = {'family':'Times New Roman', 'weight':'normal', 'size':23}

# %%
# Number
average_num_per_person_tweets_SF_ecig = []
average_num_per_person_tweets_SF_tobacco = []

# SF_allECigarette
SF_allECigarette_2016 = [132, 148, 127, 139, 107, 128, 119, 115, 127]
SF_allECigarette_2017 = [59,65,90,59,67,88,74,89,47,50,76,122]
SF_allECigarette_2018 = [111,103,102,99,81,92,127,106,92,83,141,113]
SF_allECigarette_2019 = [130,105,74,92]
SF_allECigarette_total = []
SF_allECigarette_total.extend(SF_allECigarette_2016)
SF_allECigarette_total.extend(SF_allECigarette_2017)
SF_allECigarette_total.extend(SF_allECigarette_2018)
SF_allECigarette_total.extend(SF_allECigarette_2019)
print('length of SF_allECigarette_total: ', len(SF_allECigarette_total))


# not_SF_allECigarette
not_SF_allECigarette_2016 = [22663, 24529, 21126, 23540, 20111, 16172, 17490, 16641, 16291]
not_SF_allECigarette_2017 = [17983, 13759, 14675, 14218, 13013, 13534, 13493, 14000, 6886, 9296, 15564, 15559]
not_SF_allECigarette_2018 = [16357, 14535, 16351, 15982, 15461, 16211, 18743, 17293, 19076, 15024, 18918, 17560]
not_SF_allECigarette_2019 = [18566, 16190, 13614, 13234]
not_SF_allECigarette_total = []
not_SF_allECigarette_total.extend(not_SF_allECigarette_2016)
not_SF_allECigarette_total.extend(not_SF_allECigarette_2017)
not_SF_allECigarette_total.extend(not_SF_allECigarette_2018)
not_SF_allECigarette_total.extend(not_SF_allECigarette_2019)
print('length of not_SF_allECigarette_total: ', len(not_SF_allECigarette_total))


# allECigarette
allECigarette_total = []
for i in range(37):
    allECigarette_total.append(SF_allECigarette_total[i]+not_SF_allECigarette_total[i])
print('length of allECigarette: ', len(allECigarette_total))


# allSF
allSF_2016 = [395757, 421225, 442983, 414926, 427931, 384324, 445447, 422048, 353848]
allSF_2017 = [404518, 350143, 358222, 326842, 326461, 332603, 312882, 323315, 148187, 205925, 296740, 257645]
allSF_2018 = [278884, 259869, 304292, 278291, 287698, 282691, 287065, 262239, 284484, 244884, 264046, 245877]
allSF_2019 = [274852, 253351, 225549, 252680]
allSF_total = []
allSF_total.extend(allSF_2016)
allSF_total.extend(allSF_2017)
allSF_total.extend(allSF_2018)
allSF_total.extend(allSF_2019)
print('length of allSF_total: ', len(allSF_total))


# Number of users that tweets SF ecig.
users_SF_ecig_2016 = [105, 114, 97, 96, 82, 91, 82, 81, 70]
users_SF_ecig_2017 = [50, 52, 73, 53, 53, 66, 67, 71, 38, 45, 65, 69]
users_SF_ecig_2018 = [75, 68, 68, 75, 73, 74, 87, 85, 76, 69, 119, 90]
users_SF_ecig_2019 = [110, 84, 60, 67]
users_SF_ecig_total = []
users_SF_ecig_total.extend(users_SF_ecig_2016)
users_SF_ecig_total.extend(users_SF_ecig_2017)
users_SF_ecig_total.extend(users_SF_ecig_2018)
users_SF_ecig_total.extend(users_SF_ecig_2019)
print('length of users_SF_ecig_total: ', len(users_SF_ecig_total))


# average number of per person tweets about ecig.
for i in range(37):
    average_num_per_person_tweets_SF_ecig.append(SF_allECigarette_total[i]/users_SF_ecig_total[i])
print('length of average_num_per_person_tweets_SF_ecig: ', len(average_num_per_person_tweets_SF_ecig))


# allTweets
allTweets_2016 = [70798094, 76153908, 77039352, 79730585, 75060717, 63144176, 68592777, 68306197, 60640789]
allTweets_2017 = [64761879, 49292002, 51379810, 46841051, 45592367, 46897952, 50163222, 51079160, 22112648, 31365136, 46232294, 43487766]
allTweets_2018 = [46059070, 40432909, 47289301, 45660765, 44166238, 44212483, 45858463, 39900707, 45395994, 37985764, 42937313, 41362576]
allTweets_2019 = [44209494, 38750216, 32702554, 33860264]
allTweets_total = []
allTweets_total.extend(allTweets_2016)
allTweets_total.extend(allTweets_2017)
allTweets_total.extend(allTweets_2018)
allTweets_total.extend(allTweets_2019)
print('length of allTweets_total: ', len(allTweets_total))


# ---------------------- Sentiment analysis by vader ----------------------
# positive
vader_positive_2016 = [49, 44, 52, 42, 63, 41, 44, 27, 53]
vader_positive_2017 = [22, 23, 37, 21, 27, 32, 25, 33, 17, 12, 22, 40]
vader_positive_2018 = [38, 36, 29, 31, 26, 31, 33, 35, 39, 23, 42, 26]
vader_positive_2019 = [36, 35, 20, 39]
vader_positive_total = []
vader_positive_total.extend(vader_positive_2016)
vader_positive_total.extend(vader_positive_2017)
vader_positive_total.extend(vader_positive_2018)
vader_positive_total.extend(vader_positive_2019)
print('length of vader_positive_total: ', len(vader_positive_total))

# neutral
vader_neutral_2016 = [54, 78, 46, 74, 31, 68, 63, 54, 63]
vader_neutral_2017 = [29, 31, 38, 24, 29, 43, 38, 42, 23, 26, 42, 53]
vader_neutral_2018 = [44, 47, 55, 46, 35, 43, 73, 51, 35, 45, 62, 59]
vader_neutral_2019 = [68, 52, 35, 31]
vader_neutral_total = []
vader_neutral_total.extend(vader_neutral_2016)
vader_neutral_total.extend(vader_neutral_2017)
vader_neutral_total.extend(vader_neutral_2018)
vader_neutral_total.extend(vader_neutral_2019)
print('length of vader_neutral_total: ', len(vader_neutral_total))

# negative
vader_negative_2016 = [29, 26, 29, 23, 13, 19, 12, 34, 11]
vader_negative_2017 = [8, 11, 15, 14, 11, 13, 11, 14, 7, 12, 12, 29]
vader_negative_2018 = [29, 20, 18, 22, 20, 18, 21, 20, 18, 15, 37, 28]
vader_negative_2019 = [26, 18, 19, 22]
vader_negative_total = []
vader_negative_total.extend(vader_negative_2016)
vader_negative_total.extend(vader_negative_2017)
vader_negative_total.extend(vader_negative_2018)
vader_negative_total.extend(vader_negative_2019)
print('length of vader_negative_total: ', len(vader_negative_total))


# ---------------------- Tobacco ----------------------
# SF tobacco by pre-trained classifier
SF_tobacco = [907,930,974,899,888,710,775, 731,663,626,571,619,588,570,580,665,721,349,656,662,485,550,554,604,647,583,593,606,627, 613, 486, 701, 556, 606, 620, 487, 534]
print('length of SF_tobacco: ', len(SF_tobacco))

SF_flavored_tobacco = [97, 77, 69, 85, 75, 71, 62, 45, 57, 61, 52, 53, 56, 60, 44, 42, 56, 35, 27, 51, 31, 44, 45, 40, 35, 32, 38, 51, 54, 56, 40, 38, 33, 42, 36, 48, 43]
print('length of SF_flavored_tobacco: ', len(SF_flavored_tobacco))

sentiment_SF_flavored_tobacco_positive = [22, 21, 13, 21, 16, 15, 20, 15, 11, 13, 13, 17, 16, 18, 18, 12, 11, 10, 8, 9, 9, 11, 12, 7, 6, 5, 7, 7, 14, 11, 9, 7, 8, 11, 12, 8, 9]
sentiment_SF_flavored_tobacco_neutral = [68, 50, 49, 61, 51, 44, 37, 26, 38, 42, 36, 33, 32, 38, 20, 28, 38, 20, 16, 34, 18, 25, 25, 24, 22, 17, 27, 38, 36, 41, 29, 25, 21, 24, 19, 30, 30]
sentiment_SF_flavored_tobacco_negative = [7, 6, 7, 3, 8, 12, 5, 4, 8, 6, 3, 3, 8, 4, 6, 2, 7, 5, 3, 8, 4, 8, 8, 9, 7, 10, 4, 6, 4, 4, 2, 6, 4, 7, 5, 10, 4]
print('length of sentiment_SF_flavored_tobacco_positive: ', len(sentiment_SF_flavored_tobacco_positive))
print('length of sentiment_SF_flavored_tobacco_neutral: ', len(sentiment_SF_flavored_tobacco_neutral))
print('length of sentiment_SF_flavored_tobacco_negative: ', len(sentiment_SF_flavored_tobacco_negative))

# ---------------------- Sentiment analysis for flavored tobacco ----------------------
propotion_positive_flavored_tobacco = []
propotion_neutral_flavored_tobacco = []
propotion_negative_flavored_tobacco = []
for i in range(37):
    propotion_positive_flavored_tobacco.append((sentiment_SF_flavored_tobacco_positive[i]/SF_flavored_tobacco[i])*100)
print('length of propotion_positive_flavored_tobacco: ', len(propotion_positive_flavored_tobacco))

for i in range(37):
    propotion_neutral_flavored_tobacco.append((sentiment_SF_flavored_tobacco_neutral[i]/SF_flavored_tobacco[i])*100)
print('length of propotion_neutral_flavored_tobacco: ', len(propotion_neutral_flavored_tobacco))

for i in range(37):
    propotion_negative_flavored_tobacco.append((sentiment_SF_flavored_tobacco_negative[i]/SF_flavored_tobacco[i])*100)
print('length of propotion_negative_flavored_tobacco: ', len(propotion_negative_flavored_tobacco))



# propotion of SF flavored tobacco tweets in all tobacco tweets.
propotion_SF_flavored_tobacco_in_all_tobacco_tweets = []
for i in range(37):
    propotion_SF_flavored_tobacco_in_all_tobacco_tweets.append((SF_flavored_tobacco[i]/SF_tobacco[i])*100)
print('length of propotion_SF_flavored_tobacco_in_all_tobacco_tweets: ', len(propotion_SF_flavored_tobacco_in_all_tobacco_tweets))

sentiment_tobacco_positive = [231, 236, 241, 219, 222, 148, 203, 166, 167, 145, 137, 138, 144, 120, 186, 254, 248, 106, 206, 158, 108, 123, 123, 131, 155, 122, 143, 131, 132, 165, 118, 162, 127, 114, 149, 105, 114]
sentiment_tobacco_neutral = [550, 566, 598, 568, 554, 448, 463, 440, 395, 396, 361, 392, 359, 370, 314, 336, 372, 184, 337, 401, 300, 352, 326, 372, 386, 354, 358, 368, 401, 347, 300, 401, 339, 405, 373, 306, 332]
sentiment_tobacco_negative = [126, 128, 135, 112, 112, 114, 109, 125, 101, 85, 73, 89, 85, 80, 80, 75, 101, 59, 113, 103, 77, 75, 105, 101, 106, 107, 92, 107, 94, 101, 68, 138, 90, 87, 98, 76, 88]
print('length of sentiment_tobacco_positive: ', len(sentiment_tobacco_positive))
print('length of sentiment_tobacco_neutral: ', len(sentiment_tobacco_neutral))
print('length of sentiment_tobacco_negative: ', len(sentiment_tobacco_negative))

users_SF_tobacco = [656, 682, 715, 704, 714, 578, 649, 563, 520, 501, 450, 497, 458, 459, 427, 485, 525, 286, 510, 495, 410, 431, 441, 494, 474, 476, 473, 478, 505, 500, 403, 569, 428, 423, 469, 388, 395]
print('length of users_SF_tobacco: ', len(users_SF_tobacco))

# average number of per person tweets about ecig.
for i in range(37):
    average_num_per_person_tweets_SF_tobacco.append(SF_tobacco[i]/users_SF_tobacco[i])
print('length of average_num_per_person_tweets_SF_tobacco: ', len(average_num_per_person_tweets_SF_tobacco))
# Out:
# length of SF_allECigarette_total:  37
# length of not_SF_allECigarette_total:  37
# length of allECigarette:  37
# length of allSF_total:  37
# length of users_SF_ecig_total:  37
# length of average_num_per_person_tweets_SF_ecig:  37
# length of allTweets_total:  37
# length of vader_positive_total:  37
# length of vader_neutral_total:  37
# length of vader_negative_total:  37
# length of SF_tobacco:  37
# length of SF_flavored_tobacco:  37
# length of sentiment_SF_flavored_tobacco_positive:  37
# length of sentiment_SF_flavored_tobacco_neutral:  37
# length of sentiment_SF_flavored_tobacco_negative:  37
# length of propotion_positive_flavored_tobacco:  37
# length of propotion_neutral_flavored_tobacco:  37
# length of propotion_negative_flavored_tobacco:  37
# length of propotion_SF_flavored_tobacco_in_all_tobacco_tweets:  37
# length of sentiment_tobacco_positive:  37
# length of sentiment_tobacco_neutral:  37
# length of sentiment_tobacco_negative:  37
# length of users_SF_tobacco:  37
# length of average_num_per_person_tweets_SF_tobacco:  37

# %%
# Propotion
propotion_SF_ecig_in_all_ecig = []
propotion_SF_ecig_in_all_SF_tweets = []
propotion_SF_in_all_tweets = []
propotion_positive_ecig = []
propotion_neutral_ecig = []
propotion_negative_ecig = []
propotion_positive_tobacco = []
propotion_neutral_tobacco = []
propotion_negative_tobacco = []
propotion_SF_tobacco_in_all_SF_tweets = []

# propotion of SF e-cig tweets in all e-cig tweets.
for i in range(37):
    propotion_SF_ecig_in_all_ecig.append((SF_allECigarette_total[i]/allECigarette_total[i])*100)
print('length of propotion_SF_ecig_in_all_ecig: ', len(propotion_SF_ecig_in_all_ecig))


# propotion of SF e-cig tweets in all SF tweets.
for i in range(37):
    propotion_SF_ecig_in_all_SF_tweets.append((SF_allECigarette_total[i]/allSF_total[i])*100)
print('length of propotion_SF_ecig_in_all_SF_tweets: ', len(propotion_SF_ecig_in_all_SF_tweets))


# propotion of SF tweets in total tweets.
for i in range(37):
    propotion_SF_in_all_tweets.append((allSF_total[i]/allTweets_total[i])*100)
print('length of propotion_SF_in_all_tweets: ', len(propotion_SF_in_all_tweets))


# ---------------------- Sentiment analysis by vader ----------------------
for i in range(37):
    propotion_positive_ecig.append((vader_positive_total[i]/SF_allECigarette_total[i])*100)
print('length of propotion_positive_ecig: ', len(propotion_positive_ecig))

for i in range(37):
    propotion_neutral_ecig.append((vader_neutral_total[i]/SF_allECigarette_total[i])*100)
print('length of propotion_neutral_ecig: ', len(propotion_neutral_ecig))

for i in range(37):
    propotion_negative_ecig.append((vader_negative_total[i]/SF_allECigarette_total[i])*100)
print('length of propotion_negative_ecig: ', len(propotion_negative_ecig))

# ---------------------- Tobacco ----------------------
for i in range(37):
    propotion_positive_tobacco.append((sentiment_tobacco_positive[i]/SF_tobacco[i])*100)
print('length of propotion_positive_tobacco: ', len(propotion_positive_tobacco))

for i in range(37):
    propotion_neutral_tobacco.append((sentiment_tobacco_neutral[i]/SF_tobacco[i])*100)
print('length of propotion_neutral_tobacco: ', len(propotion_neutral_tobacco))

for i in range(37):
    propotion_negative_tobacco.append((sentiment_tobacco_negative[i]/SF_tobacco[i])*100)
print('length of propotion_negative_tobacco: ', len(propotion_negative_tobacco))

# propotion of SF e-cig tweets in all SF tweets.
for i in range(37):
    propotion_SF_tobacco_in_all_SF_tweets.append((SF_tobacco[i]/allSF_total[i])*100)
print('length of propotion_SF_tobacco_in_all_SF_tweets: ', len(propotion_SF_tobacco_in_all_SF_tweets))
# Out:
# length of propotion_SF_ecig_in_all_ecig:  37
# length of propotion_SF_ecig_in_all_SF_tweets:  37
# length of propotion_SF_in_all_tweets:  37
# length of propotion_positive_ecig:  37
# length of propotion_neutral_ecig:  37
# length of propotion_negative_ecig:  37
# length of propotion_positive_tobacco:  37
# length of propotion_neutral_tobacco:  37
# length of propotion_negative_tobacco:  37
# length of propotion_SF_tobacco_in_all_SF_tweets:  37

# %% [markdown]
# ---------------------------------
# Draw Figures.

# %%
def linearRegression(x, A, B):
    return A*x + B

# %%
# Regression line
length_of_section_1 = 5+9
length_of_section_2 = length_of_section_1+12
length_of_section_3 = length_of_section_2+7
length_of_section_4 = length_of_section_3+4
x_number_section_1 = [i for i in range(0,length_of_section_1)]
x_number_section_2 = [i for i in range(length_of_section_1, length_of_section_2)]
x_number_section_3 = [i for i in range(length_of_section_2, length_of_section_3)]
x_number_section_4 = [i for i in range(length_of_section_3, length_of_section_4)]

from scipy.stats import ttest_ind_from_stats
# from scipy.stats import linregress
def drawRegressionLine_four_section(y, color):
#     print('y: ', y)
#     print('section 1: ', y[:length_of_section_1])
#     print('section 2: ', y[length_of_section_1:length_of_section_2])
#     print('section 3: ', y[length_of_section_2:length_of_section_3])
#     print('section 4: ', y[length_of_section_3:length_of_section_4])
#     print('--------------------------')
    
    # section 1
#     A_section_1, B_section_1 = optimize.curve_fit(linearRegression, x_number_section_1, y[:length_of_section_1])[0]
    popt_1, pcov_1 = optimize.curve_fit(linearRegression, x_number_section_1, y[:length_of_section_1])
    A_section_1, B_section_1 = popt_1
    x_plot_section_1 = np.arange(0, length_of_section_1, 0.01)
    y_plot_section_1 = A_section_1 * x_plot_section_1 + B_section_1
    plt.plot(x_plot_section_1, y_plot_section_1, color+'-') # , label='Users' is useless
    # Calculate the R square
    residuals_1 = y[:length_of_section_1]- linearRegression(np.asarray(x_number_section_1), *[float(A_section_1), float(B_section_1)])
    ss_res_1 = np.sum(residuals_1**2)
    ss_tot_1 = np.sum((y[:length_of_section_1]-np.mean(y[:length_of_section_1]))**2)
    r_squared_1 = 1 - (ss_res_1 / ss_tot_1) 
    
    
#     tmp = linregress()
    
    # section 2: length_of_section_1-1:length_of_section_2
    popt_2, pcov_2 = optimize.curve_fit(linearRegression, x_number_section_2, y[length_of_section_1:length_of_section_2])
    A_section_2, B_section_2 = popt_2
#     A_section_2, B_section_2 = optimize.curve_fit(linearRegression, x_number_section_2, y[length_of_section_1-1:length_of_section_2])[0]
    x_plot_section_2 = np.arange(length_of_section_1, length_of_section_2, 0.01)
    y_plot_section_2 = A_section_2 * x_plot_section_2 + B_section_2
    plt.plot(x_plot_section_2, y_plot_section_2, color+'-')
    # Calculate the R square
    residuals_2 = y[length_of_section_1:length_of_section_2]- linearRegression(np.asarray(x_number_section_2), *[float(A_section_2), float(B_section_2)])
    ss_res_2 = np.sum(residuals_2**2)
    ss_tot_2 = np.sum((y[length_of_section_1:length_of_section_2]-np.mean(y[length_of_section_1:length_of_section_2]))**2)
    r_squared_2 = 1 - (ss_res_2 / ss_tot_2)

    # section 3: length_of_section_2-1:length_of_section_3
    popt_3, pcov_3 = optimize.curve_fit(linearRegression, x_number_section_3, y[length_of_section_2:length_of_section_3])
    A_section_3, B_section_3 = popt_3
#     A_section_3, B_section_3 = optimize.curve_fit(linearRegression, x_number_section_3, y[length_of_section_2:length_of_section_3])[0]
    x_plot_section_3 = np.arange(length_of_section_2, length_of_section_3, 0.01)
    y_plot_section_3 = A_section_3 * x_plot_section_3 + B_section_3
    plt.plot(x_plot_section_3, y_plot_section_3, color+'-')
    # Calculate the R square
    residuals_3 = y[length_of_section_2:length_of_section_3]- linearRegression(np.asarray(x_number_section_3), *[float(A_section_3), float(B_section_3)])
    ss_res_3 = np.sum(residuals_3**2)
    ss_tot_3 = np.sum((y[length_of_section_2:length_of_section_3]-np.mean(y[length_of_section_2:length_of_section_3]))**2)
    r_squared_3 = 1 - (ss_res_3 / ss_tot_3)

    # section 4: length_of_section_3-1:length_of_section_4
    popt_4, pcov_4 = optimize.curve_fit(linearRegression, x_number_section_4, y[length_of_section_3:length_of_section_4])
    A_section_4, B_section_4 = popt_4
#     A_section_4, B_section_4 = optimize.curve_fit(linearRegression, x_number_section_4, y[length_of_section_3:length_of_section_4])[0]
    x_plot_section_4 = np.arange(length_of_section_3, length_of_section_4-1, 0.01)
    y_plot_section_4 = A_section_4 * x_plot_section_4 + B_section_4
    plt.plot(x_plot_section_4, y_plot_section_4, color+'-')
    # Calculate the R square
    residuals_4 = y[length_of_section_3:length_of_section_4]- linearRegression(np.asarray(x_number_section_4), *[float(A_section_4), float(B_section_4)])
    ss_res_4 = np.sum(residuals_4**2)
    ss_tot_4 = np.sum((y[length_of_section_3:length_of_section_4]-np.mean(y[length_of_section_3:length_of_section_4]))**2)
    r_squared_4 = 1 - (ss_res_4 / ss_tot_4)
    
    # Calculate the mean value.
    mean_1 = float('%.2f' % np.mean(y[:length_of_section_1]))
    mean_2 = float('%.2f' % np.mean(y[length_of_section_1:length_of_section_2]))
    mean_3 = float('%.2f' % np.mean(y[length_of_section_2:length_of_section_3]))
    mean_4 = float('%.2f' % np.mean(y[length_of_section_3:length_of_section_4]))
    
    print('Mean value in different states: ', [mean_1,mean_2,mean_3,mean_4])
    print('slope: ', [A_section_1, A_section_2, A_section_3, A_section_4])
    print('intercept: ', [B_section_1, B_section_2, B_section_3, B_section_4])
    print('R^2: ', [r_squared_1, r_squared_2, r_squared_3, r_squared_4])
    
    
    # t-test
#     print('popt_1: ', popt_1)
#     print('pcov_1: ', pcov_1)
    
    perr_1 = np.sqrt(np.diag(pcov_1))
    perr_slope_1 = perr_1[0]
    perr_intercept_1 = perr_1[1]
    
    perr_2 = np.sqrt(np.diag(pcov_2))
    perr_slope_2 = perr_2[0]
    perr_intercept_2 = perr_2[1]
    
    perr_3 = np.sqrt(np.diag(pcov_3))
    perr_slope_3 = perr_3[0]
    perr_intercept_3 = perr_3[1]
    
    perr_4 = np.sqrt(np.diag(pcov_4))
    perr_slope_4 = perr_4[0]
    perr_intercept_4 = perr_4[1]
    
#     print('perr_slope_1: ', perr_slope_1)
#     print('perr_slope_2: ', perr_slope_2)
#     print('length_of_section_1: ', length_of_section_1)
#     print('length_of_section_2-length_of_section_1: ', length_of_section_2-length_of_section_1)
    tTest_slope_1 = ttest_ind_from_stats(A_section_1, perr_slope_1, length_of_section_1, A_section_2, perr_slope_2, length_of_section_2-length_of_section_1)
    tTest_intercept_1 = ttest_ind_from_stats(B_section_1, perr_intercept_1, length_of_section_1, B_section_2, perr_intercept_2, length_of_section_2-length_of_section_1)
#     print('tTest_slope_1: ', tTest_slope_1)
#     print('tTest_intercept_1: ', tTest_intercept_1)
    
    tTest_slope_2 = ttest_ind_from_stats(A_section_2, perr_slope_2, length_of_section_2, A_section_3, perr_slope_3, length_of_section_3-length_of_section_2)
    tTest_intercept_2 = ttest_ind_from_stats(B_section_2, perr_intercept_2, length_of_section_2, B_section_3, perr_intercept_3, length_of_section_3-length_of_section_2)
#     print('tTest_slope_2: ', tTest_slope_2)
#     print('tTest_intercept_2: ', tTest_intercept_2)
    
    tTest_slope_3 = ttest_ind_from_stats(A_section_3, perr_slope_3, length_of_section_3, A_section_4, perr_slope_4, length_of_section_4-length_of_section_3)
    tTest_intercept_3 = ttest_ind_from_stats(B_section_3, perr_intercept_3, length_of_section_3, B_section_4, perr_intercept_4, length_of_section_4-length_of_section_3)
#     print('tTest_slope_3: ', tTest_slope_3)
#     print('tTest_intercept_3: ', tTest_intercept_3)
    
    print('t-test: ')
    print('slope- T value: ', [tTest_slope_1[0], tTest_slope_2[0], tTest_slope_3[0]])
    print('slope- p value: ', [tTest_slope_1[1], tTest_slope_2[1], tTest_slope_3[1]])
    print('intercept- T value: ', [tTest_intercept_1[0], tTest_intercept_2[0], tTest_intercept_3[0]])
    print('intercept- p value: ', [tTest_intercept_1[1], tTest_intercept_2[1], tTest_intercept_3[1]])

# %% [markdown]
# -------------------------------------------------------
# tobacco

# %%
x = ['2016-04','2016-05','2016-06','2016-07','2016-08','2016-09','2016-10','2016-11','2016-12','2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12',
    '2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06', '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12',
    '2019-01', '2019-02', '2019-03', '2019-04' ]

plt.figure(figsize=(14,7))


# print(x)
# itemNum = len(x)
# print(itemNum)


plt.plot(x, SF_tobacco, 'rx', label='SF tobacco realated tweets')
plt.plot(x, users_SF_tobacco, 'yx', label='Users of SF tobacco related tweets')
# plt.plot(x, average_num_per_persion_tweets_SF_ecig, 'm-', label='not first person')
plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(14, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))
plt.axvline(26, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Approved', xy=(16,0.1))
plt.axvline(33, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Enforcement ', xy=(23,0.1))

print('**************************************************************')
print('Tobacco: ')
drawRegressionLine_four_section(SF_tobacco, color='r')
print()
print('Users: ')
drawRegressionLine_four_section(users_SF_tobacco, color='y')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for number of San Francisco tobacco related tweets/users by month. ')
# plt.figure(figsize=(40,1))
plt.show()
# Out:
# **************************************************************
# Tobacco:
# slope:  [-33.25054950928864, -1.4615384615438258, -2.214285714292754, -34.9000000000001]
# intercept:  [962.6285718103761, 616.5000000013423, 661.6428571442989, 1765.8000000000036]
# R^2:  [0.892955835060846, 0.0028316511713806225, 0.005266099688746029, 0.520128109319953]
# t-test:
# slope- T value:  [-12.70381934141108, 0.1799413438680985, 4.186003003392316]
# slope- p value:  [3.806692235758788e-12, 0.8583697157686212, 0.00018167409366283811]
# intercept- T value:  [7.470601200204057, -0.4558596891668037, -4.657717671319486]
# intercept- p value:  [1.0373150156471492e-07, 0.6516682887225953, 4.4910886855733635e-05]
#
# Users:
# slope:  [-22.175824175874748, 2.363636363639333, -1.9642857142921795, -16.500000000038106]
# intercept:  [726.0000000015814, 408.4090909099796, 536.3928571440248, 988.0000000021505]
# R^2:  [0.8232444052136174, 0.017798228683340134, 0.006128046804097398, 0.33588304237863287]
# t-test:
# slope- T value:  [-14.34956713632088, 1.4506896704848087, 2.3413989235278097]
# slope- p value:  [2.8389879217197773e-13, 0.15691051100489176, 0.025032902002031867]
# intercept- T value:  [10.581766576155676, -1.7289789703750431, -2.420599236732572]
# intercept- p value:  [1.6107902747893979e-10, 0.09376148553258369, 0.020821287219307066]

# %%
# Flavored tobacco

plt.figure(figsize=(14,7))


# print(x)
# itemNum = len(x)
# print(itemNum)


plt.plot(x, SF_flavored_tobacco, 'rx', label='SF flavored tobacco tweets')
# plt.plot(x, users_SF_tobacco, 'yx', label='Users of SF tobacco related tweets')
# plt.plot(x, average_num_per_persion_tweets_SF_ecig, 'm-', label='not first person')
plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(14, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))
plt.axvline(26, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Approved', xy=(16,0.1))
plt.axvline(33, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Enforcement ', xy=(23,0.1))

print('**************************************************************')
print('Flavored tobacco: ')
drawRegressionLine_four_section(SF_flavored_tobacco, color='r')


plt.rc('legend', fontsize=15)
plt.rc('ytick', labelsize=13)
plt.rc('xtick', labelsize=12)

plt.xticks(rotation=80)
plt.xlabel('Month', font_setting)
plt.ylabel('Number', font_setting)
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for number of San Francisco flavored tobacco tweets by month. ')
# plt.figure(figsize=(40,1))
plt.show()
# Out:
# **************************************************************
# Flavored tobacco:
# Mean value in different states:  [65.71, 40.17, 44.29, 42.25]
# slope:  [-2.6725274725354904, -0.7902097902136953, -1.964285714292175, 1.5000000000010865]
# intercept:  [83.08571428589337, 55.57575757587662, 101.25000000021852, -9.500000000022757]
# R^2:  [0.6199867504130013, 0.11138508061585006, 0.2154558404558402, 0.15463917525773196]
# t-test:
# slope- T value:  [-7.331431418765654, 2.8354365965900112, -3.7186265840921964]
# slope- p value:  [1.427005912159556e-07, 0.007987790219133071, 0.0006986166832211536]
# intercept- T value:  [6.954707943501953, -4.317850610469991, 3.9539409410993307]
# intercept- p value:  [3.426351519323208e-07, 0.00014992166137278617, 0.0003566258290773816]

# %%
plt.figure(figsize=(14,7))



plt.plot(x, propotion_SF_flavored_tobacco_in_all_tobacco_tweets, 'bx', label='Proportion of SF flavored tobacco in all SF tobacco tweets')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(14, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))
plt.axvline(26, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Approved', xy=(16,0.1))
plt.axvline(33, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Enforcement ', xy=(23,0.1))

print('**************************************************************')
drawRegressionLine_four_section(propotion_SF_flavored_tobacco_in_all_tobacco_tweets, color='b')
plt.rc('legend', fontsize=15)
plt.rc('ytick', labelsize=13)
plt.rc('xtick', labelsize=12)

plt.xticks(rotation=80)
plt.xlabel('Month', font_setting)
plt.ylabel('Propotion (%)', font_setting)
plt.title('Propotion of San Francisco flavored tobacco tweets in all San Francisco tobacco related tweets. ')
# plt.figure(figsize=(40,1))
plt.show()
# Out:
# **************************************************************
# Mean value in different states:  [8.87, 6.96, 7.45, 7.66]
# slope:  [0.050119403439651156, -0.13436146339501676, -0.27823370769793776, 0.7415035383632393]
# intercept:  [8.543941703562435, 9.5827874849014, 15.519964344228086, -17.920411580388837]
# R^2:  [0.027278595648602133, 0.09577025649143167, 0.16382234755975988, 0.30733456654489166]
# t-test:
# slope- T value:  [4.306839310692394, 1.982650307703602, -5.439919966031361]
# slope- p value:  [0.00024205694170559378, 0.05632855220570524, 4.229764264338048e-06]
# intercept- T value:  [-1.4536015722821403, -3.2579923245072853, 5.66454675362943]
# intercept- p value:  [0.15900920677425012, 0.0027207114835132093, 2.137726396739628e-06]

# %%
# sentiment_SF_flavored_tobacco_positive



plt.figure(figsize=(14,7))


# print(x)
itemNum = len(x)
# print(itemNum)


# plt.subplot(2, 1, 1)


plt.plot(x, propotion_positive_flavored_tobacco, 'gx', label='Positive towards flavored tobacco')
plt.plot(x, propotion_neutral_flavored_tobacco, 'bx', label='Neutral towards flavored tobacco')
plt.plot(x, propotion_negative_flavored_tobacco, 'rx', label='Negtive towards flavored tobacco')


plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(14, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,-0.3))
plt.axvline(26, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Approved', xy=(16,-0.3))
plt.axvline(33, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Enforcement ', xy=(23,-0.3))

print('**************************************************************')
print('Positive: ')
drawRegressionLine_four_section(propotion_positive_flavored_tobacco, color='g')
print()
print('Neutral: ')
drawRegressionLine_four_section(propotion_neutral_flavored_tobacco, color='b')
print()
print('Negative: ')
drawRegressionLine_four_section(propotion_negative_flavored_tobacco, color='r')

plt.rc('legend', fontsize=12)
plt.rc('ytick', labelsize=13)
plt.rc('xtick', labelsize=12)

plt.xticks(rotation=80)
plt.xlabel('Month', font_setting)
plt.ylabel('Proportion (%)', font_setting)
plt.title('Trends for attitude towards flavored tobacco by month. Y-axis represents the proportion of corresponding tweets within each month. ')
# plt.figure(figsize=(40,1))
plt.show()
# Out:
# **************************************************************
# Positive:
# Mean value in different states:  [25.56, 24.66, 20.41, 24.28]
# slope:  [0.4969090972160015, -1.4266071288404991, 0.8367612063428944, -3.2447397563769114]
# intercept:  [22.327784778602254, 52.48036197255675, -3.854817445330047, 136.22369878213289]
# R^2:  [0.17088735957720014, 0.47998210132262986, 0.19096021682623487, 0.3400701142823196]
# t-test:
# slope- T value:  [12.413821605575277, -9.825641432261026, 6.473834689006556]
# slope- p value:  [6.175274960829965e-12, 4.869762161870147e-11, 1.8439350382846329e-07]
# intercept- T value:  [-11.716279021178394, 10.244855556122415, -6.827694012892427]
# intercept- p value:  [2.0477507001599007e-11, 1.7927597857787945e-11, 6.382447700461434e-08]
#
# Neutral:
# Mean value in different states:  [65.2, 59.12, 69.62, 60.55]
# slope:  [-0.5577244634594183, -0.10060351427893677, -1.2091475346167493, 4.7595976375128055]
# intercept:  [68.82053907021877, 61.08406306244437, 104.68945353283539, -103.65909929886212]
# R^2:  [0.22563824645127617, 0.003211159222895388, 0.38483793510079767, 0.7044969380148411]
# t-test:
# slope- T value:  [-2.650593238645442, 4.439752321292619, -12.340532897669368]
# slope- p value:  [0.014001356566123292, 0.00010620533453715594, 2.6381715252967833e-14]
# intercept- T value:  [2.554015120478477, -7.723290557045722, 13.52715088488611]
# intercept- p value:  [0.017418551130732533, 1.0327519641694658e-08, 1.8254007160222465e-15]
#
# Negative:
# Mean value in different states:  [9.25, 16.22, 9.96, 15.17]
# slope:  [0.06081536623686867, 1.5272106542387154, 0.37238632826730955, -1.5148578811424311]
# intercept:  [8.851676151390553, -13.564425251752187, -0.8346360872936971, 67.43540051694059]
# R^2:  [0.004619413038994491, 0.6965467938654797, 0.047767926121781046, 0.1630192063262671]
# t-test:
# slope- T value:  [-12.97400590028918, 6.239066249935952, 3.5461881656956877]
# slope- p value:  [2.4435072222287244e-12, 6.226195371683308e-07, 0.0011336595316985727]
# intercept- T value:  [12.625575931221793, -2.700418225370891, -4.020279560897649]
# intercept- p value:  [4.333912335273308e-12, 0.011119183573122915, 0.0002943994001935337]

# %%
# propotion_SF_flavored_tobacco_in_all_tobacco_tweets
plt.figure(figsize=(14,7))


# print(x)
# itemNum = len(x)
# print(itemNum)


plt.plot(x, SF_flavored_tobacco, 'bx', label='SF flavored tobacco tweets')
# plt.plot(x, users_SF_tobacco, 'yx', label='Users of SF tobacco related tweets')
# plt.plot(x, average_num_per_persion_tweets_SF_ecig, 'm-', label='not first person')
plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(14, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))
plt.axvline(26, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Approved', xy=(16,0.1))
plt.axvline(33, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Enforcement ', xy=(23,0.1))

print('**************************************************************')
print('Tobacco: ')
drawRegressionLine_four_section(SF_flavored_tobacco, color='b')



plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for number of San Francisco flavored tobacco tweets by month. ')
# plt.figure(figsize=(40,1))
plt.show()

# %%
plt.figure(figsize=(14,7))


# print(x)
itemNum = len(x)
# print(itemNum)


# plt.subplot(2, 1, 1)
# plt.plot(x, np.ones(itemNum)/2, 'r-', label='tobacco related')
# plt.plot(x, SF_allECigarette_total, 'r-', label='SF e-cigarette realated tweets')
# plt.plot(x, np.ones(itemNum)/3, 'b-', label='other tobacco')
# plt.plot(x, users_SF_ecig_total, 'y-', label='users of SF e-cigarette tweets')
plt.plot(x, average_num_per_person_tweets_SF_tobacco, 'mx', label='SF tobacco tweets per person')
plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(14, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))
plt.axvline(26, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Approved', xy=(16,0.1))
plt.axvline(33, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Enforcement ', xy=(23,0.1))


print('**************************************************************')
drawRegressionLine_four_section(average_num_per_person_tweets_SF_tobacco, color='m')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
plt.title('Trends for average tweets number of per person that post tobacco tweets in San Francisco ')
# plt.figure(figsize=(40,1))
plt.show()
# Out:
# **************************************************************
# slope:  [-0.007785611568229545, -0.009034865351751575, 0.0010312535492161823, -0.030898311921019994]
# intercept:  [1.330223456471145, 1.465714438278628, 1.216675514091722, 2.4064015380248547]
# R^2:  [0.34707992169642254, 0.22227567142340543, 0.00534913362967071, 0.29385952059868303]
# t-test:
# slope- T value:  [0.7435896922919855, -4.267322962303457, 5.200548729616964]
# slope- p value:  [0.4643426701440835, 0.00017287119305698894, 8.744676794912702e-06]
# intercept- T value:  [-4.671827860304846, 4.697455075474922, -5.847047391722459]
# intercept- p value:  [9.565923773101535e-05, 5.1028983600661647e-05, 1.2280643626051748e-06]

# %%
plt.figure(figsize=(14,7))



plt.plot(x, propotion_SF_tobacco_in_all_SF_tweets, 'bx', label='Proportion of SF tobacco in all SF tweets')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(14, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))
plt.axvline(26, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Approved', xy=(16,0.1))
plt.axvline(33, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Enforcement ', xy=(23,0.1))

print('**************************************************************')
drawRegressionLine_four_section(propotion_SF_tobacco_in_all_SF_tweets, color='b')

plt.rc('legend', fontsize=15)
plt.rc('ytick', labelsize=13)
plt.rc('xtick', labelsize=12)

plt.xticks(rotation=80)
plt.xlabel('Month',font_setting)
plt.ylabel('Proportion (%)',font_setting)
plt.title('Proportion of San Francisco tobacco tweets in all San Francisco tweets. ')
# plt.figure(figsize=(40,1))
plt.show()
# Out:
# **************************************************************
# slope:  [-0.004867543319629908, -0.0006701895499359178, 0.0041860514337837, -0.005624557576954237]
# intercept:  [0.22152741404455978, 0.23134876717175334, 0.10225009317244282, 0.41716077926708506]
# R^2:  [0.7121995527769625, 0.004408651030581856, 0.16107057644826528, 0.2381197287997282]
# t-test:
# slope- T value:  [-4.733308496172377, -3.3323241503861865, 4.041041056558934]
# slope- p value:  [8.18136311782193e-05, 0.002238174267225169, 0.0002772017584575142]
# intercept- T value:  [-0.5806805826415296, 3.8524911769332366, -4.284714959604136]
# intercept- p value:  [0.5668689717572825, 0.0005494833512574399, 0.00013596515877953953]
# /home/centos/anaconda3/envs/yijun/lib/python3.7/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
plt.figure(figsize=(14,7))


# print(x)
itemNum = len(x)
# print(itemNum)


# plt.subplot(2, 1, 1)


plt.plot(x, sentiment_tobacco_positive, 'gx', label='Positive towards tobacco')
plt.plot(x, sentiment_tobacco_neutral, 'bx', label='Neutral towards tobacco')
plt.plot(x, sentiment_tobacco_negative, 'rx', label='Negtive towards tobacco')


plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(14, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,-0.3))
plt.axvline(26, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Approved', xy=(16,-0.3))
plt.axvline(33, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Enforcement ', xy=(23,-0.3))

print('**************************************************************')
print('Positive: ')
drawRegressionLine_four_section(sentiment_tobacco_positive, color='g')
print()
print('Neutral: ')
drawRegressionLine_four_section(sentiment_tobacco_neutral, color='b')
print()
print('Negative: ')
drawRegressionLine_four_section(sentiment_tobacco_negative, color='r')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
plt.title('Trends for attitude towards tobacco by month. Y-axis represents the number of corresponding tweets within each month. ')
# plt.figure(figsize=(40,1))
plt.show()
# Out:
# **************************************************************
# Positive:
# slope:  [-9.496703296726206, -9.188811188833416, -2.1869173139066334e-12, -4.400000000011751]
# intercept:  [241.51428571481043, 339.1818181825559, 139.71428571458844, 272.3000000005908]
# R^2:  [0.8410808840902452, 0.40188050532878117, 1.1102230246251565e-16, 0.0851363236587519]
# t-test:
# slope- T value:  [-0.3063025614692449, -0.0, 0.0]
# slope- p value:  [0.7620157581354965, 1.0, 1.0]
# intercept- T value:  [-5.172539890621629, 0.0, -0.0]
# intercept- p value:  [2.6864188333262243e-05, 1.0, 1.0]
#
# Neutral:
# slope:  [-19.54285718914047, 5.398601331919005, -3.2857142857236337, -28.6000000000645]
# intercept:  [588.4571431579844, 230.89394094995427, 454.4285714295604, 1340.7000000029198]
# R^2:  [0.8649707036805279, 0.11948168416227112, 0.03959284484694281, 0.7112695652173905]
# t-test:
# slope- T value:  [-17.906869300458087, 3.892035298398079, 6.06664273933687]
# slope- p value:  [2.165949187822158e-15, 0.0004926997288323564, 6.30882810801313e-07]
# intercept- T value:  [14.338880967815038, -4.235902313448592, -6.9859305270554595]
# intercept- p value:  [2.885016907321849e-13, 0.00018885346455510107, 3.983584633094744e-08]
#
# Negative:
# slope:  [-4.21098901098901, 2.328671328674226, 1.0714285714287222, -1.900000000006314]
# intercept:  [132.65714285714284, 46.42424242434152, 67.50000000014519, 152.8000000003307]
# R^2:  [0.7780595224470245, 0.23149991614515464, 0.01188840748177089, 0.07435633367662209]
# t-test:
# slope- T value:  [-16.196778396418676, 1.301663359955828, 1.2751255889532693]
# slope- p value:  [2.017599912500159e-14, 0.20262187525344721, 0.21066441458103966]
# intercept- T value:  [11.941982983390526, -0.8147669662569643, -1.2343310199564708]
# intercept- p value:  [1.381684211487541e-11, 0.42142121786524545, 0.2253032571440355]
# /home/centos/anaconda3/envs/yijun/lib/python3.7/site-packages/scipy/optimize/minpack.py:799: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)

# %%
plt.figure(figsize=(14,7))


# print(x)
itemNum = len(x)
# print(itemNum)


# plt.subplot(2, 1, 1)


plt.plot(x, propotion_positive_tobacco, 'gx', label='Positive towards tobacco')
plt.plot(x, propotion_neutral_tobacco, 'bx', label='Neutral towards tobacco')
plt.plot(x, propotion_negative_tobacco, 'rx', label='Negtive towards tobacco')


plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(14, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,-0.3))
plt.axvline(26, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Approved', xy=(16,-0.3))
plt.axvline(33, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Enforcement ', xy=(23,-0.3))

print('**************************************************************')
print('Positive: ')
drawRegressionLine_four_section(propotion_positive_tobacco, color='g')
print()
print('Neutral: ')
drawRegressionLine_four_section(propotion_neutral_tobacco, color='b')
print()
print('Negative: ')
drawRegressionLine_four_section(propotion_negative_tobacco, color='r')

plt.rc('legend', fontsize=12)
plt.rc('ytick', labelsize=13)
plt.rc('xtick', labelsize=12)

plt.xticks(rotation=80)
plt.xlabel('Month', font_setting)
plt.ylabel('Proportion (%)', font_setting)
plt.title('Trends for attitude towards tobacco by month. Y-axis represents the proportion of corresponding tweets within each month. ')
# plt.figure(figsize=(40,1))
plt.show()
# Out:
# **************************************************************
# Positive:
# slope:  [-0.2009115132040713, -1.4309140103564055, 0.08549046098624491, 0.5137617140006869]
# intercept:  [25.225696764433295, 54.87854646614875, 20.93972979706628, 3.7134780689560873]
# R^2:  [0.25489712109233054, 0.7554518373012918, 0.009001252232112789, 0.09668720640057482]
# t-test:
# slope- T value:  [16.546714403551647, -12.243620304923995, -1.6087864151406104]
# slope- p value:  [1.2579188530880482e-14, 2.0723726406124234e-13, 0.11664746706995721]
# intercept- T value:  [-21.558067057060896, 11.591201218227253, 2.0567735846348034]
# intercept- p value:  [3.242483371854196e-17, 8.422664597739671e-13, 0.04722182435948804]
#
# Neutral:
# slope:  [0.15296519762173155, 1.0291966983472907, -0.26680072235842744, -1.130581033031162]
# intercept:  [60.92360235485917, 37.23045657513215, 67.96048871672923, 102.00477906457856]
# R^2:  [0.15372515549098553, 0.584958856352689, 0.05081576664466525, 0.2725071274496984]
# t-test:
# slope- T value:  [-11.100581330198569, 9.091209563937987, 2.6146058791006266]
# slope- p value:  [6.160057434299474e-11, 2.964037111495242e-10, 0.013087659144146856]
# intercept- T value:  [16.183909233013555, -8.799585608854237, -3.299996707813668]
# intercept- p value:  [2.0532963260190868e-14, 6.19255332223224e-10, 0.002229806813464718]
#
# Negative:
# slope:  [0.047946315575791876, 0.4017173120025713, 0.18131026136563877, 0.6168193190239333]
# intercept:  [13.85070088091912, 7.890996958930659, 11.099781486416056, -5.718257133323126]
# R^2:  [0.02444914282782007, 0.4332292398415023, 0.04386590355224673, 0.8072076957068055]
# t-test:
# slope- T value:  [-7.650436687499706, 2.4465063024192966, -2.2394883821667384]
# slope- p value:  [6.895350363827576e-08, 0.020294721135012714, 0.0315779328754068]
# intercept- T value:  [7.539893672629048, -1.3731912920445177, 2.957627402947863]
# intercept- p value:  [8.858396538600633e-08, 0.17954438477061216, 0.005523895764421231]

# %% [markdown]
# -------------------------------------------------------
# Ecig

# %%
# x1 = np.linspace(1, 12, 12)
# x2 = np.tile(x1, 2)
# x3 = np.linspace(1, 6, 6)
# # x = np.tile(x, 2)
# # itemNum = len(x)

# x = np.concatenate((x2, x3), axis=0)
# x = list(x)
x = ['2016-04','2016-05','2016-06','2016-07','2016-08','2016-09','2016-10','2016-11','2016-12','2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12',
    '2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06', '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12',
    '2019-01', '2019-02', '2019-03', '2019-04' ]

plt.figure(figsize=(14,7))


# print(x)
# itemNum = len(x)
# print(itemNum)


plt.plot(x, SF_allECigarette_total, 'rx', label='SF e-cigarette realated tweets')
plt.plot(x, users_SF_ecig_total, 'yx', label='Users of SF e-cigarette related tweets')
# plt.plot(x, average_num_per_persion_tweets_SF_ecig, 'm-', label='not first person')
plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(14, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))
plt.axvline(26, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Approved', xy=(16,0.1))
plt.axvline(33, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Enforcement ', xy=(23,0.1))

print('**************************************************************')
print('Tweets: ')
drawRegressionLine_four_section(SF_allECigarette_total, color='r')
print()
print('Users: ')
drawRegressionLine_four_section(users_SF_ecig_total, color='y')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for number of San Francisco e-cigarette related tweets/users by month. ')
# plt.figure(figsize=(40,1))
plt.show()
# Out:
# **************************************************************
# Tweets:
# slope:  [-6.42197802199422, 2.6153846153881397, 2.428571428574542, -14.49999999999997]
# intercept:  [147.6000000003198, 35.8333333334093, 37.285714285793496, 600.499999999999]
# R^2:  [0.7205280106938874, 0.17083667336912944, 0.06314179593620262, 0.6314761976272719]
# t-test:
# slope- T value:  [-15.336525598906748, 0.17814587788593786, 6.934582124185849]
# slope- p value:  [6.690432607030109e-14, 0.8597674788812115, 4.6409428091278513e-08]
# intercept- T value:  [11.239260602717183, -0.05453022627733692, -7.562544900455411]
# intercept- p value:  [4.7891842078846306e-11, 0.9568626492611236, 7.288068250033023e-09]
#
# Users:
# slope:  [-4.604395604407836, 1.3006993006999574, 3.42857141154153, -15.300000000035535]
# intercept:  [108.42857142880578, 39.63636363644789, -13.714285220418667, 608.1000000013235]
# R^2:  [0.843863948141789, 0.16480249995236373, 0.2007668177065186, 0.7883145310658359]
# t-test:
# slope- T value:  [-19.881290195320368, -3.158657373247127, 10.546195203555557]
# slope- p value:  [2.0500571974608676e-16, 0.0035229056534830947, 2.070373564191973e-12]
# intercept- T value:  [13.635342694785791, 2.9516183214506553, -11.494374363247974]
# intercept- p value:  [8.499011131330879e-13, 0.005976333349269908, 1.963086355058671e-13]

# %%
# x1 = np.linspace(1, 12, 12)
# x2 = np.tile(x1, 2)
# x3 = np.linspace(1, 6, 6)
# # x = np.tile(x, 2)
# # itemNum = len(x)

# x = np.concatenate((x2, x3), axis=0)
# x = list(x)
# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12',
#     '2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06', '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12',
#     '2019-01', '2019-02', '2019-03', '2019-04' ]

plt.figure(figsize=(14,7))


# print(x)
itemNum = len(x)
# print(itemNum)


# plt.subplot(2, 1, 1)
# plt.plot(x, np.ones(itemNum)/2, 'r-', label='tobacco related')
# plt.plot(x, SF_allECigarette_total, 'r-', label='SF e-cigarette realated tweets')
# plt.plot(x, np.ones(itemNum)/3, 'b-', label='other tobacco')
# plt.plot(x, users_SF_ecig_total, 'y-', label='users of SF e-cigarette tweets')
plt.plot(x, average_num_per_person_tweets_SF_ecig, 'mx', label='SF ecig tweets per person')
plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(14, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Proposal', xy=(4,0.1))
plt.axvline(26, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Approved', xy=(16,0.1))
plt.axvline(33, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Enforcement ', xy=(23,0.1))


print('**************************************************************')
drawRegressionLine_four_section(average_num_per_person_tweets_SF_ecig, color='m')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
plt.title('Trends for average tweets number of per person that post e-cigarette tweets in San Francisco ')
# plt.figure(figsize=(40,1))
plt.show()
# Out:
# **************************************************************
# slope:  [-0.007582691806971464, 0.015030549795453324, -0.01989341666626898, 0.055728177293283276]
# intercept:  [1.388540958126831, 1.0319815225817477, 1.8346128765969212, -0.6630506558155307]
# R^2:  [0.03507812235652841, 0.06947418505114766, 0.21436748057740918, 0.7873456563533076]
# t-test:
# slope- T value:  [-3.9658718723937296, 4.733913703157318, -8.23064227238237]
# slope- p value:  [0.0005743397473301723, 4.598573101817008e-05, 1.063805956289248e-09]
# intercept- T value:  [3.7452522848495597, -4.9821328744536135, 9.130962752095073]
# intercept- p value:  [0.0010003665959588558, 2.2606077276440228e-05, 8.655431304411158e-11]

# %%
# x1 = np.linspace(1, 12, 12)
# x2 = np.tile(x1, 2)
# x3 = np.linspace(1, 6, 6)
# # x = np.tile(x, 2)
# # itemNum = len(x)

# x = np.concatenate((x2, x3), axis=0)
# x = list(x)
# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12',
#     '2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06', '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12',
#     '2019-01', '2019-02', '2019-03', '2019-04' ]

plt.figure(figsize=(14,7))


# print(x)
itemNum = len(x)
# print(itemNum)


# plt.subplot(2, 1, 1)
# plt.plot(x, np.ones(itemNum)/2, 'r-', label='tobacco related')
# plt.plot(x, SF_allECigarette_total, 'r-', label='SF e-cigarette realated tweets')
# plt.plot(x, np.ones(itemNum)/3, 'b-', label='other tobacco')
plt.plot(x, allTweets_total, 'cx', label='All tweets that collected')
# plt.plot(x, allSF_total, 'p-', label='average number of per person tweets about SF ecig')
plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(14, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Proposal', xy=(4,0.1))
plt.axvline(26, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Approved', xy=(16,0.1))
plt.axvline(33, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Enforcement ', xy=(23,0.1))

print('**************************************************************')
drawRegressionLine_four_section(allTweets_total, color='c')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
plt.title('Trends for all tweets that collected from Twitter. ')
# plt.figure(figsize=(40,1))
plt.show()
# Out:
# **************************************************************
# slope:  [-2534973.1043944387, 125309.79519785604, -582391.5641211641, -3709535.1865205104]
# intercept:  [80572589.74999243, 40468664.07697514, 59411255.363556, 165359595.95557484]
# R^2:  [0.8145760943762553, 0.0029670147909909295, 0.1854349850527438, 0.8310925017924904]
# t-test:
# slope- T value:  [-12.187312948476148, 2.3908908401168136, 9.430285185402871]
# slope- p value:  [9.063933237541382e-12, 0.023065586268640144, 3.8454282052523885e-11]
# intercept- T value:  [10.260785100362806, -3.029541576890144, -10.361247153618992]
# intercept- p value:  [2.966048763521143e-10, 0.004906479268295016, 3.3225634716309454e-12]

# %%
# x1 = np.linspace(1, 12, 12)
# x2 = np.tile(x1, 2)
# x3 = np.linspace(1, 6, 6)
# # x = np.tile(x, 2)
# # itemNum = len(x)

# x = np.concatenate((x2, x3), axis=0)
# x = list(x)
# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12',
#     '2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06', '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12',
#     '2019-01', '2019-02', '2019-03', '2019-04' ]

plt.figure(figsize=(14,7))


# print(x)
itemNum = len(x)
# print(itemNum)


# plt.subplot(2, 1, 1)
# plt.plot(x, np.ones(itemNum)/2, 'r-', label='tobacco related')
# plt.plot(x, SF_allECigarette_total, 'r-', label='SF e-cigarette realated tweets')
# plt.plot(x, np.ones(itemNum)/3, 'b-', label='other tobacco')
# plt.plot(x, allTweets_total, 'c-', label='all tweets collected')
plt.plot(x, allSF_total, 'bx', label='All SF tweets that collected')
plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(14, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Proposal', xy=(4,0.1))
plt.axvline(26, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Approved', xy=(16,0.1))
plt.axvline(33, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Enforcement ', xy=(23,0.1))

print('**************************************************************')
drawRegressionLine_four_section(allSF_total, color='b')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
plt.title('Trends for all San Francisco tweets that collected from Twitter. ')
# plt.figure(figsize=(40,1))
plt.show()
# Out:
# **************************************************************
# slope:  [-7444.57802197802, -700.150561148851, -6208.392633819344, -9431.799999999817]
# intercept:  [439437.97142857144, 287513.8524328476, 447369.9578216018, 577005.0999999932]
# R^2:  [0.5695904684461153, 0.0023387936846335222, 0.5619711642575753, 0.36352995264364596]
# t-test:
# slope- T value:  [-5.061098676514703, 3.0467328600818817, 1.745343282575186]
# slope- p value:  [3.560870477587644e-05, 0.0046962398618176065, 0.08970011907052665]
# intercept- T value:  [6.208474234484067, -4.307381311232276, -2.1817433070350574]
# intercept- p value:  [2.045281467814017e-06, 0.0001544157274065976, 0.03593152014366665]

# %% [markdown]
# ----------------------------
#
# propotion

# %%
# x1 = np.linspace(1, 12, 12)
# x2 = np.tile(x1, 2)
# x3 = np.linspace(1, 6, 6)
# # x = np.tile(x, 2)
# # itemNum = len(x)

# x = np.concatenate((x2, x3), axis=0)
# x = list(x)
# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12',
#     '2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06', '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12',
#     '2019-01', '2019-02', '2019-03', '2019-04' ]

plt.figure(figsize=(14,7))



plt.plot(x, propotion_SF_in_all_tweets, 'rx', label='Propotion of SF tweets in all tweets')
# plt.plot(x, propotion_SF_ecig_in_all_SF_tweets, 'b-', label='propotion of SF e-cigarette in all SF tweets')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(14, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))
plt.axvline(26, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Approved', xy=(16,0.1))
plt.axvline(33, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Enforcement ', xy=(23,0.1))

print('**************************************************************')
drawRegressionLine_four_section(propotion_SF_in_all_tweets, color='r')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Propotion (%)')
plt.title('Propotion of San Francisco tweets in all tweets that collected from Twitter. ')
# plt.figure(figsize=(40,1))
plt.show()
# Out:
# **************************************************************
# slope:  [0.0136871682637425, -0.0036025961933230377, -0.0060517417966821085, 0.040951267439714445]
# intercept:  [0.5312531947930302, 0.7102039252797667, 0.8045500050682248, -0.7349560215076933]
# R^2:  [0.7838767690430806, 0.1714990276074304, 0.4011325520739222, 0.9808645323929035]
# t-test:
# slope- T value:  [19.2636447003074, 2.147560614764104, -26.293949667467007]
# slope- p value:  [4.1884643587015065e-16, 0.03967814874522503, 1.2241778754794019e-24]
# intercept- T value:  [-12.797837499383034, -3.607867873706385, 28.90672148457675]
# intercept- p value:  [3.2598861384696733e-12, 0.001071759945735895, 5.123904214894339e-26]

# %%
# x1 = np.linspace(1, 12, 12)
# x2 = np.tile(x1, 2)
# x3 = np.linspace(1, 6, 6)
# # x = np.tile(x, 2)
# # itemNum = len(x)

# x = np.concatenate((x2, x3), axis=0)
# x = list(x)
# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12',
#     '2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06', '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12',
#     '2019-01', '2019-02', '2019-03', '2019-04' ]

plt.figure(figsize=(14,7))


plt.plot(x, propotion_SF_ecig_in_all_ecig, 'gx', label='Propotion of SF e-cigarette in all e-cigarette')
# plt.plot(x, propotion_SF_ecig_in_all_SF_tweets, 'b-', label='propotion of SF e-cigarette in all SF tweets')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(14, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))
plt.axvline(26, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Approved', xy=(16,0.1))
plt.axvline(33, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Enforcement ', xy=(23,0.1))

print('**************************************************************')
drawRegressionLine_four_section(propotion_SF_ecig_in_all_ecig, color='g')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Propotion (%)')
plt.title('Propotion of San Francisco e-cigarette tweets in all e-cigarette tweets that collected from Twitter. ')
# plt.figure(figsize=(40,1))
plt.show()
# Out:
# **************************************************************
# slope:  [-0.01025501643444171, 4.911449864419826e-05, 0.01067814584800253, -0.011861849341471498]
# intercept:  [0.6485011959831684, 0.6185786042913661, 0.2982126101820681, 1.0519099444030928]
# R^2:  [0.11249150139386366, 4.333733400918582e-06, 0.07203273610234551, 0.04548475620191661]
# t-test:
# slope- T value:  [-3.3009074686676834, -2.4746037144342257, 2.1417143158326564]
# slope- p value:  [0.0030052379143930847, 0.019013794390086835, 0.03925508706202106]
# intercept- T value:  [0.6887484203712613, 2.9363167803930303, -2.316239062725718]
# intercept- p value:  [0.49758627453783466, 0.006210822355082746, 0.02652371276653467]

# %%
# # Second figure
# x1 = np.linspace(1, 12, 12)
# x2 = np.tile(x1, 2)
# x3 = np.linspace(1, 6, 6)
# # x = np.tile(x, 2)
# # itemNum = len(x)

# x = np.concatenate((x2, x3), axis=0)
# x = list(x)
# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12',
#     '2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06', '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12',
#     '2019-01', '2019-02', '2019-03', '2019-04' ]

plt.figure(figsize=(14,7))



plt.plot(x, propotion_SF_ecig_in_all_SF_tweets, 'bx', label='Proportion of SF e-cigarette in all SF tweets')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(14, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))
plt.axvline(26, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Approved', xy=(16,0.1))
plt.axvline(33, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Enforcement ', xy=(23,0.1))

print('**************************************************************')
drawRegressionLine_four_section(propotion_SF_ecig_in_all_SF_tweets, color='b')
plt.rc('legend', fontsize=15)
plt.rc('ytick', labelsize=13)
plt.rc('xtick', labelsize=12)

plt.xticks(rotation=80)
plt.xlabel('Month', font_setting)
plt.ylabel('Propotion (%)', font_setting)
plt.title('Propotion of San Francisco e-cigarette tweets in all San Francisco tweets. ')
# plt.figure(figsize=(40,1))
plt.show()
# Out:
# **************************************************************
# slope:  [-0.001175793274618142, 0.0009644005969429159, 0.0018582512966288656, -0.004130112535935204]
# intercept:  [0.034476205638775625, 0.01313447682988178, -0.013489725053700719, 0.18197917840798994]
# R^2:  [0.5032422540579629, 0.21962400384587588, 0.2520131228057214, 0.7172339969827565]
# t-test:
# slope- T value:  [-11.785884100476865, -2.577545374131933, 7.691933232743771]
# slope- p value:  [1.812726079187652e-11, 0.014928906661769211, 5.001180541394495e-09]
# intercept- T value:  [6.8345931289481925, 2.9815957239004116, -8.41048653499145]
# intercept- p value:  [4.5474029253317935e-07, 0.00554097863616205, 6.393369728648709e-10]

# %% [markdown]
# ----------------------------
# Sentiment analysis

# %%
# x1 = np.linspace(1, 12, 12)
# x2 = np.tile(x1, 2)
# x3 = np.linspace(1, 6, 6)
# # x = np.tile(x, 2)
# # itemNum = len(x)

# x = np.concatenate((x2, x3), axis=0)
# x = list(x)
# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12',
#     '2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06', '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12',
#     '2019-01', '2019-02', '2019-03', '2019-04']

plt.figure(figsize=(14,7))


# print(x)
itemNum = len(x)
# print(itemNum)


# plt.subplot(2, 1, 1)


plt.plot(x, vader_positive_total, 'gx', label='Positive towards e-cigarette')
plt.plot(x, vader_neutral_total, 'bx', label='Neutral towards e-cigarette')
plt.plot(x, vader_negative_total, 'rx', label='Negtive towards e-cigarette')


plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(14, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,-0.3))
plt.axvline(26, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Approved', xy=(16,-0.3))
plt.axvline(33, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Enforcement ', xy=(23,-0.3))

print('**************************************************************')
print('Positive: ')
drawRegressionLine_four_section(vader_positive_total, color='g')
print()
print('Neutral: ')
drawRegressionLine_four_section(vader_neutral_total, color='b')
print()
print('Negative: ')
drawRegressionLine_four_section(vader_negative_total, color='r')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
plt.title('Trends for attitude towards e-cigarette by month. Y-axis represents the number of corresponding tweets within each month. ')
# plt.figure(figsize=(40,1))
plt.show()
# Out:
# **************************************************************
# Positive:
# slope:  [-2.1824175801049157, 0.5279720279709983, -0.32142857143145465, -0.6000000000034855]
# intercept:  [53.114285711597894, 18.121212121249467, 42.03571428580381, 53.200000000113704]
# R^2:  [0.47841258366345896, 0.05091459897207662, 0.010579937304075138, 0.008294930875575979]
# t-test:
# slope- T value:  [-10.022440401969218, 2.2399499449155416, 0.27687820592785367]
# slope- p value:  [4.70488850400507e-10, 0.032404150504700156, 0.7835023027432868]
# intercept- T value:  [8.594783557581222, -2.5624121874652332, -0.3471053895557396]
# intercept- p value:  [8.66655480018639e-09, 0.01547376356707012, 0.7305906726994778]
#
# Neutral:
# slope:  [-2.914285714294254, 0.909090909090711, 0.7142857142850891, -12.800000000030083]
# intercept:  [67.65714285728825, 23.439393939442876, 31.857142857210214, 488.1000000010618]
# R^2:  [0.43217024539877313, 0.11705033164260614, 0.014176353841791611, 0.9470520231213873]
# t-test:
# slope- T value:  [-10.938443650478014, 0.3339985146287922, 9.731427506405804]
# slope- p value:  [8.290846231067758e-11, 0.740629680872027, 1.7201232764246915e-11]
# intercept- T value:  [9.448290904608184, -0.5365058511489581, -11.17195329969835]
# intercept- p value:  [1.4715476473508137e-09, 0.595438542547098, 4.3176421913010093e-13]
#
# Negative:
# slope:  [-1.3252747252797992, 1.1783216783220674, 2.0357142857165416, -1.1000000000045795]
# intercept:  [26.828571428627775, -5.727272727287405, -36.607142857224794, 59.200000000126906]
# R^2:  [0.43414704038685414, 0.3661543620049844, 0.33564049586776834, 0.15612903225806574]
# t-test:
# slope- T value:  [-13.773414472431508, -2.8157566933415223, 4.438997077377811]
# slope- p value:  [6.851736134341312e-13, 0.008385989916943207, 8.617932736752015e-05]
# intercept- T value:  [11.792605816143594, 3.908135041905371, -4.522021042298683]
# intercept- p value:  [1.7915594238569833e-11, 0.00047126085048823093, 6.73368413380033e-05]

# %%
# x1 = np.linspace(1, 12, 12)
# x2 = np.tile(x1, 2)
# x3 = np.linspace(1, 6, 6)
# # x = np.tile(x, 2)
# # itemNum = len(x)

# x = np.concatenate((x2, x3), axis=0)
# x = list(x)
# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12',
#     '2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06', '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12',
#     '2019-01', '2019-02', '2019-03', '2019-04']

plt.figure(figsize=(14,7))


# print(x)
itemNum = len(x)
# print(itemNum)


# plt.subplot(2, 1, 1)


plt.plot(x, propotion_positive_ecig, 'gx', label='Positive towards e-cigarette')
plt.plot(x, propotion_neutral_ecig, 'bx', label='Neutral towards e-cigarette')
plt.plot(x, propotion_negative_ecig, 'rx', label='Negtive towards e-cigarette')


plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(14, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,-0.3))
plt.axvline(26, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Approved', xy=(16,-0.3))
plt.axvline(33, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Enforcement ', xy=(23,-0.3))

print('**************************************************************')
print('Positive: ')
drawRegressionLine_four_section(propotion_positive_ecig, color='g')
print()
print('Neutral: ')
drawRegressionLine_four_section(propotion_neutral_ecig, color='b')
print()
print('Negative: ')
drawRegressionLine_four_section(propotion_negative_ecig, color='r')
plt.rc('legend', fontsize=12)
plt.rc('ytick', labelsize=13)
plt.rc('xtick', labelsize=12)

plt.xticks(rotation=80)
plt.xlabel('Month', font_setting)
plt.ylabel('Propotion (%)', font_setting)
plt.title('Trends for attitude towards e-cigarette by month. Y-axis represents the proportion of corresponding tweets within each month. ')
# plt.figure(figsize=(40,1))
plt.show()
# Out:
# **************************************************************
# Positive:
# slope:  [0.11238580528904385, -0.35395793422057253, -1.0629452947226623, 3.7790683660309488]
# intercept:  [36.46823011514651, 39.41547122606809, 61.624985459579044, -97.76686552795049]
# R^2:  [0.0033609676303235636, 0.10984476703942214, 0.1306573539548911, 0.47117516938149384]
# t-test:
# slope- T value:  [2.5530137018563983, 2.726663875591925, -6.369580401952039]
# slope- p value:  [0.017457751447937486, 0.010432614964220542, 2.5244711738842346e-07]
# intercept- T value:  [-1.4123008329895, -3.1281613224508016, 6.765685590746818]
# intercept- p value:  [0.17069759754190597, 0.003811452350189539, 7.681490254535046e-08]
#
# Neutral:
# slope:  [-0.0040473499019793024, -0.4352619844351817, -0.16049752678672635, -5.806263184388824]
# intercept:  [45.57625467748005, 56.480504466994105, 53.33685959964669, 246.02219268709246]
# R^2:  [5.467363566880046e-06, 0.11339938022336238, 0.002774386178788779, 0.8225067851216454]
# t-test:
# slope- T value:  [2.4320564543854606, -0.9334405240336767, 7.531251936431504]
# slope- p value:  [0.022844309468485525, 0.3578065924835092, 7.985099882870988e-09]
# intercept- T value:  [-4.716619753337005, 0.39478634621039765, -8.57315351434485]
# intercept- p value:  [8.5360032807966e-05, 0.6957038174753862, 4.047530365605326e-10]
#
# Negative:
# slope:  [-0.10833845539361264, 0.7892199186492097, 1.2234428215028461, 2.027194896762351]
# intercept:  [17.955515207585023, 4.104024307149389, -14.961845059014191, -48.25532986413283]
# R^2:  [0.006367074826996388, 0.4177346667524827, 0.5422599098519123, 0.4632016222595293]
# t-test:
# slope- T value:  [-6.5194556153432535, -2.957015804029743, -2.301387898422418]
# slope- p value:  [9.63688536457535e-07, 0.005895633257987738, 0.027440798420514313]
# intercept- T value:  [7.78759045863072, 5.39862030216999, 3.003301399589487]
# intercept- p value:  [5.064568137912714e-08, 6.847082525489243e-06, 0.004906482587379766]

# %%
# Fourth figure
x1 = np.linspace(1, 12, 12)
x2 = np.tile(x1, 2)
x3 = np.linspace(1, 6, 6)
# x = np.tile(x, 2)
# itemNum = len(x)

x = np.concatenate((x2, x3), axis=0)
x = list(x)
x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12',
    '2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06', '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12',
    '2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06', ]

plt.figure(figsize=(14,7))


# print(x)
itemNum = len(x)
# print(itemNum)


# plt.subplot(2, 1, 1)
plt.plot(x, np.ones(itemNum), 'r-', label='tobacco related positive')
plt.plot(x, np.ones(itemNum)-0.1, 'r--', label='tobacco related neutral')
plt.plot(x, np.ones(itemNum)-0.2, 'r-.', label='tobacco related negtive')

plt.plot(x, np.ones(itemNum)-0.3, 'g-', label='e-cigarette realated positive')
plt.plot(x, np.ones(itemNum)-0.4, 'g--', label='e-cigarette related neutral')
plt.plot(x, np.ones(itemNum)-0.5, 'g-.', label='e-cigarette related negtive')

plt.plot(x, np.ones(itemNum)-0.6, 'b-', label='other tobacco positive')
plt.plot(x, np.ones(itemNum)-0.7, 'b--', label='other tobacco neutral')
plt.plot(x, np.ones(itemNum)-0.8, 'b-.', label='other tobacco negtive')

plt.plot(x, np.ones(itemNum)-0.9, 'y-', label='first person positive')
plt.plot(x, np.ones(itemNum)-1, 'y--', label='first person neutral')
plt.plot(x, np.ones(itemNum)-1.1, 'y-.', label='first person negtive')

plt.plot(x, np.ones(itemNum)-1.2, 'm-', label='not first person positive')
plt.plot(x, np.ones(itemNum)-1.3, 'm--', label='not first person neutral')
plt.plot(x, np.ones(itemNum)-1.4, 'm-.', label='not first person negtive')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(5, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Proposal', xy=(4,-0.3))
plt.axvline(17, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Approved', xy=(16,-0.3))
plt.axvline(24, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Enforcement ', xy=(23,-0.3))




plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Attitude')
plt.title('Figure 4: Trends for attitude towards tobacco by month. Y-axis represents the propotion of corresponding tweets within each month. ')
# plt.figure(figsize=(40,1))
plt.show()

# %%
# # Second figure
# x1 = np.linspace(1, 12, 12)
# x2 = np.tile(x1, 2)
# x3 = np.linspace(1, 6, 6)
# # x = np.tile(x, 2)
# # itemNum = len(x)

# x = np.concatenate((x2, x3), axis=0)
# x = list(x)
# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12',
#     '2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06', '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12',
#     '2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06', ]

# plt.figure(figsize=(14,7))


# # print(x)
# itemNum = len(x)
# print(itemNum)


# # plt.subplot(2, 1, 1)
# plt.plot(x, np.ones(itemNum), 'r-', label='mentioning tweets')
# plt.plot(x, np.ones(itemNum)/2, 'g-.', label='mentioning users')
# plt.plot(x, np.zeros(itemNum), 'b.', label='first person users')
# plt.legend()
# # plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
# plt.axvline(5, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))
# plt.axvline(17, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Approved', xy=(16,0.1))
# plt.axvline(24, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Enforcement ', xy=(23,0.1))




# plt.xticks(rotation=80)
# plt.xlabel('Month')
# plt.ylabel('# of mentioning')
# plt.title('Figure 1: Trends for number of tobacco related tweet by month. Y-axis represents the number of corresponding tweets within each month. ')
# # plt.figure(figsize=(40,1))
# plt.show()
