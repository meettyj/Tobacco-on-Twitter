# %%
import matplotlib.pyplot as plt
import numpy as np

from scipy import optimize

# %%
import datetime

import matplotlib as mpl
 
fig = plt.figure()
 
start = datetime.datetime(2016, 1, 1)
end = datetime.datetime(2017, 1, 1)
# 设置日期的间隔为1
delta = datetime.timedelta(days= 29)
 
# 生成一个matplotlib可以识别的日期对象
dates = mpl.dates.drange(start, end, delta)

print(dates)

date_format = mpl.dates.DateFormatter("%Y-%m")
print(date_format)
# Out:
# [735964. 735993. 736022. 736051. 736080. 736109. 736138. 736167. 736196.
#  736225. 736254. 736283. 736312.]
# <matplotlib.dates.DateFormatter object at 0x7fd030fc77b8>

# %%
# Number

# ----------------------------- California -----------------------------
# California_allECigarette_2017
California_allECigarette_2017 = [2367, 1988, 2092, 1805, 1737, 1771, 1909, 2033, 976, 1174, 1961, 2008]
print('length of California_allECigarette_2017: ', len(California_allECigarette_2017))

# not_California_allECigarette_2017
not_California_allECigarette_2017 = [15672, 11836, 12673, 12472, 11343, 11850, 11658, 12056, 5957, 8171, 13678, 13673]
print('length of not_California_allECigarette_2017: ', len(not_California_allECigarette_2017))

# allECigarette_2017
allECigarette_2017 = []
for i in range(12):
    allECigarette_2017.append(California_allECigarette_2017[i]+not_California_allECigarette_2017[i])
print('length of allECigarette_2017: ', len(allECigarette_2017))


# allCalifornia_2017
allCalifornia_2017 = [7688806, 5950614, 6130864, 5623066, 5542298, 5872374, 6284243, 6242231, 2686895, 3874158, 5584508, 5218406]
print('length of allCalifornia_2017: ', len(allCalifornia_2017))


# Number of users that tweets ecig in California.
users_California_ecig_2017 = [1313, 1131, 1230, 1097, 1084, 1149, 1264, 1246, 647, 852, 1351, 1397]
print('length of users_California_ecig_2017: ', len(users_California_ecig_2017))


# average number of per person tweets about ecig in California.
average_num_per_person_tweets_California_ecig = []
for i in range(12):
    average_num_per_person_tweets_California_ecig.append(California_allECigarette_2017[i]/users_California_ecig_2017[i])
print('length of average_num_per_person_tweets_California_ecig: ', len(average_num_per_person_tweets_California_ecig))


# Number of users that tweets in California
users_California_2017 = [333885, 307678, 325899, 312275, 309270, 323365, 336303, 330514, 231445, 271542, 316768, 300338]
print('length of users_California_2017: ', len(users_California_2017))

# allTweets
allTweets_2017 = [64761879, 49292002, 51379810, 46841051, 45592367, 46897952, 50163222, 51079160, 22112648, 31365136, 46232294, 43487766]
print('length of allTweets_2017: ', len(allTweets_2017))

# Sentiment analysis
vader_positive_California_2017 = [775, 667, 719, 580, 590, 565, 605, 693, 328, 378, 645, 672]
vader_neutral_California_2017 = [1187, 1025, 1058, 942, 874, 891, 975, 991, 500, 582, 936, 891]
vader_negative_California_2017 = [405, 296, 315, 283, 273, 315, 329, 349, 148, 214, 380, 445]
print('length of vader_positive_California_2017: ', len(vader_positive_California_2017))
print('length of vader_neutral_California_2017: ', len(vader_neutral_California_2017))
print('length of vader_negative_California_2017: ', len(vader_negative_California_2017))

print('----------------------------------')
# ----------------------------- Oregon -----------------------------

# Oregon_allECigarette_2017
Oregon_allECigarette_2017 = []
print('length of Oregon_allECigarette_2017: ', len(Oregon_allECigarette_2017))

# not_Oregon_allECigarette_2017
not_Oregon_allECigarette_2017 = []
print('length of not_Oregon_allECigarette_2017: ', len(not_Oregon_allECigarette_2017))

# allOregon_2017
allOregon_2017 = []
print('length of allOregon_2017: ', len(allOregon_2017))


# Number of users that tweets ecig in Oregon.
users_Oregon_ecig_2017 = []
print('length of users_Oregon_ecig_2017: ', len(users_Oregon_ecig_2017))


# average number of per person tweets about ecig in Oregon.
average_num_per_person_tweets_Oregon_ecig = []
for i in range(12):
    average_num_per_person_tweets_Oregon_ecig.append(Oregon_allECigarette_2017[i]/users_Oregon_ecig_2017[i])
print('length of average_num_per_person_tweets_Oregon_ecig: ', len(average_num_per_person_tweets_Oregon_ecig))


# Number of users that tweets in Oregon
users_Oregon_2017 = []
print('length of users_Oregon_2017: ', len(users_Oregon_2017))

# Sentiment analysis
vader_positive_Oregon_2017 = []
vader_neutral_Oregon_2017 = []
vader_negative_Oregon_2017 = []
print('length of vader_positive_Oregon_2017: ', len(vader_positive_Oregon_2017))
print('length of vader_neutral_Oregon_2017: ', len(vader_neutral_Oregon_2017))
print('length of vader_negative_Oregon_2017: ', len(vader_negative_Oregon_2017))
# Out:
# length of California_allECigarette_2017:  12
# length of not_California_allECigarette_2017:  12
# length of allECigarette_2017:  12
# length of allCalifornia_2017:  12
# length of users_California_ecig_2017:  12
# length of average_num_per_person_tweets_California_ecig:  12
# length of users_California_2017:  12
# length of allTweets_2017:  12
# length of vader_positive_California_2017:  12
# length of vader_neutral_California_2017:  12
# length of vader_negative_California_2017:  12
# ----------------------------------
# length of Oregon_allECigarette_2017:  0
# length of not_Oregon_allECigarette_2017:  0
# length of allOregon_2017:  0
# length of users_Oregon_ecig_2017:  0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-18-b84f45d7a62f> in <module>
#      74 average_num_per_person_tweets_Oregon_ecig = []
#      75 for i in range(12):
# ---> 76     average_num_per_person_tweets_Oregon_ecig.append(Oregon_allECigarette_2017[i]/users_Oregon_ecig_2017[i])
#      77 print('length of average_num_per_person_tweets_Oregon_ecig: ', len(average_num_per_person_tweets_Oregon_ecig))
#      78
#
# IndexError: list index out of range

# %%
# Propotion
propotion_California_ecig_in_all_ecig = []
propotion_California_ecig_in_all_California_tweets = []
propotion_California_in_all_tweets = []
propotion_California_ecig_users_in_all_California_users = []
propotion_positive_ecig_California = []
propotion_neutral_ecig_California = []
propotion_negative_ecig_California = []


# propotion of California e-cig tweets in all e-cig tweets.
for i in range(12):
    propotion_California_ecig_in_all_ecig.append((California_allECigarette_2017[i]/allECigarette_2017[i])*100)
print('length of propotion_California_ecig_in_all_ecig: ', len(propotion_California_ecig_in_all_ecig))


# propotion of California e-cig tweets in all California tweets.
for i in range(12):
    propotion_California_ecig_in_all_California_tweets.append((California_allECigarette_2017[i]/allCalifornia_2017[i])*100)
print('length of propotion_California_ecig_in_all_California_tweets: ', len(propotion_California_ecig_in_all_California_tweets))


# propotion of California tweets in total tweets.
for i in range(12):
    propotion_California_in_all_tweets.append((allCalifornia_2017[i]/allTweets_2017[i])*100)
print('length of propotion_California_in_all_tweets: ', len(propotion_California_in_all_tweets))


# propotion of users post California e-cig in all California users.
# for i in range(12):
#     propotion_California_ecig_users_in_all_California_users.append((users_California_ecig_2017[i]/users_California_2017[i])*100)
# print('length of propotion_California_ecig_users_in_all_California_users: ', len(propotion_California_ecig_users_in_all_California_users))



# ---------------------- Sentiment analysis by vader ----------------------
for i in range(12):
    propotion_positive_ecig_California.append((vader_positive_California_2017[i]/California_allECigarette_2017[i])*100)
print('length of propotion_positive_ecig_California: ', len(propotion_positive_ecig_California))

for i in range(12):
    propotion_neutral_ecig_California.append((vader_neutral_California_2017[i]/California_allECigarette_2017[i])*100)
print('length of propotion_neutral_ecig_California: ', len(propotion_neutral_ecig_California))

for i in range(12):
    propotion_negative_ecig_California.append((vader_negative_California_2017[i]/California_allECigarette_2017[i])*100)
print('length of propotion_negative_ecig_California: ', len(propotion_negative_ecig_California))
# Out:
# length of propotion_California_ecig_in_all_ecig:  12
# length of propotion_California_ecig_in_all_California_tweets:  12
# length of propotion_California_in_all_tweets:  12
# length of propotion_positive_ecig_California:  12
# length of propotion_neutral_ecig_California:  12
# length of propotion_negative_ecig_California:  12

# %% [markdown]
# ---------------------------------
# Draw Figures.

# %%
def linearRegression(x, A, B):
    return A*x + B

# %%
# Regression line
length_of_section_1 = 4
length_of_section_2 = length_of_section_1+8
x_number_section_1 = [i for i in range(0,length_of_section_1)]
x_number_section_2 = [i for i in range(length_of_section_1-1, length_of_section_2)]


def drawRegressionLine_two_section(y, color):
    print('y: ', y)
    print('section 1: ', y[:length_of_section_1])
    print('section 2: ', y[length_of_section_1-1:length_of_section_2])
    print('--------------------------')
    
    # section 1
    A_section_1, B_section_1 = optimize.curve_fit(linearRegression, x_number_section_1, y[:length_of_section_1])[0]
    x_plot_section_1 = np.arange(0, length_of_section_1-1, 0.01)
    y_plot_section_1 = A_section_1 * x_plot_section_1 + B_section_1
    plt.plot(x_plot_section_1, y_plot_section_1, color+'-') # , label='Users' is useless

    # section 2: length_of_section_1-1:length_of_section_2
    A_section_2, B_section_2 = optimize.curve_fit(linearRegression, x_number_section_2, y[length_of_section_1-1:length_of_section_2])[0]
    x_plot_section_2 = np.arange(length_of_section_1-1, length_of_section_2-1, 0.01)
    y_plot_section_2 = A_section_2 * x_plot_section_2 + B_section_2
    plt.plot(x_plot_section_2, y_plot_section_2, color+'-')

# %%
# x1 = np.linspace(1, 12, 12)
# x2 = np.tile(x1, 2)
# x3 = np.linspace(1, 6, 6)
# # x = np.tile(x, 2)
# # itemNum = len(x)

# x = np.concatenate((x2, x3), axis=0)
# x = list(x)
x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))


# print(x)
# itemNum = len(x)
# print(itemNum)


plt.plot(x, California_allECigarette_2017, 'rx', label='California e-cigarette realated tweets')
# plt.plot(x, users_California_ecig_2017, 'yx', label='Users of California e-cigarette tweets')


# plt.plot(x, average_num_per_persion_tweets_SF_ecig, 'm-', label='not first person')
plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(3, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Proposal', xy=(4,0.1))



drawRegressionLine_two_section(California_allECigarette_2017, color='r')
# drawRegressionLine_two_section(users_California_ecig_2017, color='y')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for number of California related tweets/users by month. ')
# plt.figure(figsize=(40,1))
plt.show()
# Out:
# y:  [2367, 1988, 2092, 1805, 1737, 1771, 1909, 2033, 976, 1174, 1961, 2008]
# section 1:  [2367, 1988, 2092, 1805]
# section 2:  [1805, 1737, 1771, 1909, 2033, 976, 1174, 1961, 2008]
# --------------------------

# %%
# x1 = np.linspace(1, 12, 12)
# x2 = np.tile(x1, 2)
# x3 = np.linspace(1, 6, 6)
# # x = np.tile(x, 2)
# # itemNum = len(x)

# x = np.concatenate((x2, x3), axis=0)
# x = list(x)
x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))


# print(x)
# itemNum = len(x)
# print(itemNum)


# plt.plot(x, California_allECigarette_2017, 'rx', label='California e-cigarette realated tweets')
plt.plot(x, users_California_ecig_2017, 'yx', label='Users of California e-cigarette tweets')
# plt.plot(x, average_num_per_persion_tweets_SF_ecig, 'm-', label='not first person')
plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(3, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Proposal', xy=(4,0.1))


drawRegressionLine_two_section(users_California_ecig_2017, color='y')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for number of California related tweets/users by month. ')
# plt.figure(figsize=(40,1))
plt.show()
# Out:
# y:  [1313, 1131, 1230, 1097, 1084, 1149, 1264, 1246, 647, 852, 1351, 1397]
# section 1:  [1313, 1131, 1230, 1097]
# section 2:  [1097, 1084, 1149, 1264, 1246, 647, 852, 1351, 1397]
# --------------------------

# %%
x1 = np.linspace(1, 12, 12)
x2 = np.tile(x1, 2)
x3 = np.linspace(1, 6, 6)
# x = np.tile(x, 2)
# itemNum = len(x)

x = np.concatenate((x2, x3), axis=0)
x = list(x)
x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12',
    '2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06', '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12',
    '2019-01', '2019-02', '2019-03', '2019-04' ]

plt.figure(figsize=(14,7))


# print(x)
itemNum = len(x)
# print(itemNum)


# plt.subplot(2, 1, 1)
# plt.plot(x, np.ones(itemNum)/2, 'r-', label='tobacco related')
# plt.plot(x, SF_allECigarette_total, 'r-', label='SF e-cigarette realated tweets')
# plt.plot(x, np.ones(itemNum)/3, 'b-', label='other tobacco')
# plt.plot(x, users_SF_ecig_total, 'y-', label='users of SF e-cigarette tweets')
plt.plot(x, average_num_per_person_tweets_SF_ecig, 'mx', label='SF ecig tweets per person')
plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(5, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Proposal', xy=(4,0.1))
plt.axvline(17, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Approved', xy=(16,0.1))
plt.axvline(24, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Enforcement ', xy=(23,0.1))



drawRegressionLine_four_section(average_num_per_person_tweets_SF_ecig, color='m')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
plt.title('Trends for average tweets number of per person that post e-cigarette tweets in San Francisco ')
# plt.figure(figsize=(40,1))
plt.show()
# Out:
# y:  [1.18, 1.25, 1.2328767123287672, 1.1132075471698113, 1.2641509433962264, 1.3333333333333333, 1.1044776119402986, 1.2535211267605635, 1.236842105263158, 1.1111111111111112, 1.1692307692307693, 1.7681159420289856, 1.48, 1.5147058823529411, 1.5, 1.32, 1.1095890410958904, 1.2432432432432432, 1.4597701149425288, 1.2470588235294118, 1.2105263157894737, 1.2028985507246377, 1.184873949579832, 1.2555555555555555, 1.1818181818181819, 1.25, 1.2333333333333334, 1.373134328358209]
# section 1:  [1.18, 1.25, 1.2328767123287672, 1.1132075471698113, 1.2641509433962264, 1.3333333333333333]
# section 2:  [1.3333333333333333, 1.1044776119402986, 1.2535211267605635, 1.236842105263158, 1.1111111111111112, 1.1692307692307693, 1.7681159420289856, 1.48, 1.5147058823529411, 1.5, 1.32, 1.1095890410958904, 1.2432432432432432]
# section 3:  [1.2432432432432432, 1.4597701149425288, 1.2470588235294118, 1.2105263157894737, 1.2028985507246377, 1.184873949579832, 1.2555555555555555, 1.1818181818181819]
# section 4:  [1.1818181818181819, 1.25, 1.2333333333333334, 1.373134328358209]
# --------------------------

# %%
x1 = np.linspace(1, 12, 12)
x2 = np.tile(x1, 2)
x3 = np.linspace(1, 6, 6)
# x = np.tile(x, 2)
# itemNum = len(x)

x = np.concatenate((x2, x3), axis=0)
x = list(x)
x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12',
    '2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06', '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12',
    '2019-01', '2019-02', '2019-03', '2019-04' ]

plt.figure(figsize=(14,7))


# print(x)
itemNum = len(x)
# print(itemNum)


# plt.subplot(2, 1, 1)
# plt.plot(x, np.ones(itemNum)/2, 'r-', label='tobacco related')
# plt.plot(x, SF_allECigarette_total, 'r-', label='SF e-cigarette realated tweets')
# plt.plot(x, np.ones(itemNum)/3, 'b-', label='other tobacco')
plt.plot(x, allTweets_total, 'cx', label='All tweets that collected')
# plt.plot(x, allSF_total, 'p-', label='average number of per person tweets about SF ecig')
plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(5, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Proposal', xy=(4,0.1))
plt.axvline(17, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Approved', xy=(16,0.1))
plt.axvline(24, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Enforcement ', xy=(23,0.1))


drawRegressionLine_four_section(allTweets_total, color='c')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
plt.title('Trends for all tweets that collected from Twitter. ')
# plt.figure(figsize=(40,1))
plt.show()
# Out:
# y:  [64761879, 49292002, 51379810, 46841051, 45592367, 46897952, 50163222, 51079160, 22112648, 31365136, 46232294, 43487766, 46059070, 40432909, 47289301, 45660765, 44166238, 44212483, 45858463, 39900707, 45395994, 37985764, 42937313, 41362576, 44209494, 38750216, 32702554, 33860264]
# section 1:  [64761879, 49292002, 51379810, 46841051, 45592367, 46897952]
# section 2:  [46897952, 50163222, 51079160, 22112648, 31365136, 46232294, 43487766, 46059070, 40432909, 47289301, 45660765, 44166238, 44212483]
# section 3:  [44212483, 45858463, 39900707, 45395994, 37985764, 42937313, 41362576, 44209494]
# section 4:  [44209494, 38750216, 32702554, 33860264]
# --------------------------

# %%
x1 = np.linspace(1, 12, 12)
x2 = np.tile(x1, 2)
x3 = np.linspace(1, 6, 6)
# x = np.tile(x, 2)
# itemNum = len(x)

x = np.concatenate((x2, x3), axis=0)
x = list(x)
x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12',
    '2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06', '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12',
    '2019-01', '2019-02', '2019-03', '2019-04' ]

plt.figure(figsize=(14,7))


# print(x)
itemNum = len(x)
# print(itemNum)


# plt.subplot(2, 1, 1)
# plt.plot(x, np.ones(itemNum)/2, 'r-', label='tobacco related')
# plt.plot(x, SF_allECigarette_total, 'r-', label='SF e-cigarette realated tweets')
# plt.plot(x, np.ones(itemNum)/3, 'b-', label='other tobacco')
# plt.plot(x, allTweets_total, 'c-', label='all tweets collected')
plt.plot(x, allSF_total, 'bx', label='All SF tweets that collected')
plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(5, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Proposal', xy=(4,0.1))
plt.axvline(17, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Approved', xy=(16,0.1))
plt.axvline(24, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Enforcement ', xy=(23,0.1))


drawRegressionLine_four_section(allSF_total, color='b')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
plt.title('Trends for all San Francisco tweets that collected from Twitter. ')
# plt.figure(figsize=(40,1))
plt.show()
# Out:
# y:  [404518, 350143, 358222, 326842, 326461, 332603, 312882, 323315, 148187, 205925, 296740, 257645, 278884, 259869, 304292, 278291, 287698, 282691, 287065, 262239, 284484, 244884, 264046, 245877, 274852, 253351, 225549, 252680]
# section 1:  [404518, 350143, 358222, 326842, 326461, 332603]
# section 2:  [332603, 312882, 323315, 148187, 205925, 296740, 257645, 278884, 259869, 304292, 278291, 287698, 282691]
# section 3:  [282691, 287065, 262239, 284484, 244884, 264046, 245877, 274852]
# section 4:  [274852, 253351, 225549, 252680]
# --------------------------

# %% [markdown]
# ----------------------------
#
# propotion

# %%
x1 = np.linspace(1, 12, 12)
x2 = np.tile(x1, 2)
x3 = np.linspace(1, 6, 6)
# x = np.tile(x, 2)
# itemNum = len(x)

x = np.concatenate((x2, x3), axis=0)
x = list(x)
x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12',
    '2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06', '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12',
    '2019-01', '2019-02', '2019-03', '2019-04' ]

plt.figure(figsize=(14,7))



plt.plot(x, propotion_SF_in_all_tweets, 'rx', label='Propotion of SF tweets in all tweets')
# plt.plot(x, propotion_SF_ecig_in_all_SF_tweets, 'b-', label='propotion of SF e-cigarette in all SF tweets')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(5, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Proposal', xy=(4,0.1))
plt.axvline(17, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Approved', xy=(16,0.1))
plt.axvline(24, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Enforcement ', xy=(23,0.1))


drawRegressionLine_four_section(propotion_SF_in_all_tweets, color='r')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Propotion (%)')
plt.title('Propotion of San Francisco tweets in all tweets that collected from Twitter. ')
# plt.figure(figsize=(40,1))
plt.show()
# Out:
# y:  [0.6246236308245473, 0.7103444489838331, 0.6972038238366394, 0.6977682887602159, 0.7160431043205104, 0.7092058092430134, 0.6237278777667032, 0.6329685139692979, 0.6701458821213995, 0.6565410715898059, 0.6418457193579882, 0.5924539788960417, 0.6054920344679127, 0.6427165554672309, 0.6434690163849112, 0.6094751150139512, 0.6513980203611636, 0.639391820631291, 0.625980421541821, 0.6572289558678748, 0.6266720363034677, 0.644673093846421, 0.614956972272578, 0.5944431507360664, 0.6217035643972764, 0.6538053878202899, 0.6896984253890385, 0.7462434433470454]
# section 1:  [0.6246236308245473, 0.7103444489838331, 0.6972038238366394, 0.6977682887602159, 0.7160431043205104, 0.7092058092430134]
# section 2:  [0.7092058092430134, 0.6237278777667032, 0.6329685139692979, 0.6701458821213995, 0.6565410715898059, 0.6418457193579882, 0.5924539788960417, 0.6054920344679127, 0.6427165554672309, 0.6434690163849112, 0.6094751150139512, 0.6513980203611636, 0.639391820631291]
# section 3:  [0.639391820631291, 0.625980421541821, 0.6572289558678748, 0.6266720363034677, 0.644673093846421, 0.614956972272578, 0.5944431507360664, 0.6217035643972764]
# section 4:  [0.6217035643972764, 0.6538053878202899, 0.6896984253890385, 0.7462434433470454]
# --------------------------

# %%
x1 = np.linspace(1, 12, 12)
x2 = np.tile(x1, 2)
x3 = np.linspace(1, 6, 6)
# x = np.tile(x, 2)
# itemNum = len(x)

x = np.concatenate((x2, x3), axis=0)
x = list(x)
x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12',
    '2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06', '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12',
    '2019-01', '2019-02', '2019-03', '2019-04' ]

plt.figure(figsize=(14,7))


plt.plot(x, propotion_SF_ecig_in_all_ecig, 'gx', label='Propotion of SF e-cigarette in all e-cigarette')
# plt.plot(x, propotion_SF_ecig_in_all_SF_tweets, 'b-', label='propotion of SF e-cigarette in all SF tweets')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(5, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Proposal', xy=(4,0.1))
plt.axvline(17, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Approved', xy=(16,0.1))
plt.axvline(24, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Enforcement ', xy=(23,0.1))


drawRegressionLine_four_section(propotion_SF_ecig_in_all_ecig, color='g')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Propotion (%)')
plt.title('Propotion of San Francisco e-cigarette tweets in all e-cigarette tweets that collected from Twitter. ')
# plt.figure(figsize=(40,1))
plt.show()
# Out:
# y:  [0.32701474337656583, 0.47019675925925924, 0.6095496105655266, 0.41325208377110034, 0.5122324159021406, 0.6460138012039348, 0.545441143952237, 0.6316984881822698, 0.6779172075580556, 0.5349882302589343, 0.4859335038363171, 0.7780116064026529, 0.6740344911343211, 0.7036480393496379, 0.6199477298972832, 0.6156333561345688, 0.521168446789345, 0.5643133165675029, 0.6730259671436142, 0.609230415541123, 0.4799666110183639, 0.5494141788574833, 0.7398079647410672, 0.6393934249985854, 0.6953359007274282, 0.6443694384780607, 0.5406195207481005, 0.6903797088398619]
# section 1:  [0.32701474337656583, 0.47019675925925924, 0.6095496105655266, 0.41325208377110034, 0.5122324159021406, 0.6460138012039348]
# section 2:  [0.6460138012039348, 0.545441143952237, 0.6316984881822698, 0.6779172075580556, 0.5349882302589343, 0.4859335038363171, 0.7780116064026529, 0.6740344911343211, 0.7036480393496379, 0.6199477298972832, 0.6156333561345688, 0.521168446789345, 0.5643133165675029]
# section 3:  [0.5643133165675029, 0.6730259671436142, 0.609230415541123, 0.4799666110183639, 0.5494141788574833, 0.7398079647410672, 0.6393934249985854, 0.6953359007274282]
# section 4:  [0.6953359007274282, 0.6443694384780607, 0.5406195207481005, 0.6903797088398619]
# --------------------------

# %%
# Second figure
x1 = np.linspace(1, 12, 12)
x2 = np.tile(x1, 2)
x3 = np.linspace(1, 6, 6)
# x = np.tile(x, 2)
# itemNum = len(x)

x = np.concatenate((x2, x3), axis=0)
x = list(x)
x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12',
    '2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06', '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12',
    '2019-01', '2019-02', '2019-03', '2019-04' ]

plt.figure(figsize=(14,7))



plt.plot(x, propotion_SF_ecig_in_all_SF_tweets, 'bx', label='Propotion of SF e-cigarette in all SF tweets')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(5, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Proposal', xy=(4,0.1))
plt.axvline(17, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Approved', xy=(16,0.1))
plt.axvline(24, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Enforcement ', xy=(23,0.1))


drawRegressionLine_four_section(propotion_SF_ecig_in_all_SF_tweets, color='b')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Propotion (%)')
plt.title('Propotion of San Francisco e-cigarette tweets in all San Francisco tweets. ')
# plt.figure(figsize=(40,1))
plt.show()
# Out:
# y:  [0.0145852594940151, 0.018563843915200363, 0.0251240850645689, 0.018051535604359292, 0.020523125273769302, 0.026457969410979457, 0.02365108890891774, 0.02752733402409415, 0.03171668230006681, 0.024280684715308972, 0.02561164655927748, 0.047351976556890295, 0.03980149452819093, 0.03963535473642489, 0.033520434319666635, 0.03557427297325461, 0.028154523145798718, 0.03254436823245169, 0.0442408513751241, 0.04042114254554052, 0.032339252822654346, 0.03389359860178697, 0.053399786400854396, 0.045957938318752875, 0.047298182294471205, 0.04144447821401929, 0.032808835330682025, 0.036409688143105905]
# section 1:  [0.0145852594940151, 0.018563843915200363, 0.0251240850645689, 0.018051535604359292, 0.020523125273769302, 0.026457969410979457]
# section 2:  [0.026457969410979457, 0.02365108890891774, 0.02752733402409415, 0.03171668230006681, 0.024280684715308972, 0.02561164655927748, 0.047351976556890295, 0.03980149452819093, 0.03963535473642489, 0.033520434319666635, 0.03557427297325461, 0.028154523145798718, 0.03254436823245169]
# section 3:  [0.03254436823245169, 0.0442408513751241, 0.04042114254554052, 0.032339252822654346, 0.03389359860178697, 0.053399786400854396, 0.045957938318752875, 0.047298182294471205]
# section 4:  [0.047298182294471205, 0.04144447821401929, 0.032808835330682025, 0.036409688143105905]
# --------------------------

# %%
# # Third figure
# x1 = np.linspace(1, 12, 12)
# x2 = np.tile(x1, 2)
# x3 = np.linspace(1, 6, 6)
# # x = np.tile(x, 2)
# # itemNum = len(x)

# x = np.concatenate((x2, x3), axis=0)
# x = list(x)
# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12',
#     '2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06', '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12',
#     '2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06', ]

# plt.figure(figsize=(14,7))


# # print(x)
# itemNum = len(x)
# # print(itemNum)


# # plt.subplot(2, 1, 1)
# plt.plot(x, np.ones(itemNum), 'r-', label='tobacco related')
# plt.plot(x, np.ones(itemNum)/2, 'g-', label='e-cigarette realated')
# plt.plot(x, np.ones(itemNum)/3, 'b-', label='other tobacco')
# plt.plot(x, np.ones(itemNum)/4, 'y-', label='first person')
# plt.plot(x, np.zeros(itemNum)/5, 'm-', label='not first person')
# plt.legend()
# # plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
# plt.axvline(5, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))
# plt.axvline(17, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Approved', xy=(16,0.1))
# plt.axvline(24, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Enforcement ', xy=(23,0.1))




# plt.xticks(rotation=80)
# plt.xlabel('Month')
# plt.ylabel('# of poster')
# plt.title('Figure 3: Trends for number of tobacco related tweet poster by month. Y-axis represents the number of poster within each month. ')
# # plt.figure(figsize=(40,1))
# plt.show()

# %% [markdown]
# ----------------------------
# Sentiment analysis

# %%
x1 = np.linspace(1, 12, 12)
x2 = np.tile(x1, 2)
x3 = np.linspace(1, 6, 6)
# x = np.tile(x, 2)
# itemNum = len(x)

x = np.concatenate((x2, x3), axis=0)
x = list(x)
x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12',
    '2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06', '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12',
    '2019-01', '2019-02', '2019-03', '2019-04']

plt.figure(figsize=(14,7))


# print(x)
itemNum = len(x)
# print(itemNum)


# plt.subplot(2, 1, 1)


plt.plot(x, vader_positive_total, 'gx', label='Positive towards e-cigarette')
plt.plot(x, vader_neutral_total, 'bx', label='Neutral towards e-cigarette')
plt.plot(x, vader_negative_total, 'rx', label='Negtive towards e-cigarette')


plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(5, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Proposal', xy=(4,-0.3))
plt.axvline(17, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Approved', xy=(16,-0.3))
plt.axvline(24, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Enforcement ', xy=(23,-0.3))


drawRegressionLine_four_section(vader_positive_total, color='g')
drawRegressionLine_four_section(vader_neutral_total, color='b')
drawRegressionLine_four_section(vader_negative_total, color='r')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
plt.title('Trends for attitude towards e-cigarette by month. Y-axis represents the number of corresponding tweets within each month. ')
# plt.figure(figsize=(40,1))
plt.show()
# Out:
# y:  [22, 23, 37, 21, 27, 32, 25, 33, 17, 12, 22, 40, 38, 36, 29, 31, 26, 31, 33, 35, 39, 23, 42, 26, 36, 35, 20, 39]
# section 1:  [22, 23, 37, 21, 27, 32]
# section 2:  [32, 25, 33, 17, 12, 22, 40, 38, 36, 29, 31, 26, 31]
# section 3:  [31, 33, 35, 39, 23, 42, 26, 36]
# section 4:  [36, 35, 20, 39]
# --------------------------
# y:  [29, 31, 38, 24, 29, 43, 38, 42, 23, 26, 42, 53, 44, 47, 55, 46, 35, 43, 73, 51, 35, 45, 62, 59, 68, 52, 35, 31]
# section 1:  [29, 31, 38, 24, 29, 43]
# section 2:  [43, 38, 42, 23, 26, 42, 53, 44, 47, 55, 46, 35, 43]
# section 3:  [43, 73, 51, 35, 45, 62, 59, 68]
# section 4:  [68, 52, 35, 31]
# --------------------------
# y:  [8, 11, 15, 14, 11, 13, 11, 14, 7, 12, 12, 29, 29, 20, 18, 22, 20, 18, 21, 20, 18, 15, 37, 28, 26, 18, 19, 22]
# section 1:  [8, 11, 15, 14, 11, 13]
# section 2:  [13, 11, 14, 7, 12, 12, 29, 29, 20, 18, 22, 20, 18]
# section 3:  [18, 21, 20, 18, 15, 37, 28, 26]
# section 4:  [26, 18, 19, 22]
# --------------------------

# %%
x1 = np.linspace(1, 12, 12)
x2 = np.tile(x1, 2)
x3 = np.linspace(1, 6, 6)
# x = np.tile(x, 2)
# itemNum = len(x)

x = np.concatenate((x2, x3), axis=0)
x = list(x)
x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12',
    '2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06', '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12',
    '2019-01', '2019-02', '2019-03', '2019-04']

plt.figure(figsize=(14,7))


# print(x)
itemNum = len(x)
# print(itemNum)


# plt.subplot(2, 1, 1)


plt.plot(x, propotion_positive_ecig, 'gx', label='Positive towards e-cigarette')
plt.plot(x, propotion_neutral_ecig, 'bx', label='Neutral towards e-cigarette')
plt.plot(x, propotion_negative_ecig, 'rx', label='Negtive towards e-cigarette')


plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(5, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Proposal', xy=(4,-0.3))
plt.axvline(17, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Approved', xy=(16,-0.3))
plt.axvline(24, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Enforcement ', xy=(23,-0.3))


drawRegressionLine_four_section(propotion_positive_ecig, color='g')
drawRegressionLine_four_section(propotion_neutral_ecig, color='b')
drawRegressionLine_four_section(propotion_negative_ecig, color='r')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Propotion (%)')
plt.title('Trends for attitude towards e-cigarette by month. Y-axis represents the propotion of corresponding tweets within each month. ')
# plt.figure(figsize=(40,1))
plt.show()
# Out:
# y:  [37.28813559322034, 35.38461538461539, 41.11111111111111, 35.59322033898305, 40.298507462686565, 36.36363636363637, 33.78378378378378, 37.07865168539326, 36.17021276595745, 24.0, 28.947368421052634, 32.78688524590164, 34.234234234234236, 34.95145631067961, 28.431372549019606, 31.313131313131315, 32.098765432098766, 33.69565217391305, 25.984251968503933, 33.0188679245283, 42.391304347826086, 27.710843373493976, 29.78723404255319, 23.008849557522122, 27.692307692307693, 33.33333333333333, 27.027027027027028, 42.391304347826086]
# section 1:  [37.28813559322034, 35.38461538461539, 41.11111111111111, 35.59322033898305, 40.298507462686565, 36.36363636363637]
# section 2:  [36.36363636363637, 33.78378378378378, 37.07865168539326, 36.17021276595745, 24.0, 28.947368421052634, 32.78688524590164, 34.234234234234236, 34.95145631067961, 28.431372549019606, 31.313131313131315, 32.098765432098766, 33.69565217391305]
# section 3:  [33.69565217391305, 25.984251968503933, 33.0188679245283, 42.391304347826086, 27.710843373493976, 29.78723404255319, 23.008849557522122, 27.692307692307693]
# section 4:  [27.692307692307693, 33.33333333333333, 27.027027027027028, 42.391304347826086]
# --------------------------
# y:  [49.152542372881356, 47.69230769230769, 42.22222222222222, 40.67796610169492, 43.28358208955223, 48.86363636363637, 51.35135135135135, 47.19101123595505, 48.93617021276596, 52.0, 55.26315789473685, 43.44262295081967, 39.63963963963964, 45.63106796116505, 53.92156862745098, 46.464646464646464, 43.20987654320987, 46.73913043478261, 57.48031496062992, 48.113207547169814, 38.04347826086957, 54.21686746987952, 43.97163120567376, 52.21238938053098, 52.307692307692314, 49.523809523809526, 47.2972972972973, 33.69565217391305]
# section 1:  [49.152542372881356, 47.69230769230769, 42.22222222222222, 40.67796610169492, 43.28358208955223, 48.86363636363637]
# section 2:  [48.86363636363637, 51.35135135135135, 47.19101123595505, 48.93617021276596, 52.0, 55.26315789473685, 43.44262295081967, 39.63963963963964, 45.63106796116505, 53.92156862745098, 46.464646464646464, 43.20987654320987, 46.73913043478261]
# section 3:  [46.73913043478261, 57.48031496062992, 48.113207547169814, 38.04347826086957, 54.21686746987952, 43.97163120567376, 52.21238938053098, 52.307692307692314]
# section 4:  [52.307692307692314, 49.523809523809526, 47.2972972972973, 33.69565217391305]
# --------------------------
# y:  [13.559322033898304, 16.923076923076923, 16.666666666666664, 23.728813559322035, 16.417910447761194, 14.772727272727273, 14.864864864864865, 15.730337078651685, 14.893617021276595, 24.0, 15.789473684210526, 23.770491803278688, 26.126126126126124, 19.41747572815534, 17.647058823529413, 22.22222222222222, 24.691358024691358, 19.565217391304348, 16.535433070866144, 18.867924528301888, 19.565217391304348, 18.072289156626507, 26.24113475177305, 24.778761061946902, 20.0, 17.142857142857142, 25.675675675675674, 23.91304347826087]
# section 1:  [13.559322033898304, 16.923076923076923, 16.666666666666664, 23.728813559322035, 16.417910447761194, 14.772727272727273]
# section 2:  [14.772727272727273, 14.864864864864865, 15.730337078651685, 14.893617021276595, 24.0, 15.789473684210526, 23.770491803278688, 26.126126126126124, 19.41747572815534, 17.647058823529413, 22.22222222222222, 24.691358024691358, 19.565217391304348]
# section 3:  [19.565217391304348, 16.535433070866144, 18.867924528301888, 19.565217391304348, 18.072289156626507, 26.24113475177305, 24.778761061946902, 20.0]
# section 4:  [20.0, 17.142857142857142, 25.675675675675674, 23.91304347826087]
# --------------------------

# %%
# Fourth figure
x1 = np.linspace(1, 12, 12)
x2 = np.tile(x1, 2)
x3 = np.linspace(1, 6, 6)
# x = np.tile(x, 2)
# itemNum = len(x)

x = np.concatenate((x2, x3), axis=0)
x = list(x)
x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12',
    '2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06', '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12',
    '2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06', ]

plt.figure(figsize=(14,7))


# print(x)
itemNum = len(x)
# print(itemNum)


# plt.subplot(2, 1, 1)
plt.plot(x, np.ones(itemNum), 'r-', label='tobacco related positive')
plt.plot(x, np.ones(itemNum)-0.1, 'r--', label='tobacco related neutral')
plt.plot(x, np.ones(itemNum)-0.2, 'r-.', label='tobacco related negtive')

plt.plot(x, np.ones(itemNum)-0.3, 'g-', label='e-cigarette realated positive')
plt.plot(x, np.ones(itemNum)-0.4, 'g--', label='e-cigarette related neutral')
plt.plot(x, np.ones(itemNum)-0.5, 'g-.', label='e-cigarette related negtive')

plt.plot(x, np.ones(itemNum)-0.6, 'b-', label='other tobacco positive')
plt.plot(x, np.ones(itemNum)-0.7, 'b--', label='other tobacco neutral')
plt.plot(x, np.ones(itemNum)-0.8, 'b-.', label='other tobacco negtive')

plt.plot(x, np.ones(itemNum)-0.9, 'y-', label='first person positive')
plt.plot(x, np.ones(itemNum)-1, 'y--', label='first person neutral')
plt.plot(x, np.ones(itemNum)-1.1, 'y-.', label='first person negtive')

plt.plot(x, np.ones(itemNum)-1.2, 'm-', label='not first person positive')
plt.plot(x, np.ones(itemNum)-1.3, 'm--', label='not first person neutral')
plt.plot(x, np.ones(itemNum)-1.4, 'm-.', label='not first person negtive')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(5, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Proposal', xy=(4,-0.3))
plt.axvline(17, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Approved', xy=(16,-0.3))
plt.axvline(24, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Enforcement ', xy=(23,-0.3))




plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Attitude')
plt.title('Figure 4: Trends for attitude towards tobacco by month. Y-axis represents the propotion of corresponding tweets within each month. ')
# plt.figure(figsize=(40,1))
plt.show()

# %%
# # Second figure
# x1 = np.linspace(1, 12, 12)
# x2 = np.tile(x1, 2)
# x3 = np.linspace(1, 6, 6)
# # x = np.tile(x, 2)
# # itemNum = len(x)

# x = np.concatenate((x2, x3), axis=0)
# x = list(x)
# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12',
#     '2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06', '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12',
#     '2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06', ]

# plt.figure(figsize=(14,7))


# # print(x)
# itemNum = len(x)
# print(itemNum)


# # plt.subplot(2, 1, 1)
# plt.plot(x, np.ones(itemNum), 'r-', label='mentioning tweets')
# plt.plot(x, np.ones(itemNum)/2, 'g-.', label='mentioning users')
# plt.plot(x, np.zeros(itemNum), 'b.', label='first person users')
# plt.legend()
# # plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
# plt.axvline(5, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))
# plt.axvline(17, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Approved', xy=(16,0.1))
# plt.axvline(24, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Enforcement ', xy=(23,0.1))




# plt.xticks(rotation=80)
# plt.xlabel('Month')
# plt.ylabel('# of mentioning')
# plt.title('Figure 1: Trends for number of tobacco related tweet by month. Y-axis represents the number of corresponding tweets within each month. ')
# # plt.figure(figsize=(40,1))
# plt.show()
