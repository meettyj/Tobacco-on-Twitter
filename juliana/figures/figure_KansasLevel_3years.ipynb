# %%
import matplotlib.pyplot as plt
import numpy as np

from scipy import optimize

# %%
import datetime

import matplotlib as mpl
 
fig = plt.figure()
 
start = datetime.datetime(2016, 1, 1)
end = datetime.datetime(2017, 1, 1)
# 设置日期的间隔为1
delta = datetime.timedelta(days= 29)
 
# 生成一个matplotlib可以识别的日期对象
dates = mpl.dates.drange(start, end, delta)

print(dates)

date_format = mpl.dates.DateFormatter("%Y-%m")
print(date_format)
# Out:
# [735964. 735993. 736022. 736051. 736080. 736109. 736138. 736167. 736196.
#  736225. 736254. 736283. 736312.]
# ...

# %%
# Number

# ----------------------------- Kansas -----------------------------
# Kansas_allECigarette_2017
Kansas_allECigarette_2017 = [115, 132, 85, 98, 88, 75, 54, 70, 73, 78, 70, 57, 47, 41, 60, 55, 44, 29, 37, 59, 71, 58, 85, 80, 79, 67, 108, 91, 92, 126, 105, 105, 103, 122, 92, 47, 63]
print('length of Kansas_allECigarette_2017: ', len(Kansas_allECigarette_2017))

# not_Kansas_allECigarette_2017
not_Kansas_allECigarette_2017 = [22671, 24475, 21166, 23581, 20129, 16223, 17552, 16683, 16342, 17961, 13754, 14708, 14230, 13039, 13561, 13512, 14045, 6904, 9308, 15580, 15610,17298, 15324, 17242, 17169, 15475, 16195, 18779, 17306, 19042, 15002, 18954, 17567, 18574, 16203, 13641, 13263]
print('length of not_Kansas_allECigarette_2017: ', len(not_Kansas_allECigarette_2017))

# allECigarette_2017
allECigarette_2017 = []
for i in range(37):
    allECigarette_2017.append(Kansas_allECigarette_2017[i]+not_Kansas_allECigarette_2017[i])
print('length of allECigarette_2017: ', len(allECigarette_2017))


# allKansas_2017
allKansas_2017 = [381317, 395199, 382231, 389340, 400510, 361346, 371409, 369717, 325160, 357524, 270774, 271470, 249062, 218047, 219729, 242020, 254155, 118373, 169210, 238239, 217463,245159, 216073, 251016, 233912, 216562, 204834, 211363, 197013, 231538, 202786, 222545, 196385, 219403, 193762, 151218, 151878]
print('length of allKansas_2017: ', len(allKansas_2017))


# Number of users that tweets ecig in Kansas.
users_Kansas_ecig_2017 = [82, 89, 55, 84, 65, 52, 48, 47, 52,55, 52, 49, 36, 30, 43, 39, 37, 29, 34, 54, 65, 48, 55, 63, 59, 54, 70, 70, 80, 95, 80, 80, 65, 71, 75, 40, 49]
print('length of users_Kansas_ecig_2017: ', len(users_Kansas_ecig_2017))


# average number of per person tweets about ecig in Kansas.
average_num_per_person_tweets_Kansas_ecig = []
for i in range(37):
    average_num_per_person_tweets_Kansas_ecig.append(Kansas_allECigarette_2017[i]/users_Kansas_ecig_2017[i])
print('length of average_num_per_person_tweets_Kansas_ecig: ', len(average_num_per_person_tweets_Kansas_ecig))


# Number of users that tweets in Kansas
users_Kansas_2017 = [20381, 21505, 21378, 22497, 21944, 21090, 21566, 21622, 20192,19051, 17639, 18512, 17676, 17917, 17325, 18080, 18897, 13543, 15774, 18978, 17866,16820, 16432, 18543, 17121, 17191, 16551, 16972, 16760, 17459, 16238, 17106, 16135, 15713, 15046, 13895, 12218]
print('length of users_Kansas_2017: ', len(users_Kansas_2017))

# average number of per person tweets in Kansas.
average_num_per_person_tweets_Kansas = []
for i in range(37):
    average_num_per_person_tweets_Kansas.append(allKansas_2017[i]/users_Kansas_2017[i])
print('length of average_num_per_person_tweets_Kansas: ', len(average_num_per_person_tweets_Kansas))

# allTweets
allTweets_2017 = [70798094, 76153908, 77039352, 79730585, 75060717, 63144176, 68592777, 68306197, 60640789, 64761879, 49292002, 51379810, 46841051, 45592367, 46897952, 50163222, 51079160, 22112648, 31365136, 46232294, 43487766, 46059070, 40432909, 47289301, 45660765, 44166238, 44212483, 45858463, 39900707, 45395994, 37985764, 42937313, 41362576, 44209494, 38750216, 32702554, 33860264]
print('length of allTweets_2017: ', len(allTweets_2017))

# Sentiment analysis
vader_positive_Kansas_2017 = [42, 35, 26, 38, 37, 29, 17, 23, 25,30, 27, 17, 14, 19, 22, 25, 16, 10, 16, 25, 20,18, 24, 27, 24, 23, 30, 29, 29, 33, 38, 29, 26, 42, 25, 15, 20]
vader_neutral_Kansas_2017 = [50, 72, 44, 41, 33, 32, 30, 33, 39,34, 35, 33, 22, 15, 27, 17, 16, 14, 16, 26, 41,20, 45, 40, 33, 30, 47, 37, 41, 61, 34, 40, 52, 56, 44, 25, 29]
vader_negative_Kansas_2017 = [23, 25, 15, 19, 18, 14, 7, 14, 9,14, 8, 7, 11, 7, 11, 13, 12, 5, 5, 8, 10,20, 16, 13, 22, 14, 31, 25, 22, 32, 33, 36, 25, 24, 23, 7, 14]
print('length of vader_positive_Kansas_2017: ', len(vader_positive_Kansas_2017))
print('length of vader_neutral_Kansas_2017: ', len(vader_neutral_Kansas_2017))
print('length of vader_negative_Kansas_2017: ', len(vader_negative_Kansas_2017))

print('----------------------------------')
# ----------------------------- Nebraska -----------------------------

# Nebraska_allECigarette_2017
Nebraska_allECigarette_2017 = [91, 126, 61, 81, 73, 57, 46, 56, 63, 68, 51, 48, 36, 49, 42, 48, 77, 33, 40, 86, 79, 101, 67, 63, 48, 60, 90, 74, 73, 79, 67, 88, 81, 77, 58, 59, 35]
print('length of Nebraska_allECigarette_2017: ', len(Nebraska_allECigarette_2017))


# allNebraska_2017
allNebraska_2017 = [283642, 299681, 285351, 269939, 287109, 262236, 277981, 280936, 250608, 274503, 213059, 212459, 199089, 181708, 187624, 186031, 197235, 93444, 127876, 184320, 172064,185342, 161087, 174894, 167365, 161172, 166606, 155404, 147023, 176945, 147170, 162308, 147688, 159905, 143559, 117803, 108597]
print('length of allNebraska_2017: ', len(allNebraska_2017))


# Number of users that tweets ecig in Nebraska.
users_Nebraska_ecig_2017 = [75, 96, 44, 67, 58, 47, 38, 48, 45,55, 35, 33, 27, 33, 33, 37, 52, 26, 37, 74, 61,83, 57, 55, 42, 56, 63, 58, 59, 65, 58, 74, 64, 62, 53, 47, 27]
print('length of users_Nebraska_ecig_2017: ', len(users_Nebraska_ecig_2017))


# average number of per person tweets about ecig in Nebraska.
average_num_per_person_tweets_Nebraska_ecig = []
for i in range(37):
    average_num_per_person_tweets_Nebraska_ecig.append(Nebraska_allECigarette_2017[i]/users_Nebraska_ecig_2017[i])
print('length of average_num_per_person_tweets_Nebraska_ecig: ', len(average_num_per_person_tweets_Nebraska_ecig))


# Number of users that tweets in Nebraska
users_Nebraska_2017 = [15125, 15749, 17587, 16683, 16380, 15945, 16100, 15871, 14756,14180, 13338, 13522, 13196, 13214, 14152, 13427, 14914, 10603, 11919, 14224, 13251,12556, 12283, 13393, 12822, 12613, 13641, 12440, 12485, 13111, 11968, 12494, 11803, 11334, 11065, 10352, 9063]
print('length of users_Nebraska_2017: ', len(users_Nebraska_2017))

# average number of per person tweets in Nebraska.
average_num_per_person_tweets_Nebraska = []
for i in range(37):
    average_num_per_person_tweets_Nebraska.append(allNebraska_2017[i]/users_Nebraska_2017[i])
print('length of average_num_per_person_tweets_Nebraska: ', len(average_num_per_person_tweets_Nebraska))

# Sentiment analysis
vader_positive_Nebraska_2017 = [28, 37, 24, 31, 30, 28, 13, 20, 19,25, 20, 13, 9, 24, 18, 18, 27, 9, 21, 38, 22,28, 26, 22, 14, 15, 35, 31, 20, 17, 22, 29, 27, 31, 18, 20, 15]
vader_neutral_Nebraska_2017 = [50, 59, 27, 40, 29, 22, 21, 26, 25,34, 21, 26, 18, 17, 16, 13, 35, 17, 13, 29, 35,45, 25, 29, 19, 29, 33, 23, 27, 34, 33, 34, 28, 32, 25, 25, 17]
vader_negative_Nebraska_2017 = [13, 30, 10, 10, 14, 7, 12, 10, 19,9, 10, 9, 9, 8, 8, 17, 15, 7, 6, 19, 22,28, 16, 12, 15, 16, 22, 20, 26, 28, 12, 25, 26, 14, 15, 14, 3]
print('length of vader_positive_Nebraska_2017: ', len(vader_positive_Nebraska_2017))
print('length of vader_neutral_Nebraska_2017: ', len(vader_neutral_Nebraska_2017))
print('length of vader_negative_Nebraska_2017: ', len(vader_negative_Nebraska_2017))



print('----------------------------------')
# ----------------------------- Missouri -----------------------------

# Missouri_allECigarette_2017
Missouri_allECigarette_2017 = [254, 252, 257, 224, 221, 177, 193, 178, 266, 226, 177, 188, 193, 162, 167, 142, 202, 91, 144, 217, 203,263, 171, 203, 247, 160, 182, 213, 190, 196, 148, 191, 145, 140, 136, 124, 112]
print('length of Missouri_allECigarette_2017: ', len(Missouri_allECigarette_2017))


# allMissouri_2017
allMissouri_2017 = [659402, 710516, 670794, 726710, 682607, 588181, 621671, 643718, 615393, 657901, 492511, 532392, 501033, 466911, 453202, 504714, 506856, 221538, 318322, 463272, 459553,474033, 410610, 471223, 428469, 416661, 428335, 445008, 392171, 435906, 367954, 419090, 399001, 439319, 388607, 323493, 323169]
print('length of allMissouri_2017: ', len(allMissouri_2017))


# Number of users that tweets ecig in Missouri.
users_Missouri_ecig_2017 = [180, 179, 140, 156, 158, 105, 130, 101, 101,121, 95, 89, 105, 99, 99, 90, 96, 56, 85, 113, 118,148, 111, 140, 122, 120, 146, 155, 134, 144, 112, 135, 112, 113, 107, 96, 98]
print('length of users_Missouri_ecig_2017: ', len(users_Missouri_ecig_2017))


# average number of per person tweets about ecig in Missouri.
average_num_per_person_tweets_Missouri_ecig = []
for i in range(37):
    average_num_per_person_tweets_Missouri_ecig.append(Missouri_allECigarette_2017[i]/users_Missouri_ecig_2017[i])
print('length of average_num_per_person_tweets_Missouri_ecig: ', len(average_num_per_person_tweets_Missouri_ecig))


# Number of users that tweets in Missouri
users_Missouri_2017 = [40117, 42496, 42958, 47689, 42806, 38915, 40224, 39379, 37723,35469, 32138, 36115, 36105, 35273, 34994, 37272, 37535, 23867, 28494, 35090, 33914,30342, 29684, 34370, 33424, 31754, 33180, 35057, 32777, 32539, 29476, 31688, 30576, 28827, 26837, 26835, 24204]
print('length of users_Missouri_2017: ', len(users_Missouri_2017))

# average number of per person tweets in Missouri.
average_num_per_person_tweets_Missouri = []
for i in range(37):
    average_num_per_person_tweets_Missouri.append(allMissouri_2017[i]/users_Missouri_2017[i])
print('length of average_num_per_person_tweets_Missouri: ', len(average_num_per_person_tweets_Missouri))

# Sentiment analysis
vader_positive_Missouri_2017 = [86, 82, 95, 76, 87, 47, 69, 58, 85,81, 55, 55, 52, 46, 56, 40, 52, 36, 40, 58, 61,84, 49, 67, 69, 50, 68, 76, 66, 73, 41, 61, 49, 47, 50, 39, 42]
vader_neutral_Missouri_2017 = [122, 114, 140, 117, 86, 97, 97, 90, 161,120, 98, 112, 119, 103, 92, 84, 131, 47, 80, 117, 109,128, 94, 95, 130, 75, 83, 103, 79, 81, 71, 84, 52, 52, 57, 54, 49]
vader_negative_Missouri_2017 = [46, 56, 22, 31, 48, 33, 27, 30, 20,25, 24, 21, 22, 13, 19, 18, 19, 8, 24, 42, 33,51, 28, 41, 48, 35, 31, 34, 45, 42, 36, 46, 44, 41, 29, 31, 21]
print('length of vader_positive_Missouri_2017: ', len(vader_positive_Missouri_2017))
print('length of vader_neutral_Missouri_2017: ', len(vader_neutral_Missouri_2017))
print('length of vader_negative_Missouri_2017: ', len(vader_negative_Missouri_2017))


print('----------------------------------')
# ----------------------------- Oklahoma -----------------------------

# Oklahoma_allECigarette_2017
Oklahoma_allECigarette_2017 = [168, 225, 188, 165, 164, 123, 126, 124, 139, 132, 90, 128, 102, 96, 69, 71, 84, 89, 92, 154, 117,153, 126, 127, 136, 108, 129, 150, 190, 178, 129, 158, 168, 169, 169, 111, 108]
print('length of Oklahoma_allECigarette_2017: ', len(Oklahoma_allECigarette_2017))


# allOklahoma_2017
allOklahoma_2017 = [625342, 656059, 618532, 641144, 660085, 597092, 604378, 619002, 521409, 548229, 410113, 414572, 397302, 360865, 360432, 379006, 406638, 181723, 257285, 393807, 354681,373182, 341904, 376281, 382204, 345696, 341769, 351789, 311920, 362146, 310138, 349089, 323238, 349959, 298672, 235028, 245770]
print('length of allOklahoma_2017: ', len(allOklahoma_2017))


# Number of users that tweets ecig in Oklahoma.
users_Oklahoma_ecig_2017 = [117, 148, 121, 134, 112, 98, 104, 95, 91,87, 66, 75, 59, 63, 55, 63, 74, 37, 55, 105, 87,112, 100, 107, 111, 92, 113, 117, 140, 154, 102, 126, 123, 123, 119, 78, 75]
print('length of users_Oklahoma_ecig_2017: ', len(users_Oklahoma_ecig_2017))


# average number of per person tweets about ecig in Oklahoma.
average_num_per_person_tweets_Oklahoma_ecig = []
for i in range(37):
    average_num_per_person_tweets_Oklahoma_ecig.append(Oklahoma_allECigarette_2017[i]/users_Oklahoma_ecig_2017[i])
print('length of average_num_per_person_tweets_Oklahoma_ecig: ', len(average_num_per_person_tweets_Oklahoma_ecig))


# Number of users that tweets in Oklahoma
users_Oklahoma_2017 = [27260, 28575, 28510, 30242, 29795, 29563, 29961, 29286, 26829,25186, 23553, 24834, 23512, 23667, 23160, 23958, 25278, 18446, 22040, 26429, 23882,22326, 21516, 24116, 23651, 22685, 21977, 22244, 21926, 23089, 21751, 22937, 21363, 20242, 19145, 18461, 15915]
print('length of users_Oklahoma_2017: ', len(users_Oklahoma_2017))

# average number of per person tweets in Oklahoma.
average_num_per_person_tweets_Oklahoma = []
for i in range(37):
    average_num_per_person_tweets_Oklahoma.append(allOklahoma_2017[i]/users_Oklahoma_2017[i])
print('length of average_num_per_person_tweets_Oklahoma: ', len(average_num_per_person_tweets_Oklahoma))

# Sentiment analysis
vader_positive_Oklahoma_2017 = [59, 91, 68, 61, 57, 44, 50, 51, 53,55, 33, 59, 39, 36, 30, 31, 36, 9, 23, 54, 45,53, 43, 45, 55, 35, 40, 41, 64, 54, 37, 39, 54, 64, 58, 40, 34]
vader_neutral_Oklahoma_2017 = [82, 100, 88, 69, 76, 51, 43, 53, 52,42, 39, 47, 42, 41, 30, 23, 24, 69, 54, 73, 49,70, 52, 57, 60, 41, 62, 64, 77, 78, 53, 65, 64, 62, 64, 44, 48]
vader_negative_Oklahoma_2017 = [27, 34, 32, 35, 31, 28, 33, 20, 34,35, 18, 22, 21, 19, 9, 17, 24, 11, 15, 27, 23,30, 31, 25, 21, 32, 27, 45, 49, 46, 39, 54, 50, 43, 47, 27, 26]
print('length of vader_positive_Oklahoma_2017: ', len(vader_positive_Oklahoma_2017))
print('length of vader_neutral_Oklahoma_2017: ', len(vader_neutral_Oklahoma_2017))
print('length of vader_negative_Oklahoma_2017: ', len(vader_negative_Oklahoma_2017))


print('----------------------------------')
# ----------------------------- Colorado -----------------------------

# Colorado_allECigarette_2017
Colorado_allECigarette_2017 = [273, 233, 260, 289, 225, 176, 237, 204, 209, 194, 175, 201, 185, 141, 158, 193, 190, 75, 150, 221, 206,234, 223, 267, 291, 181, 186, 244, 259, 254, 190, 232, 211, 222, 201, 203, 227]
print('length of Colorado_allECigarette_2017: ', len(Colorado_allECigarette_2017))


# allColorado_2017
allColorado_2017 = [612293, 636741, 662599, 678806, 649855, 585015, 638956, 640021, 578135, 653691, 495008, 508845, 457593, 437237, 466033, 506474, 526491, 233532, 326061, 465585, 422692,475108, 424930, 494057, 479934, 438637, 450589, 477530, 408113, 463421, 385803, 423631, 404863, 448372, 391850, 334020, 347829]
print('length of allColorado_2017: ', len(allColorado_2017))


# Number of users that tweets ecig in Colorado.
users_Colorado_ecig_2017 = [167, 160, 182, 179, 157, 133, 164, 142, 121,130, 118, 130, 138, 101, 108, 135, 127, 61, 101, 136, 141,155, 150, 171, 182, 140, 143, 167, 185, 196, 144, 179, 172, 174, 146, 128, 131]
print('length of users_Colorado_ecig_2017: ', len(users_Colorado_ecig_2017))


# average number of per person tweets about ecig in Colorado.
average_num_per_person_tweets_Colorado_ecig = []
for i in range(37):
    average_num_per_person_tweets_Colorado_ecig.append(Colorado_allECigarette_2017[i]/users_Colorado_ecig_2017[i])
print('length of average_num_per_person_tweets_Colorado_ecig: ', len(average_num_per_person_tweets_Colorado_ecig))


# Number of users that tweets in Colorado
users_Colorado_2017 = [34410, 35724, 42796, 46508, 41553, 37046, 37714, 36201, 36439,36737, 31899, 36284, 32098, 32904, 35167, 38950, 37087, 23859, 28341, 33114, 32429,31455, 29506, 34003, 30839, 29145, 33046, 35421, 31945, 32067, 29307, 29667, 30288, 30002, 27461, 27233, 25037]
print('length of users_Colorado_2017: ', len(users_Colorado_2017))


# average number of per person tweets in Colorado.
average_num_per_person_tweets_Colorado = []
for i in range(37):
    average_num_per_person_tweets_Colorado.append(allColorado_2017[i]/users_Colorado_2017[i])
print('length of average_num_per_person_tweets_Colorado: ', len(average_num_per_person_tweets_Colorado))

# Sentiment analysis
vader_positive_Colorado_2017 = [81, 77, 98, 112, 87, 57, 90, 73, 57,96, 53, 64, 69, 53, 61, 58, 75, 25, 42, 82, 64,70, 61, 85, 84, 58, 66, 97, 82, 77, 62, 81, 76, 80, 75, 77, 77]
vader_neutral_Colorado_2017 = [153, 115, 125, 129, 102, 91, 110, 98, 108,76, 94, 94, 86, 66, 71, 101, 77, 33, 86, 96, 100,119, 123, 123, 157, 77, 84, 99, 114, 119, 95, 91, 78, 95, 81, 82, 92]
vader_negative_Colorado_2017 = [39, 41, 37, 48, 36, 28, 37, 33, 44,22, 28, 43, 30, 22, 26, 34, 38, 17, 22, 43, 42,45, 39, 59, 50, 46, 36, 48, 63, 58, 33, 60, 57, 47, 45, 44, 58]
print('length of vader_positive_Colorado_2017: ', len(vader_positive_Colorado_2017))
print('length of vader_neutral_Colorado_2017: ', len(vader_neutral_Colorado_2017))
print('length of vader_negative_Colorado_2017: ', len(vader_negative_Colorado_2017))
# Out:
# length of Kansas_allECigarette_2017:  37
# length of not_Kansas_allECigarette_2017:  37
# length of allECigarette_2017:  37
# length of allKansas_2017:  37
# length of users_Kansas_ecig_2017:  37
# length of average_num_per_person_tweets_Kansas_ecig:  37
# length of users_Kansas_2017:  37
# length of average_num_per_person_tweets_Kansas:  37
# length of allTweets_2017:  37
# length of vader_positive_Kansas_2017:  37
# length of vader_neutral_Kansas_2017:  37
# length of vader_negative_Kansas_2017:  37
# ----------------------------------
# length of Nebraska_allECigarette_2017:  37
# length of allNebraska_2017:  37
# length of users_Nebraska_ecig_2017:  37
# length of average_num_per_person_tweets_Nebraska_ecig:  37
# length of users_Nebraska_2017:  37
# length of average_num_per_person_tweets_Nebraska:  37
# length of vader_positive_Nebraska_2017:  37
# length of vader_neutral_Nebraska_2017:  37
# length of vader_negative_Nebraska_2017:  37
# ----------------------------------
# ...

# %%
# Propotion

# ----------------------------- Kansas -----------------------------
propotion_Kansas_ecig_in_all_ecig = []
propotion_Kansas_ecig_in_all_Kansas_tweets = []
propotion_Kansas_in_all_tweets = []
propotion_Kansas_ecig_users_in_all_Kansas_users = []
propotion_positive_ecig_Kansas = []
propotion_neutral_ecig_Kansas = []
propotion_negative_ecig_Kansas = []


# propotion of Kansas e-cig tweets in all e-cig tweets.
for i in range(37):
    propotion_Kansas_ecig_in_all_ecig.append((Kansas_allECigarette_2017[i]/allECigarette_2017[i])*100)
print('length of propotion_Kansas_ecig_in_all_ecig: ', len(propotion_Kansas_ecig_in_all_ecig))


# propotion of Kansas e-cig tweets in all Kansas tweets.
for i in range(37):
    propotion_Kansas_ecig_in_all_Kansas_tweets.append((Kansas_allECigarette_2017[i]/allKansas_2017[i])*100)
print('length of propotion_Kansas_ecig_in_all_Kansas_tweets: ', len(propotion_Kansas_ecig_in_all_Kansas_tweets))


# propotion of Kansas tweets in total tweets.
for i in range(37):
    propotion_Kansas_in_all_tweets.append((allKansas_2017[i]/allTweets_2017[i])*100)
print('length of propotion_Kansas_in_all_tweets: ', len(propotion_Kansas_in_all_tweets))


# propotion of users post Kansas e-cig in all Kansas users.
for i in range(37):
    propotion_Kansas_ecig_users_in_all_Kansas_users.append((users_Kansas_ecig_2017[i]/users_Kansas_2017[i])*100)
print('length of propotion_Kansas_ecig_users_in_all_Kansas_users: ', len(propotion_Kansas_ecig_users_in_all_Kansas_users))


# Sentiment analysis
for i in range(37):
    propotion_positive_ecig_Kansas.append((vader_positive_Kansas_2017[i]/Kansas_allECigarette_2017[i])*100)
print('length of propotion_positive_ecig_Kansas: ', len(propotion_positive_ecig_Kansas))

for i in range(37):
    propotion_neutral_ecig_Kansas.append((vader_neutral_Kansas_2017[i]/Kansas_allECigarette_2017[i])*100)
print('length of propotion_neutral_ecig_Kansas: ', len(propotion_neutral_ecig_Kansas))

for i in range(37):
    propotion_negative_ecig_Kansas.append((vader_negative_Kansas_2017[i]/Kansas_allECigarette_2017[i])*100)
print('length of propotion_negative_ecig_Kansas: ', len(propotion_negative_ecig_Kansas))


print('----------------------------------')
# ----------------------------- Nebraska -----------------------------
propotion_Nebraska_ecig_in_all_ecig = []
propotion_Nebraska_ecig_in_all_Nebraska_tweets = []
propotion_Nebraska_in_all_tweets = []
propotion_Nebraska_ecig_users_in_all_Nebraska_users = []
propotion_positive_ecig_Nebraska = []
propotion_neutral_ecig_Nebraska = []
propotion_negative_ecig_Nebraska = []


# propotion of Nebraska e-cig tweets in all e-cig tweets.
for i in range(37):
    propotion_Nebraska_ecig_in_all_ecig.append((Nebraska_allECigarette_2017[i]/allECigarette_2017[i])*100)
print('length of propotion_Nebraska_ecig_in_all_ecig: ', len(propotion_Nebraska_ecig_in_all_ecig))


# propotion of Nebraska e-cig tweets in all Nebraska tweets.
for i in range(37):
    propotion_Nebraska_ecig_in_all_Nebraska_tweets.append((Nebraska_allECigarette_2017[i]/allNebraska_2017[i])*100)
print('length of propotion_Nebraska_ecig_in_all_Nebraska_tweets: ', len(propotion_Nebraska_ecig_in_all_Nebraska_tweets))


# propotion of Nebraska tweets in total tweets.
for i in range(37):
    propotion_Nebraska_in_all_tweets.append((allNebraska_2017[i]/allTweets_2017[i])*100)
print('length of propotion_Nebraska_in_all_tweets: ', len(propotion_Nebraska_in_all_tweets))


# propotion of users post Nebraska e-cig in all Nebraska users.
for i in range(37):
    propotion_Nebraska_ecig_users_in_all_Nebraska_users.append((users_Nebraska_ecig_2017[i]/users_Nebraska_2017[i])*100)
print('length of propotion_Nebraska_ecig_users_in_all_Nebraska_users: ', len(propotion_Nebraska_ecig_users_in_all_Nebraska_users))


# Sentiment analysis
for i in range(37):
    propotion_positive_ecig_Nebraska.append((vader_positive_Nebraska_2017[i]/Nebraska_allECigarette_2017[i])*100)
print('length of propotion_positive_ecig_Nebraska: ', len(propotion_positive_ecig_Nebraska))

for i in range(37):
    propotion_neutral_ecig_Nebraska.append((vader_neutral_Nebraska_2017[i]/Nebraska_allECigarette_2017[i])*100)
print('length of propotion_neutral_ecig_Nebraska: ', len(propotion_neutral_ecig_Nebraska))

for i in range(37):
    propotion_negative_ecig_Nebraska.append((vader_negative_Nebraska_2017[i]/Nebraska_allECigarette_2017[i])*100)
print('length of propotion_negative_ecig_Nebraska: ', len(propotion_negative_ecig_Nebraska))


print('----------------------------------')
# ----------------------------- Missouri -----------------------------
propotion_Missouri_ecig_in_all_ecig = []
propotion_Missouri_ecig_in_all_Missouri_tweets = []
propotion_Missouri_in_all_tweets = []
propotion_Missouri_ecig_users_in_all_Missouri_users = []
propotion_positive_ecig_Missouri = []
propotion_neutral_ecig_Missouri = []
propotion_negative_ecig_Missouri = []


# propotion of Missouri e-cig tweets in all e-cig tweets.
for i in range(37):
    propotion_Missouri_ecig_in_all_ecig.append((Missouri_allECigarette_2017[i]/allECigarette_2017[i])*100)
print('length of propotion_Missouri_ecig_in_all_ecig: ', len(propotion_Missouri_ecig_in_all_ecig))


# propotion of Missouri e-cig tweets in all Missouri tweets.
for i in range(37):
    propotion_Missouri_ecig_in_all_Missouri_tweets.append((Missouri_allECigarette_2017[i]/allMissouri_2017[i])*100)
print('length of propotion_Missouri_ecig_in_all_Missouri_tweets: ', len(propotion_Missouri_ecig_in_all_Missouri_tweets))


# propotion of Missouri tweets in total tweets.
for i in range(37):
    propotion_Missouri_in_all_tweets.append((allMissouri_2017[i]/allTweets_2017[i])*100)
print('length of propotion_Missouri_in_all_tweets: ', len(propotion_Missouri_in_all_tweets))


# propotion of users post Missouri e-cig in all Missouri users.
for i in range(37):
    propotion_Missouri_ecig_users_in_all_Missouri_users.append((users_Missouri_ecig_2017[i]/users_Missouri_2017[i])*100)
print('length of propotion_Missouri_ecig_users_in_all_Missouri_users: ', len(propotion_Missouri_ecig_users_in_all_Missouri_users))


# Sentiment analysis
for i in range(37):
    propotion_positive_ecig_Missouri.append((vader_positive_Missouri_2017[i]/Missouri_allECigarette_2017[i])*100)
print('length of propotion_positive_ecig_Missouri: ', len(propotion_positive_ecig_Missouri))

for i in range(37):
    propotion_neutral_ecig_Missouri.append((vader_neutral_Missouri_2017[i]/Missouri_allECigarette_2017[i])*100)
print('length of propotion_neutral_ecig_Missouri: ', len(propotion_neutral_ecig_Missouri))

for i in range(37):
    propotion_negative_ecig_Missouri.append((vader_negative_Missouri_2017[i]/Missouri_allECigarette_2017[i])*100)
print('length of propotion_negative_ecig_Missouri: ', len(propotion_negative_ecig_Missouri))


print('----------------------------------')
# ----------------------------- Oklahoma -----------------------------
propotion_Oklahoma_ecig_in_all_ecig = []
propotion_Oklahoma_ecig_in_all_Oklahoma_tweets = []
propotion_Oklahoma_in_all_tweets = []
propotion_Oklahoma_ecig_users_in_all_Oklahoma_users = []
propotion_positive_ecig_Oklahoma = []
propotion_neutral_ecig_Oklahoma = []
propotion_negative_ecig_Oklahoma = []


# propotion of Oklahoma e-cig tweets in all e-cig tweets.
for i in range(37):
    propotion_Oklahoma_ecig_in_all_ecig.append((Oklahoma_allECigarette_2017[i]/allECigarette_2017[i])*100)
print('length of propotion_Oklahoma_ecig_in_all_ecig: ', len(propotion_Oklahoma_ecig_in_all_ecig))


# propotion of Oklahoma e-cig tweets in all Oklahoma tweets.
for i in range(37):
    propotion_Oklahoma_ecig_in_all_Oklahoma_tweets.append((Oklahoma_allECigarette_2017[i]/allOklahoma_2017[i])*100)
print('length of propotion_Oklahoma_ecig_in_all_Oklahoma_tweets: ', len(propotion_Oklahoma_ecig_in_all_Oklahoma_tweets))


# propotion of Oklahoma tweets in total tweets.
for i in range(37):
    propotion_Oklahoma_in_all_tweets.append((allOklahoma_2017[i]/allTweets_2017[i])*100)
print('length of propotion_Oklahoma_in_all_tweets: ', len(propotion_Oklahoma_in_all_tweets))


# propotion of users post Oklahoma e-cig in all Oklahoma users.
for i in range(37):
    propotion_Oklahoma_ecig_users_in_all_Oklahoma_users.append((users_Oklahoma_ecig_2017[i]/users_Oklahoma_2017[i])*100)
print('length of propotion_Oklahoma_ecig_users_in_all_Oklahoma_users: ', len(propotion_Oklahoma_ecig_users_in_all_Oklahoma_users))


# Sentiment analysis
for i in range(37):
    propotion_positive_ecig_Oklahoma.append((vader_positive_Oklahoma_2017[i]/Oklahoma_allECigarette_2017[i])*100)
print('length of propotion_positive_ecig_Oklahoma: ', len(propotion_positive_ecig_Oklahoma))

for i in range(37):
    propotion_neutral_ecig_Oklahoma.append((vader_neutral_Oklahoma_2017[i]/Oklahoma_allECigarette_2017[i])*100)
print('length of propotion_neutral_ecig_Oklahoma: ', len(propotion_neutral_ecig_Oklahoma))

for i in range(37):
    propotion_negative_ecig_Oklahoma.append((vader_negative_Oklahoma_2017[i]/Oklahoma_allECigarette_2017[i])*100)
print('length of propotion_negative_ecig_Oklahoma: ', len(propotion_negative_ecig_Oklahoma))


print('----------------------------------')
# ----------------------------- Colorado -----------------------------
propotion_Colorado_ecig_in_all_ecig = []
propotion_Colorado_ecig_in_all_Colorado_tweets = []
propotion_Colorado_in_all_tweets = []
propotion_Colorado_ecig_users_in_all_Colorado_users = []
propotion_positive_ecig_Colorado = []
propotion_neutral_ecig_Colorado = []
propotion_negative_ecig_Colorado = []


# propotion of Colorado e-cig tweets in all e-cig tweets.
for i in range(37):
    propotion_Colorado_ecig_in_all_ecig.append((Colorado_allECigarette_2017[i]/allECigarette_2017[i])*100)
print('length of propotion_Colorado_ecig_in_all_ecig: ', len(propotion_Colorado_ecig_in_all_ecig))


# propotion of Colorado e-cig tweets in all Colorado tweets.
for i in range(37):
    propotion_Colorado_ecig_in_all_Colorado_tweets.append((Colorado_allECigarette_2017[i]/allColorado_2017[i])*100)
print('length of propotion_Colorado_ecig_in_all_Colorado_tweets: ', len(propotion_Colorado_ecig_in_all_Colorado_tweets))


# propotion of Colorado tweets in total tweets.
for i in range(37):
    propotion_Colorado_in_all_tweets.append((allColorado_2017[i]/allTweets_2017[i])*100)
print('length of propotion_Colorado_in_all_tweets: ', len(propotion_Colorado_in_all_tweets))


# propotion of users post Colorado e-cig in all Colorado users.
for i in range(37):
    propotion_Colorado_ecig_users_in_all_Colorado_users.append((users_Colorado_ecig_2017[i]/users_Colorado_2017[i])*100)
print('length of propotion_Colorado_ecig_users_in_all_Colorado_users: ', len(propotion_Colorado_ecig_users_in_all_Colorado_users))


# Sentiment analysis
for i in range(37):
    propotion_positive_ecig_Colorado.append((vader_positive_Colorado_2017[i]/Colorado_allECigarette_2017[i])*100)
print('length of propotion_positive_ecig_Colorado: ', len(propotion_positive_ecig_Colorado))

for i in range(37):
    propotion_neutral_ecig_Colorado.append((vader_neutral_Colorado_2017[i]/Colorado_allECigarette_2017[i])*100)
print('length of propotion_neutral_ecig_Colorado: ', len(propotion_neutral_ecig_Colorado))

for i in range(37):
    propotion_negative_ecig_Colorado.append((vader_negative_Colorado_2017[i]/Colorado_allECigarette_2017[i])*100)
print('length of propotion_negative_ecig_Colorado: ', len(propotion_negative_ecig_Colorado))
# Out:
# length of propotion_Kansas_ecig_in_all_ecig:  37
# length of propotion_Kansas_ecig_in_all_Kansas_tweets:  37
# length of propotion_Kansas_in_all_tweets:  37
# length of propotion_Kansas_ecig_users_in_all_Kansas_users:  37
# length of propotion_positive_ecig_Kansas:  37
# length of propotion_neutral_ecig_Kansas:  37
# length of propotion_negative_ecig_Kansas:  37
# ----------------------------------
# length of propotion_Nebraska_ecig_in_all_ecig:  37
# length of propotion_Nebraska_ecig_in_all_Nebraska_tweets:  37
# length of propotion_Nebraska_in_all_tweets:  37
# length of propotion_Nebraska_ecig_users_in_all_Nebraska_users:  37
# length of propotion_positive_ecig_Nebraska:  37
# length of propotion_neutral_ecig_Nebraska:  37
# length of propotion_negative_ecig_Nebraska:  37
# ----------------------------------
# length of propotion_Missouri_ecig_in_all_ecig:  37
# length of propotion_Missouri_ecig_in_all_Missouri_tweets:  37
# length of propotion_Missouri_in_all_tweets:  37
# ...

# %% [markdown]
# ---------------------------------
# Draw Figures.

# %%
def linearRegression(x, A, B):
    return A*x + B

# %%
# Regression line
length_of_section_1 = 9+6
length_of_section_2 = length_of_section_1+6+12+4
x_number_section_1 = [i for i in range(0,length_of_section_1)]
x_number_section_2 = [i for i in range(length_of_section_1, length_of_section_2)]


def drawRegressionLine_two_section(y, color):
#     print('y: ', y)
#     print('section 1: ', y[:length_of_section_1])
#     print('section 2: ', y[length_of_section_1:length_of_section_2])
    
    # section 1
    popt_1, pcov_1 = optimize.curve_fit(linearRegression, x_number_section_1, y[:length_of_section_1])
    A_section_1, B_section_1 = popt_1
    x_plot_section_1 = np.arange(0, length_of_section_1, 0.01)
    y_plot_section_1 = A_section_1 * x_plot_section_1 + B_section_1
    plt.plot(x_plot_section_1, y_plot_section_1, color+'-') # , label='Users' is useless
    # Calculate the R square
    residuals_1 = y[:length_of_section_1]- linearRegression(np.asarray(x_number_section_1), *[float(A_section_1), float(B_section_1)])
    ss_res_1 = np.sum(residuals_1**2)
    ss_tot_1 = np.sum((y[:length_of_section_1]-np.mean(y[:length_of_section_1]))**2)
    r_squared_1 = 1 - (ss_res_1 / ss_tot_1)
#     print('section 1 slope: ', A_section_1)
#     print('section 1 R^2: ', r_squared_1)

    # section 2: length_of_section_1-1:length_of_section_2
    popt_2, pcov_2 = optimize.curve_fit(linearRegression, x_number_section_2, y[length_of_section_1:length_of_section_2])
    A_section_2, B_section_2 = popt_2
    x_plot_section_2 = np.arange(length_of_section_1, length_of_section_2-1, 0.01)
    y_plot_section_2 = A_section_2 * x_plot_section_2 + B_section_2
    plt.plot(x_plot_section_2, y_plot_section_2, color+'-')
    # Calculate the R square
    residuals_2 = y[length_of_section_1:length_of_section_2]- linearRegression(np.asarray(x_number_section_2), *[float(A_section_2), float(B_section_2)])
    ss_res_2 = np.sum(residuals_2**2)
    ss_tot_2 = np.sum((y[length_of_section_1:length_of_section_2]-np.mean(y[length_of_section_1:length_of_section_2]))**2)
    r_squared_2 = 1 - (ss_res_2 / ss_tot_2)
#     print('section 2 slope: ', A_section_2)
#     print('section 2 R^2: ', r_squared_2)
    
    print('slope: ', [A_section_1, A_section_2])
    print('intercept: ', [B_section_1, B_section_2])
    print('R^2: ', [r_squared_1, r_squared_2])
#     print('--------------------------')
#     print()

# %%
x = ['2016-04','2016-05','2016-06','2016-07','2016-08','2016-09','2016-10','2016-11','2016-12', '2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12','2018-01','2018-02', '2018-03','2018-04','2018-05','2018-06','2018-07','2018-08','2018-09','2018-10','2018-11','2018-12','2019-01','2019-02', '2019-03','2019-04']

plt.figure(figsize=(14,7))

plt.plot(x, Kansas_allECigarette_2017, 'rx', label='Kansas e-cigarette realated tweets')
plt.plot(x, Nebraska_allECigarette_2017, 'gx', label='Nebraska e-cigarette realated tweets')
plt.plot(x, Missouri_allECigarette_2017, 'bx', label='Missouri e-cigarette realated tweets')
plt.plot(x, Oklahoma_allECigarette_2017, 'cx', label='Oklahoma e-cigarette realated tweets')
plt.plot(x, Colorado_allECigarette_2017, 'mx', label='Colorado e-cigarette realated tweets')
# plt.plot(x, users_Kansas_ecig_2017, 'yx', label='Users of Kansas e-cigarette tweets')


# plt.plot(x, average_num_per_persion_tweets_SF_ecig, 'm-', label='not first person')
plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(15, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(7,0.1))


print('Kansas:')
drawRegressionLine_two_section(Kansas_allECigarette_2017, color='r')
print('Nebraska:')
drawRegressionLine_two_section(Nebraska_allECigarette_2017, color='g')
print('Missouri:')
drawRegressionLine_two_section(Missouri_allECigarette_2017, color='b')
print('Oklahoma:')
drawRegressionLine_two_section(Oklahoma_allECigarette_2017, color='c')
print('Colorado:')
drawRegressionLine_two_section(Colorado_allECigarette_2017, color='m')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for number of e-cigarette related tweets in different states by month. ')
# plt.figure(figsize=(40,1))
plt.show()


print('******************************************************')

# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


# plt.plot(x, Kansas_allECigarette_2017, 'rx', label='Kansas e-cigarette realated tweets')
plt.plot(x, users_Kansas_ecig_2017, 'rx', label='Users of Kansas e-cigarette tweets')
plt.plot(x, users_Nebraska_ecig_2017, 'gx', label='Users of Nebraska e-cigarette tweets')
plt.plot(x, users_Missouri_ecig_2017, 'bx', label='Users of Missouri e-cigarette tweets')
plt.plot(x, users_Oklahoma_ecig_2017, 'cx', label='Users of Oklahoma e-cigarette tweets')
plt.plot(x, users_Colorado_ecig_2017, 'mx', label='Users of Colorado e-cigarette tweets')
# plt.plot(x, average_num_per_persion_tweets_SF_ecig, 'm-', label='not first person')
plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(15, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(7,0.1))

print('Kansas:')
drawRegressionLine_two_section(users_Kansas_ecig_2017, color='r')
print('Nebraska:')
drawRegressionLine_two_section(users_Nebraska_ecig_2017, color='g')
print('Missouri:')
drawRegressionLine_two_section(users_Missouri_ecig_2017, color='b')
print('Oklahoma:')
drawRegressionLine_two_section(users_Oklahoma_ecig_2017, color='c')
print('Colorado:')
drawRegressionLine_two_section(users_Colorado_ecig_2017, color='m')

plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for number of users that post e-cigarette related tweets in different states by month. ')
# plt.figure(figsize=(40,1))
plt.show()

print('******************************************************')

# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


# plt.plot(x, Kansas_allECigarette_2017, 'rx', label='Kansas e-cigarette realated tweets')
plt.plot(x, average_num_per_person_tweets_Kansas_ecig, 'rx', label='Kansas ecig tweets per person')
plt.plot(x, average_num_per_person_tweets_Nebraska_ecig, 'gx', label='Nebraska ecig tweets per person')
plt.plot(x, average_num_per_person_tweets_Missouri_ecig, 'bx', label='Missouri ecig tweets per person')
plt.plot(x, average_num_per_person_tweets_Oklahoma_ecig, 'cx', label='Oklahoma ecig tweets per person')
plt.plot(x, average_num_per_person_tweets_Colorado_ecig, 'mx', label='Colorado ecig tweets per person')
# plt.plot(x, average_num_per_persion_tweets_SF_ecig, 'm-', label='not first person')
plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(15, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(7,0.1))

print('Kansas:')
drawRegressionLine_two_section(average_num_per_person_tweets_Kansas_ecig, color='r')
print('Nebraska:')
drawRegressionLine_two_section(average_num_per_person_tweets_Nebraska_ecig, color='g')
print('Missouri:')
drawRegressionLine_two_section(average_num_per_person_tweets_Missouri_ecig, color='b')
print('Oklahoma:')
drawRegressionLine_two_section(average_num_per_person_tweets_Oklahoma_ecig, color='c')
print('Colorado:')
drawRegressionLine_two_section(average_num_per_person_tweets_Colorado_ecig, color='m')

plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for average tweets number per person post e-cigarette related tweets in different states by month. ')
# plt.figure(figsize=(40,1))
plt.show()

print('******************************************************')

# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


plt.plot(x, allTweets_2017, 'mx', label='All tweets that collected')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(15, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(7,0.1))

print('allTweets_2017: ')
drawRegressionLine_two_section(allTweets_2017, color='m')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for all tweets that collected from Twitter by month. ')
# plt.figure(figsize=(40,1))
plt.show()

print('******************************************************')

# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


plt.plot(x, allKansas_2017, 'rx', label='All tweets that collected in Kansas')
plt.plot(x, allNebraska_2017, 'gx', label='All tweets that collected in Nebraska')
plt.plot(x, allMissouri_2017, 'bx', label='All tweets that collected in Missouri')
plt.plot(x, allOklahoma_2017, 'cx', label='All tweets that collected in Oklahoma')
plt.plot(x, allColorado_2017, 'mx', label='All tweets that collected in Colorado')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(15, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(7,0.1))

print('Kansas:')
drawRegressionLine_two_section(allKansas_2017, color='r')
print('Nebraska:')
drawRegressionLine_two_section(allNebraska_2017, color='g')
print('Missouri:')
drawRegressionLine_two_section(allMissouri_2017, color='b')
print('Oklahoma:')
drawRegressionLine_two_section(allOklahoma_2017, color='c')
print('Colorado:')
drawRegressionLine_two_section(allColorado_2017, color='m')

plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for tweets that collected from Twitter in different states by month. ')
# plt.figure(figsize=(40,1))
plt.show()

print('******************************************************')
# Out:
# Kansas:
# slope:  [-4.692857149669724, 2.4641445511042663]
# intercept:  [109.0500000642375, 15.25522303786283]
# R^2:  [0.7154940923737916, 0.34199374069346566]
# Nebraska:
# slope:  [-3.8892857142963804, 0.189158667417769]
# intercept:  [90.42500000019507, 62.58554489002704]
# R^2:  [0.5790539405634287, 0.004466749690431926]
# Missouri:
# slope:  [-5.621428571443021, -1.9649915302153853]
# intercept:  [248.35000000053955, 223.7436476571769]
# R^2:  [0.4910171238306641, 0.08622058818126943]
# Oklahoma:
# slope:  [-7.985714285733893, 2.802936194244475]
# intercept:  [191.83333333374966, 61.070581592451724]
# R^2:  [0.7717555687093569, 0.30486651730642655]
# Colorado:
# slope:  [-7.950000001256714, 2.2495765104488017]
# intercept:  [266.3166666754637, 154.4539808021416]
# R^2:  [0.7069819159986152, 0.1080023849416184]
# ******************************************************
# Kansas:
# slope:  [-3.1821428571519785, 1.4760022586119925]
# ...

# %% [markdown]
# ------------------------------------------------
# add after.

# %%
# Number of users
plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


plt.plot(x, users_Kansas_2017, 'rx', label='Twitter users in Kansas')
plt.plot(x, users_Nebraska_2017, 'gx', label='Twitter users in Nebraska')
plt.plot(x, users_Missouri_2017, 'bx', label='Twitter users in Missouri')
plt.plot(x, users_Oklahoma_2017, 'cx', label='Twitter users in Oklahoma')
plt.plot(x, users_Colorado_2017, 'mx', label='Twitter users in Colorado')
# plt.plot(x, average_num_per_persion_tweets_SF_ecig, 'm-', label='not first person')
plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(15, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))


drawRegressionLine_two_section(users_Kansas_2017, color='r')
drawRegressionLine_two_section(users_Nebraska_2017, color='g')
drawRegressionLine_two_section(users_Missouri_2017, color='b')
drawRegressionLine_two_section(users_Oklahoma_2017, color='c')
drawRegressionLine_two_section(users_Colorado_2017, color='m')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for number of Twitter users in different states by month. ')
# plt.figure(figsize=(40,1))
plt.show()


# ----------------------------------------------------
# Number of state tweets per person
plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)

plt.plot(x, average_num_per_person_tweets_Kansas, 'rx', label='Kansas tweets per person')
plt.plot(x, average_num_per_person_tweets_Nebraska, 'gx', label='Nebraska tweets per person')
plt.plot(x, average_num_per_person_tweets_Missouri, 'bx', label='Missouri tweets per person')
plt.plot(x, average_num_per_person_tweets_Oklahoma, 'cx', label='Oklahoma tweets per person')
plt.plot(x, average_num_per_person_tweets_Colorado, 'mx', label='Colorado tweets per person')
# plt.plot(x, average_num_per_persion_tweets_SF_ecig, 'm-', label='not first person')
plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(15, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))


drawRegressionLine_two_section(average_num_per_person_tweets_Kansas, color='r')
drawRegressionLine_two_section(average_num_per_person_tweets_Nebraska, color='g')
drawRegressionLine_two_section(average_num_per_person_tweets_Missouri, color='b')
drawRegressionLine_two_section(average_num_per_person_tweets_Oklahoma, color='c')
drawRegressionLine_two_section(average_num_per_person_tweets_Colorado, color='m')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for average tweets number per person post tweets in different states by month. ')
# plt.figure(figsize=(40,1))
plt.show()
# Out:
# slope:  [-341.9178590364268, -139.39808315606652]
# intercept:  [22413.09167967995, 20070.01475698079]
# R^2:  [0.7083762628017058, 0.28537832688462417]
# slope:  [-252.21428528854344, -126.02879625754817]
# intercept:  [16818.699997019805, 15566.507026341773]
# R^2:  [0.6437703733332732, 0.3807436512043484]
# slope:  [-718.4178555216946, -279.4240821879391]
# intercept:  [43855.6583222712, 38386.3140936997]
# R^2:  [0.6334280945574082, 0.2318587479256714]
# slope:  [-483.5071349337306, -225.75323710145358]
# intercept:  [30313.416608935782, 27728.38936603515]
# R^2:  [0.6445832785777459, 0.3706535914270819]
# slope:  [-488.7928495195572, -256.58835976647566]
# intercept:  [40320.2166148628, 37461.275901317866]
# R^2:  [0.297133872854645, 0.2129359156232865]
# slope:  [-0.4124904841845913, 0.013293597373290167]
# intercept:  [19.274569136716554, 12.21649975653811]
# R^2:  [0.7417471797353041, 0.004800816956125331]
# slope:  [-0.27434532441691095, 0.007429486539877961]
# ...

# %% [markdown]
# ----------------------------
#
# propotion

# %%
# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


plt.plot(x, propotion_Kansas_in_all_tweets, 'rx', label='Proportion of Kansas tweets in all tweets')
plt.plot(x, propotion_Nebraska_in_all_tweets, 'gx', label='Proportion of Nebraska tweets in all tweets')
plt.plot(x, propotion_Missouri_in_all_tweets, 'bx', label='Proportion of Missouri tweets in all tweets')
plt.plot(x, propotion_Oklahoma_in_all_tweets, 'cx', label='Proportion of Oklahoma tweets in all tweets')
plt.plot(x, propotion_Colorado_in_all_tweets, 'mx', label='Proportion of Colorado tweets in all tweets')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(15, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))

print('Kansas:')
drawRegressionLine_two_section(propotion_Kansas_in_all_tweets, color='r')
print('Nebraska:')
drawRegressionLine_two_section(propotion_Nebraska_in_all_tweets, color='g')
print('Missouri:')
drawRegressionLine_two_section(propotion_Missouri_in_all_tweets, color='b')
print('Oklahoma:')
drawRegressionLine_two_section(propotion_Oklahoma_in_all_tweets, color='c')
print('Colorado:')
drawRegressionLine_two_section(propotion_Colorado_in_all_tweets, color='m')

plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Proportion (%)')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Proportion of different states tweets in all tweets that collected from Twitter.')
# plt.figure(figsize=(40,1))
plt.show()




print('******************************************************')


# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


plt.plot(x, propotion_Kansas_ecig_in_all_ecig, 'rx', label='Proportion of Kansas ecig tweets in all ecig tweets')
plt.plot(x, propotion_Nebraska_ecig_in_all_ecig, 'gx', label='Proportion of Nebraska ecig tweets in all ecig tweets')
plt.plot(x, propotion_Missouri_ecig_in_all_ecig, 'bx', label='Proportion of Missouri ecig tweets in all ecig tweets')
plt.plot(x, propotion_Oklahoma_ecig_in_all_ecig, 'cx', label='Proportion of Oklahoma ecig tweets in all ecig tweets')
plt.plot(x, propotion_Colorado_ecig_in_all_ecig, 'mx', label='Proportion of Colorado ecig tweets in all ecig tweets')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(15, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))

print('Kansas:')
drawRegressionLine_two_section(propotion_Kansas_ecig_in_all_ecig, color='r')
print('Nebraska:')
drawRegressionLine_two_section(propotion_Nebraska_ecig_in_all_ecig, color='g')
print('Missouri:')
drawRegressionLine_two_section(propotion_Missouri_ecig_in_all_ecig, color='b')
print('Oklahoma:')
drawRegressionLine_two_section(propotion_Oklahoma_ecig_in_all_ecig, color='c')
print('Colorado:')
drawRegressionLine_two_section(propotion_Colorado_ecig_in_all_ecig, color='m')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Proportion (%)')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Proportion of different states e-cigarette tweets in all e-cigarette tweets that collected from Twitter.')
# plt.figure(figsize=(40,1))
plt.show()

print('******************************************************')

# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


plt.plot(x, propotion_Kansas_ecig_in_all_Kansas_tweets, 'rx', label='Proportion of Kansas ecig tweets in all Kansas tweets')
plt.plot(x, propotion_Nebraska_ecig_in_all_Nebraska_tweets, 'gx', label='Proportion of Nebraska ecig tweets in all Nebraska tweets')
plt.plot(x, propotion_Missouri_ecig_in_all_Missouri_tweets, 'bx', label='Proportion of Missouri ecig tweets in all Missouri tweets')
plt.plot(x, propotion_Oklahoma_ecig_in_all_Oklahoma_tweets, 'cx', label='Proportion of Oklahoma ecig tweets in all Oklahoma tweets')
plt.plot(x, propotion_Colorado_ecig_in_all_Colorado_tweets, 'mx', label='Proportion of Colorado ecig tweets in all Oklahoma tweets')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(15, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))

print('Kansas:')
drawRegressionLine_two_section(propotion_Kansas_ecig_in_all_Kansas_tweets, color='r')
print('Nebraska:')
drawRegressionLine_two_section(propotion_Nebraska_ecig_in_all_Nebraska_tweets, color='g')
print('Missouri:')
drawRegressionLine_two_section(propotion_Missouri_ecig_in_all_Missouri_tweets, color='b')
print('Oklahoma:')
drawRegressionLine_two_section(propotion_Oklahoma_ecig_in_all_Oklahoma_tweets, color='c')
print('Colorado:')
drawRegressionLine_two_section(propotion_Colorado_ecig_in_all_Colorado_tweets, color='m')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Proportion (%)')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Proportion of different state e-cigarette tweets in all tweets that collected from the same state.')
# plt.figure(figsize=(40,1))
plt.show()

print('******************************************************')
# Out:
# Kansas:
# slope:  [-0.0014110594423932623, -0.001963467493660831]
# intercept:  [0.5348797022864462, 0.5515451694199491]
# R^2:  [0.04598980964805455, 0.21428251735444415]
# Nebraska:
# slope:  [0.0027625039685551934, -0.002331547340322704]
# intercept:  [0.3822619867956867, 0.4364226969943149]
# R^2:  [0.2689135550789179, 0.4262783706074603]
# Missouri:
# slope:  [0.010112671904560043, -0.002088112601844383]
# intercept:  [0.8933665883095142, 1.0409190137900384]
# R^2:  [0.5988226233569733, 0.2260225121728653]
# Oklahoma:
# slope:  [-0.004811114465220534, -0.0027688204212574785]
# intercept:  [0.8815177125866109, 0.8646901069376607]
# R^2:  [0.2026785858733854, 0.27285775819973856]
# Colorado:
# slope:  [0.012080632067059597, -0.000917070730688474]
# intercept:  [0.8461130836423291, 1.0436497086375416]
# R^2:  [0.7947963132698448, 0.06632193614372417]
# ******************************************************
# Kansas:
# slope:  [-0.006988366067740781, 0.009441461702523246]
# ...

# %% [markdown]
# ----------------------------
# Sentiment analysis

# %%
# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


plt.plot(x, vader_positive_Kansas_2017, 'rx', label='Positive towards e-cigarette in Kansas')
plt.plot(x, vader_positive_Nebraska_2017, 'gx', label='Positive towards e-cigarette in Nebraska')
plt.plot(x, vader_positive_Missouri_2017, 'bx', label='Positive towards e-cigarette in Missouri')
plt.plot(x, vader_positive_Oklahoma_2017, 'cx', label='Positive towards e-cigarette in Oklahoma')
plt.plot(x, vader_positive_Colorado_2017, 'mx', label='Positive towards e-cigarette in Colorado')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(15, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))

print('Kansas:')
drawRegressionLine_two_section(vader_positive_Kansas_2017, color='r')
print('Nebraska:')
drawRegressionLine_two_section(vader_positive_Nebraska_2017, color='g')
print('Missouri:')
drawRegressionLine_two_section(vader_positive_Missouri_2017, color='b')
print('Oklahoma:')
drawRegressionLine_two_section(vader_positive_Oklahoma_2017, color='c')
print('Colorado:')
drawRegressionLine_two_section(vader_positive_Colorado_2017, color='m')

plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for positive attitude towards e-cigarette by month. Y-axis represents the number of corresponding tweets within each month. ')
# plt.figure(figsize=(40,1))
plt.show()



print('******************************************************')

# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


plt.plot(x, vader_neutral_Kansas_2017, 'rx', label='Neutral towards e-cigarette in Kansas')
plt.plot(x, vader_neutral_Nebraska_2017, 'gx', label='Neutral towards e-cigarette in Nebraska')
plt.plot(x, vader_neutral_Missouri_2017, 'bx', label='Neutral towards e-cigarette in Missouri')
plt.plot(x, vader_neutral_Oklahoma_2017, 'cx', label='Neutral towards e-cigarette in Oklahoma')
plt.plot(x, vader_neutral_Colorado_2017, 'mx', label='Neutral towards e-cigarette in Colorado')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(15, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))

print('Kansas:')
drawRegressionLine_two_section(vader_neutral_Kansas_2017, color='r')
print('Nebraska:')
drawRegressionLine_two_section(vader_neutral_Nebraska_2017, color='g')
print('Missouri:')
drawRegressionLine_two_section(vader_neutral_Missouri_2017, color='b')
print('Oklahoma:')
drawRegressionLine_two_section(vader_neutral_Oklahoma_2017, color='c')
print('Colorado:')
drawRegressionLine_two_section(vader_neutral_Colorado_2017, color='m')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for neutral attitude towards e-cigarette by month. Y-axis represents the number of corresponding tweets within each month. ')
# plt.figure(figsize=(40,1))
plt.show()

print('******************************************************')

# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


plt.plot(x, vader_negative_Kansas_2017, 'rx', label='Negative towards e-cigarette in Kansas')
plt.plot(x, vader_negative_Nebraska_2017, 'gx', label='Negative towards e-cigarette in Nebraska')
plt.plot(x, vader_negative_Missouri_2017, 'bx', label='Negative towards e-cigarette in Missouri')
plt.plot(x, vader_negative_Oklahoma_2017, 'cx', label='Negative towards e-cigarette in Oklahoma')
plt.plot(x, vader_negative_Colorado_2017, 'mx', label='Negative towards e-cigarette in Colorado')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(15, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))

print('Kansas:')
drawRegressionLine_two_section(vader_negative_Kansas_2017, color='r')
print('Nebraska:')
drawRegressionLine_two_section(vader_negative_Nebraska_2017, color='g')
print('Missouri:')
drawRegressionLine_two_section(vader_negative_Missouri_2017, color='b')
print('Oklahoma:')
drawRegressionLine_two_section(vader_negative_Oklahoma_2017, color='c')
print('Colorado:')
drawRegressionLine_two_section(vader_negative_Colorado_2017, color='m')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Number')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for negative attitude towards e-cigarette by month. Y-axis represents the number of corresponding tweets within each month. ')
# plt.figure(figsize=(40,1))
plt.show()

print('******************************************************')
# Out:
# Kansas:
# slope:  [-1.4285714285767273, 0.5127046866166673]
# intercept:  [36.733333333411295, 11.653303218543842]
# R^2:  [0.5708957354088565, 0.19554354704207622]
# Nebraska:
# slope:  [-1.1607142857189992, -0.00846979108068635]
# intercept:  [30.72500000006484, 23.170525127095225]
# R^2:  [0.461389607212748, 5.697401149440395e-05]
# Missouri:
# slope:  [-2.6321428571507823, -0.09260304912717143]
# intercept:  [87.09166666685447, 57.7250141164422]
# R^2:  [0.4987716709927028, 0.0019267381045988685]
# Oklahoma:
# slope:  [-2.6178571428650366, 0.8537549407111436]
# intercept:  [70.72500000015211, 21.59288537553898]
# R^2:  [0.5766586385726307, 0.17505365370473203]
# Colorado:
# slope:  [-2.421428579918403, 1.150762281197393]
# intercept:  [92.15000005942882, 41.29192546592638]
# R^2:  [0.3477943757792924, 0.22650302749768025]
# ******************************************************
# Kansas:
# slope:  [-2.2357142857213432, 1.2038396386226922]
# ...

# %% [markdown]
# ---------------------------------------
# Proportion in sentiment analysis

# %%
# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


plt.plot(x, propotion_positive_ecig_Kansas, 'rx', label='Positive towards e-cigarette in Kansas')
plt.plot(x, propotion_positive_ecig_Nebraska, 'gx', label='Positive towards e-cigarette in Nebraska')
plt.plot(x, propotion_positive_ecig_Missouri, 'bx', label='Positive towards e-cigarette in Missouri')
plt.plot(x, propotion_positive_ecig_Oklahoma, 'cx', label='Positive towards e-cigarette in Oklahoma')
plt.plot(x, propotion_positive_ecig_Colorado, 'mx', label='Positive towards e-cigarette in Colorado')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(15, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))

print('Kansas:')
drawRegressionLine_two_section(propotion_positive_ecig_Kansas, color='r')
print('Nebraska:')
drawRegressionLine_two_section(propotion_positive_ecig_Nebraska, color='g')
print('Missouri:')
drawRegressionLine_two_section(propotion_positive_ecig_Missouri, color='b')
print('Oklahoma:')
drawRegressionLine_two_section(propotion_positive_ecig_Oklahoma, color='c')
print('Colorado:')
drawRegressionLine_two_section(propotion_positive_ecig_Colorado, color='m')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Proportion (%)')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for positive attitude towards e-cigarette by month. Y-axis represents the propotion of corresponding tweets within each month. ')
# plt.figure(figsize=(40,1))
plt.show()

print('******************************************************')
# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


plt.plot(x, propotion_neutral_ecig_Kansas, 'rx', label='Neutral towards e-cigarette in Kansas')
plt.plot(x, propotion_neutral_ecig_Nebraska, 'gx', label='Neutral towards e-cigarette in Nebraska')
plt.plot(x, propotion_neutral_ecig_Missouri, 'bx', label='Neutral towards e-cigarette in Missouri')
plt.plot(x, propotion_neutral_ecig_Oklahoma, 'cx', label='Neutral towards e-cigarette in Oklahoma')
plt.plot(x, propotion_neutral_ecig_Colorado, 'mx', label='Neutral towards e-cigarette in Colorado')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(15, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))

print('Kansas:')
drawRegressionLine_two_section(propotion_neutral_ecig_Kansas, color='r')
print('Nebraska:')
drawRegressionLine_two_section(propotion_neutral_ecig_Nebraska, color='g')
print('Missouri:')
drawRegressionLine_two_section(propotion_neutral_ecig_Missouri, color='b')
print('Oklahoma:')
drawRegressionLine_two_section(propotion_neutral_ecig_Oklahoma, color='c')
print('Colorado:')
drawRegressionLine_two_section(propotion_neutral_ecig_Colorado, color='m')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Proportion (%)')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for neutral attitude towards e-cigarette by month. Y-axis represents the propotion of corresponding tweets within each month. ')
# plt.figure(figsize=(40,1))
plt.show()


print('******************************************************')
# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12']

plt.figure(figsize=(14,7))

# print(x)
# itemNum = len(x)
# print(itemNum)


plt.plot(x, propotion_negative_ecig_Kansas, 'rx', label='Negative towards e-cigarette in Kansas')
plt.plot(x, propotion_negative_ecig_Nebraska, 'gx', label='Negative towards e-cigarette in Nebraska')
plt.plot(x, propotion_negative_ecig_Missouri, 'bx', label='Negative towards e-cigarette in Missouri')
plt.plot(x, propotion_negative_ecig_Oklahoma, 'cx', label='Negative towards e-cigarette in Oklahoma')
plt.plot(x, propotion_negative_ecig_Colorado, 'mx', label='Negative towards e-cigarette in Colorado')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(15, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))

print('Kansas:')
drawRegressionLine_two_section(propotion_negative_ecig_Kansas, color='r')
print('Nebraska:')
drawRegressionLine_two_section(propotion_negative_ecig_Nebraska, color='g')
print('Missouri:')
drawRegressionLine_two_section(propotion_negative_ecig_Missouri, color='b')
print('Oklahoma:')
drawRegressionLine_two_section(propotion_negative_ecig_Oklahoma, color='c')
print('Colorado:')
drawRegressionLine_two_section(propotion_negative_ecig_Colorado, color='m')


plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Proportion (%)')
#  Y-axis represents the number of corresponding tweets within each month.
plt.title('Trends for negative attitude towards e-cigarette by month. Y-axis represents the propotion of corresponding tweets within each month. ')
# plt.figure(figsize=(40,1))
plt.show()


print('******************************************************')
# Out:
# Kansas:
# slope:  [0.2574868650664345, -0.4736243614535507]
# intercept:  [33.62098191774989, 44.781302861665175]
# R^2:  [0.04687109180564597, 0.3134458613999631]
# Nebraska:
# slope:  [0.2048896695123269, -0.09868896582150999]
# intercept:  [34.6993203413733, 36.919216499787204]
# R^2:  [0.014571706893571013, 0.0076898634729976045]
# Missouri:
# slope:  [-0.37874818302953117, 0.2915989890446916]
# intercept:  [35.22074508682558, 24.77137647416337]
# R^2:  [0.2117849557556971, 0.21921280583309632]
# Oklahoma:
# slope:  [0.37013116746364816, -0.0564591157490848]
# intercept:  [36.19665274433674, 34.157203932554104]
# R^2:  [0.25821990730630007, 0.002648418871461611]
# Colorado:
# slope:  [0.20904240178388744, 0.19691912150333957]
# intercept:  [34.293604445739895, 28.388732313842027]
# R^2:  [0.03048096035771586, 0.12261883062220669]
# ******************************************************
# Kansas:
# slope:  [-0.07300739300324355, 0.2565865967586402]
# ...

# %%
# Fourth figure
x1 = np.linspace(1, 12, 12)
x2 = np.tile(x1, 2)
x3 = np.linspace(1, 6, 6)
# x = np.tile(x, 2)
# itemNum = len(x)

x = np.concatenate((x2, x3), axis=0)
x = list(x)
x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12',
    '2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06', '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12',
    '2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06', ]

plt.figure(figsize=(14,7))


# print(x)
itemNum = len(x)
# print(itemNum)


# plt.subplot(2, 1, 1)
plt.plot(x, np.ones(itemNum), 'r-', label='tobacco related positive')
plt.plot(x, np.ones(itemNum)-0.1, 'r--', label='tobacco related neutral')
plt.plot(x, np.ones(itemNum)-0.2, 'r-.', label='tobacco related negtive')

plt.plot(x, np.ones(itemNum)-0.3, 'g-', label='e-cigarette realated positive')
plt.plot(x, np.ones(itemNum)-0.4, 'g--', label='e-cigarette related neutral')
plt.plot(x, np.ones(itemNum)-0.5, 'g-.', label='e-cigarette related negtive')

plt.plot(x, np.ones(itemNum)-0.6, 'b-', label='other tobacco positive')
plt.plot(x, np.ones(itemNum)-0.7, 'b--', label='other tobacco neutral')
plt.plot(x, np.ones(itemNum)-0.8, 'b-.', label='other tobacco negtive')

plt.plot(x, np.ones(itemNum)-0.9, 'y-', label='first person positive')
plt.plot(x, np.ones(itemNum)-1, 'y--', label='first person neutral')
plt.plot(x, np.ones(itemNum)-1.1, 'y-.', label='first person negtive')

plt.plot(x, np.ones(itemNum)-1.2, 'm-', label='not first person positive')
plt.plot(x, np.ones(itemNum)-1.3, 'm--', label='not first person neutral')
plt.plot(x, np.ones(itemNum)-1.4, 'm-.', label='not first person negtive')

plt.legend()
# plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
plt.axvline(5, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Proposal', xy=(4,-0.3))
plt.axvline(17, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Approved', xy=(16,-0.3))
plt.axvline(24, hold=None,color='black',linestyle="--")
plt.annotate(s = 'Enforcement ', xy=(23,-0.3))




plt.xticks(rotation=80)
plt.xlabel('Month')
plt.ylabel('Attitude')
plt.title('Figure 4: Trends for attitude towards tobacco by month. Y-axis represents the propotion of corresponding tweets within each month. ')
# plt.figure(figsize=(40,1))
plt.show()

# %%
# # Second figure
# x1 = np.linspace(1, 12, 12)
# x2 = np.tile(x1, 2)
# x3 = np.linspace(1, 6, 6)
# # x = np.tile(x, 2)
# # itemNum = len(x)

# x = np.concatenate((x2, x3), axis=0)
# x = list(x)
# x = ['2017-01','2017-02', '2017-03','2017-04','2017-05','2017-06','2017-07','2017-08','2017-09','2017-10','2017-11','2017-12',
#     '2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06', '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12',
#     '2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06', ]

# plt.figure(figsize=(14,7))


# # print(x)
# itemNum = len(x)
# print(itemNum)


# # plt.subplot(2, 1, 1)
# plt.plot(x, np.ones(itemNum), 'r-', label='mentioning tweets')
# plt.plot(x, np.ones(itemNum)/2, 'g-.', label='mentioning users')
# plt.plot(x, np.zeros(itemNum), 'b.', label='first person users')
# plt.legend()
# # plt.vlines(6, 0, 1, colors = "black", linestyles = "dashed")
# plt.axvline(5, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Proposal', xy=(4,0.1))
# plt.axvline(17, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Approved', xy=(16,0.1))
# plt.axvline(24, hold=None,color='black',linestyle="--")
# plt.annotate(s = 'Enforcement ', xy=(23,0.1))




# plt.xticks(rotation=80)
# plt.xlabel('Month')
# plt.ylabel('# of mentioning')
# plt.title('Figure 1: Trends for number of tobacco related tweet by month. Y-axis represents the number of corresponding tweets within each month. ')
# # plt.figure(figsize=(40,1))
# plt.show()
