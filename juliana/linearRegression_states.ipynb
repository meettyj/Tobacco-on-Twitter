# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np

from scipy import optimize
import statsmodels.api as sm

# %%
# Y. value after event.
y_ca = list(map(float,['600', '881', '381', '32.27', '47.46', '20.27']))
y_or = list(map(float,['70', '101', '38', '33.43', '48.10', '18.47']))
y_nev = list(map(float,['116', '109', '45', '39.42', '42.17', '18.41']))
y_ar = list(map(float,['110', '155', '86', '31.38', '44.21', '24.41']))

y_ka = list(map(float,['24', '34', '18', '32.70', '44.35', '22.95']))
y_neb = list(map(float,['22', '27', '17', '34.40', '40.74', '24.86']))
y_mi = list(map(float,['55', '84', '33', '32.21', '48.17', '19.62']))
y_ok = list(map(float,['43', '56', '32', '32.72', '43.39', '23.90']))
y_col = list(map(float,['70', '96', '44', '33.41', '45.53', '21.06']))

y_de1 = list(map(float,['5', '8', '4', '29.65', '45.47', '24.88']))
y_nj1 = list(map(float,['110', '188', '75', '30.24', '48.70', '21.07']))
y_pe1 = list(map(float,['130', '253', '90', '28.17', '52.17', '19.66']))
y_ma1 = list(map(float,['72', '103', '53', '31.52', '45.13', '23.35']))
y_dc = list(map(float,['37', '45', '21', '35.28', '43.91', '20.81']))

y_nj2 = list(map(float,['87', '116', '68', '32.26', '43.03', '24.71']))
y_ny = list(map(float,['299', '450', '231', '30.58', '45.92', '23.50']))
y_pe2 = list(map(float,['124', '290', '87', '25.52', '56.76', '17.72']))
y_con = list(map(float,['39', '54', '30', '31.70', '45.32', '22.99']))
y_de2 = list(map(float,['4', '6', '5', '28.89', '42.09', '29.03']))
y_ma2 = list(map(float,['71', '102', '56', '30.88', '44.93', '24.19']))

y_states = []
y_states.append(y_ca)
y_states.append(y_or)
y_states.append(y_nev)
y_states.append(y_ar)

y_states.append(y_ka)
y_states.append(y_neb)
y_states.append(y_mi)
y_states.append(y_ok)
y_states.append(y_col)

y_states.append(y_de1)
y_states.append(y_nj1)
y_states.append(y_pe1)
y_states.append(y_ma1)
y_states.append(y_dc)

y_states.append(y_nj2)
y_states.append(y_ny)
y_states.append(y_pe2)
y_states.append(y_con)
y_states.append(y_de2)
y_states.append(y_ma2)

print('length of y_states: ', len(y_states))
y_states
# Out:
# length of y_states:  20
# [[600.0, 881.0, 381.0, 32.27, 47.46, 20.27],
#  [70.0, 101.0, 38.0, 33.43, 48.1, 18.47],
#  [116.0, 109.0, 45.0, 39.42, 42.17, 18.41],
#  [110.0, 155.0, 86.0, 31.38, 44.21, 24.41],
#  [24.0, 34.0, 18.0, 32.7, 44.35, 22.95],
#  [22.0, 27.0, 17.0, 34.4, 40.74, 24.86],
#  [55.0, 84.0, 33.0, 32.21, 48.17, 19.62],
#  [43.0, 56.0, 32.0, 32.72, 43.39, 23.9],
#  [70.0, 96.0, 44.0, 33.41, 45.53, 21.06],
#  [5.0, 8.0, 4.0, 29.65, 45.47, 24.88],
#  [110.0, 188.0, 75.0, 30.24, 48.7, 21.07],
#  [130.0, 253.0, 90.0, 28.17, 52.17, 19.66],
#  [72.0, 103.0, 53.0, 31.52, 45.13, 23.35],
#  [37.0, 45.0, 21.0, 35.28, 43.91, 20.81],
#  [87.0, 116.0, 68.0, 32.26, 43.03, 24.71],
#  [299.0, 450.0, 231.0, 30.58, 45.92, 23.5],
#  [124.0, 290.0, 87.0, 25.52, 56.76, 17.72],
#  [39.0, 54.0, 30.0, 31.7, 45.32, 22.99],
#  [4.0, 6.0, 5.0, 28.89, 42.09, 29.03],
#  [71.0, 102.0, 56.0, 30.88, 44.93, 24.19]]

# %%
# X.
x1_ca = list(map(float,['940', '1420', '461', '33.41', '50.33', '16.26']))
x1_or = list(map(float,['104', '121', '38', '39.63', '45.70', '14.67']))
x1_nev = list(map(float,['180', '187', '45', '42.48', '46.31', '11.22']))
x1_ar = list(map(float,['151', '206', '87', '33.71', '46.43', '19.86']))

x1_ka = list(map(float,['26', '36', '13', '35.42', '47.19', '17.39']))
x1_neb = list(map(float,['22', '28', '11', '36.13', '44.91', '18.96']))
x1_mi = list(map(float,['68', '111', '29', '32.57', '53.56', '13.87']))
x1_ok = list(map(float,['52', '57', '26', '38.79', '41.55', '19.67']))
x1_col = list(map(float,['75', '101', '34', '35.76', '47.94', '16.30']))

x1_de1 = list(map(float,['4', '5', '2', '30.95', '46.78', '22.27']))
x1_nj1 = list(map(float,['112', '169', '65', '32.37', '48.89', '18.74']))
x1_pe1 = list(map(float,['121', '175', '63', '33.79', '48.27', '17.94']))
x1_ma1 = list(map(float,['78', '103', '40', '35.11', '45.94', '18.95']))
x1_dc = list(map(float,['27', '39', '15', '33.41', '47.57', '19.02']))

x1_nj2 = list(map(float,['117', '191', '70', '31.26', '50.15', '18.59']))
x1_ny = list(map(float,['460', '623', '194', '34.93', '49.22', '15.86']))
x1_pe2 = list(map(float,['125', '190', '72', '32.72', '48.37', '18.91']))
x1_con = list(map(float,['36', '54', '23', '31.99', '47.96', '20.04']))
x1_de2 = list(map(float,['4', '7', '3', '30.73', '47.18', '22.09']))
x1_ma2 = list(map(float,['76', '103', '43', '34.18', '45.74', '20.07']))

x1 = []
x1.append(x1_ca)
x1.append(x1_or)
x1.append(x1_nev)
x1.append(x1_ar)

x1.append(x1_ka)
x1.append(x1_neb)
x1.append(x1_mi)
x1.append(x1_ok)
x1.append(x1_col)

x1.append(x1_de1)
x1.append(x1_nj1)
x1.append(x1_pe1)
x1.append(x1_ma1)
x1.append(x1_dc)

x1.append(x1_nj2)
x1.append(x1_ny)
x1.append(x1_pe2)
x1.append(x1_con)
x1.append(x1_de2)
x1.append(x1_ma2)

print('length of x1: ', len(x1))
x1
# Out:
# length of x1:  20
# [[940.0, 1420.0, 461.0, 33.41, 50.33, 16.26],
#  [104.0, 121.0, 38.0, 39.63, 45.7, 14.67],
#  [180.0, 187.0, 45.0, 42.48, 46.31, 11.22],
#  [151.0, 206.0, 87.0, 33.71, 46.43, 19.86],
#  [26.0, 36.0, 13.0, 35.42, 47.19, 17.39],
#  [22.0, 28.0, 11.0, 36.13, 44.91, 18.96],
#  [68.0, 111.0, 29.0, 32.57, 53.56, 13.87],
#  [52.0, 57.0, 26.0, 38.79, 41.55, 19.67],
#  [75.0, 101.0, 34.0, 35.76, 47.94, 16.3],
#  [4.0, 5.0, 2.0, 30.95, 46.78, 22.27],
#  [112.0, 169.0, 65.0, 32.37, 48.89, 18.74],
#  [121.0, 175.0, 63.0, 33.79, 48.27, 17.94],
#  [78.0, 103.0, 40.0, 35.11, 45.94, 18.95],
#  [27.0, 39.0, 15.0, 33.41, 47.57, 19.02],
#  [117.0, 191.0, 70.0, 31.26, 50.15, 18.59],
#  [460.0, 623.0, 194.0, 34.93, 49.22, 15.86],
#  [125.0, 190.0, 72.0, 32.72, 48.37, 18.91],
#  [36.0, 54.0, 23.0, 31.99, 47.96, 20.04],
#  [4.0, 7.0, 3.0, 30.73, 47.18, 22.09],
#  [76.0, 103.0, 43.0, 34.18, 45.74, 20.07]]

# %%
x_remaining = []
x_remaining.append(list(map(float, '1 & 39399349 & 8227985 & 356464 & 2823 & 1647 & 0.03421'.split('&'))))
x_remaining.append(list(map(float, '0 & 4146592 & 559398 & 31190  & 264 & 140 & 0.04729 '.split('&'))))
x_remaining.append(list(map(float, '0 & 2972405 & 716884 & 44812 & 413 & 158 & 0.06007 '.split('&'))))
x_remaining.append(list(map(float, '0 & 7048876 & 1147103 & 52683  & 446 & 311  & 0.03862 '.split('&'))))

x_remaining.append(list(map(float, '1 & 2910689 & 330855 & 20019  & 76 & 55  & 0.02288 '.split('&'))))
x_remaining.append(list(map(float, '0 & 1917575 & 251061 & 15053 & 63 & 48 & 0.02487 '.split('&'))))
x_remaining.append(list(map(float, '0 & 6108612 & 601529 & 38826  & 209 & 123 & 0.03488'.split('&'))))
x_remaining.append(list(map(float, '0 & 3932640 & 535637 & 26928  & 135 & 95 & 0.02524 '.split('&'))))
x_remaining.append(list(map(float, '0 & 5615902 & 580055 & 36898  & 210 & 142 & 0.03626'.split('&'))))

x_remaining.append(list(map(float, '1 & 957078 & 71256 & 5527 & 12 & 10  & 0.01853'.split('&'))))
x_remaining.append(list(map(float, '0 & 8888543 & 1285099 & 74721 & 347 & 227 & 0.02806'.split('&'))))
x_remaining.append(list(map(float, '1 & 12790447 & 1328496 & 80112 & 359 & 254 & 0.02748 '.split('&'))))
x_remaining.append(list(map(float, '0 & 6024891 & 1038921 & 50680 & 221 & 137 & 0.02089 '.split('&'))))
x_remaining.append(list(map(float, '1 & 695691 & 432070 & 34813 & 82 & 58 & 0.01907'.split('&'))))

x_remaining.append(list(map(float, '1 & 8908520 & 1179505 & 71063  & 379 & 237 & 0.03432'.split('&'))))
x_remaining.append(list(map(float, '0 & 19542209 & 2860083 & 180237 & 1279 & 692 &  0.05319'.split('&'))))
x_remaining.append(list(map(float, '1 & 12807060 & 1232635 & 76275  & 387 & 270  & 0.03264'.split('&'))))
x_remaining.append(list(map(float, '0 & 3572665 & 411658 & 23249 & 114 & 84  & 0.02824'.split('&'))))
x_remaining.append(list(map(float, '1 & 967171 & 66676 & 5182  & 14 & 11  & 0.02366 '.split('&'))))
x_remaining.append(list(map(float, '0 & 6042718 & 966546 & 48972 & 223 & 149  & 0.02324'.split('&'))))

print('length of x_remaining: ', len(x_remaining))
x_remaining
# Out:
# length of x_remaining:  20
# [[1.0, 39399349.0, 8227985.0, 356464.0, 2823.0, 1647.0, 0.03421],
#  [0.0, 4146592.0, 559398.0, 31190.0, 264.0, 140.0, 0.04729],
#  [0.0, 2972405.0, 716884.0, 44812.0, 413.0, 158.0, 0.06007],
#  [0.0, 7048876.0, 1147103.0, 52683.0, 446.0, 311.0, 0.03862],
#  [1.0, 2910689.0, 330855.0, 20019.0, 76.0, 55.0, 0.02288],
#  [0.0, 1917575.0, 251061.0, 15053.0, 63.0, 48.0, 0.02487],
#  [0.0, 6108612.0, 601529.0, 38826.0, 209.0, 123.0, 0.03488],
#  [0.0, 3932640.0, 535637.0, 26928.0, 135.0, 95.0, 0.02524],
#  [0.0, 5615902.0, 580055.0, 36898.0, 210.0, 142.0, 0.03626],
#  [1.0, 957078.0, 71256.0, 5527.0, 12.0, 10.0, 0.01853],
#  [0.0, 8888543.0, 1285099.0, 74721.0, 347.0, 227.0, 0.02806],
#  [1.0, 12790447.0, 1328496.0, 80112.0, 359.0, 254.0, 0.02748],
#  [0.0, 6024891.0, 1038921.0, 50680.0, 221.0, 137.0, 0.02089],
#  [1.0, 695691.0, 432070.0, 34813.0, 82.0, 58.0, 0.01907],
#  [1.0, 8908520.0, 1179505.0, 71063.0, 379.0, 237.0, 0.03432],
#  [0.0, 19542209.0, 2860083.0, 180237.0, 1279.0, 692.0, 0.05319],
#  [1.0, 12807060.0, 1232635.0, 76275.0, 387.0, 270.0, 0.03264],
#  [0.0, 3572665.0, 411658.0, 23249.0, 114.0, 84.0, 0.02824],
#  [1.0, 967171.0, 66676.0, 5182.0, 14.0, 11.0, 0.02366],
#  [0.0, 6042718.0, 966546.0, 48972.0, 223.0, 149.0, 0.02324]]

# %%
for i in range(6):
    print('this is column %d.' %(i+1))
    X_training = []
    y_training = list(np.asarray(y_states)[:,i])
    print('y_training: ', y_training)
    # to get X_training
    for j in range(len(x1)):
        tmp = [x1[j][i]]
        tmp.extend(x_remaining[j])
        X_training.append(tmp)
#     print('X_training: ', X_training)
    X_training = sm.add_constant(X_training)
#     print('X_training: ', X_training)
    model = sm.OLS(y_training, X_training).fit()
    print('section: ', i)
#     print('model summary: ',model.summary())
    print('model summary: ',model.summary(xname=['Const', 'Value_before', 'Tax', 'population', 'F_tweets', 'F_tweetPosters', 'F_ecigTweets', 'F_ecigTweetPosters', 'P_ecigTweets2']))
    print()
    print('%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%')
    print()
    
    
#     break
# Out:
# this is column 1.
# y_training:  [600.0, 70.0, 116.0, 110.0, 24.0, 22.0, 55.0, 43.0, 70.0, 5.0, 110.0, 130.0, 72.0, 37.0, 87.0, 299.0, 124.0, 39.0, 4.0, 71.0]
# section:  0
# model summary:                              OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.998
# Method:                 Least Squares   F-statistic:                     1458.
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):           1.57e-15
# Time:                        03:12:42   Log-Likelihood:                -56.050
# No. Observations:                  20   AIC:                             130.1
# Df Residuals:                      11   BIC:                             139.1
# Df Model:                           8
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Const                -19.1362      8.311     -2.303      0.042     -37.428      -0.845
# Value_before           1.3482      0.252      5.355      0.000       0.794       1.902
# Tax                    2.5071      3.011      0.833      0.423      -4.120       9.134
# population          9.594e-07   1.14e-06      0.838      0.420   -1.56e-06    3.48e-06
# F_tweets            2.533e-05   9.44e-06      2.685      0.021    4.57e-06    4.61e-05
# F_tweetPosters         0.0007      0.000      3.407      0.006       0.000       0.001
# F_ecigTweets          -0.5971      0.130     -4.586      0.001      -0.884      -0.310
# F_ecigTweetPosters     0.3249      0.098      3.322      0.007       0.110       0.540
# P_ecigTweets2        558.3903    257.382      2.169      0.053      -8.104    1124.885
# ==============================================================================
# Omnibus:                        1.606   Durbin-Watson:                   2.054
# Prob(Omnibus):                  0.448   Jarque-Bera (JB):                1.317
# Skew:                          -0.581   Prob(JB):                        0.518
# Kurtosis:                       2.522   Cond. No.                     2.52e+09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.52e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# this is column 2.
# y_training:  [881.0, 101.0, 109.0, 155.0, 34.0, 27.0, 84.0, 56.0, 96.0, 8.0, 188.0, 253.0, 103.0, 45.0, 116.0, 450.0, 290.0, 54.0, 6.0, 102.0]
# section:  1
# model summary:                              OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.991
# Model:                            OLS   Adj. R-squared:                  0.984
# Method:                 Least Squares   F-statistic:                     144.8
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):           4.82e-10
# Time:                        03:12:42   Log-Likelihood:                -87.307
# No. Observations:                  20   AIC:                             192.6
# Df Residuals:                      11   BIC:                             201.6
# Df Model:                           8
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Const                -37.9572     39.679     -0.957      0.359    -125.289      49.375
# Value_before          -2.0583      1.232     -1.671      0.123      -4.769       0.653
# Tax                   16.4677     14.736      1.118      0.288     -15.965      48.901
# population          1.567e-05   5.65e-06      2.772      0.018    3.23e-06    2.81e-05
# F_tweets           -1.982e-06    4.5e-05     -0.044      0.966      -0.000    9.71e-05
# F_tweetPosters         0.0005      0.001      0.566      0.583      -0.002       0.003
# F_ecigTweets           1.0438      0.693      1.507      0.160      -0.481       2.568
# F_ecigTweetPosters     0.0439      0.389      0.113      0.912      -0.812       0.900
# P_ecigTweets2        278.1392   1237.905      0.225      0.826   -2446.472    3002.750
# ==============================================================================
# Omnibus:                       11.989   Durbin-Watson:                   2.319
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               11.937
# Skew:                          -1.079   Prob(JB):                      0.00256
# Kurtosis:                       6.110   Cond. No.                     2.54e+09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.54e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# this is column 3.
# y_training:  [381.0, 38.0, 45.0, 86.0, 18.0, 17.0, 33.0, 32.0, 44.0, 4.0, 75.0, 90.0, 53.0, 21.0, 68.0, 231.0, 87.0, 30.0, 5.0, 56.0]
# section:  2
# model summary:                              OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.997
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                     427.5
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):           1.31e-12
# Time:                        03:12:42   Log-Likelihood:                -59.998
# No. Observations:                  20   AIC:                             138.0
# Df Residuals:                      11   BIC:                             147.0
# Df Model:                           8
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Const                 19.8058     10.167      1.948      0.077      -2.572      42.184
# Value_before           0.8525      0.641      1.331      0.210      -0.557       2.262
# Tax                   -9.5627      3.527     -2.711      0.020     -17.325      -1.800
# population          2.308e-06   1.53e-06      1.506      0.160   -1.06e-06    5.68e-06
# F_tweets           -6.009e-05   1.13e-05     -5.331      0.000   -8.49e-05   -3.53e-05
# F_tweetPosters         0.0009      0.000      3.689      0.004       0.000       0.001
# F_ecigTweets           0.0310      0.059      0.523      0.612      -0.099       0.161
# F_ecigTweetPosters    -0.0047      0.206     -0.023      0.982      -0.457       0.448
# P_ecigTweets2       -547.0266    301.542     -1.814      0.097   -1210.716     116.663
# ==============================================================================
# Omnibus:                        0.582   Durbin-Watson:                   1.542
# Prob(Omnibus):                  0.748   Jarque-Bera (JB):                0.175
# Skew:                          -0.229   Prob(JB):                        0.916
# Kurtosis:                       2.966   Cond. No.                     2.42e+09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.42e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# this is column 4.
# y_training:  [32.27, 33.43, 39.42, 31.38, 32.7, 34.4, 32.21, 32.72, 33.41, 29.65, 30.24, 28.17, 31.52, 35.28, 32.26, 30.58, 25.52, 31.7, 28.89, 30.88]
# section:  3
# model summary:                              OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.838
# Model:                            OLS   Adj. R-squared:                  0.720
# Method:                 Least Squares   F-statistic:                     7.103
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):            0.00201
# Time:                        03:12:42   Log-Likelihood:                -30.676
# No. Observations:                  20   AIC:                             79.35
# Df Residuals:                      11   BIC:                             88.31
# Df Model:                           8
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Const                 19.0632      5.860      3.253      0.008       6.166      31.960
# Value_before           0.2953      0.179      1.654      0.126      -0.098       0.688
# Tax                   -0.0485      0.839     -0.058      0.955      -1.894       1.797
# population         -1.224e-06   3.22e-07     -3.801      0.003   -1.93e-06   -5.15e-07
# F_tweets            4.703e-06   2.86e-06      1.646      0.128   -1.58e-06     1.1e-05
# F_tweetPosters      9.139e-05   5.45e-05      1.676      0.122   -2.86e-05       0.000
# F_ecigTweets          -0.0116      0.014     -0.841      0.418      -0.042       0.019
# F_ecigTweetPosters     0.0050      0.023      0.214      0.835      -0.047       0.057
# P_ecigTweets2        130.4823     77.439      1.685      0.120     -39.960     300.925
# ==============================================================================
# Omnibus:                        2.529   Durbin-Watson:                   1.843
# Prob(Omnibus):                  0.282   Jarque-Bera (JB):                1.203
# Skew:                           0.167   Prob(JB):                        0.548
# Kurtosis:                       1.846   Cond. No.                     2.69e+09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.69e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# this is column 5.
# y_training:  [47.46, 48.1, 42.17, 44.21, 44.35, 40.74, 48.17, 43.39, 45.53, 45.47, 48.7, 52.17, 45.13, 43.91, 43.03, 45.92, 56.76, 45.32, 42.09, 44.93]
# section:  4
# model summary:                              OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.686
# Model:                            OLS   Adj. R-squared:                  0.457
# Method:                 Least Squares   F-statistic:                     2.999
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):             0.0475
# Time:                        03:12:42   Log-Likelihood:                -42.399
# No. Observations:                  20   AIC:                             102.8
# Df Residuals:                      11   BIC:                             111.8
# Df Model:                           8
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Const                 35.1716     14.154      2.485      0.030       4.018      66.325
# Value_before           0.0790      0.309      0.256      0.803      -0.600       0.758
# Tax                    1.1279      1.502      0.751      0.468      -2.178       4.434
# population          1.292e-06    5.8e-07      2.226      0.048    1.48e-08    2.57e-06
# F_tweets            2.296e-06   4.65e-06      0.494      0.631   -7.93e-06    1.25e-05
# F_tweetPosters     -4.093e-05    9.8e-05     -0.418      0.684      -0.000       0.000
# F_ecigTweets          -0.0172      0.025     -0.700      0.498      -0.071       0.037
# F_ecigTweetPosters    -0.0024      0.040     -0.059      0.954      -0.091       0.086
# P_ecigTweets2        121.2964    126.116      0.962      0.357    -156.284     398.877
# ==============================================================================
# Omnibus:                        4.186   Durbin-Watson:                   2.283
# Prob(Omnibus):                  0.123   Jarque-Bera (JB):                2.134
# Skew:                          -0.508   Prob(JB):                        0.344
# Kurtosis:                       4.236   Cond. No.                     2.44e+09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.44e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# this is column 6.
# y_training:  [20.27, 18.47, 18.41, 24.41, 22.95, 24.86, 19.62, 23.9, 21.06, 24.88, 21.07, 19.66, 23.35, 20.81, 24.71, 23.5, 17.72, 22.99, 29.03, 24.19]
# section:  5
# model summary:                              OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.704
# Model:                            OLS   Adj. R-squared:                  0.489
# Method:                 Least Squares   F-statistic:                     3.272
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):             0.0362
# Time:                        03:12:42   Log-Likelihood:                -36.525
# No. Observations:                  20   AIC:                             91.05
# Df Residuals:                      11   BIC:                             100.0
# Df Model:                           8
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Const                  8.9201      9.548      0.934      0.370     -12.094      29.934
# Value_before           0.9393      0.346      2.716      0.020       0.178       1.700
# Tax                   -0.8359      1.085     -0.770      0.457      -3.225       1.553
# population           1.39e-08   4.32e-07      0.032      0.975   -9.37e-07    9.65e-07
# F_tweets           -2.997e-06    4.1e-06     -0.730      0.480    -1.2e-05    6.03e-06
# F_tweetPosters       -3.9e-05   7.22e-05     -0.540      0.600      -0.000       0.000
# F_ecigTweets           0.0305      0.018      1.665      0.124      -0.010       0.071
# F_ecigTweetPosters    -0.0293      0.033     -0.885      0.395      -0.102       0.044
# P_ecigTweets2        -77.7468    127.183     -0.611      0.553    -357.674     202.181
# ==============================================================================
# Omnibus:                        0.310   Durbin-Watson:                   2.053
# Prob(Omnibus):                  0.856   Jarque-Bera (JB):                0.009
# Skew:                           0.046   Prob(JB):                        0.995
# Kurtosis:                       2.950   Cond. No.                     3.31e+09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.31e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
