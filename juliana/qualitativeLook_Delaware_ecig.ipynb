# %%
import os
# os.chdir('C:/Users/eddie/Desktop/Prof. Rumi Chunara/alcohol')
import json
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer 
import re

# %%
# month_list = ['04','05','06','07','08','09','10','11','12']
# '01', '02', '03',   
month_list = ['10','11','12']
month_list2 = ['01', '02', '03', '04','05','06']

# %%
# sentiment analysis
def analyzeSentimentByVader(texts):
    positive_text = [[],[]]
    neutral_text = [[],[]]
    negative_text = [[],[]]
    
#     score_total = []    

    analyzer = SentimentIntensityAnalyzer()
    for sentence in texts:
        vs = analyzer.polarity_scores(sentence)
    #     print("{:*<65} {}".format(sentence, str(vs)))
    #     print('------------------------')
#         print(vs)
        if vs['compound'] >= 0.05:
#             print(vs['compound'])
            positive_text[0].append(sentence)
            positive_text[1].append(vs)
        elif vs['compound'] <= 0.05 and vs['compound'] > -0.05:
#             print(vs['compound'])
            neutral_text[0].append(sentence)
            neutral_text[1].append(vs)
        elif vs['compound'] <= -0.05:
#             print(vs['compound'])
            negative_text[0].append(sentence)
            negative_text[1].append(vs)
#         score_total.append(vs)

    return positive_text, neutral_text, negative_text

# %%
# text without link.

num_positive_tweets_in_total = []
num_neutral_tweets_in_total = []
num_negative_tweets_in_total = []


filePath = '/mnt/volume/result/State_DelawareLevel/'
for month in month_list:
    text_in_month = []
    user_month = set()
    fileName = 'juliana_D.C._allECigarette_2017_'+month+'_categoryKeyWord.json'
    file = filePath + fileName
    with open(file, "r") as f:
        everyLines = f.readlines()
        print('length of tweets in month %s: %d' % (month, len(everyLines)))
        for line in everyLines:
            try:
                lineInJson = json.loads(line)
            except:
                print('Cannot load the line: ', line)
            textInLine = lineInJson["text"]
#             print(textInLine)
            textAfterRE = re.sub('https?:\/\/t\.co\/[\s\S]{10}', '', textInLine)
            text_in_month.append(textAfterRE)
    
    # get sentiment
    positive_text, neutral_text, negative_text = analyzeSentimentByVader(text_in_month)
    num_positive = len(positive_text[0])
    num_neutral = len(neutral_text[0])
    num_negative = len(negative_text[0])
    
    num_positive_tweets_in_total.append(positive_text[0])
    num_neutral_tweets_in_total.append(neutral_text[0])
    num_negative_tweets_in_total.append(negative_text[0])
    
    print('How many positive text: ', num_positive)
    print('How many neutral text: ', num_neutral)
    print('How many negative text: ', num_negative)
    print('--------------------')

    
    
    
    
for month in month_list2:
    text_in_month = []
    user_month = set()
    fileName = 'juliana_D.C._allECigarette_2018_'+month+'_categoryKeyWord.json'
    file = filePath + fileName
    with open(file, "r") as f:
        everyLines = f.readlines()
        print('length of tweets in month %s: %d' % (month, len(everyLines)))
        for line in everyLines:
            try:
                lineInJson = json.loads(line)
            except:
                print('Cannot load the line: ', line)
            textInLine = lineInJson["text"]
#             print(textInLine)
            textAfterRE = re.sub('https?:\/\/t\.co\/[\s\S]{10}', '', textInLine)
            text_in_month.append(textAfterRE)
    
    # get sentiment
    positive_text, neutral_text, negative_text = analyzeSentimentByVader(text_in_month)
    num_positive = len(positive_text[0])
    num_neutral = len(neutral_text[0])
    num_negative = len(negative_text[0])
    
    num_positive_tweets_in_total.append(positive_text[0])
    num_neutral_tweets_in_total.append(neutral_text[0])
    num_negative_tweets_in_total.append(negative_text[0])
    
    print('How many positive text: ', num_positive)
    print('How many neutral text: ', num_neutral)
    print('How many negative text: ', num_negative)
    print('--------------------')
#     break
# Out:
# length of tweets in month 10: 36
# How many positive text:  15
# How many neutral text:  18
# How many negative text:  3
# --------------------
# length of tweets in month 11: 75
# How many positive text:  29
# How many neutral text:  41
# How many negative text:  5
# --------------------
# length of tweets in month 12: 58
# How many positive text:  18
# How many neutral text:  24
# How many negative text:  16
# --------------------
# length of tweets in month 01: 80
# How many positive text:  25
# How many neutral text:  43
# How many negative text:  12
# --------------------
# length of tweets in month 02: 64
# How many positive text:  13
# How many neutral text:  39
# How many negative text:  12
# --------------------
# length of tweets in month 03: 98
# How many positive text:  30
# How many neutral text:  53
# How many negative text:  15
# --------------------
# length of tweets in month 04: 155
# How many positive text:  52
# How many neutral text:  72
# How many negative text:  31
# --------------------
# length of tweets in month 05: 118
# How many positive text:  40
# How many neutral text:  54
# How many negative text:  24
# --------------------
# length of tweets in month 06: 84
# How many positive text:  28
# How many neutral text:  39
# How many negative text:  17
# --------------------

# %%
for i in num_positive_tweets_in_total[0]:
    print(i)
    print('')

for i in num_neutral_tweets_in_total[0]:
    print(i)
    print('')
    
for i in num_negative_tweets_in_total[0]:
    print(i)
    print('')
    
print()
for i in num_positive_tweets_in_total[1]:
    print(i)
    print('')
    
print()
for i in num_neutral_tweets_in_total[1]:
    print(i)
    print('')
    
print()
for i in num_negative_tweets_in_total[1]:
    print(i)
    print('')   
    
print()
for i in num_positive_tweets_in_total[2]:
    print(i)
    print('')
    
print()
for i in num_neutral_tweets_in_total[2]:
    print(i)
    print('')
    
print()
for i in num_negative_tweets_in_total[2]:
    print(i)
    print('')
    
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!1
# Out:
# @dorkly looks like a vaporeon/glaceon eevee-lution
#
# @KatTimpf @LongRoomNews Looks like you’re the new face of the vaping lobby! 😂
#
# Interested in a #job in #Washington, DC? This could be a great fit:  #BoozAllen #BusinessMgmt #Veterans #Hiring
#
# This #job might be a great fit for you: Projects Manager -  #BoozAllen #BusinessMgmt #Washington, DC #Veterans
#
# This is how you make a good cigar @cortezcigars @casalucadc #meshintl #eventplanning #washingtondc
#
# This is how you make a good cigar @cortezcigars @casalucadc #meshintl #eventplanning #washingtondc
#
# Yeaa if you say vaping is too much you’re honestly just stupid .... it’s literally more cost efficient and you can do it anywhere
#
# Fall fest was a success #vapenation @ American University
#
# @SciGuySpace @HolsMichael Um, that might surprise @blueorigin @virgingalactic @EricStallmer etc (all on the program…
#
# Those new brons look like vapor maxes
#
# they’re finally releasing laceless vapormaxes so all those sellers of the CDG joints on grailed can kiss my ass lmao
#
# Embajador José Tomás Pérez invitado de honor en Gala del Cigarro Dominicano, en Washington, D.C. @josetomasperezv…
#
# And a lovely time was had by all: Cigarette 🚬 Dougie Poole 🏊 Bong Wish 🌟Lisa Mezzacappa 🎼at…
#
# Evading the obvious (taxes) and focusing on vaporware like social impact bonds, kindness of billionaires, and ISAs
#
# Yes this is a vaping mod made from bone  cc @KatTimpf
#
# Just posted a photo @ Mimosa Salon
#
# @kumub Chokwadi! Vapedza vopihwa mari to provide recommendations as experts on Africa!
#
# Where in tarnation is my vape💨
#
# Who's up for a smoke and a dram @TG_Cigars Monday night?
#
# The amount of weed in a vape to get you high compared to how much you’d have to roll is just oc
#
# ICAN, internationella kampanjen för avskaffandet av kärnvapen tilldelas fredspriset.
#
# &amp; they be swishers 😢🤢
#
# @pinksostuckup shorty glued all the swisher packs together made a costume
#
# Big Boi been slept on!
#
# @wheretobuyvapes Check this out!!
#
# 🤗🤗😂
#
# #TheDoorAndTheSmokestack #UnseenDC @ Randall Junior High School
#
# Get home and cant find the charger to this fuckin vape 😢😭
#
# #OHNOitsBAD
# #GO #FOLLOW
# @its_badguy on @instagram #TODAY
# #itsBadGuy #Instagram #Instafamous #VapeFamous #HipHop…
#
# @zzzJV @undisputed @LilTunechi @FS1 @CNN Hey Bud, atleast we can still Njoy som action packed College Football on a…
#
# BRUHHH
#
# On arriving late to a meeting with Obama at the White House.
# Ta-Nehisi Coates in conversation…
#
# #SmokesNJokes #HouseParty #ComedyKickback #OpenMic grace.lovedc 2 Levels of Class #BlackOwned…
#
# @pinksostuckup @MrsTee_Bee @EvoRoLLiN sis want me to fight her cousin cause she smoke swishers and got a ugly family. how is that my fault!
#
# theres no way this is real
#
# @_mejjar sorry i vape jer
#
#
# i am walking around capital hill and the middle schoolers are talking about how much it smells like skunk (it was someone’s vape) lmaooooo
#
# It's that time again! We're hanging out with our friends from Tryst in Adams Morgan again!…
#
# @spindlypete There’s a vape shop directly next door to my job but honestly the crowd going in and out of there kept…
#
# in my defense it didn’t look like a vape. it looked like the nose hair trimmer the rock used in the game plan
#
# Love to all the vape daddies this holiday weekend
#
# Join us for #BLUFDC next Sunday at the dceaglebar! Men in #highcow, folks smoking #cigars,…
#
# I just saw a guy in his mid to late 40's ask a guy in his 70's if he wanted to hit his vape 😂 #deadandcompany
#
# i love going to school here at american university where i can sit next to boys in class that hit their juul every 2 min! #blessed
#
# Electric, like a vape pen
#
# Last college paper is going to be about vape laws by state and I really think I'm ending on a good note
#
# Vape that smells like donuts is like hazelnut or Irish Mist coffee. What's the point?
#
# okay i’ve never heard of juuling until tonight &amp; all these freshman are judging me, why am i such an old person
#
# #WeekendChronicles #Friyay Happy Birthday again @larae_89 😘. #babypassmethehookah…
#
# Man o man. Y’all better.... nvm happy thanksgiving 🍁🦃🍽 vapenacup x #Smiggletreats 😎👀 @…
#
# @theykravekaaay @islahchavos @ayeeohhgee I love you too ❤️I couldn’t ask for a better friend 🤞🏽you the realest shordy
#
# Smokin p’s like I’m a vapor heaterrrrr 😤
#
# Join #UCHAPS for a congressional briefing on PrEP. Learn more at .
#
# I have the power of god and vaporwave on my side
#
# It ain’t no reason Mistics should be as good as they are, them hoes are immaculate
#
# Ian from @trystdc National Cathedral is this month's winner! @ Tryst DC
#
# Pablo vs Makda. Pablo won. @ Tryst DC
#
# THANK YOU TIVA PEER AWARDS!  Fabulous evening with DC's best creators! #tivapeerawards2017 #mediaproduction #dc #dmv
#
# At TIVA-DC Peer Awards with scriptwriter and producer Bart Woodward. #tivapeerawards2017
#
# At TIVA-DC Peer Awards w my friend filmmaker Ishu Krishna. #tivapeerawards2017  #Filmmaking #media #mediaproduction…
#
# Honored to be recognized for our MTA program featuring Brad Meltzer at the #tivapeerawards2017 @WIFV_DC @FFXNetwork @bradmeltzer
#
# Question- Anyone know of a tax break for #vaping? 😎 #TaxCuts #TaxReformNow
#
# People love Juuls more than their relationships
#
# #12ECOGworkshop this is a great time for a shameless plug on my own research: a similar phenomenon occurs upon stim…
#
# Jefe 💙 the kids. Shoutout to Andrew Merydith! Exclusive Vapormax from the Doernbecher…
#
#
# my aunt saw me smoking😩😂 "Taysia why. dont smoke them smoke a vapor they got flavors😩😂😂😂😂.
#
# I'm at @Nordstrom Rack 12th Street in Washington, DC
#
# #VapeNation
#
# Wasn’t able to get the vapor max! Wasn’t able to get my LV bag!
#
# @Dcpc1and2 @DBHforRecovery @DCPrevNetwk @dctfc1 @BreatheDC @SashaBruceYouth @Wards78DCPC @TobaccoFreeKids…
#
# @Dcpc1and2 @DBHforRecovery @DCPrevNetwk @dctfc1 @BreatheDC @SashaBruceYouth @Wards78DCPC @TobaccoFreeKids…
#
# @Dcpc1and2 @DBHforRecovery @DCPrevNetwk @dctfc1 @BreatheDC @SashaBruceYouth @Wards78DCPC @TobaccoFreeKids…
#
# @Dcpc1and2 @DBHforRecovery @DCPrevNetwk @dctfc1 @BreatheDC @SashaBruceYouth @Wards78DCPC @TobaccoFreeKids…
#
# Tonight! @damarisalopez hosts #TopFloorFridays at Ozio 11/17 @ Ozio Martini &amp; Cigar Lounge
#
# @Dcpc1and2 @DBHforRecovery @DCPrevNetwk @dctfc1 @BreatheDC @SashaBruceYouth @Wards78DCPC @TobaccoFreeKids…
#
# i’m the type of person who vapes in the designated smoking area
#
# #DETROIT #VAPELIFE #ECC COMING BACK TO THE CITY!!! I was in #DC for the first one but I will…
#
# this guy was vaping in his car but i deadass thought he was using an electrical nose hair trimmer
#
# How To Use Vicks Vaporub To Get Rid Of Accumulated Belly Fat And Cellulite, Eliminate Stretch Marks And Have Firmer…
#
# Yung e-cig
#
# 8 juuls in my car
#
# Get Some Paper... 💵
# Not The Vapors... 🤒
# 😂😂😂...
# (most of u won't get this) #KnowYourCulture @…
#
# The #FAA updated its guidance for Electronic Flight Bag (EFB) applications, which allows industry to manage their E…
#
# @PapaJohns #FreeSmoke
#
# @progers71 @louieswisher @MarieKondo Not my shelves
#
# If you're looking for work in #Washington, DC, check out this #job:  #BoozAllen…
#
# You’ll never see me in public without my phone, wallet, and Juul
#
# Data Shows Nike’s Vaporfly 4% Marathon Shoe Increases Running Economy  #science
#
# Its game day in #DC #kotd #nike Vapormax @ Capital One Arena
#
# @muvaperry
#
# @Vaped_taylor @Cernovich These schmucks actually think anyone with any sense doesn’t realize why these counter inte…
#
# @wheretobuyvapes Check this out!!
#
# We're #hiring! Click to apply: Projects Manager -  #BoozAllen #BusinessMgmt #Washington, DC #Veterans #CareerArc
#
# Scorsese shot... @ Tryst DC
#
# That Linea tho... @ Tryst DC
#
# Word.
#
# Step and repeat.
# #tivapeerawards2017 @ French Embassy in the U.S.
#
# This Pineapple Express vape pen tho 💕😌
#
# #tivapeerawards2017 #acreativedc #film #womeninfilm @ French Embassy in the U.S.
#
# @ddale8 gets the vapors, again. Is it the southern climes or his fragile wiring?
#
# just paid a kid on my floor $3 for a half used creme brûlée juul pod bc that’s #life rn
#
# The vape runeth dry
#
# @fukusyunyu @mbi_bridal @cindycapo @CarlRamallo @shellieblum @MeloniFulvio @Ms_Terree @RomanJancic @oda_f…
#
# #TopFloorFridays hosted by @damarisalopez 👯🎉🍾 @ Ozio Martini &amp; Cigar Lounge
#
# #adamsmorgan @ Tryst DC
#
# vapenacup x #Smiggletreats @ Southeast, Washington, D.C.
#
#
# @AmandaNevaPena Please don't forget three Latino Walmart shoppers randomly killed in Colorado by white nutjob last…
#
# overheard at AU: "starting to vape is like grieving. it has multiple phases"
#
# don’t even bother talking to me if u smoke swishers
#
# I sneeze all day every day at work because I’m allergic to cigarette smoke and the person closest to me smokes a pack a day. I’m so over it.
#
# Gaby defeats Amanda @ Tryst DC
#
#
# i like to sleep directly next to my juul and pen for obvious reasons i think
#
# Sleep - Dopesmoker
#
# Jeff Sessions loves Jerusalem but he won't even listen to this! What a cuck!!! 🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸
#
# Promo video for The Shattterday Party at @averys_on_hst :: Presented by washingtonvapeco ::…
#
# Credit to washingtonvapecompany : 🎉 The $100 Winner for 12/21 is rich_dabbington…
#
# @uncriticalsimon Smokeless tobacco and vaping, like what you previously linked to, is a funny example since Big Tob…
#
# my dad told me my hands smelt like vape but like dad vapes don’t smell like cigarettes lol 🤔
#
# Lol @ "you other DMV podcast don't want no smoke"
#
# Freezing my ass off but this is too good to not burn!! #cigars…
#
# @jayy_beeeee Everybody Love Swishers Doee But Hate Backwoods 😂
#
# jake knocked my juul out of my hand over the fence and the security…
#
# Someone walked in the bathroom while I was vaping and it was all good until I forgot how to use the sink
#
# Come Join Your Girle 'Sleek' &amp; @diamondjadoredc At #TheSmokeShop Tonight #171IntiativeComplaint…
#
# Come Join Your Girle 'Sleek' @diamondjadoredc  Family At #TheSmokeShop Tonight…
#
# @wendyr13 No Supreme?  No Vape?
#
# Ryan just be walkin around vaping lmao
#
# We'll have free quesadillas and t-shirts for $10 at 9:30 tonight at Tryst in Adams Morgan. Open to everyone…
#
# LOL vapors
#
# Wow shout out to these drunk 30 year olds vaping in my Lyft line like I know I've been messy but this is a whole ne…
#
#
# @eiteamokarina @Viviane6677 @carolina_smal @Jose93571656 @RedIsabel @ModiPuccia @ZoyaDayala @consuiglesias…
#
# If u smoke swishers your opinion on anything do not matter
#
# what if Trump started vaping regularly in public
#
# I can’t find my vape charger😑
#
# @Mena_WorldPeace Waiting for the vape shop bank combo store..... maybe even mix a sheetz in there
#
# Some personal news: I am not planning to take up vaping or to launch a newsletter or podcast in 2018 or ever.
#
# @GiggleSmokes I feel this
#
# @mariemary2653 @elynnhardi @Vote4USA2018 @ManMet80 @PerkinsonForMO @4everNeverTrump @PinkRavenRoth @CapRogers2018…
#
# @PinkRavenRoth @DrNat01 @ManMet80 @RevHatcher @No_Apathy @jennifergarlen @emyryly @allyaranda @IndivChi_South…
#
# SO we end up at the casino guess who not go in ...🤑🤷🏽‍♀️ ... Njoy slim
#
# Can a vaping device deliver medicine and breathing treatments?
#
# #IMWITHTHESMOKE #THELEAGUE #MADEINDC I GOT @timbaland ALL DAY &amp; TWICE ON SUNDAY. IF YOU NEED…
#
# Getting a Vape Pen &gt;&gt;&gt; Every other decision made in 2017
#
# Omggggg I Need More Vape Juice
#
# @kravejerky @jinseijuice @EssentiapHwater royalgourmet @lacolombecoffee @shrubdistrict…
#
# @_chris_simon I hear Jesus has a juul from @realchrisharden
#
# @_chris_simon I here Jesus has a juul from @realchrisharden
#
# You smoke swishers don’t you
#
# @EdKrassen @PinkRavenRoth Bold prediction: 52 out of 100 Congress people won't care.
#
# @scatesryan3 @SchneeAffen @babetotheleft @skepticalbrotha @LeftsidefromNY @PinkRavenRoth @NoFascistLies Par for the…
#
# The banners are up and the quesadillas are hot at Tryst. If you are here for @AmericanAnthro  #amanth17 come say hi…
#
# “What is that...bewitching scent you’re wearing?”
#
# “Vick’s VapoRub.”
#
# OFFWhite x Nike VaporMax
#
# Available Instore or below 👇
#
#
# juul pods are a hot commodity nowadays
#
#
# A crying shame. The Mn Gov. should appoint his #wife.
#
# Remedy for this sick day: VapoRub and my favorite Archie-inspired teen drama / murder mystery #Riverdale
#
# Remedy for this sick day: VapoRub and my favorite Archie-inspired teen drama / murder mystery @CW_Riverdale season 2
#
# Trees still standing while houses all vaporized. Move along nothing to see here. It’s not like we’re at war or bein…
#
# That time when Kristen tried to make me seem like a bad bitch but I had an asthma attack half way through on a vApE…
#
# only committment i know is the committment to my ciggarette when its below freezing out
#
# stop using juuls in 2018
#
# @GretchenCarlson I love the smell of napalm in the morning—you just vaporized that rape apologist creep with a smoo…
#
# I don’t know what the hell I was dreaming last night but apparently I said, “Welcome to Juul National Park”
#
# Training for eventually re-entering the work force without the need for constant cigarette breaks and fight the inc…
#
# “DIS DICK AINT FREE” -Martin Luther King
#
# Vaping in church. You going to hell? Asking for a friend.
#
# Rachel hittin’ the vape hard lmaooooo she’s tight
#
# @nukestrat I have serious doubts that the PAK-DA will emerge anytime in the foreseeable future... Basically vaporwa…
#
# @SchneeAffen @babetotheleft @scatesryan3 @skepticalbrotha @LeftsidefromNY @PinkRavenRoth @NoFascistLies No, most pe…
#
# @wcruz73 The pearl clutch *and* the double-fan to ward off the oncoming vapors. He is precious and I am dead.

# %%
for i in num_positive_tweets_in_total[3]:
    print(i)
    print('')

print()
for i in num_positive_tweets_in_total[4]:
    print(i)
    print('')
    
print()
for i in num_positive_tweets_in_total[5]:
    print(i)
    print('')
    
print()
for i in num_positive_tweets_in_total[6]:
    print(i)
    print('')

print()
for i in num_positive_tweets_in_total[7]:
    print(i)
    print('')
    
print()
for i in num_positive_tweets_in_total[8]:
    print(i)
    print('')
    
# print()
# for i in num_positive_tweets_in_total[9]:
#     print(i)
#     print('')
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%


# 2016.05
print('NEUTRAL')


# # 2016.06

    
print()
for i in num_neutral_tweets_in_total[3]:
    print(i)
    print('')

print()
for i in num_neutral_tweets_in_total[4]:
    print(i)
    print('')
    
print()
for i in num_neutral_tweets_in_total[5]:
    print(i)
    print('')
print()

for i in num_neutral_tweets_in_total[6]:
    print(i)
    print('')
    
print()
for i in num_neutral_tweets_in_total[7]:
    print(i)
    print('')
    
print()
for i in num_neutral_tweets_in_total[8]:
    print(i)
    print('')
    
# print()
# for i in num_neutral_tweets_in_total[9]:
#     print(i)
#     print('')   
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
    
# 2016.05
print('NEGATIVE')


    
print()
for i in num_negative_tweets_in_total[3]:
    print(i)
    print('')
    
print()
for i in num_negative_tweets_in_total[4]:
    print(i)
    print('')
    
print()
for i in num_negative_tweets_in_total[5]:
    print(i)
    print('')
    
print()
for i in num_negative_tweets_in_total[6]:
    print(i)
    print('')

print()
for i in num_negative_tweets_in_total[7]:
    print(i)
    print('')
    
print()
for i in num_negative_tweets_in_total[8]:
    print(i)
    print('')
    
# print()
# for i in num_negative_tweets_in_total[9]:
#     print(i)
#     print('')
# Out:
# I really hate juuls but the juul burial videos are hilarious
#
# @KicksFinder the 1st mention of 'Nike Zoom VaporFly 4%' appears on your TL. Now is Trending Topic in United States! #trndnl
#
# Trend Alert: 'Nike Zoom VaporFly 4%'. More trends at  #trndnl
#
# i hope the stars
# are kissing your cheeks tonight @ Tryst DC
#
# @Cyn_Santana Lol Vick’s vapor rub on your feet does the same thing as onions babe
#
# Retail on any other pair of Vapormax’s has been $190. They’re literally profiting and capitalizing off Black Histor…
#
# @camiweinstock tryst always has the best music, i was in there on wednesday &amp; they were playing exclusively børns &amp;…
#
# YALL WANT THIS 🧐❓ #KeezyDuzIt #GUCCIGANG
#
# Me taking a hit from my friend’s juul and then saying “yes” like that girl from the vine
#
# #ReggaeOnTheRoof Tonight at Eden Everyone's favorite Sunday Night Vibe! Hookah by acehookah and…
#
# @Vapingit This will forever be my favorite published manuscript. I have to assume it was written on a bet that they…
#
# I been without my vape for 2 days i was Press to go get juice 😂
#
# The Conet Project - Recordings Of Shortwave Numbers Stations/1111
#
# It sounds like the vapor garbage that my defecti…
#
# The Conet Project - Recordings Of Shortwave Numbers Stations/1111
#
# It sounds like the vapor garbage that my defecti…
#
# to the girl in a UCSB sweatshirt furiously vaping outside Ward, thank u and have a nice day
#
# @Onikuno @EyeGetDubs yall had a good run
#
# #Vaping probably isn’t good for you but at least it’s better than #smoking - theverge…
#
# @StefanDidak I appreciate the fact that @DanielKagan’s ability to #vape in committee is a #Bipartisan effort!
#
# Primera vez que me hago eco del señor Scharifker que durante años ha sostenido una línea apaciguadora ante la barba…
#
# @MusicForLife61 @PeterCamacho9 @atlgrace2 @Lawrence I am NOT blowing smoke, merely suggesting we don't say FAIL Schumer didn't fail.
#
# the vapormax soles have me SUPER on the fence
#
# Thanks to @NASEM_Health for this important contribution on #eCigHealthEffects.
#
# Imperative that we prevent youth a…
#
# ATTENTION ALL #VAPEFAM GO TO BLOW SOME CLOUDS ON adv_kit PAGE!💨💨💨 Thank yall for the support and…
#
# ATTENTION ALL #VAPEFAM I need all of you to go #follow @inkedatty RIGHT TF NOW! #DoIt 🤣 They…
#
# Too sunny of a day? Need some cool clouds at the beach? Just contact your local vapers. They got clouds for days
#
#
# @kravejacob OMG YES!! I WANT THEIR BOOGERS !!! 😍😩
#
# Celebrating today by overcoming my fear of walking on bridges while I smoke my Juul, drink Dunkin’ Donuts iced coff…
#
# @OneDayAtATime @JustinaMachado And that #vaporub joke had me dying
#
# @larry_draws this colossus is giving me the vapors
#
# I want another vape. #4 🤷🏽‍♀️
#
# Congrats to @dfreelon (also son of Phil Freelon) @kidolopez etc on their awesome study of minority perceptions of n…
#
# At Pineda Catalonia, Art honey &amp; I can have a tryst
# Our love will be sealed with a kiss
#
# VIDEO OUT NOW 😈 ONCE I TOUCH 1K PLAYS IM DROPPING #GUCCIGANG 😈 DROP A 💪🏾 THEN CLICK THE LINK IN MY BIO 🔥GO TUNE IN🔥…
#
# I want to vape tobacco like Uma.
#
# Vaping, good music, glasses, Workers World, and cars
#
# Send cool cucumber juul pods
#
# Congrats to #FIN @IivoNiskanen on winning the 50km #CrossCountrySkiing Mass Start. The marathon of cross country sk…
#
# Go get me some swishers 😈
#
#
# @wheretobuyvapes Oh my goodness this is the bomb rite here ☂️🔮💜
#
# @wheretobuyvapes Wow that Beautiful
#
# #Hezbollah's mouthpiece in #Lebanon celebrates #Iran's #ballistic prowess: its success in replicating #NorthKorean/…
#
# Last five albums!!
# Thank you @trystdc! @ Tryst DC
#
# @AVAPeeMan @Bighead_Andy dont call im jih like in a noisy environment
#
# @Vapingit @Clive_Bates That is at least one thing that *everyone* can agree upon--damn Clive Bates!
#
# Smoking a cig on the back patio, enjoying the first coffee of the day as a light chilly breeze wafts by, listening…
#
# KOGA had a productive day in Frankfort with the passage of SB 249 in committee and advocating for interests of the…
#
# @chetlemonrules @jcgreenx @RexHuppke Seeing as I live in DC it sure was nice knowing you cuz. At least I will be vaporized.
#
# Just saw a guy walking down the sidewalk with Juul in one hand and the Communist Manifesto in the other i love college
#
# Forgot to post thissss,hope ya havin a good day! #SmileHoe 🙃 @ Tryst DC
#
# @sternshow - let us know how we can reach Scott the Engineer - want to feature him in a news report about vaping. ksuiters@sbgtv.com
#
# @tweeteraymee @VapeCloudss @daztoons @fawfulfan 🤔 this also sounds like something a bot would say.
#
# these bros infront of me rn hitting a juul like they the cooooooolest motherfuckers in this place
#
# Which will we elect first: A gaming president or a vaping president? This isn’t a poll, I just want more people to think about it.
#
# Dunkirk wawa sells juul pods. You’re welcome.
#
# Help me help you #freesmoke
#
# If you hand me swishers, ima point you to the nearest exit
#
# @renegade_roo Lisa Frank 420/Modern Computing by McIntosh Plus.
# This is some really good Vaporwave that's very relaxing.
#
# Super stars to watch! These amazing teen scientists-tackling rare diseases, crop blight &amp; vaping. Thanks for inviti…
#
# I should have went home and got my fucking Vape now ion even feel like getting up😩
#
# Oooo mysterio! Ooo he’d be a great Kraven. #CoyCasting I really want A-Team movie! Gotta get She-Hulk and America a…
#
# The good old days when a simple stained blue dress and a cigar could get you #impeached
# The…
#
# My vape device will no longer charge.
#
# It had a good life and got to see many states and a country or two.
#
# Got to meet @SteveForbesCEO at #LibertyCon18 and thank him for the Op Eds he has written on vaping.
#
# Also got to me…
#
# Personally, I don’t think the walkout was efficient. Yes I am a republican. Yes I like trump. Yes I enjoy the 2nd a…
#
# Have you tried the Juul? If so, feel free to lmk if you like it!
#
# Thanks ☺️
# Which one do you prefer?
#
# @McKeganey1 Read with interest your argument that FDA should recognize that e-cigs help smokers quit. Have follow u…
#
# Ok, NOW I'm ready for @awesomecon... #starwars #thelastjedi #steelbook #bluray #dvd #funkopop…
#
# @unfriendlynigga IDK why...lol don’t like vapes like that. Lol
#
#
# @lipiroy @theheartysoul @ucanquit2 @NYCTreatTobacco @TobaccoFreeKids @DrHowardLiu @MapleLeafs @Capitals No comment. LOL. 😉
#
# @maureen_ferrari @lipiroy @theheartysoul @ucanquit2 @NYCTreatTobacco @TobaccoFreeKids I like the Bruins. So 👍. 🏒
#
# @lipiroy @maureen_ferrari @theheartysoul @ucanquit2 @NYCTreatTobacco @TobaccoFreeKids 🤣 #priceless and I have no id…
#
# @maureen_ferrari @lipiroy @theheartysoul @ucanquit2 @NYCTreatTobacco @TobaccoFreeKids Better? 😊
#
# @lipiroy @theheartysoul @ucanquit2 @NYCTreatTobacco @TobaccoFreeKids @DrHowardLiu #honored to be in such amazing co…
#
# @lipiroy @theheartysoul @ucanquit2 @NYCTreatTobacco @TobaccoFreeKids You are a true rockstar, Lipi. Sincerely, than…
#
# @lipiroy @theheartysoul @ucanquit2 @NYCTreatTobacco @TobaccoFreeKids Better yet, don’t start smoking.
#
# Update on not vaping, it sucks.
#
# Q&amp;As at Awesomecon! #Fin #Jake #starwars #geek #washingtondc @ Awesome Con
#
# Final panel at #ecigsummit listening to good question from @gopaulblair of @taxreformer
#
# Prof. Ann McNeill: In the UK, the smokers who could benefit the most from vaping -- those who have never tried e-ci…
#
# @tommyzax Marlboro / Altria don't own Juul. No one ever gives a clear answer, but I believe Juul turned them down.
#
# Assessment from several in the room of the 2nd Annual E-Cigarette Summit is net positive. Helps to have a strong Eu…
#
# I love this. Congratulations! So happy you’re happy :) keep sending me those e-cig boxes...
#
# Clive Bates asks Deborah Arnott if she regrets the e-liquid strength threshold in the EU. Also asks about notificat…
#
# Interesting retrospective data from @LionShahab, re: gateway effect, using NYTS data. #ecigsummit
#
# Kids also have the right to truthful information about relative risks between smoking and vaping, too. We do this w…
#
# Interesting hypothesis is that e-cigs may prevent some youth from becoming smokers -- @LionShahab #ecigsummit
#
# Prof. Mermelstein: Definitely a link between more e-cigarette use ---&gt; less cigarettes smoked. #ecigsummit
#
# More slides from. Prof. Mermelstein, including results from 10 interviewees who successfully switched to vaping aft…
#
# Dr. Lynn Kozlowski playing audio from @Surgeon_General addressing me at SRNT. Dr K agrees that kids should not vape…
#
# "Does anyone here work for Altria? I'm sorry, but Citi says Juul is eating your lunch and I'm happy about that." --…
#
# "Does anyone work for Altria? I'm sorry, but Citi says Juul is eating your lunch and I'm happy about that." -- @Clive_Bates #ecigsummit
#
# @cortezcigars you now have a new fan &amp; aficionado follower!!! 😚😙
#
# @dog_feelings have you met Nigel? For a possible fren? Please. Njoy. This good. boy. @AndreaMcCarren
#
# Japan leans towards self-regulation of advertising, so truthful claims about iQOS are able to be made. #ecigsummit
#
# Matt Myers just acknowledged that JUUL may be an extremely effective tool for getting smokers to quit, and yet cont…
#
# @ubervaper @AmberJPhillips @AmericanAir This is one airline really eager to alienate their customers.
#
# @ubervaper @AmberJPhillips @AmericanAir Well, it seems that @AmericanAir wants to take the lead in this collective…
#
# You should not be vaping at 6:40 am . Love yourself.
#
# #nicotine #ecigs #science
#
# 10Q @CrisDelnevo (who I think is the only twitting author) ++
#
# Transitions in electronic…
#
# @zhlndrf No but we did joke about how my one student is a JUUL MUUL for all her friends in Switzerland, where JUULs are illegal
#
# That might look like steam but it’s just @danielmarquard’s dank cloud. We get it, you vape. @…
#
# dear girl juuling and facetiming her friend while in the library rn: i literally hope you die
#
# i am TRULY blessed to not be working today.... shadows, off white vapormax AND them ugly ass yeezys 😂
#
# One benefit of vaping over smoking is no one asks to “bum” a vape
#
# They hoeing out these vapormax plus’.... I’m good
#
# Tomorrow! Pull Up to #FreeSmokeDC at mkloungedc
# Happy Hour 5pm-8pm
# Party 8pm-2am
# “With every…
#
# Happy to have my vape back from him lol
#
# 😂My favorite line
#
# @YankeeSource Swisher was a huge boost for the team's morale and its hard to quantify that.
#
# @marcm714 Lol!  I use a pipe or electronic vape, thank you very much.
#
# According to a Justice Department official, the remaining redactions in the document are "narrowly tailored to prot…
#
# Great news for #publichealth! Thanks @US_FDA for keeping #ecigs &amp; #tobacco away from children.
#
# @imjustdani_ lol just go try on some vapormaxes and walk around in em for a bit to see how you like the sole on em
#
# Happy Fri-Yay!!! #peruvianfood #foodtruck #peruvianbrothers #peruvianbros #vivaperu #thislife…
#
# Vape and Netflix ☺️
#
# Howdy, folk coming to #ecigsummit would benefit from taking a swing through either or both of these classics on…
#
# @AlanChargin Thanks, for letting us know. As a matter of reference, the 72-hour posting is for residential areas; w…
#
# Lol I shouldn’t have hit that vape pen so hard Jesus
#
# vapenacup ☕️ #ThursdaynightThrowndown x @DMVCoffeeLive thanks for the fun @ Washington National…
#
# @Kraveko girl we had dressdown today &amp; i through on some pants &amp; a crop top &amp; a lil jacket . i’m not playing w. the…
#
#
# Kind of want those 98’s. Kind of need some vapormaxs
#
# Very good @LFDcigars smoke; I highly recommend this cigar!
# Enjoy life folks!
#
# #CIGARS #Churchill #LittoGomez…
#
# @muvaperry @foolish564 bruh on god this me 😂😂 when I'm eating your food
#
# @RosslynVA And, thanks for the professional nod! Just to be clear ... the #juuling issue is totally separate from t…
#
# Awesome night with @TobaccoFreeKids honoring @MLB for knocking tobacco out of the park! ⚾️⚾️
#
# Inspired after hearing about the amazing #AntiTobacco advocacy &amp; policy work being done by @TobaccoFreeKids, Youth…
#
# @ladviento @TobaccoFreeKids Nice! Have fun!
#
# Great piece, @veroderugy -&gt; FDA should allow for innovation, not push for vaping regulation
#
# Excited to attend the @TobaccoFreeKids Youth Advocates of the Year Gala tonight! Always so inspiring!!
#
# This is a pretty efficient way to observe the "continuum of perspectives" about #smoking #harmreduction #vaping…
#
# The Swisher boys requested this lax star so ask some questions pls!!
#
# @karaswisher @louieswisher Creeps?  Nope.  Sadly it’s sprinting in...
#
# I just had my juul confiscated by the United States senate welcome to DC
#
# Made up my mind ... I want the off white vapor max’s
#
# This #job might be a great fit for you: CAFE MANAGER -  #Retail #Washington, DC #Hiring #CareerArc
#
# Starlito had to forget his verse on grape swishers lmao nigga was just freestyling
#
# @ezhurb @ThomasFalcigno @BrianneKNadeau Mandatory surcharge... you mean a tax?
#
# @ezhurb @ThomasFalcigno @BrianneKNadeau Do we have a new supporter for  @ElectLoriParker!🙂
#
# Wow, I’ve been Juulig all wrong.
#
# “Keep practicing. Never let someone tell you you’re too small or too slow.” -@CP3...I’m so PROUD of the undeniable…
#
# To be fair, DSA made it possible for the Chapo boys to buy new vape pens, got Jacobin some new subscribers, and ele…
#
# Just saw a guy blow a big vape cloud and then chug a Red Bull. Calm down buddy it’s Tuesday.
#
# 😂
#
# @BTSKSmoke Can you be my teacher too? I want some all white vapor max size 5.5, thanksssss🙂
#
# Happy birthday @_PurpleSmoke 🎈🎉🎁🎊🎈 @…
#
# FDA requires additional e-cigarette makers to provide critical information so the agency can better examine youth u…
#
# The greatest resource to help smokers that costs NOTHING is the vape community. No government or non-profit could c…
#
# @Krave_The_Ju Thank you!!
#
# Juul vaping device sweeping American schools on sale in UAE's grey market  via @TheNationalUAE
#
# Special report: Medical opinion shifts from tolerating e-cigs to actively promoting them to smokers…
#
# @marcorubio Hey there an #hillintern party in #RepAndyHarris office BYOV
#
# V=VAPE
#
# @AVAPeeMan easy
#
# @AVAPeeMan i fix yes
#
# People sometimes describe chimney swifts as "flying cigars". I'm thinking "blunts with wings" works better. #dc #birding
#
# The spinning wheel got a big cheer at the Portuguese Embassy in Washington. #FIN #Eurovision
#
# Bitch you on dicks your lil sisters &amp; your momma love Drizzy #Iwantallthesmoke
#
# @Rsquared @louieswisher @GDSHoppers It looks great
#
# BBC News - Facebook privacy: Survey suggests continuing US loyalty  Because they're Americans
#
# “I feel like vaping at brunch could be on brand” -@Kayla_Kennedy1
#
# listened all the way to the credits of @Today_Explained's juul episode... hi @christinamta! your jewel cover was 💯🔥
#
#
# I want the vapormax flynit 2s
#
# Transitions in Cigarette Smoking Associated with Use of the JUUL Vaping Device Among 18,799 Adults in the United St…
#
# Dropped my juul and I apologized to it??
#
# @KissKraver @revdjenk Oh okay gotcha. Well if you’re not asking something I guess I don’t have anything to answer.
#
# unless dey want dat den it’s #freesmoke💯💯💯
#
# The FDA doesn’t know if flavored vaping chemicals are safe to breathe
#
# If Japan legalized nicotine vape, the impressive record of IQOS converting smokers, which has slowed, would continu…
#
# @itskravemelanin I love you. You rock
#
# @EvaPenhallurick Great movie. Much better than I was expecting it to be, honestly.
#
# How vaping helps even hardened smokers quit  via @uniofeastanglia
#
# @KalinBuggs @AmourDai You don’t sound convincing, but I tryst you 😂
#
# @NickAimone @BryanMatecun Listen... you gotta look at the advanced stats. There's more to squad play than just kill…
#
# If you like credibly researched, well-written work, read @gbentley1 -&gt; The elusive 'epidemic' of teen vaping
#
# @MsShanBo @HiltonVenice @HiltonSuggests @RickSteves Have a wonderful time, #Venezia is magical. Get multi-day Vapor…
#
# @itskravemelanin I have an opportunity for you serious inquiry
#
# @VapingmominRI @GregTHR It’s a different regulatory scheme. IQOS, containing tobacco, is treated like a cigarette.…
#
# @jakezorz @thetomzone Buying Pods online thru juul saves both $ and the wincing ego.  (Original Tobacco is like mov…
#
# @Spankingpepe @jordanbpeterson @RubinReport @h3h3productions Is it the vape-naysh-styled glasses or the full beard? 😂
#
# “Who knew there was such thing as vape insurance?” Haha
#
# @itskravemelanin @UnderstandTrap all this glowing well done beef is making me hungry
#
# I don’t want diamonds, I want juuls
#
# Happy Birthday Sissy Pooh - __neshiaworld - Njoy YOUR Day #HunnyBunny21❤️🎉💋 @ Washington, District of Columbia
#
# @itskravemelanin I love your work
#
# The vapormax acronyms would look fresh with these.
#
# lol that’s what I thought that juuls stupid lol
#
# Some girl just told me to stop juuling because I’m giving her second hand smoke
#
# @realtamiaworld
# I just heard this on my RIDE into work!
# YESSSSS!
# @DonnieSimpson
# Plz play it later so I can blast my…
#
# If it was in a Hispanic country they would’ve just put Vick’s Vaporub and she would’ve been fine
#
# NEUTRAL
#
# Your mcm ditched you at the bar to go rip fat clouds from his juul and crack Tide pods in his mouth before shotgunn…
#
# Team #FightClub.
#
# @bulldogbeerwine @Ncbeerguys @BitesnBuzz @GoodBeerTweet @QCBicycles @DNewtonespn @TheArtOfVape @MontfordMisfits Now…
#
# @nikestore will y’all have the VaporMax CNY today?
#
# @GroverNorquist @kdrkrepp @RepDonBeyer Go vape something
#
# @SenateGOP @NancyPelosi Still blowing smoke...in 2 years ( or do you think the market bubble will break sooner?) we…
#
# There is a difference between Cigar and cigarette. But to Nigerian smokers, they are the same thing. They will alwa…
#
# Juul is over. We're suorin, flyin
#
# @N1RMFANMSNBC @ManMet80 @DemocratWit @4everNeverTrump @PinkRavenRoth @jillieparks @SallyDeal4 @Vote4USA2018…
#
# Hot Chocolate. OMNOMNOM! @ Tryst DC
#
# We don’t cause we dont do coke😭😭
#
# @J23app Did you know that 'Nike Zoom VaporFly 4%' was Trending Topic for 1 hour? →  @KicksFinder #trndnl
#
# @tedlieu @realDonaldTrump @POTUS Beyond blowjobs?! Beyond cigars?! Beyond blue dresses?!
#
# Vaping...because Gaping contains chemicals Too
#
# @michaelb3600
#
#
#
# 👀 Is those swishers 🚮
#
# @Mrs_Schwarzski @ZShiva__Resists @irrevdissident @SallyDeal4 @DrNat01 @SMSIndivisible @DemocratWit @PinkRavenRoth…
#
# A vape
#
# @Mouse_Jones Not the first! I think Biz Markie caught a case on the Vapors.
#
# @grapesmoker the one and only
#
# “Shit I left my juul in the zip car”
#
# @Kraven_Raven24 @Pirate_Resists @debhagen2 @OutOrangeSpot @FrakerMonica @ZShiva__Resists @BamaWatchtower @jsavite…
#
# Can’t smoke with boys I dont tryst y’all now 😂😂
#
# @dountzzface @ManMet80 @DemocratWit @4everNeverTrump @PinkRavenRoth @jillieparks @SallyDeal4 @Vote4USA2018…
#
# @golden_ange78 @ManMet80 @DemocratWit @4everNeverTrump @PinkRavenRoth @jillieparks @SallyDeal4 @Vote4USA2018…
#
# @golden_ange78 @ManMet80 @DemocratWit @4everNeverTrump @PinkRavenRoth @jillieparks @SallyDeal4 @Vote4USA2018…
#
# @Mitchrick @ManMet80 @DemocratWit @4everNeverTrump @PinkRavenRoth @jillieparks @SallyDeal4 @Vote4USA2018…
#
# There’s a spare Juul pod in each of my Brooks Brothers suit jackets. Don’t @ me #BradLife
#
# @jgitchell Tide Pods - the JUUL of laundry products.
#
# “Ian and Vape Pen” @ Washington, District of Columbia
#
# The Potomac was awash in sublimating water vapor: temps swung from the teens to the 70s…
#
# The Chainvapers #MakeABandLessInteresting
#
# Rolling class 1/14: Learn How to Roll Papers, Leafs, Cannacigars, Cones, Orgami Blunts with…
#
# @RNA2021 @ZShiva__Resists @Davisfor35th @PinkRavenRoth @1IronMan2018 @DemocratWit @ManMet80 @AndyP2V…
#
# @VivianActivist @ZShiva__Resists @Davisfor35th @PinkRavenRoth @1IronMan2018 @DemocratWit @ManMet80 @AndyP2V…
#
# Sheneka Stresin Me Out Where Is My Vapeeeeeeee
#
# Listening to Shoop, drinking coffee at Tryst, planning out the next few weeks 💃🏽💃🏽💃🏽 shoop-shoop badoop-shoop badoop badoop badoop 🎶🎶
#
# @ZShiva__Resists @Davisfor35th @PinkRavenRoth @1IronMan2018 @DemocratWit @ManMet80 @AndyP2V @ScarletAvengers Very r…
#
# @vape_loftmd @AJFcigars I have gravitated to cigars and blends that skew Nicaraguan; LFD, My Father, RP, DE, and a…
#
# @vape_loftmd @AJFcigars Also, obviously, much of what is produced or sourced through and by @AJFcigars is in my wheelhouse!
#
# @J23app Did you know that 'Nike Zoom VaporFly 4%' was Trending Topic for 1 hour? →  @KicksFinder #trndnl
#
# Pinky’s up when you hit the juul
#
#
# 19 of em dropping tomorrow... #FreeSmoke #Soundville @ Washington, District of Columbia
#
# Chicken &amp; double-smoked bacon sandwich (Starbucks)
#
# What do you mean I can’t rip my Juul in the library??
#
# #TBT
#
# Presenting at the #tivapeerawards2017 ❤️
#
# #DC @ French Embassy in the U.S.
#
# @tronlynxo elle swishers* 🌚
#
# This tweet is for all the vape mommies and daddies out there
#
# I'm at Capital One Arena in Washington, DC
#
# ⒈ #GalentinesDay
# ⒉ #FatTuesday
# ⒊ #InternetFriendsDay
# ⒋ Louise Linton
# ⒌ #FLTravelChat
# ⒍ Blue Apron
# ⒎ SNAP
# ⒏…
#
# @JUULvapor
#
# Post Sunday @solidcorestudio  smoothies @trystdc @ Tryst DC
#
# #TeamUSA women’s national #hockey team beat #FIN 3-1!!! But #CAN is who we gotta beat #PyeongChang2018 #USA
#
# #IceHockey women’s national team beat #FIN 3-1! But #CAN is the ultimate opponent #PyeongChang2018 #TeamUSA #USA #BestOfUS
#
# Catherine Rampell, syndicated columnist for The Washington Post talks about the Trump presidency &amp; the economic out…
#
# Me, my vape, and gay slothy sloth
#
# @michaelianblack @ubervaper What does impeachment do? One big “you’re fired.” Do the math.
#
# Kendall just showed me the first picture he ever took of me and I’m vaping
#
# Grape Swishers x @LITO615
#
# But I know you nasty...like them grape swishers
#
# Post @solidcorestudio drinks @trystdc 👍🏻 @ Tryst DC
#
# “I saw a juul pod outside on the ground at practice today and I thought of you”
#
# @JANETCANARY @Mr_JSheffield @reliusprimal @GCVaPersimmon61 @IvankaTrump
#
# Excelente intervención de @KravetzDaniela en audiencia de caso #LindaLoaiza ante @CorteIDH relativo sobre análisis…
#
# Vape Nation and Vape Nation 2.0
#
# @JANETCANARY @Mr_JSheffield @reliusprimal @GCVaPersimmon61 @IvankaTrump Chicken, that’s the pot calling the kettle…
#
# @nycsouthpaw Or vaping tobacco?
#
# @maustermuhle Whenever I see *private roads* I get the vapors.
#
# I’m home with a cold and my mom just called to insist I busy out the #vaporu #vaborub #mexicanmom #solatino
#
# I know a lot of #brave and #curious folk who will read this, based on the updated @PHE_uk #ecigs #evicdence review.…
#
# This #ecigs #nicotine #misperceptions summary of @PHE_uk from @CR_UK.
#
# #BoomShakalaka
#
#
#
#
#
# "#Juul?" "Yes." "What flavor?" "Tobacco--I just quit smoking a month ago--this was the first thing that worked for…
#
# FDA Rule on Vaping Claims Raises Speech Issues, Says @WLF | Broadcasting &amp; Cable
#
# I quit vaping on Monday so I've had a blast this week
#
# EVERYONE in the Cod community uses Juul 🤢
#
# Donald Trump pratade i totalt fyra minuter om hur vapenvana lärare som älskar sina elever bör bära vapen. Han uppsk…
#
# Día de jersey verde con el 10 en la espada.... saliendo al campo de juego en el este momento! #VaPorTi 💪🏼
#
# Either tell me how it is happening, or be complicit when the hammer falls.
#
# Guy vaping on platform at Archives. Ummm. @unsuckdcmetro @wmata
#
# Now Hiring: Entry Level Architect / Project Architect | Stoiber+Associates: US - DC - Washington |  #jobs
#
# Someone just asked me if they could order a valentine’s day cupcake with a heart and a juul on it
#
#
# animal crackers on the side of my #americano
# #kidatheart #dc #tryst #cheflife @ Tryst DC
#
# @AVAPeeMan @Bighead_Andy lol mannn i just left va 😫
#
# @AVAPeeMan @Bighead_Andy wuzzap
#
# @AVAPeeMan @Bighead_Andy u in miami deadass
#
# PUÑETA MI VAPE 😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭
#
# “I also wonder if you could getaway with pajamas at Tryst.”
#
# Coming up just after 1 pm ET with Wolf Blitzer. (@ CNN in Washington, DC)
#
# Random girl "are you a spy!? I'm Anonymous antifa! Can I have a cigarette!?"
#
# Uuuuuuuhhhh...... I'm reaaallly reall…
#
# Juul is not a valid Scrabble word
#
# @kidcongo @jlhulford1 I'm going with hydrodynamic vortex ring antisymmetry, microwave cavity, or vaporized silicon.
#
# Does anyone know what ABGs and hypebeasts grow up into? Nurses and vape shop owners? Marketing at Bait and Kith? Where do they all go !!!
#
# Attending @sfataorg D.C. Fly-in..... Grover Norquist and @gopaulblair of Americans for Tax Reform. #Vape
#
# @jg_bollard - Few coffee shops in any city are open past 7 pm.
# - Tryst has turned into a bar by now anyway.
# -…
#
# #FreeSmoke
#
# @TomDurkin1 @kimhatchie @angelfly72 @rboudbee @nasiraestes @AnnLadenberger @perdue_jrp @marthaevapearl…
#
# @TomDurkin1 @kimhatchie @angelfly72 @rboudbee @nasiraestes @AnnLadenberger @perdue_jrp @marthaevapearl…
#
# @TomDurkin1 @kimhatchie @angelfly72 @rboudbee @nasiraestes @AnnLadenberger @perdue_jrp @marthaevapearl…
#
# @TomDurkin1 @kimhatchie @angelfly72 @rboudbee @nasiraestes @AnnLadenberger @perdue_jrp @marthaevapearl…
#
# @TomDurkin1 @kimhatchie @angelfly72 @rboudbee @nasiraestes @AnnLadenberger @perdue_jrp @marthaevapearl…
#
# @TomDurkin1 @kimhatchie @angelfly72 @rboudbee @nasiraestes @AnnLadenberger @perdue_jrp @marthaevapearl…
#
# @TomDurkin1 @kimhatchie @angelfly72 @rboudbee @nasiraestes @AnnLadenberger @perdue_jrp @marthaevapearl…
#
# @TomDurkin1 @kimhatchie @angelfly72 @rboudbee @nasiraestes @AnnLadenberger @perdue_jrp @marthaevapearl…
#
# @TomDurkin1 @kimhatchie @angelfly72 @rboudbee @nasiraestes @AnnLadenberger @perdue_jrp @marthaevapearl…
#
# @TomDurkin1 @kimhatchie @angelfly72 @rboudbee @nasiraestes @AnnLadenberger @perdue_jrp @marthaevapearl…
#
# @seneca @marcm714 Almost times sq. Two of them. One selling edibles and the other was selling weed and vape pen cartridges.
#
# @nasiraestes @TomDurkin1 @kimhatchie @angelfly72 @rboudbee @AnnLadenberger @perdue_jrp @marthaevapearl…
#
# @call_me_leezy 🤔🤔🤔 .. i don’t tryst myself
#
# I need a vape pen
#
# @crushingbort Immediate vaporization
#
# My Vape😂
#
# a normal sunday: mimosas and brunch and vape juice w @teamk8e
#
# I think ima buy a new vape. This weekend
#
# I Need A Pair Of Vapor Maxes
#
# Listen....
#
# @lvusell Tú sabes cómo es baby
#
# @bymeg What is vaping tobacco?
#
# Film noir but instead of cigarettes everyone is vaping
#
# @PinkyKillaCorn x @DENISHAZE x JOESMOKESWISDOM
#
# 2nd, it Should Be Hemp Paper, a WaterPiece  or a Vape
#
# Speaking of @kungfuvapes  ......
# #homies #phonehomiewuzhere…
#
# @kungfuvapes after a @capitals #win !!!!!!
# #phonehomiewuzhere…
#
# if you pull out the right one you smoke swishers and i can’t fw you.
#
# You automatically get this tattoo when you spend $150+ on juul pods
#
# I need some al black vapor maxes asap
#
# #labellezzanonhadifetti #naiade #antonio #canova #Washington #National #Gallery #Washingtondc #liricigreci
#
# Biz Markie after the #WizRaptors . #Vapors
#
# Going to start keeping tabs on how long it waits for a service to come over you at tryst so far it’s been 7 minutes
#
# @AVAPeeMan
#
# Chicken &amp; double-smoked bacon panini (Starbucks)
#
# Vape high is boneless af.
#
# Reflection room #ChangeGonnaCome #Fin @ Smithsonian National Museum…
#
# The FDA is conflicted about regulating flavors in e-cigarettes, according to this statement. Flavors have helped ci…
#
# This vape pen is lit
#
#
# Those VaporMax 97 is a shoe I gotta have. And since Xae won’t buy them for me I’ll buy them myself 🤷🏾‍♀️
#
# @maureen_ferrari @lipiroy @theheartysoul @ucanquit2 @NYCTreatTobacco @TobaccoFreeKids Oh jeez. Here we go. 😉
#
# @lipiroy @maureen_ferrari @theheartysoul @ucanquit2 @NYCTreatTobacco @TobaccoFreeKids @NHL 🙏
#
# @maureen_ferrari @lipiroy @theheartysoul @ucanquit2 @NYCTreatTobacco @TobaccoFreeKids 🙌
#
# @lipiroy @theheartysoul @ucanquit2 @NYCTreatTobacco @TobaccoFreeKids Indeed, and this is why prevention is just as…
#
# @lostinthesmoke_ its cold in the 757 rn too........
#
# Vaping culture needs to go away
#
# WE HAVE ARRIVED! COME SEE @phonehomie dabbing_granny @chriscrayzie @kungfuvapes all…
#
# @plantbasedvibes The vape pen is the move
#
# DC WE ARE OUT HERE!!!!!!!!! dabbing_granny @kungfuvapes @chriscrayzie @alex_entlaw…
#
# @Buccigross @BlueJacketsNHL @Capitals @Ticket_IQ @BauerHockey @NoSweatCo #bucciovertimechallenge Calvert/Kuznetsov
#
# @Buccigross @BlueJacketsNHL @Capitals @Ticket_IQ @BauerHockey @NoSweatCo Eller #bucciovertimechallenge
#
# 👹 My New Bae dabbing_granny
#
# #youmustconcentrate #kungfuvapes…
#
# Got a new shipment!!! Contact me nowwww 202-716-3332 #vapormax @ Bennett Career Institute
#
# Turning Points Brands adds to their e-cig portfolio with the purchase of Vapor Supply. They also have Vapor Beast.…
#
# Laurent Huber, Executive Director of Action on Smoking and Health (ASH) US at #ecigsummit
#
# David Graham of @NJOYVape now speaking -- says he's "going to be a little controversial." #ecigsummit
#
# Recommendations from @NJOYVape on fixing drug regs and the PMTA process. #ecigsummit
#
# “I don’t think e-cigarettes should be taxed at all beyond the sales tax” - Iowa Democrat Attorney General Tom Mille…
#
# Michael Cummings on what the e-cig industry should do.
#
# Why exactly should our survival be dependent on us being pr…
#
# Is nicotine reduction necessary? #ecigsummit
#
# Deborah Arnott of @ASH_LDN -- UK e-cig regulations are in line WHO recommendations, despite wild west claims of som…
#
# Impact of EC use on biomarkers of exposure -- @LionShahab #ecigsummit
#
# Prof. Ann McNeill: If you are a smoker and a Daily Mail reader, what are you going to think about e-cigs?
#
# McNeill…
#
# @GregTHR The real epidemic is anti-tobacco-anti-vaping researchers personal and professional misconduct with their…
#
# Dr. Neal Benowitz declares youth and young adult Juul use to be an EPIDEMIC, "as you know." #ecigsummit
#
# Up next: @LionShahab on five common claims about e-cigs -- renormalization, youth gateway, effectiveness for cessat…
#
# For years, I wondered how Matt Myers is able to sleep at night, but I finally figured it out #ecigsummit
#
# Dr. Kozlowski: Youth are doing a lot more than just vaping. Is there any adult activity that some youth won't engag…
#
# Nations consider re-think on e-cigarette legislation  via @TheNationalUAE
#
# Dem Vapors Doe
#
# @curlyheadavaa @sheewiinningg2 @Kraveko @xharimaa @gorgeousasskie @_shaydennaria 😂😂💯
#
# 21 year old in 1960: has insurance for health, home, and auto
#
# 21 year old in 2018: has insurance for juul
#
# 🖐✋✋Firing Squad
#
# i was awake for maybe 10 seconds this morning before breaking my juul charger omMG
#
# I have talked about JUULs with every single person I’ve seen over the past 48 hours
#
# I'm kinda an elitist about nicotine, chill with your juul little guy
#
# @Drake #WEWANTALLTHESMOKE
#
# For sale: Nike Air Vapormax OFF WHITE size 8.5 $650 @ Washington, District of Columbia
#
# mrpandadc @ Tryst DC
#
# We're #hiring! Click to apply: Pharmaceutical Sales Rep (Part-Time) -Washington, DC - TYA25127 -…
#
# mango juul pods + Red Bull = sex
#
# Nike Air Vapormax 97
# “ Silver Bullet “
# Men’s size 11.5
# $300 obo (443)977-8338 @ Washington,…
#
# On the phone with @annerowlandkidd as she walks around Manhattan checking every vape shop for a Juul that she can haggle for $45
#
# @Buccigross @BlueJacketsNHL @Capitals @Ticket_IQ @BauerHockey @NoSweatCo Vanek/Oshie #bucciovertimechallenge
#
# vapenacup coffee ☕️ Give the barista some one time. Pull up tonight!!!! hosted by…
#
# #NotInSenecaCounty today! Taking to the blue skies, then crossing the Potomac River to talk…
#
# Look to my left and see my coworker huffing Vics vapor rub...#officelife
#
# i’d wear the vapormax utility before anything else
#
# “Tripe Melange” #ParallelUniverse #TrumpWave Computing #VaporWave #FascWave #AltWave #NeXTWave
#
# #NowPlaying #FreeSmoke 💨💨 on @Spinrilla #NSC #TinoToldYou 🔥🔥👌🏾
# .
# .
# .
#  #Mixtape #NewMusic #Indie…
#
# Me, 7 juuls later
#
# @ubiqlife can be at georgetown store before you close. Got a 10.5/11 in the Off-White Vapormax i can wear out of the store?
#
# Bout to watch this episode of Dexter and vape then to sleep!!
#
# @ubiqlife do y’all have size 11.5 or 12 for the Vapormaxes?
#
# @evancharb ~ahem~ it's spelled Juul.
#
# @Kraveko 😂😂😂
#
# #playoffszn #RepTheDistrict #DCFamily #WeWantAllTheSmoke #Wiztern
#
# #playoffszn #RepTheDistrict #DCFamily #WeWantAllTheSmoke #Wiztern
#
# @krassenstein So those clutching their pearls and having a case of the vapors.
#
# Hecho. Esto es muy importante!
#
# @Montel_Williams @drsanjaygupta We have @RCPLondon, @PHE_uk, @CR_UK all studying the subject and concluding vaping…
#
# My young shooter don’t smoke swisher but got a Swiss account
#
# @tjl This is the over 40 version of vaping and icing in the EEOB
#
# Chilling wit the hipsters at the cafe in Adam Morgan area of DC @ Tryst DC
#
# The Juul is mightier than the sword
#
# She must’ve rolled some swishers 🤦🏾‍♂️
#
# Chicken &amp; double-smoked bacon sandwich (Starbucks)
#
# En Spinetta uno consigue cosas igual de densas que Zeppelin, hasta baladas jazz/flamencas a estilo Bebo Valdez y El Cigala.
#
# A guy just leaned out of his truck, vaping, and what I thought was gonna be a catcall was “we’re going to Syria, baby!” End times.
#
# The wrist fwapped when it shoulda flicked?!! 😳😫😂 #coffeewars ☕️⚔️☕️vapenacup the Vape Wuz…
#
# @Kraveko lmaoooooo
#
#
# Oh my lord what is it with these Georgetown boys and their juuls I have literally gotten whiffs of both mint and st…
#
# @elizard_21 I can see an Axe/Juul collab somewhere here
#
# Chicken &amp; double-smoked bacon panini (Starbucks)
#
# I vape pot bro
#
# Soly getting out of bed tomorrow #TeamTron #Vaporized @NoLayingUp @TronCarterNLU @DJPie
#
# wht if cars ran on juul pods instead
#
# Chicken &amp; double-smoked bacon panini (Starbucks)
#
# @ladviento @TobaccoFreeKids New job?
#
# Chicken &amp; double-smoked bacon panini (Starbucks)
#
# Just copped these vapor max pluses
#
# @pemullen @louieswisher @haddadmedia Oh man
#
# We have the Space Cannon vape from vape.bubblers in stock. A pocket sized…
#
# @VapingAdvocate @SuckMyMod @GrimmGreen @IndoorSmokers @fatcatvapor @mihotep My thoughts are that the US media is lo…
#
# Ruzica sam bila...
#
# He’s 100% Juulin’
#
# OH: “can you charge my vape?”
#
# Should @jgitchell be allowed to use this meme as his WhatsApp picture? #vapefam
#
# I can only imagine how many juul’s exist within the halls of my all boys Jesuit high school
#
# Im Addictedddd To My Fuckin Vape Pen
#
# #VapeCartridge
# #SourTangie
# #LiveResin
# If you have not got your Sour…
#
# #VapeCartridge
# #GorillaGlue
# #THC
# #CBD
# #liveResin
# New Vape cartridges…
#
# #VapeCartridge
# #GirlScoutCookies
# #LiveResin
# Have you got your Vape…
#
# @brooketheis11 I hear not one L, Brooke!!
#
# #truly #necessary #ThcOil #Vape 😂😊😊😊😊Thanks htownloud #dc…
#
# lmao of course the first vaping death happened in Florida
#
# @_sashayed vaporwave beelzebub summer 2k18
#
# Yupppp RE cranking for freeeee ✊🏾🤟🏾 #Goodman #awholelotoffreesmokegoingon
#
# #vaporwave #trumpwave #StableGenius
#
# #RealGOAT
#
# Going to the Vape shop on M
#
# Anyone a men’s size 8? Offwhite VaporMax for you.
#
# This French Country designed kitchen gave me the vapors!…
#
# @MooseAdvice Currently taking a break from editing a paper and listening to an Africa by Toto vaporwave remix
#
# #Edibles
# #VapeCartridges
# 1 gram ( OUT OF STOCK )
#
# Half gram ( OUT OF STOCK…
#
# #Edibles
# #VapeCartridges
# 1 gram ( OUT OF STOCK )
#
# Half gram ( OUT OF STOCK…
#
# @phkeane @louieswisher He is trolling me
#
# @phkeane @louieswisher Always
#
# *bad ‘tears of a clown’ joke*
#
# #TheSmokeMan
#
# touch her butt and buy her juul pods
#
# @marcoleonardi9 Sul punto #1 non mi sorprendo, ma mi stupisce il loro silenzio. Dove sono finiti?
#
#
# Campaigns against smoking or youth vaping may appeal to SOME. It also has OPPOSITE effect with others who don’t lik…
#
# Chicken &amp; double-smoked bacon panini (Starbucks)
#
# "Access to e-cigarettes can't come at the expense of a whole generation of youth"
#
# " Too many young people are still being initiated onto tobacco products... access to e-cigarettes can't come at the…
#
# "Too many young people are still being initiated onto tobacco products... access to e-cigarettes can't come at the…
#
# "Too many young people are still being initiated onto #tobacco products... access to e-cigarettes can't come at the…
#
# @AVAPeeMan lemme get it lmaoo
#
# @AVAPeeMan
#
# @James_Stacey_ @JoeHockey All about the vape!
#
# He just got OUT of his seat to tell me the smoke was getting in his food. First of all, it’s vapor. Second of all,…
#
# I need to cop some vape juice
#
# #LEGENDARY #BOOTH #SHIT #NCF @NatlCannaFest @kungfuvapes…
#
# Fueling up at @trystdc @ Tryst DC
#
# the sound of two juuls hissing in tandem is a 2018 mating call
#
#
# Comparing Emissions from HnBs, E-Cigs and Cigarettes  via @vaping_post @FarsalinosK
#
# @politiCOHEN_ @Nike You mean off-white vapors? The others are available via retail on the SNKRS app. Or you could a…
#
# i need me a pair of nike air vapormax asap
#
# The vape part has me cackling
#
# @KissKraver @revdjenk Is that a request or a command?
#
# @eb4prez I think they're all high on the marijuana cigarettes.
#
# “ Cryin dollar signs when my cash flows…
#
# #healthyvapes…
#
# @itskravemelanin Omg verse lives matter
#
# can’t wait to use my final minutes between a push notification about an incoming missile &amp; being vaporized by a nuk…
#
# I'm on Amtrak sitting in the cafe car and the guy across from me is vaping and blowing the smoke into his backpack…
#
# Just saw Capital Response cop team and dc cops go in there #raid or #shop #dcpolice #capitalpolice #notovape (@ Cap…
#
# @mountainjuul 🙄🙄
#
# @_Sky_Marie Do you know what the vapors are?
#
# @AvaPetterson @DrugedPosts Anyone have an extra pair of trousers for ya boy? 😂😂🤷🏽‍♂️
#
# @SkiptoMy_Lu2 If u were real you'd bring that vape pen
#
# Your mcm doesn't brush his teeth cause he uses mint juul pods
#
# Ew people are really out here letting other people hit their juul?💀 wondering why you’re sick...
#
# @breatheb12 #B12Vape @DIVINITY57 Learn how to…
#
# Camelot. 🥀 #musicaltheater #theatre #camelot #stc #dctheatre #curtaincall #fin @ Shakespeare Theatre Co
#
# @s8mb Dude, why would you choose Vaporean. All those choices, and you choose *that*
#
# PR22-0887 [NEW] Board Of Physical Therapy Nicholas Caylor Confirmation Resolution Of 2018
#
# a news reporter told me to hit the juul for the camera catch me on the column
#
# Chicken &amp; double-smoked bacon panini (Starbucks)
#
# Vaping Set To Wipe Out Tobacco Bonds
#
# popcorn, gummies, drops, cakes, slushies, juice, vapes, blunts, joints, dabs....😪
#
# Thursday! #FreesmokeDC is back at MK Lounge! RSVP LINK IN OUR BIO! @ Washington, District of Columbia
#
# How many cig smokers swapped for vape daddies would it take to fix the ozone layer
#
# 4Js + 2Vapes
#
# My oven was smoking while I was looking for my juul. I had dropped my juul in the oven.
#
# Run the juuls
#
# Drinking a Mod Project Pink Vapor Stew by @skabrewing @ Savor: An American Craft Beer &amp; Food Experience —
#
# *To the tune of Talking Heads' "(Nothing but) Flowers"*
#
# And as things fell apart, I got some vaporwave unddiiiiiii…
#
# Thursday! #FreesmokeDC is back at MK Lounge! RSVP LINK IN OUR BIO! @ Washington, District of Columbia
#
# I can’t wait to get off so i can run to my vape and bed😩
#
# To this day I still don’t understand why there are toilets in restaurants private Juul rooms
#
# @SheySongz721 Vapor rub Vicks
#
# I'm at M Street Vape in Washington, DC
#
# @IoveIycafe @kravejacob GDNSHSJSJAJJAHAJAHAHAHAHAHHAHAIFKWKDJHSJDHSISJAIAH
#
# NEGATIVE
#
# This is why I live next to the Pentagon: I'de rather get vaporized instantly than have to fight the mirelurks...
#
# Hey look, @BillNye The Fake Science Guy brushes aside serious benefit of vaping to smokers in yet another demonstra…
#
# Drinking a Vape Tricks by @Prairieales at @roofersuniondc —
#
# I can’t fw drake the same after I listened to over and realized he smoke swishers. He prob a serial killer
#
# This would be awful if we knew it was *because* of e-cigs that kids started smoking. For another perspective see…
#
# @fatcatvapor He testified at a local vapor ban - he’s in Pittsburgh. I think he also did an op-ed on taxes there, too
#
# Shout out to my young padawan Eric B. - Drinking a Vape Tricks by @Prairieales at @roofersuniondc  —
#
# I don’t hear the chatter cuz it’s fuck you niggas pay me. 😤Only thing I’m chasing is my money on…
#
# @tiavapes Waste not want not
#
# @lilpump  “First Off Nigga Fuck Trump” - @___KEEZY #GUCCIGANG
#
# @TheRealShamIAm You can roll em fucked up unlike swishers or papers and its Still gonna pull, its crazy
#
# Sis Stressing Me Out Where Is My Vapeeeeeee
#
#
# Drinking a Vape Tricks by @Prairieales @ Chloe —
#
# @kravejacob ROCKY CAME HERE TO DO THE DAMN THING !!!
#
# wth is juul
#
# shouldn’t you be here with your parents??? throw away your juul. you’re not cool. i’m drowning myself off his dock
#
# There is nothing funnier than a fat nigga in some vapormax’s.
#
# I have a broken vape and a full can of Grizzly right in front of me 😰
#
# @VapeZoneVA So hard to choose! But they were playing Je Veux and I died because Zaz est mon premiére amour and I’d never heard her in the US
#
# Well... she’s not dead yet like the other family members who faced death being vaporized by mortar shelling
#
# @BlackRaven2018 @sarahchad_ bullshit, hes got over 3 million in his pocket from the NRA, fo you think he gives a fu…
#
# @JANETCANARY @Mr_JSheffield @reliusprimal @GCVaPersimmon61 @IvankaTrump Boo ... you have no idea.
#
# Home with the flu and my #mexicanmom just called to insist I cover myself in #vaporu aka #vaporub because it will c…
#
# @GiggleSmokes Nah only Netflix games get boring in less than a day
#
#
# @thehill Not leaving DC? What are they gonna do hang out at Tryst all day with no job?
#
# You knew #GaryCohn was leaving once he got vaporized by #Trump on trade. I hear he blamed the new trade policy on t…
#
# sitting in bed with a juul and i just lose the pod while holding the base ummmmmmmmm i’m pissed
#
# @VapeCloudss @daztoons @fawfulfan Killed 20 and wounded 100’s of people? Was he The Flash?
#
# Nice try bot.
#
# I quit nicotine a few weeks ago after smoking and  vaping for the last 6 years and my goodness is it a horrible experience
#
# @WBeezy_ I told my guy this the other day.. niggas tryna say all the vapors and shit are trash
#
# Juuling alone outside in the rain because vapers are,,, an oppressed
#
# Ahora estoy comiendo aceitunas sin parar, juuling obsesivamente y tomando matcha mientras que veo esa película de miedo Verónica
#
# I’m going to buy another fucking vape tomorrow I guess and give it a try tired of a pack of cigarettes a day
#
# Some insights on harm reduction by @GregTHR #LibertyCon18 #vaping #SaveLives
#
# Vaping and harm reduction session with @GregTHR at #LibertyCon18 @sfliberty
#
# don't tell my husband (or my years-long #Tarheels crush Tyler Hansbrough) but Theo Pinson gives me the vapors 😍…
#
# @tribelaw Exactly what we expect from a narcissistic, self-serving, unethical,  incompetent, dictator wannabe and h…
#
# Smoking my Juul while hiding in the single-use bathroom to avoid being in class is good praxis,,, right?
#
# @FutureSocialism I dig it, I've got a whole set of gear I dub "Australian vaporwave" just to fuck with people (I di…
#
#
# can not wait to get my vapormax pluses this weekend uugggghh 😫
#
# @wyatt_privilege He was vaporized as he lived: cursing out dudebros while harassing women
#
# @hustindarrel @Buccigross @BlueJacketsNHL @Capitals @Ticket_IQ @BauerHockey @NoSweatCo If I’m wrong and we still wi…
#
# Dr. Tom Glynn, formerly of the American Cancer Society, kicks things off as Chair of the #ecigsummit
#
# David Graham: When you ask consumers why they're vaping, they say "quit." They don't use words like "switch."…
#
# Disappointed in myself for not snapping photo of my colleague David Graham of @NJOYVape speaking at #ecigsummit - h…
#
# Matt Myers of @TobaccoFreeKids appears to be trying to present himself as a balanced voice in the harm reduction de…
#
# Big failure by FDA: Two years later, @FDATobacco still has not established this docket, explains @NJOYVape's David…
#
# Benowitz: Acrolein is a concern, but levels are generally much lower than in cigarettes. #ecigsummit
#
# @tommyzax College-aged Juul use is denormalizing and further decreasing cigarette usage. Not like having three ciga…
#
# @BV_dodderer @ASH_LDN Media reporting about studies looking at absolute risks of e-cigs vs comparing to relative ri…
#
# @Laurie_Garrett @JohnsHopkinsSPH No, I don't work for Juul.
#
# Most adults who quit are also using non-tobacco flavor…
#
# @Laurie_Garrett You started off by accusing independent e-cig companies (the only ones who sell the flavors you ide…
#
# @VaporFI I'm tired of your shit. This is the second time in a row I ordered from you and you just didn't bother to…
#
# 7 On Your Side exposed the trend of teens juuling &amp; vaping in school back in February. Today the @nytimes continues…
#
# My students are all about to be drunk and smoking JUULs at 10am for fucking Georgetown day aka Root Elementary school Fun-In-The-Sun
#
# #FreeSmokeDC is Back BC Fest Week at mkloungedc ! 4/26 RSVP LINK IN OUR BIO! Don’t miss this…
#
# I’m outside smoking my vape and this crack head walks up to me and says, “damn baby you doing the damn thing with y…
#
# also selling my vapormax dm me if u serious
#
# What’s wrong w y’all niggas?
#
# @ayoooforeignn @Kraveko @theonek_ @thebrattky @theereallb @OnlyKeyaa they lied like shit to you😂
#
# Be informed about JUUL devices and talk to you kids about the dangers! #Thisisyourbrainondrugs
#
# I want some vapormax soooo bad
#
# @KateBennett_DC This may be the weirdest any of the Trump cabinet members have done to date.
#
# Close but no cigar!!! @ Capital One Arena
#
# A famous linguist just saw me hit a Juul from afar and now I’m having an anxiety attack
#
# @JUULvapor This is good news but can your company publicize more about what investments are being made to combat teen use?
#
# .@SMPAGWU's @davekarpf at @gelmanlibrary: Psychographics is vaporware. Perhaps possible in a lab, but doubt that ca…
#
# Bro cmon Bro lemme hit the freaking Juul
#
# @meli_fig @JamusLynch Church management software and vaping came up before DCA. I was confused.
#
# I complained on Reddit that someone stole my blue juul and some stranger just offered to mail me one from their shop
#
#
# I lost my vape😑 i need a blunt in DC wassup with it ?
#
# If Elon Musk wants to argue "Why are you covering crashes when you should be staffing up your capitol bureaus? What…
#
# This "new sin to tax" chart on e-cig taxation in @TaxProToday's list of "worst places to have fun" thanks to taxes…
#
# Learning more about the dangers of E-Cigs! #ACHA2018 #TobaccoFreeUK #WellnessMatters @iQuitatUK @UKTakeAction
#
# The @NewYorker Juul craze piece is fascinating for many reasons but I am shook, SHOOK that there is apparently “mil…
#
# SCREAMING
#
# Juul. Because someone accepted the impossible challenge of making junior high worse. Juul.
#
# Damn vape pens going crazy
#
# im drunk and don’t have my juul im gonna kms
#
# My mother tried to steal my juul wtf
#
# Stop it w/ the vapormax on everything 🤦🏾‍♂️
#
# @chellssseaaaa @Taylor_Lynn127 Shut up Chelsea stop vaping
#
# Why on earth would a public health department give such terrible advice? Because the debate over vaping isn't about…
#
# @skrymir42 Yes, there are okey of them ... even among the vape community. One of my biggest frustrations is when va…
#
# @markse68 We could pick good ones. Sadly, you’re right and some vapers fall into that space too. 😕
#
# One @JUULvapor? Nah I need three.
#
# Tobacco control groups and public health advocates should stop hating smokers and vapers. If they don’t hate them,…
#
# how do yall smoke swishers and rellos? wtf i dont get it 😂😭 yall parents aint teach yall better?
#
# Hilariously tragic
#
# Why is everyone fucking vaping in the lib now? I hate this place
#
# @AVAPeeMan oh f no
#
# This nigga just tried to play me about my vape pen. I was about to go back inside but now I gotta sit here longer out of spite.
#
# @Mykl0 It’s weird to me. Life isn’t just Hops and JUUL, kids! Let’s saison!
#
# Saw on the news how a “vape” pen exploded in someone’s face and killed them. 😤 Got me scared a bit (just a bit). Te…
#
#
# Update: can confirm someone vaping set the alarm off. A buddy and himself didn’t believe the fire alarms would go o…
#
# There is no Julien there is only JUUL
#
# I had a dream i found my juul. Woke up, no juul 😭
#
# The sound alone gave yah boi here the vapors
#
# Like...my vaporwave phase lasted a REALLY long time. Been into Trap music even before ATL.
# Hip-Hop/Carribean chunes…
#
# @NoahShelly Pro tip: put your juul in the microwave and set it to “popcorn” charges in about 30 sec
#
# “what else do we talk about...we both like to vape”
#
# I shit you not these words came out of her mouth
#
# Bans on E-Cigarette Flavors Can't Be Justified by the 'Wildfire Spread' of Adolescent Vaping, Which Seems to Be Dec…
#
# @JamaicaVaper Don’t disagree. Functioning institutions are critical. I think that desire may fuel excessive tendenc…
#
# Teen Vape Rates Keep Falling
#
# My mom was worried I was bulimic because I’d leave the table after dinner to hit my juul
#
# When people ask if I wanna hot box and there talking about vaping I die a little on the inside😪😩
#
# Is This (E-Cigarette) Ban Putting Australian Lives at Risk?
#
# E-cigarettes: Harm reduction faces obstacles
#
# @CrazyVaper @AMike4761 Now you’ve done it. Ammo use will be banned, now, because all that gunpowder will cause clim…
#
# I think it’s worse than cigarettes. Sickening.
#
# How to: become the most hated woman on earth in a single snapchat @JUULvapor
